# %% [markdown]
# # **Classification** des **séries temporelles** avec `sktime`

# %% [markdown]
# ## Métadonnées

# %% [markdown]
# - **Expérience nº :** 2
# - **Date :** 05/11/2023
# - **Heure :** 13:31
# - **Données :** `ready_Evaporation.csv`
# - **Splitter :** `TimeSeriesSplit`
# - **Méthode :** TSF

# %% [markdown]
# ## Sommaire

# %% [markdown]
# 1. Initialisation
# 2. Découpage des données
# 3. Conversion des données
# 4. Modélisation
# 5. Évaluation

# %% [markdown]
# ## 1. Initialisation

# %%
# Importation des bibliothèques et modules nécessaires au fonctionnement de ce notebook

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style = "darkgrid", palette = "colorblind")
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from imblearn.over_sampling import RandomOverSampler, SMOTE
from joblib import dump, load # pour enregistrer et charger les modèles.
n_coeurs = 4

# %%
# Importation du jeu de données et enregistrement dans le DataFrame `df`

# Instanciation df 
df = pd.read_csv('../../data/processed/model_weatherAUS.csv', index_col = 1).sort_index()
df.drop(columns = 'Unnamed: 0', inplace = True)

# %%
# Inspection de la structure de `df`

df.head()
# Out:
#             MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# Date
# 2007-11-01      8.0     24.3       0.0          3.4       6.3           30.0
# 2007-11-02     14.0     26.9       3.6          4.4       9.7           39.0
# 2007-11-03     13.7     23.4       3.6          5.8       3.3           85.0
# 2007-11-04     13.3     15.5      39.8          7.2       9.1           54.0
# 2007-11-05      7.6     16.1       2.8          5.6      10.6           50.0
#
#             WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  Month  \
# Date                                                              ...
# 2007-11-01           6.0          20.0         68.0         29.0  ...     11
# 2007-11-02           4.0          17.0         80.0         36.0  ...     11
# 2007-11-03           6.0           6.0         82.0         69.0  ...     11
# 2007-11-04          30.0          24.0         62.0         56.0  ...     11
# 2007-11-05          20.0          28.0         68.0         49.0  ...     11
#
#             Day  LocationNum  WindGustDirNum  WindDir9amNum  WindDir3pmNum  \
# Date
# 2007-11-01    1           15        2.356194       3.926991       2.356194
# 2007-11-02    2           15        0.392699       0.000000       3.141593
# 2007-11-03    3           15        2.356194       1.570796       1.178097
# 2007-11-04    4           15        2.356194       2.748894       3.141593
# 2007-11-05    5           15        5.105088       5.105088       5.890486
#
#              Latitude   Longitude  CodeRegionNum  NonMesNum
# Date
# 2007-11-01 -35.297591  149.101268              1          2
# 2007-11-02 -35.297591  149.101268              1          2
# 2007-11-03 -35.297591  149.101268              1          2
# 2007-11-04 -35.297591  149.101268              1          2
# 2007-11-05 -35.297591  149.101268              1          2
#
# [5 rows x 29 columns]

# %% [markdown]
# ## 2. Découpage des données

# %%
# Découpage de `df` sur l'axe des colonnes : séparation des variables explicatives (`data`) et cible (`target`)

data = df.drop(columns = "RainTomorrow")
target = df["RainTomorrow"]

# %%
# Découpage de `data` et de `target` sur l'axe des lignes : séparation des jeux d'entraînement (`*_train`) et de test (`*_test`) avec le splitter `TimeSeriesSplit`

from sklearn.model_selection import TimeSeriesSplit

tss = TimeSeriesSplit(n_splits = 5) ## Nous fixons le paramètre `n_splits` à 5 afin d'avoir une répartition de 80 / 20 entre les jeux d'entraînement et de test, respectivement.

for train_index, test_index in tss.split(data):
    X_train, X_test = data.iloc[train_index, :], data.iloc[test_index,:]
    y_train, y_test = target.iloc[train_index], target.iloc[test_index]

# %%
# Oversample avec SMOTE
#smote = SMOTE(random_state = 12, n_jobs = n_coeurs)
#X_sm, y_sm = smote.fit_resample(X_train, y_train)

# %% [markdown]
# ## 3. Conversion des données

# %%
X_train.shape
# Out:
# (117323, 28)

# %%
# Scale de X_train, X_test:
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (117323, 28)

# %%
# Récupération des dimensions

X_train_d1, X_train_d2 = X_train.shape
X_test_d1, X_test_d2 = X_test.shape

# Conversion des DataFrames `X` en arrays de 3 dimensions

X_train_np = X_train.reshape(X_train_d1, X_train_d2, 1)
X_test_np = X_test.reshape(X_test_d1, X_test_d2, 1)

# Conversion des Series `y` en arrays de 1 dimension

y_train_np = y_train.to_numpy()
y_test_np = y_test.to_numpy()

# %% [markdown]
# ## 4. Modélisation

# %% [markdown]
# La méthode TSF (_time series forest_) appartient à la famille des approches de classification des séries temporelles basées sur les **intervalles** (_interval-based approaches_).
#
# Il s'agit d'une adaptation aux séries temporelles de l'algorithme _random forest classifier_ (RCF).
#
# La TSF utilise un arbre de décision pour chaque intervalle, les arbres de décision agrégés constituant la forêt. Chaque arbre de décision est un modèle d'apprentissage automatique qui attribue ensuite une classe à son intervalle de données. Étant donné que les arbres de décision s'entraînent sur un intervalle différent de la série temporelle globale, ils peuvent ne pas produire la même classification, d'où la nécessité du vote d'ensemble à la fin du processus.
#
# Des études expérimentales ont démontré que la TSF est capable de produire de meilleurs résultats que la KNN + DTW.
#
# Références :
# 1. https://developer.ibm.com/learningpaths/get-started-time-series-classification-api/what-is-time-series-classification
# 2. https://towardsdatascience.com/a-brief-introduction-to-time-series-classification-algorithms-7b4284d31b97
# 3. https://arxiv.org/abs/1602.01711

# %%
# Instanciation d'un modèle classificateur via un Pipeline

from sklearn.pipeline import Pipeline
from sktime.transformations.panel.compose import ColumnConcatenator
from sktime.classification.interval_based import TimeSeriesForestClassifier

steps = [
    ("concatenate", ColumnConcatenator()), ## Cette étape permet de transformer les jeux de données multivariées en univariées afin qu'ils puissent être traités par `TimeSeriesForestClassifier`.
    ("classify", TimeSeriesForestClassifier()),
]

clf_rf_ts = Pipeline(steps)

# %%
# Récupération des paramètres initiaux de la TSF

clf_rf_ts["classify"].get_params()
# Out:
# {'inner_series_length': None,
#  'min_interval': 3,
#  'n_estimators': 200,
#  'n_jobs': 1,
#  'random_state': None}

# %%
# Entraînement du modèle
clf_rf_ts.fit(X_train_np, y_train_np)
# Out:
# Pipeline(steps=[('concatenate', ColumnConcatenator()),
#                 ('classify', TimeSeriesForestClassifier())])

# %%
dump(clf_rf_ts, 'saves/model_saves/save_TSF_Alex_scale.joblib')
# Out:
# ['saves/model_saves/save_TSF_Alex_scale.joblib']

# %%
# Récupération des paramètres ajustés de la TSF

clf_rf_ts["classify"].get_fitted_params()
# Out:
# {'classes': array([0, 1], dtype=int64),
#  'intervals': [array([[20, 23],
#          [ 7, 15],
#          [10, 20],
#          [16, 26],
#          [ 8, 12]]),
#   array([[11, 24],
#          [ 6, 12],
#          [17, 20],
#          [17, 26],
#          [11, 21]]),
#   array([[19, 24],
#          [ 8, 13],
#          [ 8, 15],
#          [ 0,  3],
#          [20, 23]]),
#   array([[11, 15],
#          [19, 22],
#          [24, 27],
#          [17, 20],
#          [14, 17]]),
#   array([[ 1,  4],
#          [18, 21],
#          [ 4, 17],
#          [ 3, 13],
#          [ 0,  3]]),
#   array([[18, 24],
#          [11, 16],
#          [17, 20],
#          [11, 26],
#          [23, 26]]),
#   array([[11, 19],
#          [18, 21],
#          [20, 23],
#          [ 2, 23],
#          [12, 15]]),
#   array([[21, 26],
#          [ 4, 15],
#          [11, 24],
#          [ 3, 13],
#          [20, 23]]),
#   array([[ 1,  4],
#          [10, 13],
#          [17, 26],
#          [21, 24],
#          [ 1,  4]]),
#   array([[14, 25],
#          [ 7, 14],
#          [ 2, 11],
#          [ 2, 20],
#          [ 3,  8]]),
#   array([[22, 25],
#          [ 0,  3],
#          [23, 26],
#          [16, 20],
#          [24, 27]]),
#   array([[ 3, 26],
#          [20, 23],
#          [ 4, 23],
#          [11, 16],
#          [ 7, 12]]),
#   array([[20, 23],
#          [ 1, 16],
#          [ 9, 23],
#          [22, 26],
#          [16, 21]]),
#   array([[ 3, 19],
#          [ 3, 24],
#          [ 2, 22],
#          [16, 19],
#          [19, 22]]),
#   array([[11, 14],
#          [23, 26],
#          [ 2, 17],
#          [10, 13],
#          [17, 22]]),
#   array([[10, 19],
#          [12, 15],
#          [17, 26],
#          [ 5, 20],
#          [24, 27]]),
#   array([[12, 17],
#          [10, 22],
#          [17, 23],
#          [ 6, 16],
#          [ 1, 11]]),
#   array([[ 1, 24],
#          [ 4, 21],
#          [ 5, 18],
#          [ 4,  9],
#          [20, 25]]),
#   array([[10, 21],
#          [24, 27],
#          [10, 26],
#          [10, 19],
#          [18, 24]]),
#   array([[23, 26],
#          [ 7, 19],
#          [17, 22],
#          [20, 24],
#          [ 5, 18]]),
#   array([[13, 25],
#          [14, 17],
#          [19, 22],
#          [21, 26],
#          [23, 26]]),
#   array([[23, 26],
#          [21, 26],
#          [ 7, 26],
#          [20, 23],
#          [11, 15]]),
#   array([[23, 26],
#          [ 9, 19],
#          [ 6, 23],
#          [ 2,  7],
#          [ 0,  3]]),
#   array([[ 3, 23],
#          [11, 26],
#          [18, 21],
#          [10, 18],
#          [10, 14]]),
#   array([[ 7, 10],
#          [ 0, 19],
#          [18, 21],
#          [ 8, 26],
#          [ 7, 10]]),
#   array([[11, 14],
#          [ 6,  9],
#          [12, 17],
#          [ 8, 20],
#          [17, 22]]),
#   array([[19, 22],
#          [ 0, 16],
#          [15, 18],
#          [15, 18],
#          [16, 19]]),
#   array([[14, 26],
#          [15, 26],
#          [16, 22],
#          [23, 26],
#          [ 7, 17]]),
#   array([[ 0, 16],
#          [ 7, 18],
#          [15, 21],
#          [20, 24],
#          [23, 26]]),
#   array([[15, 18],
#          [ 8, 14],
#          [24, 27],
#          [19, 24],
#          [21, 24]]),
#   array([[15, 22],
#          [ 2,  9],
#          [11, 14],
#          [22, 25],
#          [ 5, 14]]),
#   array([[23, 26],
#          [ 6, 15],
#          [ 8, 13],
#          [23, 26],
#          [ 1, 20]]),
#   array([[ 2,  9],
#          [ 7, 22],
#          [ 9, 18],
#          [ 9, 25],
#          [14, 24]]),
#   array([[ 2, 22],
#          [20, 24],
#          [19, 24],
#          [ 5, 17],
#          [22, 25]]),
#   array([[ 9, 21],
#          [ 9, 25],
#          [10, 18],
#          [17, 26],
#          [24, 27]]),
#   array([[ 3, 21],
#          [ 3,  9],
#          [23, 26],
#          [ 9, 15],
#          [ 1,  4]]),
#   array([[21, 26],
#          [ 6, 25],
#          [ 5, 18],
#          [ 5, 18],
#          [ 1, 15]]),
#   array([[23, 26],
#          [14, 23],
#          [ 8, 14],
#          [12, 19],
#          [ 6, 26]]),
#   array([[11, 21],
#          [ 4, 25],
#          [19, 23],
#          [ 0, 19],
#          [ 6, 17]]),
#   array([[11, 20],
#          [12, 26],
#          [ 6, 25],
#          [15, 25],
#          [24, 27]]),
#   array([[ 4, 12],
#          [17, 20],
#          [20, 23],
#          [ 0, 13],
#          [ 9, 12]]),
#   array([[16, 25],
#          [ 9, 12],
#          [17, 22],
#          [15, 19],
#          [ 1, 13]]),
#   array([[ 3, 15],
#          [ 0,  5],
#          [10, 13],
#          [16, 21],
#          [17, 20]]),
#   array([[19, 26],
#          [10, 26],
#          [15, 20],
#          [24, 27],
#          [ 2, 18]]),
#   array([[ 8, 14],
#          [16, 21],
#          [16, 20],
#          [ 0,  6],
#          [17, 23]]),
#   array([[22, 25],
#          [24, 27],
#          [ 0, 16],
#          [11, 15],
#          [20, 23]]),
#   array([[ 9, 13],
#          [10, 25],
#          [15, 19],
#          [18, 25],
#          [19, 26]]),
#   array([[ 5, 14],
#          [23, 26],
#          [ 6, 18],
#          [ 0, 19],
#          [15, 18]]),
#   array([[ 6, 24],
#          [14, 26],
#          [ 9, 16],
#          [13, 25],
#          [18, 24]]),
#   array([[ 9, 15],
#          [13, 24],
#          [11, 19],
#          [10, 24],
#          [21, 24]]),
#   array([[ 7, 17],
#          [ 5, 24],
#          [ 9, 23],
#          [17, 20],
#          [16, 19]]),
#   array([[10, 16],
#          [22, 25],
#          [19, 25],
#          [17, 25],
#          [11, 26]]),
#   array([[18, 22],
#          [23, 26],
#          [ 7, 11],
#          [21, 24],
#          [20, 23]]),
#   array([[16, 19],
#          [21, 24],
#          [18, 25],
#          [20, 24],
#          [19, 24]]),
#   array([[14, 24],
#          [19, 22],
#          [24, 27],
#          [ 4, 20],
#          [23, 26]]),
#   array([[23, 26],
#          [22, 25],
#          [16, 25],
#          [24, 27],
#          [21, 25]]),
#   array([[22, 25],
#          [ 6, 10],
#          [22, 25],
#          [15, 26],
#          [ 2,  7]]),
#   array([[23, 26],
#          [ 7, 13],
#          [11, 14],
#          [ 2,  6],
#          [18, 21]]),
#   array([[15, 18],
#          [ 6, 22],
#          [ 4, 25],
#          [ 4, 22],
#          [15, 26]]),
#   array([[16, 23],
#          [ 2, 24],
#          [13, 24],
#          [ 5, 17],
#          [13, 16]]),
#   array([[16, 19],
#          [18, 21],
#          [ 6, 16],
#          [ 3, 17],
#          [ 1, 14]]),
#   array([[ 8, 25],
#          [18, 26],
#          [ 9, 25],
#          [14, 25],
#          [15, 21]]),
#   array([[ 7, 10],
#          [ 6, 14],
#          [ 1,  6],
#          [11, 25],
#          [24, 27]]),
#   array([[ 7, 18],
#          [ 8, 19],
#          [23, 26],
#          [ 0,  3],
#          [ 7, 23]]),
#   array([[24, 27],
#          [ 9, 16],
#          [14, 23],
#          [18, 22],
#          [24, 27]]),
#   array([[11, 15],
#          [ 0, 16],
#          [ 8, 20],
#          [ 6, 12],
#          [ 7, 23]]),
#   array([[15, 26],
#          [18, 21],
#          [15, 25],
#          [12, 15],
#          [ 6, 21]]),
#   array([[23, 26],
#          [21, 24],
#          [16, 24],
#          [10, 13],
#          [16, 19]]),
#   array([[ 4, 17],
#          [23, 26],
#          [ 0,  3],
#          [ 7, 22],
#          [12, 15]]),
#   array([[ 9, 20],
#          [ 5,  8],
#          [ 2, 14],
#          [22, 25],
#          [ 0, 24]]),
#   array([[18, 23],
#          [ 9, 17],
#          [13, 16],
#          [14, 17],
#          [10, 26]]),
#   array([[20, 23],
#          [21, 25],
#          [23, 26],
#          [ 2,  9],
#          [10, 15]]),
#   array([[ 8, 26],
#          [24, 27],
#          [12, 24],
#          [ 9, 12],
#          [22, 25]]),
#   array([[10, 15],
#          [23, 26],
#          [20, 25],
#          [20, 25],
#          [ 0, 18]]),
#   array([[ 5, 24],
#          [ 6, 20],
#          [ 2,  7],
#          [ 6, 25],
#          [12, 16]]),
#   array([[ 0,  6],
#          [ 0, 11],
#          [15, 18],
#          [18, 21],
#          [21, 26]]),
#   array([[18, 21],
#          [24, 27],
#          [12, 19],
#          [ 0, 23],
#          [23, 26]]),
#   array([[18, 24],
#          [ 0, 13],
#          [12, 15],
#          [24, 27],
#          [ 2,  8]]),
#   array([[11, 26],
#          [ 2,  5],
#          [23, 26],
#          [ 9, 17],
#          [11, 16]]),
#   array([[22, 25],
#          [23, 26],
#          [18, 21],
#          [13, 26],
#          [ 2, 24]]),
#   array([[ 2, 12],
#          [15, 18],
#          [17, 21],
#          [ 8, 17],
#          [ 0, 14]]),
#   array([[12, 23],
#          [ 3, 22],
#          [ 2, 25],
#          [ 5,  9],
#          [20, 23]]),
#   array([[10, 22],
#          [12, 20],
#          [ 9, 24],
#          [ 8, 25],
#          [17, 23]]),
#   array([[19, 22],
#          [10, 18],
#          [ 5, 20],
#          [22, 25],
#          [20, 24]]),
#   array([[13, 26],
#          [ 2, 20],
#          [14, 19],
#          [10, 14],
#          [ 2,  7]]),
#   array([[23, 26],
#          [ 1, 18],
#          [15, 18],
#          [16, 22],
#          [23, 26]]),
#   array([[ 9, 24],
#          [17, 22],
#          [10, 13],
#          [ 0, 10],
#          [12, 22]]),
#   array([[13, 23],
#          [14, 20],
#          [ 3, 25],
#          [13, 16],
#          [ 9, 22]]),
#   array([[ 9, 18],
#          [ 7, 19],
#          [21, 24],
#          [ 0, 23],
#          [23, 26]]),
#   array([[11, 14],
#          [20, 24],
#          [14, 20],
#          [20, 23],
#          [ 0,  3]]),
#   array([[ 3,  6],
#          [15, 18],
#          [ 3, 20],
#          [23, 26],
#          [ 4, 24]]),
#   array([[11, 25],
#          [20, 26],
#          [20, 26],
#          [19, 22],
#          [ 1,  6]]),
#   array([[22, 25],
#          [23, 26],
#          [11, 15],
#          [ 9, 26],
#          [10, 15]]),
#   array([[13, 20],
#          [14, 24],
#          [ 9, 26],
#          [ 1, 16],
#          [10, 13]]),
#   array([[18, 21],
#          [ 0, 10],
#          [22, 25],
#          [14, 19],
#          [ 5, 15]]),
#   array([[ 4, 18],
#          [20, 23],
#          [ 0,  9],
#          [21, 24],
#          [20, 23]]),
#   array([[18, 22],
#          [24, 27],
#          [12, 15],
#          [ 4,  8],
#          [ 7, 17]]),
#   array([[11, 14],
#          [19, 25],
#          [ 9, 16],
#          [ 6, 23],
#          [22, 25]]),
#   array([[10, 16],
#          [17, 23],
#          [10, 13],
#          [19, 22],
#          [10, 23]]),
#   array([[ 8, 13],
#          [ 0,  3],
#          [22, 26],
#          [ 8, 20],
#          [ 1, 16]]),
#   array([[20, 24],
#          [23, 26],
#          [ 5, 25],
#          [16, 24],
#          [ 0,  3]]),
#   array([[ 8, 19],
#          [12, 25],
#          [16, 26],
#          [18, 25],
#          [14, 24]]),
#   array([[14, 25],
#          [10, 23],
#          [ 2, 14],
#          [12, 21],
#          [ 6, 24]]),
#   array([[ 8, 14],
#          [22, 25],
#          [17, 20],
#          [12, 24],
#          [ 1, 23]]),
#   array([[ 3, 22],
#          [ 9, 13],
#          [ 2,  7],
#          [21, 24],
#          [18, 24]]),
#   array([[20, 23],
#          [17, 23],
#          [16, 19],
#          [21, 24],
#          [ 5, 14]]),
#   array([[ 2, 16],
#          [ 2,  9],
#          [15, 18],
#          [19, 25],
#          [ 8, 14]]),
#   array([[16, 21],
#          [ 2, 21],
#          [ 8, 14],
#          [19, 26],
#          [13, 22]]),
#   array([[12, 18],
#          [ 7, 23],
#          [16, 19],
#          [11, 14],
#          [ 8, 11]]),
#   array([[ 3, 17],
#          [ 0, 16],
#          [23, 26],
#          [23, 26],
#          [12, 20]]),
#   array([[14, 19],
#          [13, 16],
#          [12, 24],
#          [24, 27],
#          [ 4,  7]]),
#   array([[20, 23],
#          [ 0, 22],
#          [19, 22],
#          [ 8, 20],
#          [19, 23]]),
#   array([[ 2, 17],
#          [13, 16],
#          [19, 22],
#          [14, 23],
#          [17, 22]]),
#   array([[ 1, 14],
#          [23, 26],
#          [22, 25],
#          [23, 26],
#          [11, 14]]),
#   array([[ 3, 17],
#          [10, 13],
#          [18, 21],
#          [19, 22],
#          [ 5, 15]]),
#   array([[ 1, 12],
#          [21, 24],
#          [24, 27],
#          [ 2, 10],
#          [ 1,  4]]),
#   array([[13, 22],
#          [ 2,  7],
#          [ 2, 19],
#          [14, 17],
#          [ 5,  8]]),
#   array([[ 3, 10],
#          [ 2, 18],
#          [ 9, 12],
#          [22, 26],
#          [ 5, 21]]),
#   array([[19, 24],
#          [10, 23],
#          [10, 18],
#          [14, 26],
#          [ 6,  9]]),
#   array([[ 7, 11],
#          [20, 26],
#          [ 1, 16],
#          [ 8, 11],
#          [ 8, 21]]),
#   array([[21, 24],
#          [22, 25],
#          [ 7, 12],
#          [10, 13],
#          [ 8, 11]]),
#   array([[ 2,  5],
#          [ 4, 10],
#          [10, 23],
#          [15, 21],
#          [12, 25]]),
#   array([[18, 22],
#          [ 5, 24],
#          [21, 24],
#          [21, 24],
#          [ 1, 19]]),
#   array([[13, 17],
#          [ 6, 16],
#          [ 9, 21],
#          [ 2, 16],
#          [16, 19]]),
#   array([[ 6, 13],
#          [ 4,  7],
#          [11, 26],
#          [ 8, 26],
#          [ 2,  5]]),
#   array([[18, 26],
#          [20, 23],
#          [ 4, 23],
#          [17, 21],
#          [ 9, 25]]),
#   array([[ 1, 22],
#          [ 3,  6],
#          [15, 23],
#          [ 6, 21],
#          [15, 20]]),
#   array([[ 8, 20],
#          [ 8, 20],
#          [23, 26],
#          [ 4, 17],
#          [ 1, 12]]),
#   array([[ 0, 25],
#          [ 1,  8],
#          [ 5, 10],
#          [11, 14],
#          [22, 26]]),
#   array([[ 5, 12],
#          [ 7, 10],
#          [19, 22],
#          [20, 23],
#          [ 1, 12]]),
#   array([[22, 25],
#          [21, 24],
#          [ 1,  7],
#          [ 0, 26],
#          [ 4, 23]]),
#   array([[20, 23],
#          [ 4,  7],
#          [18, 26],
#          [17, 21],
#          [16, 23]]),
#   array([[11, 23],
#          [ 3, 23],
#          [ 3, 24],
#          [14, 17],
#          [23, 26]]),
#   array([[23, 26],
#          [ 0,  3],
#          [21, 24],
#          [15, 23],
#          [23, 26]]),
#   array([[ 4, 17],
#          [15, 23],
#          [21, 25],
#          [ 6, 14],
#          [ 9, 17]]),
#   array([[10, 21],
#          [ 1, 11],
#          [ 5,  8],
#          [11, 22],
#          [ 3, 24]]),
#   array([[10, 13],
#          [15, 25],
#          [ 4,  9],
#          [ 5, 12],
#          [18, 22]]),
#   array([[21, 24],
#          [11, 25],
#          [21, 24],
#          [ 5, 11],
#          [24, 27]]),
#   array([[ 0,  8],
#          [ 7, 22],
#          [15, 25],
#          [ 7, 26],
#          [ 0,  5]]),
#   array([[11, 14],
#          [ 6, 18],
#          [11, 23],
#          [18, 21],
#          [16, 19]]),
#   array([[24, 27],
#          [18, 21],
#          [15, 21],
#          [11, 14],
#          [11, 19]]),
#   array([[14, 21],
#          [20, 23],
#          [20, 26],
#          [12, 15],
#          [17, 20]]),
#   array([[20, 25],
#          [16, 24],
#          [ 7, 21],
#          [ 4, 21],
#          [ 1, 12]]),
#   array([[24, 27],
#          [23, 26],
#          [21, 24],
#          [21, 24],
#          [14, 20]]),
#   array([[17, 21],
#          [ 8, 11],
#          [16, 23],
#          [17, 25],
#          [16, 22]]),
#   array([[16, 19],
#          [20, 23],
#          [11, 14],
#          [ 3, 25],
#          [14, 23]]),
#   array([[13, 19],
#          [ 7, 14],
#          [15, 26],
#          [18, 21],
#          [14, 26]]),
#   array([[18, 21],
#          [21, 24],
#          [ 0, 20],
#          [ 9, 19],
#          [16, 21]]),
#   array([[12, 20],
#          [21, 25],
#          [11, 15],
#          [22, 25],
#          [ 0, 18]]),
#   array([[ 2, 21],
#          [ 7, 17],
#          [ 2,  5],
#          [ 0, 13],
#          [ 0, 16]]),
#   array([[ 6, 25],
#          [15, 26],
#          [ 3,  6],
#          [24, 27],
#          [17, 20]]),
#   array([[ 9, 19],
#          [19, 22],
#          [19, 22],
#          [16, 24],
#          [22, 25]]),
#   array([[23, 26],
#          [12, 22],
#          [24, 27],
#          [20, 23],
#          [ 0,  5]]),
#   array([[ 7, 17],
#          [19, 23],
#          [11, 17],
#          [11, 19],
#          [ 1,  5]]),
#   array([[10, 24],
#          [18, 21],
#          [18, 21],
#          [18, 21],
#          [22, 25]]),
#   array([[24, 27],
#          [ 3,  6],
#          [18, 21],
#          [21, 24],
#          [14, 17]]),
#   array([[24, 27],
#          [11, 14],
#          [17, 20],
#          [13, 16],
#          [18, 21]]),
#   array([[ 2, 20],
#          [23, 26],
#          [ 7, 10],
#          [10, 13],
#          [ 0,  7]]),
#   array([[ 6, 22],
#          [ 7, 10],
#          [24, 27],
#          [23, 26],
#          [11, 14]]),
#   array([[ 1, 21],
#          [ 6, 14],
#          [ 2, 13],
#          [22, 25],
#          [ 2, 22]]),
#   array([[16, 21],
#          [ 6, 23],
#          [24, 27],
#          [23, 26],
#          [19, 25]]),
#   array([[24, 27],
#          [ 0, 26],
#          [11, 14],
#          [ 8, 16],
#          [15, 22]]),
#   array([[21, 24],
#          [ 1, 11],
#          [ 4,  8],
#          [ 5, 11],
#          [17, 20]]),
#   array([[18, 26],
#          [18, 22],
#          [ 1, 16],
#          [15, 23],
#          [23, 26]]),
#   array([[12, 15],
#          [ 5, 17],
#          [ 3, 24],
#          [15, 18],
#          [11, 21]]),
#   array([[ 9, 20],
#          [20, 24],
#          [11, 18],
#          [ 2, 12],
#          [ 0, 14]]),
#   array([[22, 26],
#          [20, 23],
#          [15, 18],
#          [ 9, 20],
#          [23, 26]]),
#   array([[22, 25],
#          [ 5, 21],
#          [23, 26],
#          [15, 24],
#          [12, 18]]),
#   array([[11, 14],
#          [ 3,  8],
#          [ 3,  7],
#          [18, 24],
#          [21, 24]]),
#   array([[ 9, 17],
#          [13, 16],
#          [14, 17],
#          [ 5,  8],
#          [19, 22]]),
#   array([[23, 26],
#          [12, 25],
#          [10, 24],
#          [12, 19],
#          [ 0, 18]]),
#   array([[ 0, 12],
#          [24, 27],
#          [11, 16],
#          [ 9, 13],
#          [20, 23]]),
#   array([[ 3, 14],
#          [20, 26],
#          [16, 19],
#          [23, 26],
#          [ 4, 23]]),
#   array([[12, 15],
#          [ 5, 11],
#          [11, 18],
#          [ 8, 15],
#          [15, 18]]),
#   array([[24, 27],
#          [15, 18],
#          [20, 23],
#          [ 4, 14],
#          [22, 25]]),
#   array([[19, 26],
#          [19, 22],
#          [ 1, 20],
#          [16, 19],
#          [14, 25]]),
#   array([[ 4, 25],
#          [ 5, 20],
#          [ 3, 15],
#          [14, 23],
#          [22, 25]]),
#   array([[ 1,  4],
#          [16, 23],
#          [ 7, 10],
#          [ 7, 21],
#          [15, 20]]),
#   array([[ 7, 10],
#          [ 3, 19],
#          [ 8, 14],
#          [ 2,  5],
#          [21, 26]]),
#   array([[ 7, 11],
#          [ 6, 22],
#          [ 0,  5],
#          [ 5,  8],
#          [ 3, 25]]),
#   array([[22, 25],
#          [21, 24],
#          [24, 27],
#          [12, 15],
#          [ 7, 10]]),
#   array([[21, 24],
#          [ 0,  3],
#          [ 4, 25],
#          [ 7, 24],
#          [ 0, 12]]),
#   array([[ 2,  5],
#          [23, 26],
#          [ 1, 10],
#          [24, 27],
#          [ 9, 20]]),
#   array([[ 6,  9],
#          [ 9, 20],
#          [12, 25],
#          [21, 24],
#          [14, 17]]),
#   array([[12, 15],
#          [ 0, 22],
#          [15, 23],
#          [ 2,  5],
#          [24, 27]]),
#   array([[ 2,  8],
#          [ 6, 20],
#          [12, 22],
#          [10, 26],
#          [22, 25]]),
#   array([[12, 15],
#          [ 6, 18],
#          [23, 26],
#          [ 8, 25],
#          [ 0, 12]]),
#   array([[21, 24],
#          [11, 22],
#          [12, 25],
#          [ 0, 16],
#          [ 7, 26]]),
#   array([[12, 15],
#          [18, 22],
#          [19, 22],
#          [19, 25],
#          [19, 22]]),
#   array([[23, 26],
#          [ 6, 18],
#          [21, 24],
#          [ 3, 21],
#          [ 1, 11]]),
#   array([[ 7, 25],
#          [ 1,  9],
#          [24, 27],
#          [ 9, 13],
#          [ 9, 25]]),
#   array([[16, 24],
#          [ 6, 17],
#          [19, 22],
#          [ 4, 24],
#          [10, 19]]),
#   array([[21, 24],
#          [22, 26],
#          [10, 18],
#          [13, 20],
#          [ 5,  8]]),
#   array([[16, 21],
#          [23, 26],
#          [ 3, 19],
#          [15, 18],
#          [14, 17]]),
#   array([[18, 26],
#          [ 7, 21],
#          [ 3,  8],
#          [ 4, 26],
#          [13, 18]]),
#   array([[ 9, 18],
#          [ 2, 18],
#          [12, 18],
#          [ 7, 10],
#          [ 3,  8]]),
#   array([[20, 23],
#          [ 3, 18],
#          [24, 27],
#          [ 0,  5],
#          [24, 27]]),
#   array([[15, 20],
#          [18, 21],
#          [ 4, 19],
#          [ 5,  9],
#          [14, 22]]),
#   array([[20, 26],
#          [17, 21],
#          [16, 22],
#          [16, 22],
#          [10, 13]]),
#   array([[17, 25],
#          [15, 23],
#          [24, 27],
#          [ 9, 20],
#          [ 8, 20]])],
#  'estimators': [DecisionTreeClassifier(criterion='entropy', random_state=1955419291),
#   DecisionTreeClassifier(criterion='entropy', random_state=1799201853),
#   DecisionTreeClassifier(criterion='entropy', random_state=1815230794),
#   DecisionTreeClassifier(criterion='entropy', random_state=1208372790),
#   DecisionTreeClassifier(criterion='entropy', random_state=1376299357),
#   DecisionTreeClassifier(criterion='entropy', random_state=452753106),
#   DecisionTreeClassifier(criterion='entropy', random_state=351853488),
#   DecisionTreeClassifier(criterion='entropy', random_state=839875621),
#   DecisionTreeClassifier(criterion='entropy', random_state=488142233),
#   DecisionTreeClassifier(criterion='entropy', random_state=1484119646),
#   DecisionTreeClassifier(criterion='entropy', random_state=1394776364),
#   DecisionTreeClassifier(criterion='entropy', random_state=190893291),
#   DecisionTreeClassifier(criterion='entropy', random_state=1005682624),
#   DecisionTreeClassifier(criterion='entropy', random_state=2003017874),
#   DecisionTreeClassifier(criterion='entropy', random_state=2303717),
#   DecisionTreeClassifier(criterion='entropy', random_state=311365680),
#   DecisionTreeClassifier(criterion='entropy', random_state=1797815676),
#   DecisionTreeClassifier(criterion='entropy', random_state=1340508211),
#   DecisionTreeClassifier(criterion='entropy', random_state=1479976952),
#   DecisionTreeClassifier(criterion='entropy', random_state=2065629740),
#   DecisionTreeClassifier(criterion='entropy', random_state=1576096273),
#   DecisionTreeClassifier(criterion='entropy', random_state=817848546),
#   DecisionTreeClassifier(criterion='entropy', random_state=1310990634),
#   DecisionTreeClassifier(criterion='entropy', random_state=504629504),
#   DecisionTreeClassifier(criterion='entropy', random_state=1291918728),
#   DecisionTreeClassifier(criterion='entropy', random_state=497052041),
#   DecisionTreeClassifier(criterion='entropy', random_state=618131327),
#   DecisionTreeClassifier(criterion='entropy', random_state=497837502),
#   DecisionTreeClassifier(criterion='entropy', random_state=1330919020),
#   DecisionTreeClassifier(criterion='entropy', random_state=986776338),
#   DecisionTreeClassifier(criterion='entropy', random_state=2145206828),
#   DecisionTreeClassifier(criterion='entropy', random_state=1972963939),
#   DecisionTreeClassifier(criterion='entropy', random_state=276168733),
#   DecisionTreeClassifier(criterion='entropy', random_state=1698883586),
#   DecisionTreeClassifier(criterion='entropy', random_state=877231347),
#   DecisionTreeClassifier(criterion='entropy', random_state=1044682431),
#   DecisionTreeClassifier(criterion='entropy', random_state=869849427),
#   DecisionTreeClassifier(criterion='entropy', random_state=2025445542),
#   DecisionTreeClassifier(criterion='entropy', random_state=107365976),
#   DecisionTreeClassifier(criterion='entropy', random_state=1800515646),
#   DecisionTreeClassifier(criterion='entropy', random_state=1887408798),
#   DecisionTreeClassifier(criterion='entropy', random_state=1459736499),
#   DecisionTreeClassifier(criterion='entropy', random_state=1919739076),
#   DecisionTreeClassifier(criterion='entropy', random_state=1829925475),
#   DecisionTreeClassifier(criterion='entropy', random_state=1707786120),
#   DecisionTreeClassifier(criterion='entropy', random_state=1821729842),
#   DecisionTreeClassifier(criterion='entropy', random_state=32618787),
#   DecisionTreeClassifier(criterion='entropy', random_state=1117063811),
#   DecisionTreeClassifier(criterion='entropy', random_state=352926828),
#   DecisionTreeClassifier(criterion='entropy', random_state=399574258),
#   DecisionTreeClassifier(criterion='entropy', random_state=1039819049),
#   DecisionTreeClassifier(criterion='entropy', random_state=1812512542),
#   DecisionTreeClassifier(criterion='entropy', random_state=690815586),
#   DecisionTreeClassifier(criterion='entropy', random_state=1204116339),
#   DecisionTreeClassifier(criterion='entropy', random_state=1334115879),
#   DecisionTreeClassifier(criterion='entropy', random_state=1480470620),
#   DecisionTreeClassifier(criterion='entropy', random_state=1505960414),
#   DecisionTreeClassifier(criterion='entropy', random_state=1851761745),
#   DecisionTreeClassifier(criterion='entropy', random_state=1237992016),
#   DecisionTreeClassifier(criterion='entropy', random_state=1837751616),
#   DecisionTreeClassifier(criterion='entropy', random_state=1881936562),
#   DecisionTreeClassifier(criterion='entropy', random_state=743847828),
#   DecisionTreeClassifier(criterion='entropy', random_state=195099754),
#   DecisionTreeClassifier(criterion='entropy', random_state=241079893),
#   DecisionTreeClassifier(criterion='entropy', random_state=1385667711),
#   DecisionTreeClassifier(criterion='entropy', random_state=1519942273),
#   DecisionTreeClassifier(criterion='entropy', random_state=1331869078),
#   DecisionTreeClassifier(criterion='entropy', random_state=1405430029),
#   DecisionTreeClassifier(criterion='entropy', random_state=264144061),
#   DecisionTreeClassifier(criterion='entropy', random_state=2101263257),
#   DecisionTreeClassifier(criterion='entropy', random_state=85109282),
#   DecisionTreeClassifier(criterion='entropy', random_state=1579105077),
#   DecisionTreeClassifier(criterion='entropy', random_state=754493672),
#   DecisionTreeClassifier(criterion='entropy', random_state=1911769169),
#   DecisionTreeClassifier(criterion='entropy', random_state=447175933),
#   DecisionTreeClassifier(criterion='entropy', random_state=604162485),
#   DecisionTreeClassifier(criterion='entropy', random_state=1791625839),
#   DecisionTreeClassifier(criterion='entropy', random_state=642374213),
#   DecisionTreeClassifier(criterion='entropy', random_state=2037657332),
#   DecisionTreeClassifier(criterion='entropy', random_state=673007396),
#   DecisionTreeClassifier(criterion='entropy', random_state=118201695),
#   DecisionTreeClassifier(criterion='entropy', random_state=646161406),
#   DecisionTreeClassifier(criterion='entropy', random_state=1056149644),
#   DecisionTreeClassifier(criterion='entropy', random_state=543776658),
#   DecisionTreeClassifier(criterion='entropy', random_state=2126114163),
#   DecisionTreeClassifier(criterion='entropy', random_state=812300460),
#   DecisionTreeClassifier(criterion='entropy', random_state=406680304),
#   DecisionTreeClassifier(criterion='entropy', random_state=1588107820),
#   DecisionTreeClassifier(criterion='entropy', random_state=710068354),
#   DecisionTreeClassifier(criterion='entropy', random_state=1159088780),
#   DecisionTreeClassifier(criterion='entropy', random_state=478264260),
#   DecisionTreeClassifier(criterion='entropy', random_state=1841070539),
#   DecisionTreeClassifier(criterion='entropy', random_state=497574933),
#   DecisionTreeClassifier(criterion='entropy', random_state=1473251623),
#   DecisionTreeClassifier(criterion='entropy', random_state=811326926),
#   DecisionTreeClassifier(criterion='entropy', random_state=14608015),
#   DecisionTreeClassifier(criterion='entropy', random_state=1700298173),
#   DecisionTreeClassifier(criterion='entropy', random_state=1334893813),
#   DecisionTreeClassifier(criterion='entropy', random_state=1808250005),
#   DecisionTreeClassifier(criterion='entropy', random_state=317192771),
#   DecisionTreeClassifier(criterion='entropy', random_state=150916779),
#   DecisionTreeClassifier(criterion='entropy', random_state=23707247),
#   DecisionTreeClassifier(criterion='entropy', random_state=710617812),
#   DecisionTreeClassifier(criterion='entropy', random_state=730954796),
#   DecisionTreeClassifier(criterion='entropy', random_state=1642079217),
#   DecisionTreeClassifier(criterion='entropy', random_state=1966427687),
#   DecisionTreeClassifier(criterion='entropy', random_state=132972780),
#   DecisionTreeClassifier(criterion='entropy', random_state=930395260),
#   DecisionTreeClassifier(criterion='entropy', random_state=1952316544),
#   DecisionTreeClassifier(criterion='entropy', random_state=190821916),
#   DecisionTreeClassifier(criterion='entropy', random_state=621111118),
#   DecisionTreeClassifier(criterion='entropy', random_state=1690463258),
#   DecisionTreeClassifier(criterion='entropy', random_state=1090642120),
#   DecisionTreeClassifier(criterion='entropy', random_state=401720301),
#   DecisionTreeClassifier(criterion='entropy', random_state=1910656846),
#   DecisionTreeClassifier(criterion='entropy', random_state=227096987),
#   DecisionTreeClassifier(criterion='entropy', random_state=1048761582),
#   DecisionTreeClassifier(criterion='entropy', random_state=1750323477),
#   DecisionTreeClassifier(criterion='entropy', random_state=2082837886),
#   DecisionTreeClassifier(criterion='entropy', random_state=1775171418),
#   DecisionTreeClassifier(criterion='entropy', random_state=930350490),
#   DecisionTreeClassifier(criterion='entropy', random_state=1350159863),
#   DecisionTreeClassifier(criterion='entropy', random_state=967629624),
#   DecisionTreeClassifier(criterion='entropy', random_state=284900604),
#   DecisionTreeClassifier(criterion='entropy', random_state=1562294134),
#   DecisionTreeClassifier(criterion='entropy', random_state=260833647),
#   DecisionTreeClassifier(criterion='entropy', random_state=2007026056),
#   DecisionTreeClassifier(criterion='entropy', random_state=1984448606),
#   DecisionTreeClassifier(criterion='entropy', random_state=133457241),
#   DecisionTreeClassifier(criterion='entropy', random_state=1113370310),
#   DecisionTreeClassifier(criterion='entropy', random_state=2065678837),
#   DecisionTreeClassifier(criterion='entropy', random_state=1972688101),
#   DecisionTreeClassifier(criterion='entropy', random_state=1720716287),
#   DecisionTreeClassifier(criterion='entropy', random_state=1617551629),
#   DecisionTreeClassifier(criterion='entropy', random_state=1096827813),
#   DecisionTreeClassifier(criterion='entropy', random_state=918476977),
#   DecisionTreeClassifier(criterion='entropy', random_state=1335377047),
#   DecisionTreeClassifier(criterion='entropy', random_state=1779807548),
#   DecisionTreeClassifier(criterion='entropy', random_state=1183866773),
#   DecisionTreeClassifier(criterion='entropy', random_state=1214650920),
#   DecisionTreeClassifier(criterion='entropy', random_state=1033495828),
#   DecisionTreeClassifier(criterion='entropy', random_state=832394172),
#   DecisionTreeClassifier(criterion='entropy', random_state=1423513159),
#   DecisionTreeClassifier(criterion='entropy', random_state=1012337893),
#   DecisionTreeClassifier(criterion='entropy', random_state=1366915815),
#   DecisionTreeClassifier(criterion='entropy', random_state=384848296),
#   DecisionTreeClassifier(criterion='entropy', random_state=698984337),
#   DecisionTreeClassifier(criterion='entropy', random_state=1290529970),
#   DecisionTreeClassifier(criterion='entropy', random_state=1111603128),
#   DecisionTreeClassifier(criterion='entropy', random_state=309051296),
#   DecisionTreeClassifier(criterion='entropy', random_state=1049875436),
#   DecisionTreeClassifier(criterion='entropy', random_state=1556923549),
#   DecisionTreeClassifier(criterion='entropy', random_state=87983157),
#   DecisionTreeClassifier(criterion='entropy', random_state=183363488),
#   DecisionTreeClassifier(criterion='entropy', random_state=345989742),
#   DecisionTreeClassifier(criterion='entropy', random_state=321237935),
#   DecisionTreeClassifier(criterion='entropy', random_state=1725859498),
#   DecisionTreeClassifier(criterion='entropy', random_state=923369343),
#   DecisionTreeClassifier(criterion='entropy', random_state=938349999),
#   DecisionTreeClassifier(criterion='entropy', random_state=481390412),
#   DecisionTreeClassifier(criterion='entropy', random_state=1616320661),
#   DecisionTreeClassifier(criterion='entropy', random_state=1093387731),
#   DecisionTreeClassifier(criterion='entropy', random_state=534435221),
#   DecisionTreeClassifier(criterion='entropy', random_state=51426297),
#   DecisionTreeClassifier(criterion='entropy', random_state=1373737527),
#   DecisionTreeClassifier(criterion='entropy', random_state=1901764387),
#   DecisionTreeClassifier(criterion='entropy', random_state=1611763258),
#   DecisionTreeClassifier(criterion='entropy', random_state=358317315),
#   DecisionTreeClassifier(criterion='entropy', random_state=1426195072),
#   DecisionTreeClassifier(criterion='entropy', random_state=2041917593),
#   DecisionTreeClassifier(criterion='entropy', random_state=1838545819),
#   DecisionTreeClassifier(criterion='entropy', random_state=50001920),
#   DecisionTreeClassifier(criterion='entropy', random_state=515830364),
#   DecisionTreeClassifier(criterion='entropy', random_state=715908354),
#   DecisionTreeClassifier(criterion='entropy', random_state=1004916504),
#   DecisionTreeClassifier(criterion='entropy', random_state=100534642),
#   DecisionTreeClassifier(criterion='entropy', random_state=965484137),
#   DecisionTreeClassifier(criterion='entropy', random_state=2667896),
#   DecisionTreeClassifier(criterion='entropy', random_state=120817666),
#   DecisionTreeClassifier(criterion='entropy', random_state=1958079610),
#   DecisionTreeClassifier(criterion='entropy', random_state=525991813),
#   DecisionTreeClassifier(criterion='entropy', random_state=871303249),
#   DecisionTreeClassifier(criterion='entropy', random_state=1015703947),
#   DecisionTreeClassifier(criterion='entropy', random_state=94556222),
#   DecisionTreeClassifier(criterion='entropy', random_state=26912078),
#   DecisionTreeClassifier(criterion='entropy', random_state=401660289),
#   DecisionTreeClassifier(criterion='entropy', random_state=603963848),
#   DecisionTreeClassifier(criterion='entropy', random_state=323001635),
#   DecisionTreeClassifier(criterion='entropy', random_state=630958713),
#   DecisionTreeClassifier(criterion='entropy', random_state=1626058462),
#   DecisionTreeClassifier(criterion='entropy', random_state=1647413345),
#   DecisionTreeClassifier(criterion='entropy', random_state=854153674),
#   DecisionTreeClassifier(criterion='entropy', random_state=547123348),
#   DecisionTreeClassifier(criterion='entropy', random_state=731865085),
#   DecisionTreeClassifier(criterion='entropy', random_state=1246270964),
#   DecisionTreeClassifier(criterion='entropy', random_state=811969943),
#   DecisionTreeClassifier(criterion='entropy', random_state=718155680),
#   DecisionTreeClassifier(criterion='entropy', random_state=1513535844),
#   DecisionTreeClassifier(criterion='entropy', random_state=380554605),
#   DecisionTreeClassifier(criterion='entropy', random_state=601974695)],
#  'n_classes': 2,
#  'fit_time': 627541}

# %%
X_test.shape
# Out:
# (23464, 28)

# %%
# Réalisation des prédictions
clf_rf_ts = load('saves/model_saves/save_TSF_Alex_scale.joblib')
y_pred = clf_rf_ts.predict(X_test_np)

# %% [markdown]
# ## 5. Évaluation

# %%
# Élaboration de la matrice de confusion

pd.crosstab(y_test, y_pred, rownames = ["Classe réelle"], colnames = ["Classe prédite"])
# Out:
# Classe prédite      0     1
# Classe réelle
# 0               17613   506
# 1                3688  1657

# %%
# Élaboration du rapport de classification

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.89     18119
#            1       0.77      0.31      0.44      5345
#
#     accuracy                           0.82     23464
#    macro avg       0.80      0.64      0.67     23464
# weighted avg       0.81      0.82      0.79     23464

# %% [markdown]
# # 6. Roc

# %%
clf_rf_ts = load('saves/model_saves/save_TSF_Alex_scale.joblib')
# On fait la prediction sur test:
preds = clf_rf_ts.predict_proba(X_test_np)

################################ On cherche le meilleur seuil:
# Création des arrays fpr, tpr et seuils:
fpr, tpr, seuils = roc_curve(y_test, preds[:, 1], pos_label = 1) # on choisit pred[:, 1] pour prendre parmi les deux probas celle qui correspond à la classe positive.

# Pour calculer l'aire sous la courbe ROC:
roc_auc = auc(x = fpr, y = tpr)

# Comment trouver le meilleur seuil?
dist = 1
for (x, y, s) in zip(fpr, tpr, seuils):
    dist1 = np.square(x**2 + (y-1)**2) 
    if dist1 < dist:
        dist = dist1
        seuil_best = 1 - s # pourquoi dois-je faire ça?
        fpr_best = x
        tpr_best = y
        
#print("Meilleur seuil:", seuil_best, "meilleur fpr:", fpr_best, "meilleur tpr:", tpr_best)

# Tracé de ROC:
plt.figure(figsize = (7, 7))
plt.axis('equal')

plt.scatter(fpr_best, tpr_best, s = 60, c = 'red', marker = '*', alpha = 1, label = "Meilleur seuil = %0.3f" % seuil_best)
plt.plot(fpr, tpr, c = 'orange', label = 'Modèle TSF (auc = %0.2f)' % roc_auc)
plt.plot(fpr, fpr, 'b--', label = 'Aléatoire (auc = 0.5)')

plt.title('Courbe Roc TSF scale')
plt.xlabel('Taux de faux positifs :fpr')
plt.ylabel('Taux de vrais positifs :tpr')
plt.legend()

plt.show()

################### On applique le meilleur seuil:
y_pred = pd.Series(np.where(preds[:, 1] > seuil_best, 1, 0))

print("Report TSF scale", "\n", classification_report(y_test, y_pred,  digits = 2))
print(confusion_matrix(y_test, y_pred))
# Out:
# Report TSF scale
#                precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88     18119
#            1       0.92      0.07      0.12      5345
#
#     accuracy                           0.79     23464
#    macro avg       0.85      0.53      0.50     23464
# weighted avg       0.81      0.79      0.71     23464
#
# [[18088    31]
#  [ 4993   352]]

# %% [markdown]
# Bilan: faut pas faire d'opti roc sur ce modèle non plus! :)
