# %% [markdown]
# # **Classification** des **séries temporelles** avec `sktime`

# %% [markdown]
# ## Métadonnées

# %% [markdown]
# - **Expérience nº :** 2
# - **Date :** 05/11/2023
# - **Heure :** 13:31
# - **Données :** `ready_Evaporation.csv`
# - **Splitter :** `TimeSeriesSplit`
# - **Méthode :** TSF

# %% [markdown]
# ## Sommaire

# %% [markdown]
# 1. Initialisation
# 2. Découpage des données
# 3. Conversion des données
# 4. Modélisation
# 5. Évaluation

# %% [markdown]
# ## 1. Initialisation

# %%
# Importation des bibliothèques et modules nécessaires au fonctionnement de ce notebook

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style = "darkgrid", palette = "colorblind")
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from imblearn.over_sampling import RandomOverSampler, SMOTE
from joblib import dump, load # pour enregistrer et charger les modèles.
n_coeurs = 4

# %%
# Importation du jeu de données et enregistrement dans le DataFrame `df`

# Instanciation df
df = pd.read_csv('../../../../data/processed/model_weatherAUS.csv', index_col = 1).sort_index()
df.drop(columns = 'Unnamed: 0', inplace = True)

# %%
# Inspection de la structure de `df`

df.head()
# Out:
#             MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# Date
# 2007-11-01      8.0     24.3       0.0          3.4       6.3           30.0
# 2007-11-02     14.0     26.9       3.6          4.4       9.7           39.0
# 2007-11-03     13.7     23.4       3.6          5.8       3.3           85.0
# 2007-11-04     13.3     15.5      39.8          7.2       9.1           54.0
# 2007-11-05      7.6     16.1       2.8          5.6      10.6           50.0
#
#             WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  Month  \
# Date                                                              ...
# 2007-11-01           6.0          20.0         68.0         29.0  ...     11
# 2007-11-02           4.0          17.0         80.0         36.0  ...     11
# 2007-11-03           6.0           6.0         82.0         69.0  ...     11
# 2007-11-04          30.0          24.0         62.0         56.0  ...     11
# 2007-11-05          20.0          28.0         68.0         49.0  ...     11
#
#             Day  LocationNum  WindGustDirNum  WindDir9amNum  WindDir3pmNum  \
# Date
# 2007-11-01    1           15        2.356194       3.926991       2.356194
# 2007-11-02    2           15        0.392699       0.000000       3.141593
# 2007-11-03    3           15        2.356194       1.570796       1.178097
# 2007-11-04    4           15        2.356194       2.748894       3.141593
# 2007-11-05    5           15        5.105088       5.105088       5.890486
#
#              Latitude   Longitude  CodeRegionNum  NonMesNum
# Date
# 2007-11-01 -35.297591  149.101268              1          2
# 2007-11-02 -35.297591  149.101268              1          2
# 2007-11-03 -35.297591  149.101268              1          2
# 2007-11-04 -35.297591  149.101268              1          2
# 2007-11-05 -35.297591  149.101268              1          2
#
# [5 rows x 29 columns]

# %% [markdown]
# ## 2. Découpage des données

# %%
# Découpage de `df` sur l'axe des colonnes : séparation des variables explicatives (`data`) et cible (`target`)

data = df.drop(columns = "RainTomorrow")
target = df["RainTomorrow"]

# %%
# Découpage de `data` et de `target` sur l'axe des lignes : séparation des jeux d'entraînement (`*_train`) et de test (`*_test`) avec le splitter `TimeSeriesSplit`

from sklearn.model_selection import TimeSeriesSplit

tss = TimeSeriesSplit(n_splits = 5) ## Nous fixons le paramètre `n_splits` à 5 afin d'avoir une répartition de 80 / 20 entre les jeux d'entraînement et de test, respectivement.

for train_index, test_index in tss.split(data):
    X_train, X_test = data.iloc[train_index, :], data.iloc[test_index,:]
    y_train, y_test = target.iloc[train_index], target.iloc[test_index]

# %% [markdown]
# ## 3. Conversion des données

# %%
X_train.shape
# Out:
# (117323, 28)

# %%
# Scale de X_train, X_test:
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Oversample avec SMOTE
smote = SMOTE(random_state = 12, n_jobs = n_coeurs)
X_sm, y_sm = smote.fit_resample(X_train, y_train)
# Out:
# C:\Users\AlexW\anaconda3\envs\projet_meteo\Lib\site-packages\imblearn\over_sampling\_smote\base.py:336: FutureWarning: The parameter `n_jobs` has been deprecated in 0.10 and will be removed in 0.12. You can pass an nearest neighbors estimator where `n_jobs` is already set instead.
#   warnings.warn(

# %%
X_sm.shape
# Out:
# (182934, 28)

# %%
# Récupération des dimensions

X_train_d1, X_train_d2 = X_sm.shape
X_test_d1, X_test_d2 = X_test.shape

# Conversion des DataFrames `X` en arrays de 3 dimensions

X_train_np = X_sm.reshape(X_train_d1, X_train_d2, 1)
X_test_np = X_test.reshape(X_test_d1, X_test_d2, 1)

# Conversion des Series `y` en arrays de 1 dimension

y_train_np = y_sm.to_numpy()
y_test_np = y_test.to_numpy()

# %% [markdown]
# ## 4. Modélisation

# %% [markdown]
# La méthode TSF (_time series forest_) appartient à la famille des approches de classification des séries temporelles basées sur les **intervalles** (_interval-based approaches_).
#
# Il s'agit d'une adaptation aux séries temporelles de l'algorithme _random forest classifier_ (RCF).
#
# La TSF utilise un arbre de décision pour chaque intervalle, les arbres de décision agrégés constituant la forêt. Chaque arbre de décision est un modèle d'apprentissage automatique qui attribue ensuite une classe à son intervalle de données. Étant donné que les arbres de décision s'entraînent sur un intervalle différent de la série temporelle globale, ils peuvent ne pas produire la même classification, d'où la nécessité du vote d'ensemble à la fin du processus.
#
# Des études expérimentales ont démontré que la TSF est capable de produire de meilleurs résultats que la KNN + DTW.
#
# Références :
# 1. https://developer.ibm.com/learningpaths/get-started-time-series-classification-api/what-is-time-series-classification
# 2. https://towardsdatascience.com/a-brief-introduction-to-time-series-classification-algorithms-7b4284d31b97
# 3. https://arxiv.org/abs/1602.01711

# %%
# Instanciation d'un modèle classificateur via un Pipeline

from sklearn.pipeline import Pipeline
from sktime.transformations.panel.compose import ColumnConcatenator
from sktime.classification.interval_based import TimeSeriesForestClassifier

steps = [
    ("concatenate", ColumnConcatenator()), ## Cette étape permet de transformer les jeux de données multivariées en univariées afin qu'ils puissent être traités par `TimeSeriesForestClassifier`.
    ("classify", TimeSeriesForestClassifier()),
]

clf_rf_ts = Pipeline(steps)

# %%
# Récupération des paramètres initiaux de la TSF

clf_rf_ts["classify"].get_params()
# Out:
# {'inner_series_length': None,
#  'min_interval': 3,
#  'n_estimators': 200,
#  'n_jobs': 1,
#  'random_state': None}

# %%
# Entraînement du modèle
clf_rf_ts.fit(X_train_np, y_train_np)
# Out:
# Pipeline(steps=[('concatenate', ColumnConcatenator()),
#                 ('classify', TimeSeriesForestClassifier())])

# %%
dump(clf_rf_ts, 'saves/model_saves/save_TSF_Alex_scale_SMOTE.joblib')
# Out:
# ['saves/model_saves/save_TSF_Alex_scale_SMOTE.joblib']

# %%
# Récupération des paramètres ajustés de la TSF

clf_rf_ts["classify"].get_fitted_params()
# Out:
# {'classes': array([0, 1], dtype=int64),
#  'intervals': [array([[13, 26],
#          [ 4, 25],
#          [21, 24],
#          [ 5, 18],
#          [ 1, 13]]),
#   array([[23, 26],
#          [23, 26],
#          [21, 24],
#          [ 8, 26],
#          [ 3, 20]]),
#   array([[ 9, 24],
#          [ 5,  8],
#          [10, 13],
#          [ 5, 25],
#          [ 7, 24]]),
#   array([[14, 19],
#          [ 0,  5],
#          [18, 22],
#          [ 2,  6],
#          [17, 20]]),
#   array([[19, 24],
#          [22, 25],
#          [ 5, 14],
#          [16, 21],
#          [ 6, 14]]),
#   array([[ 0,  9],
#          [22, 26],
#          [15, 22],
#          [11, 18],
#          [20, 23]]),
#   array([[ 4, 24],
#          [18, 21],
#          [11, 14],
#          [ 1, 14],
#          [22, 25]]),
#   array([[ 0, 19],
#          [12, 17],
#          [14, 18],
#          [10, 22],
#          [18, 22]]),
#   array([[ 2, 19],
#          [ 6, 17],
#          [17, 23],
#          [13, 24],
#          [10, 18]]),
#   array([[10, 21],
#          [20, 23],
#          [15, 25],
#          [ 1, 24],
#          [ 5, 16]]),
#   array([[14, 23],
#          [11, 23],
#          [14, 19],
#          [10, 13],
#          [23, 26]]),
#   array([[22, 25],
#          [19, 22],
#          [18, 24],
#          [ 2,  8],
#          [ 7, 15]]),
#   array([[24, 27],
#          [22, 25],
#          [10, 15],
#          [ 9, 17],
#          [ 8, 11]]),
#   array([[19, 23],
#          [16, 19],
#          [20, 24],
#          [13, 16],
#          [ 2,  5]]),
#   array([[18, 21],
#          [15, 20],
#          [22, 25],
#          [23, 26],
#          [17, 20]]),
#   array([[ 5, 12],
#          [22, 26],
#          [14, 20],
#          [14, 20],
#          [15, 25]]),
#   array([[20, 23],
#          [16, 19],
#          [19, 22],
#          [17, 20],
#          [22, 25]]),
#   array([[ 6, 23],
#          [21, 26],
#          [22, 26],
#          [22, 25],
#          [20, 23]]),
#   array([[ 5, 19],
#          [ 0,  3],
#          [15, 18],
#          [ 5, 18],
#          [18, 21]]),
#   array([[12, 24],
#          [21, 24],
#          [ 2, 20],
#          [11, 14],
#          [17, 21]]),
#   array([[ 6,  9],
#          [ 1,  6],
#          [19, 26],
#          [ 9, 15],
#          [15, 18]]),
#   array([[22, 25],
#          [22, 25],
#          [ 1,  4],
#          [ 4, 16],
#          [ 9, 15]]),
#   array([[ 7, 20],
#          [20, 23],
#          [16, 23],
#          [16, 19],
#          [ 7, 10]]),
#   array([[18, 25],
#          [ 1, 19],
#          [21, 26],
#          [ 9, 17],
#          [15, 21]]),
#   array([[20, 23],
#          [ 4, 19],
#          [ 2,  5],
#          [ 8, 17],
#          [11, 19]]),
#   array([[ 1, 26],
#          [10, 15],
#          [24, 27],
#          [ 0, 21],
#          [18, 21]]),
#   array([[ 6,  9],
#          [19, 22],
#          [11, 19],
#          [ 8, 20],
#          [ 7, 10]]),
#   array([[13, 26],
#          [16, 25],
#          [21, 26],
#          [17, 22],
#          [ 0, 20]]),
#   array([[10, 23],
#          [15, 25],
#          [19, 23],
#          [ 3, 23],
#          [ 9, 13]]),
#   array([[ 4, 12],
#          [16, 22],
#          [23, 26],
#          [ 1,  4],
#          [ 6, 24]]),
#   array([[ 8, 19],
#          [ 2, 14],
#          [15, 18],
#          [10, 13],
#          [12, 26]]),
#   array([[ 3, 21],
#          [11, 14],
#          [24, 27],
#          [20, 26],
#          [18, 23]]),
#   array([[24, 27],
#          [15, 23],
#          [24, 27],
#          [23, 26],
#          [20, 23]]),
#   array([[17, 20],
#          [ 9, 19],
#          [ 2, 25],
#          [12, 15],
#          [ 5,  8]]),
#   array([[ 7, 21],
#          [ 4, 12],
#          [14, 20],
#          [ 1, 12],
#          [14, 17]]),
#   array([[14, 18],
#          [13, 23],
#          [21, 24],
#          [ 5, 14],
#          [23, 26]]),
#   array([[ 3,  6],
#          [ 4, 20],
#          [23, 26],
#          [23, 26],
#          [23, 26]]),
#   array([[ 6, 25],
#          [ 8, 11],
#          [17, 20],
#          [16, 23],
#          [ 6, 21]]),
#   array([[13, 16],
#          [ 7, 24],
#          [14, 21],
#          [23, 26],
#          [ 7, 23]]),
#   array([[17, 20],
#          [16, 25],
#          [21, 24],
#          [17, 20],
#          [ 8, 25]]),
#   array([[22, 25],
#          [17, 25],
#          [21, 24],
#          [ 2, 17],
#          [21, 26]]),
#   array([[ 9, 12],
#          [24, 27],
#          [ 5, 16],
#          [12, 25],
#          [21, 24]]),
#   array([[21, 24],
#          [ 2,  5],
#          [24, 27],
#          [15, 23],
#          [16, 19]]),
#   array([[24, 27],
#          [20, 25],
#          [ 1,  4],
#          [14, 17],
#          [19, 22]]),
#   array([[ 3,  6],
#          [22, 25],
#          [16, 21],
#          [18, 24],
#          [ 0, 15]]),
#   array([[12, 23],
#          [19, 22],
#          [10, 16],
#          [ 2, 26],
#          [18, 21]]),
#   array([[22, 25],
#          [14, 24],
#          [13, 19],
#          [ 6,  9],
#          [10, 17]]),
#   array([[ 6, 23],
#          [17, 20],
#          [ 4, 15],
#          [ 7, 14],
#          [ 1,  8]]),
#   array([[16, 19],
#          [ 5, 11],
#          [ 6, 14],
#          [ 8, 11],
#          [22, 25]]),
#   array([[22, 25],
#          [17, 20],
#          [19, 23],
#          [19, 25],
#          [ 8, 22]]),
#   array([[ 8, 17],
#          [ 6, 20],
#          [ 1,  4],
#          [10, 13],
#          [ 9, 22]]),
#   array([[17, 20],
#          [ 0,  9],
#          [ 3, 21],
#          [16, 19],
#          [14, 17]]),
#   array([[24, 27],
#          [22, 25],
#          [ 3,  6],
#          [24, 27],
#          [ 1, 13]]),
#   array([[ 6, 18],
#          [22, 25],
#          [ 4,  7],
#          [15, 18],
#          [24, 27]]),
#   array([[10, 16],
#          [20, 23],
#          [18, 25],
#          [ 5, 18],
#          [19, 22]]),
#   array([[ 1,  4],
#          [23, 26],
#          [ 3, 15],
#          [10, 13],
#          [ 8, 20]]),
#   array([[10, 21],
#          [19, 26],
#          [24, 27],
#          [10, 24],
#          [ 7, 26]]),
#   array([[24, 27],
#          [14, 24],
#          [24, 27],
#          [23, 26],
#          [12, 20]]),
#   array([[17, 20],
#          [17, 23],
#          [ 6, 13],
#          [11, 14],
#          [ 0, 10]]),
#   array([[18, 22],
#          [23, 26],
#          [18, 21],
#          [ 7, 14],
#          [21, 24]]),
#   array([[23, 26],
#          [12, 17],
#          [24, 27],
#          [ 0, 26],
#          [23, 26]]),
#   array([[ 7, 24],
#          [23, 26],
#          [14, 21],
#          [ 7, 10],
#          [ 4, 22]]),
#   array([[22, 25],
#          [22, 26],
#          [20, 25],
#          [ 0,  3],
#          [22, 25]]),
#   array([[14, 21],
#          [ 5, 26],
#          [19, 25],
#          [19, 22],
#          [ 2, 26]]),
#   array([[ 8, 21],
#          [ 0,  5],
#          [19, 22],
#          [14, 22],
#          [ 9, 18]]),
#   array([[ 1, 20],
#          [18, 24],
#          [17, 24],
#          [23, 26],
#          [17, 26]]),
#   array([[ 2, 10],
#          [20, 24],
#          [ 1,  4],
#          [19, 26],
#          [23, 26]]),
#   array([[ 5,  9],
#          [17, 20],
#          [ 7, 14],
#          [10, 20],
#          [24, 27]]),
#   array([[10, 24],
#          [ 0, 25],
#          [ 6, 10],
#          [ 4, 19],
#          [22, 26]]),
#   array([[11, 24],
#          [ 7, 13],
#          [13, 26],
#          [ 2, 14],
#          [ 0, 18]]),
#   array([[23, 26],
#          [ 2,  5],
#          [ 1, 12],
#          [11, 21],
#          [ 4,  8]]),
#   array([[10, 26],
#          [24, 27],
#          [10, 18],
#          [19, 23],
#          [17, 21]]),
#   array([[ 7, 17],
#          [19, 22],
#          [ 4, 13],
#          [12, 21],
#          [23, 26]]),
#   array([[ 0, 12],
#          [20, 25],
#          [24, 27],
#          [15, 18],
#          [14, 17]]),
#   array([[ 9, 14],
#          [16, 20],
#          [17, 20],
#          [ 0, 18],
#          [15, 18]]),
#   array([[ 5, 18],
#          [ 9, 25],
#          [ 8, 11],
#          [10, 13],
#          [ 9, 23]]),
#   array([[23, 26],
#          [ 0, 20],
#          [13, 23],
#          [18, 22],
#          [19, 26]]),
#   array([[14, 24],
#          [22, 26],
#          [21, 25],
#          [18, 24],
#          [ 6, 23]]),
#   array([[15, 19],
#          [ 9, 23],
#          [15, 18],
#          [10, 16],
#          [17, 20]]),
#   array([[ 6, 23],
#          [20, 25],
#          [ 0,  3],
#          [ 8, 20],
#          [23, 26]]),
#   array([[21, 24],
#          [15, 24],
#          [ 2, 18],
#          [15, 21],
#          [13, 16]]),
#   array([[10, 25],
#          [ 3, 24],
#          [16, 19],
#          [12, 26],
#          [15, 18]]),
#   array([[12, 15],
#          [ 6, 24],
#          [15, 19],
#          [ 4, 15],
#          [23, 26]]),
#   array([[ 6,  9],
#          [20, 25],
#          [21, 26],
#          [ 6, 20],
#          [ 0,  3]]),
#   array([[ 1, 19],
#          [13, 25],
#          [ 5,  8],
#          [16, 22],
#          [19, 22]]),
#   array([[ 7, 10],
#          [ 0, 21],
#          [23, 26],
#          [13, 25],
#          [ 4,  7]]),
#   array([[12, 20],
#          [ 3,  6],
#          [ 6, 26],
#          [15, 18],
#          [ 6, 16]]),
#   array([[24, 27],
#          [15, 18],
#          [22, 26],
#          [ 7, 15],
#          [16, 25]]),
#   array([[ 7, 14],
#          [10, 24],
#          [ 8, 11],
#          [ 9, 14],
#          [24, 27]]),
#   array([[ 5, 16],
#          [ 4, 25],
#          [23, 26],
#          [ 5, 14],
#          [18, 21]]),
#   array([[ 1, 11],
#          [18, 22],
#          [14, 24],
#          [ 2, 13],
#          [ 7, 10]]),
#   array([[19, 22],
#          [11, 25],
#          [ 2,  9],
#          [24, 27],
#          [14, 19]]),
#   array([[ 4, 20],
#          [21, 24],
#          [ 3, 10],
#          [16, 25],
#          [15, 20]]),
#   array([[24, 27],
#          [ 8, 16],
#          [15, 18],
#          [ 3, 16],
#          [10, 24]]),
#   array([[ 6, 22],
#          [ 5, 11],
#          [21, 24],
#          [21, 24],
#          [20, 23]]),
#   array([[ 5, 20],
#          [22, 25],
#          [12, 18],
#          [19, 22],
#          [24, 27]]),
#   array([[22, 25],
#          [13, 19],
#          [16, 20],
#          [ 8, 22],
#          [ 2, 25]]),
#   array([[ 4, 12],
#          [ 4, 11],
#          [11, 14],
#          [24, 27],
#          [ 9, 23]]),
#   array([[19, 22],
#          [ 2,  9],
#          [ 4, 18],
#          [20, 23],
#          [16, 21]]),
#   array([[20, 23],
#          [23, 26],
#          [ 6, 23],
#          [13, 20],
#          [15, 18]]),
#   array([[ 9, 20],
#          [ 1, 15],
#          [23, 26],
#          [ 3, 25],
#          [19, 22]]),
#   array([[12, 15],
#          [ 8, 13],
#          [11, 18],
#          [ 7, 19],
#          [ 5,  8]]),
#   array([[16, 23],
#          [ 4, 26],
#          [15, 18],
#          [ 3, 17],
#          [16, 19]]),
#   array([[22, 26],
#          [ 9, 12],
#          [10, 17],
#          [10, 23],
#          [ 2,  5]]),
#   array([[ 4, 14],
#          [22, 25],
#          [ 4,  9],
#          [18, 23],
#          [12, 16]]),
#   array([[10, 25],
#          [ 7, 21],
#          [11, 26],
#          [ 6, 22],
#          [22, 25]]),
#   array([[20, 25],
#          [23, 26],
#          [24, 27],
#          [ 2,  7],
#          [ 7, 10]]),
#   array([[14, 23],
#          [ 2, 11],
#          [ 5, 10],
#          [ 8, 24],
#          [10, 18]]),
#   array([[ 5, 12],
#          [ 1,  4],
#          [22, 25],
#          [12, 15],
#          [ 5, 14]]),
#   array([[11, 23],
#          [12, 20],
#          [24, 27],
#          [ 1, 22],
#          [ 8, 11]]),
#   array([[14, 21],
#          [ 0, 25],
#          [ 6, 18],
#          [12, 15],
#          [22, 25]]),
#   array([[19, 22],
#          [21, 24],
#          [ 2, 20],
#          [21, 24],
#          [ 5, 20]]),
#   array([[16, 19],
#          [ 6, 18],
#          [18, 23],
#          [ 9, 24],
#          [14, 20]]),
#   array([[ 5, 25],
#          [11, 26],
#          [13, 16],
#          [ 4, 10],
#          [17, 26]]),
#   array([[ 4,  9],
#          [17, 20],
#          [11, 14],
#          [ 3, 22],
#          [ 9, 15]]),
#   array([[13, 18],
#          [ 4, 22],
#          [ 3, 17],
#          [ 5,  9],
#          [12, 23]]),
#   array([[19, 25],
#          [19, 25],
#          [ 9, 18],
#          [17, 20],
#          [22, 25]]),
#   array([[ 4, 17],
#          [ 8, 12],
#          [17, 21],
#          [15, 26],
#          [16, 22]]),
#   array([[14, 17],
#          [ 3,  6],
#          [15, 25],
#          [14, 17],
#          [ 2,  5]]),
#   array([[19, 25],
#          [ 4,  7],
#          [11, 14],
#          [ 9, 17],
#          [18, 24]]),
#   array([[15, 23],
#          [17, 26],
#          [18, 23],
#          [15, 18],
#          [19, 22]]),
#   array([[ 4, 21],
#          [11, 14],
#          [23, 26],
#          [21, 24],
#          [ 4, 24]]),
#   array([[10, 26],
#          [ 2, 10],
#          [12, 23],
#          [12, 15],
#          [ 8, 25]]),
#   array([[ 2, 10],
#          [15, 18],
#          [ 4, 10],
#          [17, 22],
#          [ 7, 10]]),
#   array([[24, 27],
#          [23, 26],
#          [10, 25],
#          [ 0,  4],
#          [22, 25]]),
#   array([[18, 21],
#          [24, 27],
#          [ 5, 16],
#          [ 6, 16],
#          [11, 16]]),
#   array([[11, 22],
#          [ 8, 11],
#          [19, 22],
#          [ 5, 19],
#          [16, 19]]),
#   array([[ 9, 12],
#          [16, 23],
#          [24, 27],
#          [16, 24],
#          [ 0, 23]]),
#   array([[15, 21],
#          [ 9, 20],
#          [12, 17],
#          [ 3, 13],
#          [21, 25]]),
#   array([[17, 21],
#          [ 8, 15],
#          [ 8, 20],
#          [ 9, 20],
#          [ 3,  6]]),
#   array([[22, 25],
#          [16, 23],
#          [ 3, 10],
#          [12, 15],
#          [ 4, 10]]),
#   array([[21, 24],
#          [ 7, 11],
#          [ 5,  9],
#          [16, 19],
#          [21, 25]]),
#   array([[12, 26],
#          [ 3, 23],
#          [12, 23],
#          [24, 27],
#          [11, 14]]),
#   array([[ 3, 10],
#          [13, 25],
#          [24, 27],
#          [23, 26],
#          [24, 27]]),
#   array([[ 5, 24],
#          [ 1, 13],
#          [14, 17],
#          [15, 20],
#          [22, 26]]),
#   array([[ 5, 13],
#          [17, 20],
#          [18, 23],
#          [12, 19],
#          [ 6, 17]]),
#   array([[15, 24],
#          [23, 26],
#          [15, 21],
#          [ 2, 26],
#          [ 2, 13]]),
#   array([[ 1, 10],
#          [ 6, 15],
#          [ 6, 25],
#          [19, 22],
#          [23, 26]]),
#   array([[11, 19],
#          [16, 22],
#          [22, 25],
#          [ 4, 22],
#          [ 2, 22]]),
#   array([[14, 20],
#          [ 6,  9],
#          [13, 18],
#          [14, 21],
#          [22, 25]]),
#   array([[22, 26],
#          [20, 24],
#          [ 9, 12],
#          [11, 24],
#          [11, 14]]),
#   array([[ 1,  9],
#          [ 4, 20],
#          [20, 23],
#          [ 0, 17],
#          [ 6,  9]]),
#   array([[ 1,  4],
#          [19, 24],
#          [19, 22],
#          [14, 20],
#          [24, 27]]),
#   array([[ 3, 23],
#          [10, 19],
#          [ 0, 18],
#          [ 4, 13],
#          [15, 18]]),
#   array([[23, 26],
#          [ 5, 24],
#          [ 5, 19],
#          [19, 24],
#          [22, 25]]),
#   array([[18, 21],
#          [ 7, 21],
#          [13, 23],
#          [10, 26],
#          [ 3, 24]]),
#   array([[23, 26],
#          [ 1, 20],
#          [ 7, 10],
#          [ 9, 16],
#          [20, 24]]),
#   array([[ 2,  8],
#          [ 0, 10],
#          [11, 17],
#          [21, 24],
#          [19, 22]]),
#   array([[ 4, 12],
#          [ 1,  8],
#          [22, 25],
#          [ 3, 11],
#          [ 6, 16]]),
#   array([[ 8, 13],
#          [ 0,  7],
#          [ 8, 15],
#          [ 2, 21],
#          [14, 23]]),
#   array([[23, 26],
#          [ 3, 25],
#          [23, 26],
#          [22, 25],
#          [14, 21]]),
#   array([[ 3, 12],
#          [17, 20],
#          [ 0,  5],
#          [22, 25],
#          [22, 25]]),
#   array([[13, 16],
#          [ 4, 22],
#          [23, 26],
#          [22, 26],
#          [11, 15]]),
#   array([[ 2, 15],
#          [ 4, 26],
#          [ 0, 18],
#          [20, 23],
#          [22, 25]]),
#   array([[ 6, 20],
#          [16, 26],
#          [ 3,  8],
#          [ 4, 16],
#          [ 0, 12]]),
#   array([[ 0, 19],
#          [10, 14],
#          [24, 27],
#          [19, 24],
#          [24, 27]]),
#   array([[ 4,  8],
#          [16, 19],
#          [ 3, 18],
#          [14, 24],
#          [24, 27]]),
#   array([[12, 15],
#          [20, 26],
#          [ 1,  4],
#          [12, 15],
#          [12, 22]]),
#   array([[24, 27],
#          [ 5, 24],
#          [11, 16],
#          [17, 26],
#          [21, 24]]),
#   array([[14, 18],
#          [17, 26],
#          [ 4, 15],
#          [12, 25],
#          [17, 26]]),
#   array([[ 9, 19],
#          [ 4, 10],
#          [ 2,  9],
#          [ 8, 11],
#          [ 6,  9]]),
#   array([[13, 20],
#          [ 9, 24],
#          [15, 18],
#          [ 0, 14],
#          [ 3,  6]]),
#   array([[12, 25],
#          [ 6, 13],
#          [20, 23],
#          [ 3,  6],
#          [ 3,  6]]),
#   array([[ 1, 14],
#          [11, 24],
#          [20, 23],
#          [ 3, 23],
#          [11, 16]]),
#   array([[ 1, 25],
#          [ 1, 19],
#          [20, 23],
#          [ 3, 22],
#          [19, 26]]),
#   array([[ 0, 17],
#          [12, 15],
#          [13, 16],
#          [ 5, 17],
#          [11, 26]]),
#   array([[16, 22],
#          [11, 14],
#          [ 8, 11],
#          [18, 21],
#          [16, 19]]),
#   array([[13, 16],
#          [21, 26],
#          [13, 21],
#          [ 0, 22],
#          [22, 25]]),
#   array([[ 5, 10],
#          [ 1, 17],
#          [23, 26],
#          [ 3, 10],
#          [16, 20]]),
#   array([[ 8, 13],
#          [ 2,  9],
#          [18, 22],
#          [14, 21],
#          [12, 20]]),
#   array([[21, 24],
#          [ 3,  6],
#          [ 8, 11],
#          [ 8, 14],
#          [21, 24]]),
#   array([[17, 20],
#          [ 3,  8],
#          [ 9, 17],
#          [ 0, 13],
#          [24, 27]]),
#   array([[12, 24],
#          [10, 13],
#          [ 4, 14],
#          [ 6, 12],
#          [ 4, 26]]),
#   array([[ 8, 14],
#          [10, 13],
#          [ 2, 23],
#          [15, 18],
#          [ 9, 22]]),
#   array([[ 7, 10],
#          [12, 21],
#          [15, 21],
#          [18, 21],
#          [19, 23]]),
#   array([[ 4, 14],
#          [13, 22],
#          [ 8, 26],
#          [11, 26],
#          [ 1, 21]]),
#   array([[11, 14],
#          [ 3, 14],
#          [21, 26],
#          [22, 25],
#          [ 2, 26]]),
#   array([[14, 21],
#          [ 9, 12],
#          [15, 22],
#          [18, 21],
#          [ 6, 21]]),
#   array([[15, 20],
#          [13, 18],
#          [19, 26],
#          [13, 16],
#          [ 1, 12]]),
#   array([[10, 24],
#          [11, 22],
#          [ 7, 17],
#          [ 7, 10],
#          [23, 26]]),
#   array([[20, 23],
#          [ 1,  8],
#          [12, 16],
#          [10, 13],
#          [19, 23]]),
#   array([[12, 24],
#          [15, 18],
#          [10, 13],
#          [15, 21],
#          [17, 21]]),
#   array([[10, 18],
#          [14, 22],
#          [21, 25],
#          [24, 27],
#          [ 1, 17]]),
#   array([[16, 25],
#          [20, 25],
#          [ 1, 14],
#          [17, 23],
#          [15, 18]]),
#   array([[14, 23],
#          [19, 23],
#          [ 2,  5],
#          [ 2, 13],
#          [ 5, 25]]),
#   array([[21, 24],
#          [ 5, 15],
#          [ 6, 21],
#          [18, 21],
#          [ 1, 19]]),
#   array([[17, 25],
#          [10, 15],
#          [23, 26],
#          [13, 18],
#          [ 2, 20]]),
#   array([[12, 15],
#          [24, 27],
#          [17, 20],
#          [10, 13],
#          [22, 26]]),
#   array([[ 0,  3],
#          [ 4, 24],
#          [ 0,  3],
#          [19, 22],
#          [19, 25]]),
#   array([[23, 26],
#          [ 1,  7],
#          [10, 13],
#          [13, 16],
#          [12, 25]]),
#   array([[ 5, 14],
#          [ 9, 14],
#          [ 1, 24],
#          [ 7, 26],
#          [13, 20]]),
#   array([[20, 23],
#          [17, 20],
#          [ 3, 14],
#          [ 8, 16],
#          [10, 23]]),
#   array([[20, 23],
#          [ 2, 15],
#          [ 8, 12],
#          [13, 19],
#          [ 6, 23]]),
#   array([[ 3, 17],
#          [11, 15],
#          [19, 22],
#          [ 9, 12],
#          [ 1,  6]]),
#   array([[21, 24],
#          [22, 25],
#          [ 8, 23],
#          [10, 13],
#          [ 0, 20]]),
#   array([[11, 26],
#          [ 7, 17],
#          [ 3, 20],
#          [ 9, 17],
#          [ 4,  7]]),
#   array([[ 0, 15],
#          [23, 26],
#          [ 2, 26],
#          [16, 19],
#          [ 9, 20]]),
#   array([[23, 26],
#          [ 7, 15],
#          [24, 27],
#          [19, 22],
#          [18, 21]]),
#   array([[12, 15],
#          [16, 26],
#          [ 7, 13],
#          [ 5, 24],
#          [15, 21]]),
#   array([[22, 25],
#          [11, 14],
#          [18, 25],
#          [23, 26],
#          [ 9, 25]])],
#  'estimators': [DecisionTreeClassifier(criterion='entropy', random_state=1217262671),
#   DecisionTreeClassifier(criterion='entropy', random_state=1298117595),
#   DecisionTreeClassifier(criterion='entropy', random_state=511477702),
#   DecisionTreeClassifier(criterion='entropy', random_state=915494104),
#   DecisionTreeClassifier(criterion='entropy', random_state=280438583),
#   DecisionTreeClassifier(criterion='entropy', random_state=1936078439),
#   DecisionTreeClassifier(criterion='entropy', random_state=849269969),
#   DecisionTreeClassifier(criterion='entropy', random_state=1331115697),
#   DecisionTreeClassifier(criterion='entropy', random_state=371912607),
#   DecisionTreeClassifier(criterion='entropy', random_state=527649276),
#   DecisionTreeClassifier(criterion='entropy', random_state=1527707329),
#   DecisionTreeClassifier(criterion='entropy', random_state=1253616462),
#   DecisionTreeClassifier(criterion='entropy', random_state=842588337),
#   DecisionTreeClassifier(criterion='entropy', random_state=1914990076),
#   DecisionTreeClassifier(criterion='entropy', random_state=1174043122),
#   DecisionTreeClassifier(criterion='entropy', random_state=1632970711),
#   DecisionTreeClassifier(criterion='entropy', random_state=382978819),
#   DecisionTreeClassifier(criterion='entropy', random_state=2056488532),
#   DecisionTreeClassifier(criterion='entropy', random_state=1257405911),
#   DecisionTreeClassifier(criterion='entropy', random_state=948692393),
#   DecisionTreeClassifier(criterion='entropy', random_state=1737049947),
#   DecisionTreeClassifier(criterion='entropy', random_state=1833815550),
#   DecisionTreeClassifier(criterion='entropy', random_state=1360741626),
#   DecisionTreeClassifier(criterion='entropy', random_state=1357190709),
#   DecisionTreeClassifier(criterion='entropy', random_state=1293523471),
#   DecisionTreeClassifier(criterion='entropy', random_state=1759120525),
#   DecisionTreeClassifier(criterion='entropy', random_state=1886944918),
#   DecisionTreeClassifier(criterion='entropy', random_state=1208032851),
#   DecisionTreeClassifier(criterion='entropy', random_state=2130471773),
#   DecisionTreeClassifier(criterion='entropy', random_state=666717713),
#   DecisionTreeClassifier(criterion='entropy', random_state=145097395),
#   DecisionTreeClassifier(criterion='entropy', random_state=1314002813),
#   DecisionTreeClassifier(criterion='entropy', random_state=465145473),
#   DecisionTreeClassifier(criterion='entropy', random_state=356819061),
#   DecisionTreeClassifier(criterion='entropy', random_state=1690799165),
#   DecisionTreeClassifier(criterion='entropy', random_state=1712173497),
#   DecisionTreeClassifier(criterion='entropy', random_state=1208803049),
#   DecisionTreeClassifier(criterion='entropy', random_state=1223513907),
#   DecisionTreeClassifier(criterion='entropy', random_state=426249039),
#   DecisionTreeClassifier(criterion='entropy', random_state=1181451359),
#   DecisionTreeClassifier(criterion='entropy', random_state=2076639008),
#   DecisionTreeClassifier(criterion='entropy', random_state=2135079279),
#   DecisionTreeClassifier(criterion='entropy', random_state=215579543),
#   DecisionTreeClassifier(criterion='entropy', random_state=1972575622),
#   DecisionTreeClassifier(criterion='entropy', random_state=1196775611),
#   DecisionTreeClassifier(criterion='entropy', random_state=1174615090),
#   DecisionTreeClassifier(criterion='entropy', random_state=794498966),
#   DecisionTreeClassifier(criterion='entropy', random_state=1895777043),
#   DecisionTreeClassifier(criterion='entropy', random_state=331568347),
#   DecisionTreeClassifier(criterion='entropy', random_state=686909699),
#   DecisionTreeClassifier(criterion='entropy', random_state=1735578574),
#   DecisionTreeClassifier(criterion='entropy', random_state=1724580392),
#   DecisionTreeClassifier(criterion='entropy', random_state=1337784827),
#   DecisionTreeClassifier(criterion='entropy', random_state=1592188048),
#   DecisionTreeClassifier(criterion='entropy', random_state=1135183467),
#   DecisionTreeClassifier(criterion='entropy', random_state=122195081),
#   DecisionTreeClassifier(criterion='entropy', random_state=1204836633),
#   DecisionTreeClassifier(criterion='entropy', random_state=1361189114),
#   DecisionTreeClassifier(criterion='entropy', random_state=1433482396),
#   DecisionTreeClassifier(criterion='entropy', random_state=1378562102),
#   DecisionTreeClassifier(criterion='entropy', random_state=2132502693),
#   DecisionTreeClassifier(criterion='entropy', random_state=1042155028),
#   DecisionTreeClassifier(criterion='entropy', random_state=1453546750),
#   DecisionTreeClassifier(criterion='entropy', random_state=1459262859),
#   DecisionTreeClassifier(criterion='entropy', random_state=475205437),
#   DecisionTreeClassifier(criterion='entropy', random_state=393334442),
#   DecisionTreeClassifier(criterion='entropy', random_state=1045102641),
#   DecisionTreeClassifier(criterion='entropy', random_state=1856873388),
#   DecisionTreeClassifier(criterion='entropy', random_state=317334490),
#   DecisionTreeClassifier(criterion='entropy', random_state=437815873),
#   DecisionTreeClassifier(criterion='entropy', random_state=1643238322),
#   DecisionTreeClassifier(criterion='entropy', random_state=74432967),
#   DecisionTreeClassifier(criterion='entropy', random_state=1715205097),
#   DecisionTreeClassifier(criterion='entropy', random_state=2121197886),
#   DecisionTreeClassifier(criterion='entropy', random_state=1608652647),
#   DecisionTreeClassifier(criterion='entropy', random_state=72688487),
#   DecisionTreeClassifier(criterion='entropy', random_state=307443697),
#   DecisionTreeClassifier(criterion='entropy', random_state=524780824),
#   DecisionTreeClassifier(criterion='entropy', random_state=1323502234),
#   DecisionTreeClassifier(criterion='entropy', random_state=1002204738),
#   DecisionTreeClassifier(criterion='entropy', random_state=1033100015),
#   DecisionTreeClassifier(criterion='entropy', random_state=1775648725),
#   DecisionTreeClassifier(criterion='entropy', random_state=1909247869),
#   DecisionTreeClassifier(criterion='entropy', random_state=756010139),
#   DecisionTreeClassifier(criterion='entropy', random_state=1793360730),
#   DecisionTreeClassifier(criterion='entropy', random_state=489519592),
#   DecisionTreeClassifier(criterion='entropy', random_state=1640203045),
#   DecisionTreeClassifier(criterion='entropy', random_state=1258767178),
#   DecisionTreeClassifier(criterion='entropy', random_state=59708975),
#   DecisionTreeClassifier(criterion='entropy', random_state=304717503),
#   DecisionTreeClassifier(criterion='entropy', random_state=736917790),
#   DecisionTreeClassifier(criterion='entropy', random_state=86019055),
#   DecisionTreeClassifier(criterion='entropy', random_state=1215011796),
#   DecisionTreeClassifier(criterion='entropy', random_state=125847718),
#   DecisionTreeClassifier(criterion='entropy', random_state=659092624),
#   DecisionTreeClassifier(criterion='entropy', random_state=966700162),
#   DecisionTreeClassifier(criterion='entropy', random_state=1024030540),
#   DecisionTreeClassifier(criterion='entropy', random_state=1541926423),
#   DecisionTreeClassifier(criterion='entropy', random_state=358059295),
#   DecisionTreeClassifier(criterion='entropy', random_state=1536406848),
#   DecisionTreeClassifier(criterion='entropy', random_state=50652302),
#   DecisionTreeClassifier(criterion='entropy', random_state=346545529),
#   DecisionTreeClassifier(criterion='entropy', random_state=390247504),
#   DecisionTreeClassifier(criterion='entropy', random_state=346967913),
#   DecisionTreeClassifier(criterion='entropy', random_state=368811193),
#   DecisionTreeClassifier(criterion='entropy', random_state=932626395),
#   DecisionTreeClassifier(criterion='entropy', random_state=305538575),
#   DecisionTreeClassifier(criterion='entropy', random_state=1514789747),
#   DecisionTreeClassifier(criterion='entropy', random_state=452338355),
#   DecisionTreeClassifier(criterion='entropy', random_state=2135214301),
#   DecisionTreeClassifier(criterion='entropy', random_state=384721754),
#   DecisionTreeClassifier(criterion='entropy', random_state=1297783771),
#   DecisionTreeClassifier(criterion='entropy', random_state=1515949842),
#   DecisionTreeClassifier(criterion='entropy', random_state=719466338),
#   DecisionTreeClassifier(criterion='entropy', random_state=1159356278),
#   DecisionTreeClassifier(criterion='entropy', random_state=493085554),
#   DecisionTreeClassifier(criterion='entropy', random_state=2036250284),
#   DecisionTreeClassifier(criterion='entropy', random_state=1030390794),
#   DecisionTreeClassifier(criterion='entropy', random_state=1618128142),
#   DecisionTreeClassifier(criterion='entropy', random_state=2103290036),
#   DecisionTreeClassifier(criterion='entropy', random_state=301762148),
#   DecisionTreeClassifier(criterion='entropy', random_state=1488672053),
#   DecisionTreeClassifier(criterion='entropy', random_state=2014302912),
#   DecisionTreeClassifier(criterion='entropy', random_state=1021269485),
#   DecisionTreeClassifier(criterion='entropy', random_state=2030182271),
#   DecisionTreeClassifier(criterion='entropy', random_state=1688053241),
#   DecisionTreeClassifier(criterion='entropy', random_state=314332824),
#   DecisionTreeClassifier(criterion='entropy', random_state=1566437246),
#   DecisionTreeClassifier(criterion='entropy', random_state=1405019906),
#   DecisionTreeClassifier(criterion='entropy', random_state=157826),
#   DecisionTreeClassifier(criterion='entropy', random_state=80316330),
#   DecisionTreeClassifier(criterion='entropy', random_state=1424488417),
#   DecisionTreeClassifier(criterion='entropy', random_state=2053462952),
#   DecisionTreeClassifier(criterion='entropy', random_state=1948122968),
#   DecisionTreeClassifier(criterion='entropy', random_state=1723729281),
#   DecisionTreeClassifier(criterion='entropy', random_state=734200693),
#   DecisionTreeClassifier(criterion='entropy', random_state=426446988),
#   DecisionTreeClassifier(criterion='entropy', random_state=1496954020),
#   DecisionTreeClassifier(criterion='entropy', random_state=499050586),
#   DecisionTreeClassifier(criterion='entropy', random_state=1482303056),
#   DecisionTreeClassifier(criterion='entropy', random_state=365302699),
#   DecisionTreeClassifier(criterion='entropy', random_state=2142048074),
#   DecisionTreeClassifier(criterion='entropy', random_state=1700808427),
#   DecisionTreeClassifier(criterion='entropy', random_state=1703001943),
#   DecisionTreeClassifier(criterion='entropy', random_state=849509882),
#   DecisionTreeClassifier(criterion='entropy', random_state=1517192819),
#   DecisionTreeClassifier(criterion='entropy', random_state=1555437861),
#   DecisionTreeClassifier(criterion='entropy', random_state=1437491495),
#   DecisionTreeClassifier(criterion='entropy', random_state=1241810519),
#   DecisionTreeClassifier(criterion='entropy', random_state=1946729701),
#   DecisionTreeClassifier(criterion='entropy', random_state=1802761730),
#   DecisionTreeClassifier(criterion='entropy', random_state=2036865216),
#   DecisionTreeClassifier(criterion='entropy', random_state=2092288130),
#   DecisionTreeClassifier(criterion='entropy', random_state=333335119),
#   DecisionTreeClassifier(criterion='entropy', random_state=1474353145),
#   DecisionTreeClassifier(criterion='entropy', random_state=136746787),
#   DecisionTreeClassifier(criterion='entropy', random_state=1013509470),
#   DecisionTreeClassifier(criterion='entropy', random_state=1595889271),
#   DecisionTreeClassifier(criterion='entropy', random_state=565943930),
#   DecisionTreeClassifier(criterion='entropy', random_state=1679357132),
#   DecisionTreeClassifier(criterion='entropy', random_state=600166861),
#   DecisionTreeClassifier(criterion='entropy', random_state=1105604209),
#   DecisionTreeClassifier(criterion='entropy', random_state=895133553),
#   DecisionTreeClassifier(criterion='entropy', random_state=631117275),
#   DecisionTreeClassifier(criterion='entropy', random_state=1997345140),
#   DecisionTreeClassifier(criterion='entropy', random_state=1590059963),
#   DecisionTreeClassifier(criterion='entropy', random_state=1858141951),
#   DecisionTreeClassifier(criterion='entropy', random_state=102865025),
#   DecisionTreeClassifier(criterion='entropy', random_state=911919711),
#   DecisionTreeClassifier(criterion='entropy', random_state=669764690),
#   DecisionTreeClassifier(criterion='entropy', random_state=70095111),
#   DecisionTreeClassifier(criterion='entropy', random_state=228180954),
#   DecisionTreeClassifier(criterion='entropy', random_state=413592255),
#   DecisionTreeClassifier(criterion='entropy', random_state=990485641),
#   DecisionTreeClassifier(criterion='entropy', random_state=64350496),
#   DecisionTreeClassifier(criterion='entropy', random_state=5357751),
#   DecisionTreeClassifier(criterion='entropy', random_state=287011463),
#   DecisionTreeClassifier(criterion='entropy', random_state=1085264466),
#   DecisionTreeClassifier(criterion='entropy', random_state=109120816),
#   DecisionTreeClassifier(criterion='entropy', random_state=1038471397),
#   DecisionTreeClassifier(criterion='entropy', random_state=894218859),
#   DecisionTreeClassifier(criterion='entropy', random_state=2119637875),
#   DecisionTreeClassifier(criterion='entropy', random_state=643166818),
#   DecisionTreeClassifier(criterion='entropy', random_state=514161253),
#   DecisionTreeClassifier(criterion='entropy', random_state=1767533605),
#   DecisionTreeClassifier(criterion='entropy', random_state=1862774930),
#   DecisionTreeClassifier(criterion='entropy', random_state=1493865954),
#   DecisionTreeClassifier(criterion='entropy', random_state=1030044161),
#   DecisionTreeClassifier(criterion='entropy', random_state=1401527659),
#   DecisionTreeClassifier(criterion='entropy', random_state=1742672892),
#   DecisionTreeClassifier(criterion='entropy', random_state=1035791122),
#   DecisionTreeClassifier(criterion='entropy', random_state=857362333),
#   DecisionTreeClassifier(criterion='entropy', random_state=946316866),
#   DecisionTreeClassifier(criterion='entropy', random_state=680189223),
#   DecisionTreeClassifier(criterion='entropy', random_state=2070052183),
#   DecisionTreeClassifier(criterion='entropy', random_state=1858969965),
#   DecisionTreeClassifier(criterion='entropy', random_state=86554983),
#   DecisionTreeClassifier(criterion='entropy', random_state=1409568150),
#   DecisionTreeClassifier(criterion='entropy', random_state=1657334482),
#   DecisionTreeClassifier(criterion='entropy', random_state=397230360)],
#  'n_classes': 2,
#  'fit_time': 1098752}

# %%
X_test_np.shape
# Out:
# (23464, 28, 1)

# %%
# Réalisation des prédictions
clf_rf_ts = load('saves/model_saves/save_TSF_Alex_scale_SMOTE.joblib')
y_pred = clf_rf_ts.predict(X_test_np)

# %% [markdown]
# ## 5. Évaluation

# %%
# Élaboration de la matrice de confusion

pd.crosstab(y_test, y_pred, rownames = ["Classe réelle"], colnames = ["Classe prédite"])
# Out:
# Classe prédite      0     1
# Classe réelle
# 0               16492  1627
# 1                2436  2909

# %%
# Élaboration du rapport de classification

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89     18119
#            1       0.64      0.54      0.59      5345
#
#     accuracy                           0.83     23464
#    macro avg       0.76      0.73      0.74     23464
# weighted avg       0.82      0.83      0.82     23464

# %% [markdown]
# # 6. Roc

# %%
clf_rf_ts = load('saves/model_saves/save_TSF_Alex_scale_SMOTE.joblib')
# On fait la prediction sur test:
preds = clf_rf_ts.predict_proba(X_test_np)

################################ On cherche le meilleur seuil:
# Création des arrays fpr, tpr et seuils:
fpr, tpr, seuils = roc_curve(y_test, preds[:, 1], pos_label = 1) # on choisit pred[:, 1] pour prendre parmi les deux probas celle qui correspond à la classe positive.

# Pour calculer l'aire sous la courbe ROC:
roc_auc = auc(x = fpr, y = tpr)

# Comment trouver le meilleur seuil?
dist = 1
for (x, y, s) in zip(fpr, tpr, seuils):
    dist1 = np.square(x**2 + (y-1)**2)
    if dist1 < dist:
        dist = dist1
        seuil_best = 1 - s # pourquoi dois-je faire ça?
        fpr_best = x
        tpr_best = y

#print("Meilleur seuil:", seuil_best, "meilleur fpr:", fpr_best, "meilleur tpr:", tpr_best)

# Tracé de ROC:
plt.figure(figsize = (7, 7))
plt.axis('equal')

plt.scatter(fpr_best, tpr_best, s = 60, c = 'red', marker = '*', alpha = 1, label = "Meilleur seuil = %0.3f" % seuil_best)
plt.plot(fpr, tpr, c = 'orange', label = 'Modèle TSF (auc = %0.2f)' % roc_auc)
plt.plot(fpr, fpr, 'b--', label = 'Aléatoire (auc = 0.5)')

plt.title('Courbe Roc TSF scale_SMOTE')
plt.xlabel('Taux de faux positifs :fpr')
plt.ylabel('Taux de vrais positifs :tpr')
plt.legend()

plt.show()

################### On applique le meilleur seuil:
y_pred = pd.Series(np.where(preds[:, 1] > seuil_best, 1, 0))

print("Report TSF scale_SMOTE", "\n", classification_report(y_test, y_pred,  digits = 2))
print(confusion_matrix(y_test, y_pred))
# Out:
# Report TSF scale_SMOTE
#                precision    recall  f1-score   support
#
#            0       0.83      0.97      0.89     18119
#            1       0.76      0.31      0.44      5345
#
#     accuracy                           0.82     23464
#    macro avg       0.79      0.64      0.67     23464
# weighted avg       0.81      0.82      0.79     23464
#
# [[17584   535]
#  [ 3676  1669]]

# %% [markdown]
# Bilan: faut pas faire d'opti roc sur ce modèle non plus! :)
