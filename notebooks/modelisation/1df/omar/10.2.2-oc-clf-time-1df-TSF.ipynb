# %% [markdown]
# # **Classification** des **séries temporelles** avec `sktime`

# %% [markdown]
# ## Métadonnées

# %% [markdown]
# - **Expérience nº :** 10.2.2
# - **Date :** 16/11/2023
# - **Heure :** 16:33
# - **Données :** `model_weatherAUS.csv`
# - **Tri :** index chronologique
# - **Découpage :** `TimeSeriesSplit`
# - **Mise à l'échelle :** non
# - **Rééquilibrage :** non
# - **Conversion :** `numpyfy`
# - **Algorithme :** TSF

# %% [markdown]
# ## Sommaire

# %% [markdown]
# 1. Initialisation
# 2. Découpage
# 3. Conversion
# 4. Modélisation
# 5. Évaluation

# %% [markdown]
# ## 1. Initialisation

# %%
# Importation des bibliothèques et modules nécessaires au fonctionnement de ce notebook

import pandas as pd
import numpy as np

from sklearn.metrics import classification_report

# %%
# Importation du jeu de données et enregistrement dans le DataFrame `df`

df = pd.read_csv("../../../data/1df/model_weatherAUS.csv", index_col = 1).sort_index()
df = df.drop(columns = "Unnamed: 0")

# %%
# Inspection de la structure de `df`

df.head()
# Out:
#             MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# Date
# 2007-11-01      8.0     24.3       0.0          3.4       6.3           30.0
# 2007-11-02     14.0     26.9       3.6          4.4       9.7           39.0
# 2007-11-03     13.7     23.4       3.6          5.8       3.3           85.0
# 2007-11-04     13.3     15.5      39.8          7.2       9.1           54.0
# 2007-11-05      7.6     16.1       2.8          5.6      10.6           50.0
#
#             WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  Month  \
# Date                                                              ...
# 2007-11-01           6.0          20.0         68.0         29.0  ...     11
# 2007-11-02           4.0          17.0         80.0         36.0  ...     11
# 2007-11-03           6.0           6.0         82.0         69.0  ...     11
# 2007-11-04          30.0          24.0         62.0         56.0  ...     11
# 2007-11-05          20.0          28.0         68.0         49.0  ...     11
#
#             Day  LocationNum  WindGustDirNum  WindDir9amNum  WindDir3pmNum  \
# Date
# 2007-11-01    1           15        2.356194       3.926991       2.356194
# 2007-11-02    2           15        0.392699       0.000000       3.141593
# 2007-11-03    3           15        2.356194       1.570796       1.178097
# 2007-11-04    4           15        2.356194       2.748894       3.141593
# 2007-11-05    5           15        5.105088       5.105088       5.890486
#
#              Latitude   Longitude  CodeRegionNum  NonMesNum
# Date
# 2007-11-01 -35.297591  149.101268              1          2
# 2007-11-02 -35.297591  149.101268              1          2
# 2007-11-03 -35.297591  149.101268              1          2
# 2007-11-04 -35.297591  149.101268              1          2
# 2007-11-05 -35.297591  149.101268              1          2
#
# [5 rows x 29 columns]

# %%
# Inspection de la structure de `df`

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 140787 entries, 2007-11-01 to 2017-06-25
# Data columns (total 29 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   MinTemp         140787 non-null  float64
#  1   MaxTemp         140787 non-null  float64
#  2   Rainfall        140787 non-null  float64
#  3   Evaporation     140787 non-null  float64
#  4   Sunshine        140787 non-null  float64
#  5   WindGustSpeed   140787 non-null  float64
#  6   WindSpeed9am    140787 non-null  float64
#  7   WindSpeed3pm    140787 non-null  float64
#  8   Humidity9am     140787 non-null  float64
#  9   Humidity3pm     140787 non-null  float64
#  10  Pressure9am     140787 non-null  float64
#  11  Pressure3pm     140787 non-null  float64
#  12  Cloud9am        140787 non-null  float64
#  13  Cloud3pm        140787 non-null  float64
#  14  Temp9am         140787 non-null  float64
#  15  Temp3pm         140787 non-null  float64
#  16  RainToday       140787 non-null  int64
#  17  RainTomorrow    140787 non-null  int64
#  18  Year            140787 non-null  int64
#  19  Month           140787 non-null  int64
#  20  Day             140787 non-null  int64
#  21  LocationNum     140787 non-null  int64
#  22  WindGustDirNum  140787 non-null  float64
#  23  WindDir9amNum   140787 non-null  float64
#  24  WindDir3pmNum   140787 non-null  float64
#  25  Latitude        140787 non-null  float64
#  26  Longitude       140787 non-null  float64
#  27  CodeRegionNum   140787 non-null  int64
#  28  NonMesNum       140787 non-null  int64
# dtypes: float64(21), int64(8)
# memory usage: 32.2+ MB

# %% [markdown]
# ## 2. Découpage

# %%
# Découpage de `df` sur l'axe des colonnes : séparation des variables explicatives (`data`) et cible (`target`)

data = df.drop(columns = "RainTomorrow")
target = df["RainTomorrow"]

# %%
# Découpage de `data` et de `target` sur l'axe des lignes : séparation des jeux d'entraînement (`*_train`) et de test (`*_test`) avec le splitter `TimeSeriesSplit`

from sklearn.model_selection import TimeSeriesSplit

tss = TimeSeriesSplit(n_splits = 5) ## Nous fixons le paramètre `n_splits` à 5 afin d'avoir une répartition de 80 / 20 entre les jeux d'entraînement et de test, respectivement.

for train_index, test_index in tss.split(data):
    X_train, X_test = data.iloc[train_index, :], data.iloc[test_index,:]
    y_train, y_test = target.iloc[train_index], target.iloc[test_index]

# %% [markdown]
# ## 3. Conversion

# %%
# Importation de la fonction artisanale `numpyfy`

from numpyfy import numpyfy

# %%
# Application de la fonction `numpyfy` aux 4 jeux de données issus du découpage effectué par le splitter `TimeSeriesSplit` afin de les convertir en arrays et ainsi les rendre compatibles avec `sktime`

X_train, X_test, y_train, y_test = numpyfy(X_train, X_test, y_train, y_test)

# %% [markdown]
# ## 4. Modélisation

# %%
# Instanciation d'un modèle classificateur via un Pipeline

from sklearn.pipeline import Pipeline
from sktime.transformations.panel.compose import ColumnConcatenator
from sktime.classification.interval_based import TimeSeriesForestClassifier

steps = [
    ("concatenate", ColumnConcatenator()), ## Cette étape permet de transformer les jeux de données multivariées en univariées afin qu'ils puissent être traités par `TimeSeriesForestClassifier`.
    ("classify", TimeSeriesForestClassifier()),
]

clf_rf_ts = Pipeline(steps)

# %%
# Récupération des paramètres initiaux de la TSF

clf_rf_ts["classify"].get_params()
# Out:
# {'min_interval': 3, 'n_estimators': 200, 'n_jobs': 1, 'random_state': None}

# %%
# Entraînement du modèle

clf_rf_ts.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('concatenate', ColumnConcatenator()),
#                 ('classify', TimeSeriesForestClassifier())])

# %%
# Récupération des paramètres ajustés de la TSF

clf_rf_ts["classify"].get_fitted_params()
# Out:
# {'classes': array([0, 1]),
#  'intervals': [array([[ 5, 16],
#          [20, 25],
#          [ 8, 11],
#          [13, 16],
#          [15, 18]]),
#   array([[20, 25],
#          [11, 26],
#          [ 4, 21],
#          [22, 25],
#          [19, 26]]),
#   array([[15, 26],
#          [ 1, 10],
#          [15, 25],
#          [ 6, 24],
#          [ 2, 14]]),
#   array([[ 1, 10],
#          [14, 23],
#          [ 5, 17],
#          [ 6, 12],
#          [17, 26]]),
#   array([[20, 26],
#          [17, 20],
#          [11, 14],
#          [24, 27],
#          [21, 25]]),
#   array([[12, 19],
#          [14, 17],
#          [16, 19],
#          [17, 25],
#          [ 1,  7]]),
#   array([[ 7, 20],
#          [ 3,  7],
#          [ 0, 16],
#          [15, 23],
#          [11, 17]]),
#   array([[24, 27],
#          [23, 26],
#          [ 2, 15],
#          [ 0, 17],
#          [19, 26]]),
#   array([[ 7, 10],
#          [24, 27],
#          [ 1, 17],
#          [21, 25],
#          [21, 24]]),
#   array([[16, 24],
#          [17, 20],
#          [ 3, 14],
#          [ 2, 17],
#          [20, 23]]),
#   array([[22, 26],
#          [21, 24],
#          [16, 24],
#          [16, 20],
#          [14, 20]]),
#   array([[12, 22],
#          [13, 21],
#          [ 4, 18],
#          [23, 26],
#          [10, 13]]),
#   array([[21, 24],
#          [21, 24],
#          [ 0, 18],
#          [ 0,  3],
#          [23, 26]]),
#   array([[ 0, 13],
#          [ 9, 16],
#          [17, 21],
#          [ 5,  9],
#          [18, 21]]),
#   array([[22, 26],
#          [19, 23],
#          [ 7, 24],
#          [ 4, 22],
#          [ 6, 17]]),
#   array([[ 6, 12],
#          [ 1, 19],
#          [23, 26],
#          [ 2, 24],
#          [ 8, 11]]),
#   array([[11, 21],
#          [20, 23],
#          [20, 23],
#          [16, 22],
#          [ 8, 23]]),
#   array([[23, 26],
#          [18, 22],
#          [22, 26],
#          [ 1, 25],
#          [14, 19]]),
#   array([[12, 15],
#          [12, 22],
#          [ 4, 10],
#          [22, 25],
#          [24, 27]]),
#   array([[15, 18],
#          [14, 24],
#          [ 4,  7],
#          [19, 22],
#          [ 8, 21]]),
#   array([[10, 17],
#          [ 8, 15],
#          [14, 20],
#          [ 7, 14],
#          [ 2, 19]]),
#   array([[ 3, 16],
#          [16, 19],
#          [21, 24],
#          [14, 24],
#          [ 3, 17]]),
#   array([[14, 21],
#          [ 3, 13],
#          [21, 24],
#          [ 1,  8],
#          [ 2, 23]]),
#   array([[ 4, 10],
#          [ 4, 17],
#          [10, 13],
#          [ 0, 10],
#          [14, 19]]),
#   array([[22, 25],
#          [ 8, 16],
#          [16, 22],
#          [17, 20],
#          [ 8, 11]]),
#   array([[ 8, 11],
#          [ 3, 15],
#          [ 7, 16],
#          [22, 26],
#          [ 5,  8]]),
#   array([[ 6, 12],
#          [17, 20],
#          [17, 20],
#          [12, 18],
#          [23, 26]]),
#   array([[15, 20],
#          [ 8, 11],
#          [22, 25],
#          [10, 15],
#          [ 4, 14]]),
#   array([[ 5, 19],
#          [ 0,  3],
#          [15, 24],
#          [14, 17],
#          [11, 22]]),
#   array([[13, 19],
#          [ 6, 25],
#          [18, 21],
#          [17, 21],
#          [14, 23]]),
#   array([[10, 24],
#          [23, 26],
#          [16, 19],
#          [19, 22],
#          [17, 21]]),
#   array([[ 0,  3],
#          [19, 24],
#          [21, 24],
#          [21, 24],
#          [10, 21]]),
#   array([[ 1,  4],
#          [19, 22],
#          [ 3, 16],
#          [10, 18],
#          [19, 23]]),
#   array([[ 4,  7],
#          [ 0, 11],
#          [15, 24],
#          [18, 24],
#          [ 5, 15]]),
#   array([[ 2, 20],
#          [24, 27],
#          [ 4, 19],
#          [17, 20],
#          [11, 24]]),
#   array([[18, 21],
#          [10, 18],
#          [ 4, 24],
#          [13, 24],
#          [21, 24]]),
#   array([[18, 21],
#          [17, 20],
#          [14, 25],
#          [13, 16],
#          [24, 27]]),
#   array([[ 3, 11],
#          [ 9, 20],
#          [16, 22],
#          [17, 26],
#          [21, 25]]),
#   array([[24, 27],
#          [10, 13],
#          [23, 26],
#          [21, 24],
#          [ 4,  7]]),
#   array([[ 1, 21],
#          [ 1, 10],
#          [21, 26],
#          [24, 27],
#          [12, 15]]),
#   array([[21, 26],
#          [ 3,  6],
#          [16, 26],
#          [ 5,  8],
#          [11, 21]]),
#   array([[13, 22],
#          [ 9, 18],
#          [10, 13],
#          [14, 24],
#          [10, 24]]),
#   array([[17, 25],
#          [ 6, 15],
#          [ 3, 14],
#          [ 6, 24],
#          [22, 26]]),
#   array([[16, 24],
#          [ 0,  6],
#          [18, 21],
#          [ 4, 16],
#          [16, 24]]),
#   array([[ 6, 10],
#          [ 6, 22],
#          [14, 20],
#          [ 8, 11],
#          [14, 18]]),
#   array([[ 2,  5],
#          [13, 26],
#          [20, 24],
#          [18, 21],
#          [11, 14]]),
#   array([[17, 26],
#          [11, 26],
#          [13, 22],
#          [14, 17],
#          [11, 16]]),
#   array([[ 4, 18],
#          [ 3,  8],
#          [ 1, 22],
#          [20, 23],
#          [10, 23]]),
#   array([[17, 22],
#          [12, 15],
#          [23, 26],
#          [14, 17],
#          [16, 21]]),
#   array([[ 3, 20],
#          [ 9, 15],
#          [20, 23],
#          [ 7, 13],
#          [11, 21]]),
#   array([[24, 27],
#          [19, 22],
#          [ 3, 17],
#          [16, 22],
#          [ 6, 21]]),
#   array([[12, 19],
#          [ 8, 11],
#          [17, 20],
#          [19, 22],
#          [20, 23]]),
#   array([[ 9, 17],
#          [ 7, 10],
#          [17, 21],
#          [22, 25],
#          [22, 26]]),
#   array([[24, 27],
#          [11, 22],
#          [23, 26],
#          [10, 18],
#          [ 9, 12]]),
#   array([[14, 17],
#          [23, 26],
#          [ 9, 17],
#          [14, 19],
#          [17, 23]]),
#   array([[ 8, 11],
#          [ 7, 25],
#          [17, 20],
#          [ 9, 12],
#          [11, 20]]),
#   array([[10, 21],
#          [10, 24],
#          [17, 26],
#          [ 0,  5],
#          [ 2, 20]]),
#   array([[ 5, 25],
#          [ 7, 11],
#          [ 3,  6],
#          [10, 14],
#          [24, 27]]),
#   array([[ 5, 22],
#          [15, 21],
#          [21, 24],
#          [ 3, 18],
#          [ 2, 25]]),
#   array([[14, 23],
#          [19, 26],
#          [21, 25],
#          [ 9, 16],
#          [16, 19]]),
#   array([[24, 27],
#          [18, 22],
#          [ 8, 13],
#          [21, 24],
#          [ 2, 14]]),
#   array([[ 8, 11],
#          [23, 26],
#          [ 7, 14],
#          [23, 26],
#          [ 8, 12]]),
#   array([[ 4,  7],
#          [ 1,  7],
#          [14, 22],
#          [15, 26],
#          [18, 21]]),
#   array([[ 2, 17],
#          [22, 25],
#          [ 0, 11],
#          [10, 20],
#          [21, 25]]),
#   array([[ 4, 18],
#          [ 7, 14],
#          [13, 25],
#          [ 7, 17],
#          [ 4, 25]]),
#   array([[ 0,  6],
#          [ 8, 11],
#          [ 1, 10],
#          [ 0, 18],
#          [24, 27]]),
#   array([[ 7, 10],
#          [11, 14],
#          [ 1, 22],
#          [11, 19],
#          [ 0, 24]]),
#   array([[ 1, 21],
#          [22, 25],
#          [14, 17],
#          [ 1, 11],
#          [12, 15]]),
#   array([[10, 20],
#          [17, 25],
#          [ 1,  9],
#          [ 3, 15],
#          [15, 19]]),
#   array([[ 0,  3],
#          [22, 26],
#          [10, 17],
#          [16, 19],
#          [16, 26]]),
#   array([[ 9, 17],
#          [15, 23],
#          [ 1, 22],
#          [19, 23],
#          [ 5, 20]]),
#   array([[11, 22],
#          [11, 16],
#          [24, 27],
#          [20, 23],
#          [20, 25]]),
#   array([[22, 25],
#          [10, 13],
#          [12, 15],
#          [14, 17],
#          [ 0, 23]]),
#   array([[ 0,  3],
#          [21, 25],
#          [13, 23],
#          [ 2, 16],
#          [ 2, 22]]),
#   array([[ 3,  6],
#          [14, 23],
#          [12, 16],
#          [15, 26],
#          [12, 15]]),
#   array([[12, 22],
#          [20, 24],
#          [ 8, 13],
#          [ 7, 10],
#          [15, 25]]),
#   array([[22, 26],
#          [ 0,  8],
#          [23, 26],
#          [18, 21],
#          [ 6, 15]]),
#   array([[17, 21],
#          [15, 21],
#          [22, 25],
#          [23, 26],
#          [15, 22]]),
#   array([[ 9, 16],
#          [24, 27],
#          [ 6, 15],
#          [23, 26],
#          [17, 20]]),
#   array([[16, 26],
#          [ 6, 19],
#          [14, 21],
#          [21, 24],
#          [19, 26]]),
#   array([[10, 16],
#          [15, 18],
#          [13, 20],
#          [13, 19],
#          [24, 27]]),
#   array([[15, 25],
#          [14, 21],
#          [ 8, 19],
#          [ 6,  9],
#          [ 8, 25]]),
#   array([[21, 25],
#          [15, 18],
#          [11, 23],
#          [21, 26],
#          [20, 25]]),
#   array([[11, 22],
#          [18, 21],
#          [15, 25],
#          [ 3, 12],
#          [15, 20]]),
#   array([[ 8, 15],
#          [23, 26],
#          [14, 22],
#          [15, 18],
#          [20, 26]]),
#   array([[24, 27],
#          [ 8, 20],
#          [22, 25],
#          [16, 25],
#          [ 6,  9]]),
#   array([[14, 26],
#          [20, 23],
#          [23, 26],
#          [15, 18],
#          [ 8, 23]]),
#   array([[23, 26],
#          [14, 24],
#          [ 8, 25],
#          [13, 19],
#          [22, 25]]),
#   array([[ 9, 26],
#          [ 0, 26],
#          [23, 26],
#          [ 4,  9],
#          [ 2, 15]]),
#   array([[ 7, 18],
#          [ 2, 19],
#          [17, 23],
#          [ 1,  4],
#          [23, 26]]),
#   array([[20, 23],
#          [ 1, 16],
#          [13, 20],
#          [ 2, 11],
#          [17, 23]]),
#   array([[ 7, 10],
#          [14, 18],
#          [15, 25],
#          [16, 24],
#          [13, 26]]),
#   array([[ 3, 22],
#          [15, 25],
#          [ 9, 23],
#          [ 8, 15],
#          [11, 18]]),
#   array([[ 6,  9],
#          [20, 26],
#          [ 5, 19],
#          [20, 23],
#          [ 1,  9]]),
#   array([[21, 24],
#          [ 3, 11],
#          [ 9, 12],
#          [22, 25],
#          [17, 26]]),
#   array([[ 1, 17],
#          [13, 23],
#          [24, 27],
#          [10, 23],
#          [10, 17]]),
#   array([[22, 25],
#          [ 3, 16],
#          [ 4, 24],
#          [22, 25],
#          [ 8, 17]]),
#   array([[15, 19],
#          [20, 26],
#          [ 0,  3],
#          [20, 23],
#          [ 6,  9]]),
#   array([[19, 22],
#          [20, 25],
#          [ 4, 25],
#          [17, 20],
#          [ 5,  9]]),
#   array([[24, 27],
#          [23, 26],
#          [17, 20],
#          [21, 24],
#          [10, 16]]),
#   array([[ 5, 20],
#          [17, 26],
#          [ 3,  7],
#          [24, 27],
#          [15, 20]]),
#   array([[ 7, 22],
#          [ 8, 26],
#          [20, 24],
#          [ 1, 23],
#          [21, 24]]),
#   array([[19, 22],
#          [ 5,  8],
#          [17, 22],
#          [ 4, 14],
#          [14, 17]]),
#   array([[13, 16],
#          [10, 14],
#          [16, 26],
#          [ 5,  8],
#          [10, 20]]),
#   array([[ 3, 19],
#          [24, 27],
#          [ 2, 25],
#          [19, 22],
#          [ 7, 18]]),
#   array([[ 7, 19],
#          [11, 14],
#          [ 1, 26],
#          [ 2, 21],
#          [10, 13]]),
#   array([[14, 20],
#          [ 3,  6],
#          [12, 20],
#          [14, 24],
#          [16, 19]]),
#   array([[ 1, 24],
#          [ 6, 21],
#          [11, 20],
#          [17, 20],
#          [18, 22]]),
#   array([[ 5, 10],
#          [17, 20],
#          [22, 25],
#          [ 4,  7],
#          [ 5, 23]]),
#   array([[11, 26],
#          [16, 26],
#          [20, 25],
#          [10, 26],
#          [ 8, 12]]),
#   array([[17, 24],
#          [23, 26],
#          [15, 26],
#          [ 0, 24],
#          [11, 14]]),
#   array([[19, 23],
#          [21, 26],
#          [12, 24],
#          [19, 25],
#          [12, 15]]),
#   array([[10, 22],
#          [ 1, 18],
#          [20, 24],
#          [ 7, 16],
#          [ 0, 26]]),
#   array([[11, 19],
#          [ 6, 12],
#          [ 7, 20],
#          [ 8, 23],
#          [24, 27]]),
#   array([[ 0,  5],
#          [14, 20],
#          [ 9, 12],
#          [ 4, 24],
#          [10, 24]]),
#   array([[21, 24],
#          [ 2, 13],
#          [20, 23],
#          [ 4, 13],
#          [ 7, 23]]),
#   array([[17, 20],
#          [ 0, 24],
#          [ 1,  8],
#          [ 4, 16],
#          [16, 26]]),
#   array([[16, 26],
#          [ 9, 25],
#          [ 5,  8],
#          [18, 26],
#          [24, 27]]),
#   array([[15, 18],
#          [15, 18],
#          [18, 22],
#          [22, 25],
#          [19, 23]]),
#   array([[ 7, 26],
#          [20, 24],
#          [15, 20],
#          [ 9, 17],
#          [16, 25]]),
#   array([[ 0,  3],
#          [ 6, 14],
#          [14, 22],
#          [19, 24],
#          [20, 23]]),
#   array([[ 6,  9],
#          [ 9, 17],
#          [18, 23],
#          [10, 15],
#          [18, 21]]),
#   array([[22, 25],
#          [13, 16],
#          [ 4, 14],
#          [23, 26],
#          [ 6, 25]]),
#   array([[22, 25],
#          [18, 23],
#          [21, 26],
#          [ 9, 22],
#          [ 9, 18]]),
#   array([[15, 21],
#          [16, 21],
#          [21, 24],
#          [24, 27],
#          [17, 21]]),
#   array([[14, 25],
#          [12, 19],
#          [20, 23],
#          [ 7, 18],
#          [ 5, 18]]),
#   array([[ 2, 20],
#          [15, 22],
#          [17, 20],
#          [ 7, 21],
#          [23, 26]]),
#   array([[ 3, 11],
#          [18, 21],
#          [ 1, 23],
#          [ 6, 17],
#          [12, 19]]),
#   array([[24, 27],
#          [ 0, 16],
#          [15, 24],
#          [ 4,  7],
#          [10, 16]]),
#   array([[ 6,  9],
#          [15, 22],
#          [14, 18],
#          [ 0, 10],
#          [ 2, 15]]),
#   array([[17, 20],
#          [22, 25],
#          [12, 20],
#          [ 5,  8],
#          [24, 27]]),
#   array([[ 7, 10],
#          [ 5, 19],
#          [ 1, 15],
#          [18, 21],
#          [22, 25]]),
#   array([[ 6, 17],
#          [ 4, 22],
#          [19, 25],
#          [ 0, 11],
#          [14, 17]]),
#   array([[13, 16],
#          [17, 25],
#          [16, 25],
#          [ 3, 25],
#          [23, 26]]),
#   array([[ 2, 15],
#          [ 1,  9],
#          [23, 26],
#          [14, 24],
#          [14, 22]]),
#   array([[19, 22],
#          [ 7, 20],
#          [22, 26],
#          [20, 25],
#          [17, 20]]),
#   array([[13, 26],
#          [24, 27],
#          [12, 16],
#          [16, 19],
#          [ 7, 11]]),
#   array([[22, 25],
#          [ 7, 24],
#          [23, 26],
#          [ 3,  6],
#          [20, 23]]),
#   array([[17, 22],
#          [24, 27],
#          [10, 16],
#          [20, 23],
#          [12, 25]]),
#   array([[ 6, 23],
#          [ 4, 20],
#          [10, 17],
#          [ 6, 18],
#          [17, 22]]),
#   array([[19, 22],
#          [20, 23],
#          [17, 20],
#          [23, 26],
#          [18, 26]]),
#   array([[18, 26],
#          [ 6, 22],
#          [ 1, 21],
#          [ 8, 22],
#          [10, 26]]),
#   array([[17, 20],
#          [ 2,  5],
#          [14, 21],
#          [20, 23],
#          [14, 25]]),
#   array([[ 0, 24],
#          [20, 23],
#          [ 5, 10],
#          [17, 25],
#          [ 9, 25]]),
#   array([[ 4, 10],
#          [21, 26],
#          [14, 19],
#          [17, 23],
#          [14, 23]]),
#   array([[ 1,  5],
#          [ 5,  8],
#          [22, 25],
#          [21, 24],
#          [ 8, 15]]),
#   array([[20, 25],
#          [ 6, 14],
#          [21, 24],
#          [ 8, 19],
#          [17, 20]]),
#   array([[15, 22],
#          [22, 25],
#          [13, 22],
#          [12, 15],
#          [24, 27]]),
#   array([[21, 25],
#          [ 2,  8],
#          [20, 23],
#          [14, 24],
#          [12, 15]]),
#   array([[ 1, 26],
#          [ 9, 24],
#          [ 1, 11],
#          [ 0,  6],
#          [ 3, 19]]),
#   array([[ 1,  4],
#          [16, 19],
#          [22, 25],
#          [17, 24],
#          [ 5, 11]]),
#   array([[14, 21],
#          [18, 21],
#          [ 8, 11],
#          [ 7, 22],
#          [18, 21]]),
#   array([[ 3, 12],
#          [ 9, 26],
#          [20, 24],
#          [17, 25],
#          [ 6, 25]]),
#   array([[ 5, 15],
#          [ 7, 12],
#          [14, 24],
#          [13, 20],
#          [23, 26]]),
#   array([[ 8, 17],
#          [ 2,  5],
#          [21, 25],
#          [20, 24],
#          [20, 24]]),
#   array([[21, 24],
#          [ 0, 19],
#          [16, 21],
#          [ 2, 13],
#          [ 4,  9]]),
#   array([[18, 26],
#          [14, 17],
#          [20, 23],
#          [ 3,  6],
#          [ 2, 15]]),
#   array([[10, 23],
#          [13, 26],
#          [14, 21],
#          [ 6, 13],
#          [ 7, 18]]),
#   array([[24, 27],
#          [15, 22],
#          [ 4, 16],
#          [ 5,  8],
#          [ 6, 19]]),
#   array([[ 1, 15],
#          [23, 26],
#          [19, 24],
#          [23, 26],
#          [16, 19]]),
#   array([[ 0, 10],
#          [18, 21],
#          [14, 25],
#          [ 5, 10],
#          [11, 17]]),
#   array([[14, 21],
#          [ 6, 16],
#          [23, 26],
#          [14, 21],
#          [ 8, 23]]),
#   array([[ 3, 15],
#          [22, 25],
#          [23, 26],
#          [22, 25],
#          [ 1, 10]]),
#   array([[23, 26],
#          [ 0, 23],
#          [ 4,  7],
#          [12, 18],
#          [18, 25]]),
#   array([[ 4, 19],
#          [10, 23],
#          [12, 24],
#          [19, 23],
#          [ 9, 24]]),
#   array([[ 5, 26],
#          [ 6,  9],
#          [24, 27],
#          [19, 22],
#          [17, 21]]),
#   array([[21, 25],
#          [11, 20],
#          [ 1, 24],
#          [ 9, 21],
#          [24, 27]]),
#   array([[14, 20],
#          [ 7, 23],
#          [21, 24],
#          [ 3,  9],
#          [10, 17]]),
#   array([[14, 17],
#          [ 5,  8],
#          [16, 19],
#          [22, 25],
#          [ 3, 16]]),
#   array([[14, 18],
#          [ 3,  7],
#          [17, 24],
#          [ 4,  7],
#          [ 8, 18]]),
#   array([[ 9, 12],
#          [11, 22],
#          [ 5, 16],
#          [16, 19],
#          [24, 27]]),
#   array([[23, 26],
#          [ 0, 22],
#          [14, 17],
#          [15, 23],
#          [24, 27]]),
#   array([[15, 22],
#          [11, 18],
#          [13, 23],
#          [23, 26],
#          [15, 18]]),
#   array([[20, 23],
#          [21, 26],
#          [ 9, 12],
#          [13, 23],
#          [21, 24]]),
#   array([[24, 27],
#          [ 8, 11],
#          [ 9, 12],
#          [14, 17],
#          [22, 25]]),
#   array([[ 3,  6],
#          [13, 18],
#          [ 4, 25],
#          [18, 21],
#          [ 2, 24]]),
#   array([[19, 22],
#          [ 7, 11],
#          [10, 13],
#          [16, 24],
#          [ 7, 19]]),
#   array([[19, 22],
#          [ 8, 25],
#          [21, 26],
#          [10, 22],
#          [ 6,  9]]),
#   array([[ 8, 15],
#          [ 4, 16],
#          [ 8, 11],
#          [12, 22],
#          [ 6,  9]]),
#   array([[13, 19],
#          [ 4,  7],
#          [ 3, 16],
#          [ 5,  8],
#          [ 7, 18]]),
#   array([[ 0, 20],
#          [ 7, 10],
#          [ 6, 18],
#          [11, 24],
#          [ 6, 11]]),
#   array([[11, 22],
#          [ 7, 11],
#          [ 9, 26],
#          [17, 20],
#          [22, 25]]),
#   array([[ 9, 25],
#          [ 4, 16],
#          [ 3, 25],
#          [ 3, 26],
#          [ 2, 11]]),
#   array([[23, 26],
#          [16, 23],
#          [20, 23],
#          [ 8, 20],
#          [16, 19]]),
#   array([[ 9, 24],
#          [ 5, 16],
#          [17, 20],
#          [ 1, 20],
#          [10, 26]]),
#   array([[20, 23],
#          [23, 26],
#          [13, 17],
#          [ 2, 17],
#          [ 1, 18]]),
#   array([[24, 27],
#          [ 5, 17],
#          [ 7, 10],
#          [ 9, 12],
#          [23, 26]]),
#   array([[ 0, 18],
#          [13, 18],
#          [23, 26],
#          [13, 21],
#          [24, 27]]),
#   array([[ 4, 18],
#          [ 2, 19],
#          [20, 26],
#          [10, 20],
#          [24, 27]]),
#   array([[24, 27],
#          [ 4, 14],
#          [ 5, 18],
#          [15, 18],
#          [12, 19]]),
#   array([[20, 23],
#          [24, 27],
#          [24, 27],
#          [ 2, 18],
#          [ 3, 23]]),
#   array([[23, 26],
#          [ 0,  3],
#          [16, 23],
#          [ 5, 16],
#          [18, 21]]),
#   array([[21, 24],
#          [17, 20],
#          [22, 25],
#          [22, 25],
#          [21, 24]]),
#   array([[24, 27],
#          [ 5,  8],
#          [21, 26],
#          [20, 24],
#          [12, 25]]),
#   array([[16, 24],
#          [ 6, 15],
#          [ 1, 10],
#          [ 2,  9],
#          [ 5, 13]]),
#   array([[19, 26],
#          [15, 26],
#          [23, 26],
#          [ 1,  4],
#          [10, 17]]),
#   array([[13, 16],
#          [12, 19],
#          [22, 25],
#          [ 9, 18],
#          [14, 24]]),
#   array([[24, 27],
#          [ 5,  8],
#          [19, 22],
#          [13, 16],
#          [11, 14]]),
#   array([[19, 22],
#          [11, 24],
#          [ 0, 17],
#          [13, 24],
#          [24, 27]]),
#   array([[18, 24],
#          [ 7, 10],
#          [ 2, 25],
#          [13, 23],
#          [ 1, 22]])],
#  'estimators': [DecisionTreeClassifier(criterion='entropy', random_state=1847304261),
#   DecisionTreeClassifier(criterion='entropy', random_state=2113890815),
#   DecisionTreeClassifier(criterion='entropy', random_state=1880356171),
#   DecisionTreeClassifier(criterion='entropy', random_state=1775630829),
#   DecisionTreeClassifier(criterion='entropy', random_state=1273428565),
#   DecisionTreeClassifier(criterion='entropy', random_state=1422539534),
#   DecisionTreeClassifier(criterion='entropy', random_state=499155411),
#   DecisionTreeClassifier(criterion='entropy', random_state=1928207638),
#   DecisionTreeClassifier(criterion='entropy', random_state=436302730),
#   DecisionTreeClassifier(criterion='entropy', random_state=1678930370),
#   DecisionTreeClassifier(criterion='entropy', random_state=1296184469),
#   DecisionTreeClassifier(criterion='entropy', random_state=1307669102),
#   DecisionTreeClassifier(criterion='entropy', random_state=1113249120),
#   DecisionTreeClassifier(criterion='entropy', random_state=1042987105),
#   DecisionTreeClassifier(criterion='entropy', random_state=541671575),
#   DecisionTreeClassifier(criterion='entropy', random_state=518178658),
#   DecisionTreeClassifier(criterion='entropy', random_state=295040777),
#   DecisionTreeClassifier(criterion='entropy', random_state=398494999),
#   DecisionTreeClassifier(criterion='entropy', random_state=2104941034),
#   DecisionTreeClassifier(criterion='entropy', random_state=1572220352),
#   DecisionTreeClassifier(criterion='entropy', random_state=172000288),
#   DecisionTreeClassifier(criterion='entropy', random_state=750015492),
#   DecisionTreeClassifier(criterion='entropy', random_state=57052062),
#   DecisionTreeClassifier(criterion='entropy', random_state=1383743799),
#   DecisionTreeClassifier(criterion='entropy', random_state=783760519),
#   DecisionTreeClassifier(criterion='entropy', random_state=1753670032),
#   DecisionTreeClassifier(criterion='entropy', random_state=787282523),
#   DecisionTreeClassifier(criterion='entropy', random_state=943239143),
#   DecisionTreeClassifier(criterion='entropy', random_state=1839248666),
#   DecisionTreeClassifier(criterion='entropy', random_state=354146827),
#   DecisionTreeClassifier(criterion='entropy', random_state=401054867),
#   DecisionTreeClassifier(criterion='entropy', random_state=793436106),
#   DecisionTreeClassifier(criterion='entropy', random_state=459752959),
#   DecisionTreeClassifier(criterion='entropy', random_state=1882633583),
#   DecisionTreeClassifier(criterion='entropy', random_state=692538684),
#   DecisionTreeClassifier(criterion='entropy', random_state=2010666964),
#   DecisionTreeClassifier(criterion='entropy', random_state=122554188),
#   DecisionTreeClassifier(criterion='entropy', random_state=1229347280),
#   DecisionTreeClassifier(criterion='entropy', random_state=200639747),
#   DecisionTreeClassifier(criterion='entropy', random_state=130446748),
#   DecisionTreeClassifier(criterion='entropy', random_state=1563581949),
#   DecisionTreeClassifier(criterion='entropy', random_state=888410027),
#   DecisionTreeClassifier(criterion='entropy', random_state=96358774),
#   DecisionTreeClassifier(criterion='entropy', random_state=290761523),
#   DecisionTreeClassifier(criterion='entropy', random_state=184504092),
#   DecisionTreeClassifier(criterion='entropy', random_state=196151388),
#   DecisionTreeClassifier(criterion='entropy', random_state=940501348),
#   DecisionTreeClassifier(criterion='entropy', random_state=727833451),
#   DecisionTreeClassifier(criterion='entropy', random_state=1663541104),
#   DecisionTreeClassifier(criterion='entropy', random_state=72485169),
#   DecisionTreeClassifier(criterion='entropy', random_state=585718049),
#   DecisionTreeClassifier(criterion='entropy', random_state=383150036),
#   DecisionTreeClassifier(criterion='entropy', random_state=2046871449),
#   DecisionTreeClassifier(criterion='entropy', random_state=805672704),
#   DecisionTreeClassifier(criterion='entropy', random_state=1496948656),
#   DecisionTreeClassifier(criterion='entropy', random_state=497810483),
#   DecisionTreeClassifier(criterion='entropy', random_state=1618407985),
#   DecisionTreeClassifier(criterion='entropy', random_state=1513110053),
#   DecisionTreeClassifier(criterion='entropy', random_state=1300091852),
#   DecisionTreeClassifier(criterion='entropy', random_state=1194861217),
#   DecisionTreeClassifier(criterion='entropy', random_state=2121069340),
#   DecisionTreeClassifier(criterion='entropy', random_state=612507259),
#   DecisionTreeClassifier(criterion='entropy', random_state=678129249),
#   DecisionTreeClassifier(criterion='entropy', random_state=746660479),
#   DecisionTreeClassifier(criterion='entropy', random_state=741708632),
#   DecisionTreeClassifier(criterion='entropy', random_state=1941312459),
#   DecisionTreeClassifier(criterion='entropy', random_state=1861716984),
#   DecisionTreeClassifier(criterion='entropy', random_state=701129857),
#   DecisionTreeClassifier(criterion='entropy', random_state=1385218450),
#   DecisionTreeClassifier(criterion='entropy', random_state=1818432963),
#   DecisionTreeClassifier(criterion='entropy', random_state=1867517602),
#   DecisionTreeClassifier(criterion='entropy', random_state=679613980),
#   DecisionTreeClassifier(criterion='entropy', random_state=1450134107),
#   DecisionTreeClassifier(criterion='entropy', random_state=736540083),
#   DecisionTreeClassifier(criterion='entropy', random_state=1378016099),
#   DecisionTreeClassifier(criterion='entropy', random_state=194136645),
#   DecisionTreeClassifier(criterion='entropy', random_state=266829096),
#   DecisionTreeClassifier(criterion='entropy', random_state=918607147),
#   DecisionTreeClassifier(criterion='entropy', random_state=1182890028),
#   DecisionTreeClassifier(criterion='entropy', random_state=373269418),
#   DecisionTreeClassifier(criterion='entropy', random_state=1457071872),
#   DecisionTreeClassifier(criterion='entropy', random_state=629049843),
#   DecisionTreeClassifier(criterion='entropy', random_state=1448881546),
#   DecisionTreeClassifier(criterion='entropy', random_state=997332023),
#   DecisionTreeClassifier(criterion='entropy', random_state=385742370),
#   DecisionTreeClassifier(criterion='entropy', random_state=1178397191),
#   DecisionTreeClassifier(criterion='entropy', random_state=664243683),
#   DecisionTreeClassifier(criterion='entropy', random_state=649365392),
#   DecisionTreeClassifier(criterion='entropy', random_state=1836809803),
#   DecisionTreeClassifier(criterion='entropy', random_state=267511611),
#   DecisionTreeClassifier(criterion='entropy', random_state=195591754),
#   DecisionTreeClassifier(criterion='entropy', random_state=180875614),
#   DecisionTreeClassifier(criterion='entropy', random_state=1911651288),
#   DecisionTreeClassifier(criterion='entropy', random_state=1219489424),
#   DecisionTreeClassifier(criterion='entropy', random_state=1002847420),
#   DecisionTreeClassifier(criterion='entropy', random_state=114141516),
#   DecisionTreeClassifier(criterion='entropy', random_state=275599723),
#   DecisionTreeClassifier(criterion='entropy', random_state=95164887),
#   DecisionTreeClassifier(criterion='entropy', random_state=1871021991),
#   DecisionTreeClassifier(criterion='entropy', random_state=1005344789),
#   DecisionTreeClassifier(criterion='entropy', random_state=1472697573),
#   DecisionTreeClassifier(criterion='entropy', random_state=1150391659),
#   DecisionTreeClassifier(criterion='entropy', random_state=484902906),
#   DecisionTreeClassifier(criterion='entropy', random_state=2041288530),
#   DecisionTreeClassifier(criterion='entropy', random_state=1802606141),
#   DecisionTreeClassifier(criterion='entropy', random_state=1212525283),
#   DecisionTreeClassifier(criterion='entropy', random_state=745153667),
#   DecisionTreeClassifier(criterion='entropy', random_state=1605727183),
#   DecisionTreeClassifier(criterion='entropy', random_state=1950041654),
#   DecisionTreeClassifier(criterion='entropy', random_state=48361098),
#   DecisionTreeClassifier(criterion='entropy', random_state=1469107432),
#   DecisionTreeClassifier(criterion='entropy', random_state=1179462642),
#   DecisionTreeClassifier(criterion='entropy', random_state=1222742260),
#   DecisionTreeClassifier(criterion='entropy', random_state=693487518),
#   DecisionTreeClassifier(criterion='entropy', random_state=1697308883),
#   DecisionTreeClassifier(criterion='entropy', random_state=878776489),
#   DecisionTreeClassifier(criterion='entropy', random_state=174044308),
#   DecisionTreeClassifier(criterion='entropy', random_state=669880072),
#   DecisionTreeClassifier(criterion='entropy', random_state=260771718),
#   DecisionTreeClassifier(criterion='entropy', random_state=655178641),
#   DecisionTreeClassifier(criterion='entropy', random_state=983547847),
#   DecisionTreeClassifier(criterion='entropy', random_state=1896157872),
#   DecisionTreeClassifier(criterion='entropy', random_state=2068145941),
#   DecisionTreeClassifier(criterion='entropy', random_state=1548621803),
#   DecisionTreeClassifier(criterion='entropy', random_state=384134427),
#   DecisionTreeClassifier(criterion='entropy', random_state=1111468403),
#   DecisionTreeClassifier(criterion='entropy', random_state=1911956890),
#   DecisionTreeClassifier(criterion='entropy', random_state=960211129),
#   DecisionTreeClassifier(criterion='entropy', random_state=949456776),
#   DecisionTreeClassifier(criterion='entropy', random_state=1066767103),
#   DecisionTreeClassifier(criterion='entropy', random_state=215979279),
#   DecisionTreeClassifier(criterion='entropy', random_state=1194559793),
#   DecisionTreeClassifier(criterion='entropy', random_state=1099856568),
#   DecisionTreeClassifier(criterion='entropy', random_state=593785826),
#   DecisionTreeClassifier(criterion='entropy', random_state=174450438),
#   DecisionTreeClassifier(criterion='entropy', random_state=327138054),
#   DecisionTreeClassifier(criterion='entropy', random_state=1294242519),
#   DecisionTreeClassifier(criterion='entropy', random_state=518469852),
#   DecisionTreeClassifier(criterion='entropy', random_state=1265321740),
#   DecisionTreeClassifier(criterion='entropy', random_state=417755878),
#   DecisionTreeClassifier(criterion='entropy', random_state=245174480),
#   DecisionTreeClassifier(criterion='entropy', random_state=1288549019),
#   DecisionTreeClassifier(criterion='entropy', random_state=201369751),
#   DecisionTreeClassifier(criterion='entropy', random_state=58957260),
#   DecisionTreeClassifier(criterion='entropy', random_state=1465138548),
#   DecisionTreeClassifier(criterion='entropy', random_state=1118326228),
#   DecisionTreeClassifier(criterion='entropy', random_state=1828790880),
#   DecisionTreeClassifier(criterion='entropy', random_state=708580642),
#   DecisionTreeClassifier(criterion='entropy', random_state=768042322),
#   DecisionTreeClassifier(criterion='entropy', random_state=393516418),
#   DecisionTreeClassifier(criterion='entropy', random_state=638251503),
#   DecisionTreeClassifier(criterion='entropy', random_state=1923599864),
#   DecisionTreeClassifier(criterion='entropy', random_state=889915170),
#   DecisionTreeClassifier(criterion='entropy', random_state=1340666080),
#   DecisionTreeClassifier(criterion='entropy', random_state=1938813339),
#   DecisionTreeClassifier(criterion='entropy', random_state=243605950),
#   DecisionTreeClassifier(criterion='entropy', random_state=66617466),
#   DecisionTreeClassifier(criterion='entropy', random_state=949483969),
#   DecisionTreeClassifier(criterion='entropy', random_state=1256097684),
#   DecisionTreeClassifier(criterion='entropy', random_state=954304352),
#   DecisionTreeClassifier(criterion='entropy', random_state=305357138),
#   DecisionTreeClassifier(criterion='entropy', random_state=1724203304),
#   DecisionTreeClassifier(criterion='entropy', random_state=398400402),
#   DecisionTreeClassifier(criterion='entropy', random_state=1706669122),
#   DecisionTreeClassifier(criterion='entropy', random_state=1231988616),
#   DecisionTreeClassifier(criterion='entropy', random_state=29494259),
#   DecisionTreeClassifier(criterion='entropy', random_state=995599611),
#   DecisionTreeClassifier(criterion='entropy', random_state=671020543),
#   DecisionTreeClassifier(criterion='entropy', random_state=1285122406),
#   DecisionTreeClassifier(criterion='entropy', random_state=680244805),
#   DecisionTreeClassifier(criterion='entropy', random_state=601698301),
#   DecisionTreeClassifier(criterion='entropy', random_state=1273732154),
#   DecisionTreeClassifier(criterion='entropy', random_state=1559397795),
#   DecisionTreeClassifier(criterion='entropy', random_state=1754712694),
#   DecisionTreeClassifier(criterion='entropy', random_state=192621731),
#   DecisionTreeClassifier(criterion='entropy', random_state=1703361266),
#   DecisionTreeClassifier(criterion='entropy', random_state=1299232285),
#   DecisionTreeClassifier(criterion='entropy', random_state=481972461),
#   DecisionTreeClassifier(criterion='entropy', random_state=1535792795),
#   DecisionTreeClassifier(criterion='entropy', random_state=1661498240),
#   DecisionTreeClassifier(criterion='entropy', random_state=1715537204),
#   DecisionTreeClassifier(criterion='entropy', random_state=1981349336),
#   DecisionTreeClassifier(criterion='entropy', random_state=1518405293),
#   DecisionTreeClassifier(criterion='entropy', random_state=1390881952),
#   DecisionTreeClassifier(criterion='entropy', random_state=814371174),
#   DecisionTreeClassifier(criterion='entropy', random_state=350511145),
#   DecisionTreeClassifier(criterion='entropy', random_state=380892949),
#   DecisionTreeClassifier(criterion='entropy', random_state=931776155),
#   DecisionTreeClassifier(criterion='entropy', random_state=1862714103),
#   DecisionTreeClassifier(criterion='entropy', random_state=474531023),
#   DecisionTreeClassifier(criterion='entropy', random_state=2127246161),
#   DecisionTreeClassifier(criterion='entropy', random_state=2053560571),
#   DecisionTreeClassifier(criterion='entropy', random_state=498023735),
#   DecisionTreeClassifier(criterion='entropy', random_state=757253872),
#   DecisionTreeClassifier(criterion='entropy', random_state=1860160540),
#   DecisionTreeClassifier(criterion='entropy', random_state=1631231021),
#   DecisionTreeClassifier(criterion='entropy', random_state=723751024),
#   DecisionTreeClassifier(criterion='entropy', random_state=1415784793),
#   DecisionTreeClassifier(criterion='entropy', random_state=1362943115),
#   DecisionTreeClassifier(criterion='entropy', random_state=1797232855)],
#  'n_classes': 2,
#  'fit_time': 672502}

# %%
# Réalisation des prédictions

y_pred = clf_rf_ts.predict(X_test)

# %% [markdown]
# ## 5. Évaluation

# %%
# Élaboration de la matrice de confusion

pd.crosstab(y_test, y_pred, rownames = ["Classe réelle"], colnames = ["Classe prédite"])
# Out:
# Classe prédite      0     1
# Classe réelle
# 0               17703   416
# 1                3744  1601

# %%
# Élaboration du rapport de classification

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.89     18119
#            1       0.79      0.30      0.43      5345
#
#     accuracy                           0.82     23464
#    macro avg       0.81      0.64      0.66     23464
# weighted avg       0.82      0.82      0.79     23464
