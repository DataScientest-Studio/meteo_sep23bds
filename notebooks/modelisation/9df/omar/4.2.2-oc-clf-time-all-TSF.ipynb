# %% [markdown]
# # **Classification** des **séries temporelles** avec `sktime`

# %% [markdown]
# ## Métadonnées

# %% [markdown]
# - **Expérience nº :** 4.2.2
# - **Date :** 11/11/2023
# - **Heure :** 11:15
# - **Données :** `ready_all.csv`
# - **Tri :** index chronologique
# - **Découpage :** `TimeSeriesSplit`
# - **Mise à l'échelle :** non
# - **Rééquilibrage :** non
# - **Conversion :** `numpyfy`
# - **Algorithme :** TSF

# %% [markdown]
# ## Sommaire

# %% [markdown]
# 1. Initialisation
# 2. Découpage
# 3. Conversion
# 4. Modélisation
# 5. Évaluation

# %% [markdown]
# ## 1. Initialisation

# %%
# Importation des bibliothèques et modules nécessaires au fonctionnement de ce notebook

import pandas as pd
import numpy as np

from sklearn.metrics import classification_report

# %%
# Importation du jeu de données et enregistrement dans le DataFrame `df`

df = pd.read_csv("../../../data/9df/Alex/ready_all.csv", index_col = 1).sort_index()
df = df.drop(columns = "Unnamed: 0")

# %%
# Inspection de la structure de `df`

df.head()
# Out:
#             MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# Date
# 2007-11-01      8.0     24.3       0.0          3.4       6.3           30.0
# 2007-11-02     14.0     26.9       3.6          4.4       9.7           39.0
# 2007-11-03     13.7     23.4       3.6          5.8       3.3           85.0
# 2007-11-04     13.3     15.5      39.8          7.2       9.1           54.0
# 2007-11-05      7.6     16.1       2.8          5.6      10.6           50.0
#
#             WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  month  \
# Date                                                              ...
# 2007-11-01           6.0          20.0         68.0         29.0  ...     11
# 2007-11-02           4.0          17.0         80.0         36.0  ...     11
# 2007-11-03           6.0           6.0         82.0         69.0  ...     11
# 2007-11-04          30.0          24.0         62.0         56.0  ...     11
# 2007-11-05          20.0          28.0         68.0         49.0  ...     11
#
#             day  LocationNum  WindGustDirNum  WindDir9amNum  WindDir3pmNum  \
# Date
# 2007-11-01    1           15        2.356194       3.926991       2.356194
# 2007-11-02    2           15        0.392699       0.000000       3.141593
# 2007-11-03    3           15        2.356194       1.570796       1.178097
# 2007-11-04    4           15        2.356194       2.748894       3.141593
# 2007-11-05    5           15        5.105088       5.105088       5.890486
#
#              Latitude   Longitude  CodeRegionNum  NonMesNum
# Date
# 2007-11-01 -35.297591  149.101268              1          2
# 2007-11-02 -35.297591  149.101268              1          2
# 2007-11-03 -35.297591  149.101268              1          2
# 2007-11-04 -35.297591  149.101268              1          2
# 2007-11-05 -35.297591  149.101268              1          2
#
# [5 rows x 29 columns]

# %%
# Inspection de la structure de `df`

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 77728 entries, 2007-11-01 to 2017-06-25
# Data columns (total 29 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   MinTemp         77728 non-null  float64
#  1   MaxTemp         77728 non-null  float64
#  2   Rainfall        77728 non-null  float64
#  3   Evaporation     77728 non-null  float64
#  4   Sunshine        77728 non-null  float64
#  5   WindGustSpeed   77728 non-null  float64
#  6   WindSpeed9am    77728 non-null  float64
#  7   WindSpeed3pm    77728 non-null  float64
#  8   Humidity9am     77728 non-null  float64
#  9   Humidity3pm     77728 non-null  float64
#  10  Pressure9am     77728 non-null  float64
#  11  Pressure3pm     77728 non-null  float64
#  12  Cloud9am        77728 non-null  float64
#  13  Cloud3pm        77728 non-null  float64
#  14  Temp9am         77728 non-null  float64
#  15  Temp3pm         77728 non-null  float64
#  16  RainToday       77728 non-null  int64
#  17  RainTomorrow    77728 non-null  int64
#  18  year            77728 non-null  int64
#  19  month           77728 non-null  int64
#  20  day             77728 non-null  int64
#  21  LocationNum     77728 non-null  int64
#  22  WindGustDirNum  77728 non-null  float64
#  23  WindDir9amNum   77728 non-null  float64
#  24  WindDir3pmNum   77728 non-null  float64
#  25  Latitude        77728 non-null  float64
#  26  Longitude       77728 non-null  float64
#  27  CodeRegionNum   77728 non-null  int64
#  28  NonMesNum       77728 non-null  int64
# dtypes: float64(21), int64(8)
# memory usage: 17.8+ MB

# %% [markdown]
# ## 2. Découpage

# %%
# Découpage de `df` sur l'axe des colonnes : séparation des variables explicatives (`data`) et cible (`target`)

data = df.drop(columns = "RainTomorrow")
target = df["RainTomorrow"]

# %%
# Découpage de `data` et de `target` sur l'axe des lignes : séparation des jeux d'entraînement (`*_train`) et de test (`*_test`) avec le splitter `TimeSeriesSplit`

from sklearn.model_selection import TimeSeriesSplit

tss = TimeSeriesSplit(n_splits = 5) ## Nous fixons le paramètre `n_splits` à 5 afin d'avoir une répartition de 80 / 20 entre les jeux d'entraînement et de test, respectivement.

for train_index, test_index in tss.split(data):
    X_train, X_test = data.iloc[train_index, :], data.iloc[test_index,:]
    y_train, y_test = target.iloc[train_index], target.iloc[test_index]

# %% [markdown]
# ## 3. Conversion

# %%
# Importation de la fonction artisanale `numpyfy`

from numpyfy import numpyfy

# %%
# Application de la fonction `numpyfy` aux 4 jeux de données issus du découpage effectué par le splitter `TimeSeriesSplit` afin de les convertir en arrays et ainsi les rendre compatibles avec `sktime`

X_train, X_test, y_train, y_test = numpyfy(X_train, X_test, y_train, y_test)

# %% [markdown]
# ## 4. Modélisation

# %%
# Instanciation d'un modèle classificateur via un Pipeline

from sklearn.pipeline import Pipeline
from sktime.transformations.panel.compose import ColumnConcatenator
from sktime.classification.interval_based import TimeSeriesForestClassifier

steps = [
    ("concatenate", ColumnConcatenator()), ## Cette étape permet de transformer les jeux de données multivariées en univariées afin qu'ils puissent être traités par `TimeSeriesForestClassifier`.
    ("classify", TimeSeriesForestClassifier()),
]

clf_rf_ts = Pipeline(steps)

# %%
# Récupération des paramètres initiaux de la TSF

clf_rf_ts["classify"].get_params()
# Out:
# {'min_interval': 3, 'n_estimators': 200, 'n_jobs': 1, 'random_state': None}

# %%
# Entraînement du modèle

clf_rf_ts.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('concatenate', ColumnConcatenator()),
#                 ('classify', TimeSeriesForestClassifier())])

# %%
# Récupération des paramètres ajustés de la TSF

clf_rf_ts["classify"].get_fitted_params()
# Out:
# {'classes': array([0, 1]),
#  'intervals': [array([[ 2, 11],
#          [ 3, 12],
#          [22, 25],
#          [11, 14],
#          [ 2, 10]]),
#   array([[22, 25],
#          [24, 27],
#          [18, 23],
#          [ 9, 15],
#          [16, 22]]),
#   array([[ 9, 13],
#          [23, 26],
#          [11, 19],
#          [23, 26],
#          [ 0,  6]]),
#   array([[15, 18],
#          [16, 19],
#          [22, 26],
#          [ 2,  9],
#          [19, 25]]),
#   array([[18, 21],
#          [19, 25],
#          [16, 23],
#          [ 9, 19],
#          [20, 23]]),
#   array([[15, 18],
#          [15, 19],
#          [12, 19],
#          [11, 22],
#          [ 0,  8]]),
#   array([[14, 19],
#          [ 3, 13],
#          [23, 26],
#          [ 6, 18],
#          [21, 24]]),
#   array([[20, 23],
#          [14, 17],
#          [11, 14],
#          [ 8, 23],
#          [ 5, 18]]),
#   array([[ 5, 20],
#          [ 4,  8],
#          [16, 22],
#          [21, 24],
#          [13, 23]]),
#   array([[24, 27],
#          [17, 22],
#          [10, 18],
#          [ 5, 25],
#          [16, 19]]),
#   array([[22, 25],
#          [19, 26],
#          [ 1,  4],
#          [21, 24],
#          [12, 19]]),
#   array([[12, 23],
#          [11, 21],
#          [22, 25],
#          [15, 25],
#          [ 4, 14]]),
#   array([[ 2,  5],
#          [14, 19],
#          [20, 23],
#          [18, 22],
#          [16, 24]]),
#   array([[ 1, 20],
#          [17, 26],
#          [ 8, 12],
#          [11, 25],
#          [ 7, 20]]),
#   array([[11, 23],
#          [19, 22],
#          [20, 23],
#          [20, 26],
#          [22, 25]]),
#   array([[ 5, 21],
#          [ 0, 21],
#          [14, 26],
#          [17, 21],
#          [ 1,  9]]),
#   array([[16, 26],
#          [ 7, 10],
#          [ 2, 19],
#          [17, 21],
#          [15, 18]]),
#   array([[19, 22],
#          [ 8, 19],
#          [ 8, 17],
#          [ 9, 19],
#          [ 3,  6]]),
#   array([[ 5, 16],
#          [11, 14],
#          [23, 26],
#          [ 0, 23],
#          [20, 23]]),
#   array([[ 4, 11],
#          [ 8, 22],
#          [22, 26],
#          [13, 24],
#          [19, 22]]),
#   array([[ 5, 16],
#          [ 4, 11],
#          [ 2, 24],
#          [12, 21],
#          [ 3, 26]]),
#   array([[ 8, 23],
#          [ 8, 11],
#          [ 7, 10],
#          [14, 17],
#          [22, 25]]),
#   array([[22, 25],
#          [10, 23],
#          [20, 23],
#          [ 2, 24],
#          [15, 19]]),
#   array([[11, 21],
#          [ 6,  9],
#          [ 1, 16],
#          [ 6, 15],
#          [ 5, 25]]),
#   array([[ 3, 11],
#          [11, 25],
#          [21, 24],
#          [16, 21],
#          [24, 27]]),
#   array([[ 0, 20],
#          [ 9, 22],
#          [23, 26],
#          [12, 15],
#          [ 2,  7]]),
#   array([[21, 26],
#          [ 5,  8],
#          [ 9, 13],
#          [21, 24],
#          [14, 17]]),
#   array([[12, 23],
#          [ 8, 17],
#          [ 5, 16],
#          [17, 22],
#          [ 5,  8]]),
#   array([[23, 26],
#          [19, 22],
#          [ 3, 20],
#          [18, 26],
#          [10, 18]]),
#   array([[ 1, 22],
#          [23, 26],
#          [20, 23],
#          [10, 26],
#          [10, 20]]),
#   array([[14, 18],
#          [ 4, 25],
#          [ 9, 12],
#          [17, 20],
#          [12, 18]]),
#   array([[12, 18],
#          [ 3, 14],
#          [13, 18],
#          [ 0, 10],
#          [17, 25]]),
#   array([[15, 18],
#          [ 7, 10],
#          [ 2, 24],
#          [ 9, 24],
#          [ 0, 17]]),
#   array([[ 5, 26],
#          [ 8, 15],
#          [21, 26],
#          [13, 24],
#          [17, 22]]),
#   array([[ 2, 20],
#          [23, 26],
#          [ 2, 17],
#          [13, 26],
#          [23, 26]]),
#   array([[12, 20],
#          [12, 17],
#          [17, 21],
#          [ 5,  8],
#          [ 3, 17]]),
#   array([[ 3, 19],
#          [12, 15],
#          [12, 25],
#          [13, 26],
#          [10, 15]]),
#   array([[ 0, 21],
#          [ 4, 20],
#          [11, 17],
#          [ 5,  8],
#          [19, 26]]),
#   array([[ 5,  9],
#          [ 9, 21],
#          [16, 19],
#          [ 8, 17],
#          [ 0,  3]]),
#   array([[ 1, 22],
#          [ 5, 24],
#          [ 7, 25],
#          [14, 25],
#          [21, 24]]),
#   array([[12, 18],
#          [ 2, 13],
#          [ 5, 15],
#          [17, 22],
#          [20, 23]]),
#   array([[ 8, 24],
#          [17, 20],
#          [21, 25],
#          [14, 19],
#          [24, 27]]),
#   array([[24, 27],
#          [19, 24],
#          [ 1, 11],
#          [20, 23],
#          [13, 16]]),
#   array([[23, 26],
#          [19, 25],
#          [ 9, 17],
#          [13, 25],
#          [18, 21]]),
#   array([[ 3, 16],
#          [ 3, 20],
#          [ 8, 17],
#          [16, 19],
#          [ 6,  9]]),
#   array([[24, 27],
#          [22, 25],
#          [ 4, 20],
#          [15, 18],
#          [23, 26]]),
#   array([[ 0, 21],
#          [ 1,  8],
#          [ 6, 11],
#          [ 8, 11],
#          [10, 18]]),
#   array([[14, 18],
#          [15, 18],
#          [11, 22],
#          [ 5, 24],
#          [ 4, 15]]),
#   array([[ 6, 21],
#          [22, 25],
#          [ 9, 12],
#          [ 2, 11],
#          [ 5,  9]]),
#   array([[12, 18],
#          [20, 23],
#          [ 9, 24],
#          [16, 19],
#          [16, 25]]),
#   array([[ 7, 21],
#          [ 4, 23],
#          [22, 25],
#          [ 8, 24],
#          [15, 23]]),
#   array([[12, 26],
#          [12, 15],
#          [13, 16],
#          [16, 19],
#          [17, 21]]),
#   array([[23, 26],
#          [16, 25],
#          [13, 16],
#          [ 8, 22],
#          [ 6, 24]]),
#   array([[14, 17],
#          [ 9, 18],
#          [14, 17],
#          [23, 26],
#          [24, 27]]),
#   array([[23, 26],
#          [22, 25],
#          [21, 24],
#          [ 1, 15],
#          [ 1,  9]]),
#   array([[13, 16],
#          [10, 14],
#          [ 0, 21],
#          [13, 24],
#          [20, 23]]),
#   array([[ 6, 20],
#          [ 7, 10],
#          [15, 21],
#          [15, 18],
#          [17, 25]]),
#   array([[10, 13],
#          [ 9, 19],
#          [ 2,  5],
#          [ 5, 26],
#          [ 9, 23]]),
#   array([[20, 23],
#          [18, 25],
#          [10, 13],
#          [17, 22],
#          [ 0, 12]]),
#   array([[ 1, 12],
#          [ 2, 26],
#          [12, 18],
#          [ 0, 24],
#          [24, 27]]),
#   array([[ 4,  8],
#          [ 4, 17],
#          [23, 26],
#          [ 6, 15],
#          [ 0,  3]]),
#   array([[ 8, 11],
#          [20, 26],
#          [23, 26],
#          [ 1, 22],
#          [24, 27]]),
#   array([[ 8, 11],
#          [10, 25],
#          [22, 25],
#          [16, 19],
#          [11, 26]]),
#   array([[ 4, 12],
#          [ 2,  8],
#          [ 4, 15],
#          [16, 25],
#          [ 4, 15]]),
#   array([[23, 26],
#          [ 3,  8],
#          [15, 18],
#          [10, 13],
#          [ 4, 10]]),
#   array([[14, 17],
#          [ 1,  7],
#          [20, 24],
#          [13, 16],
#          [17, 21]]),
#   array([[19, 26],
#          [16, 20],
#          [ 8, 14],
#          [20, 23],
#          [20, 26]]),
#   array([[16, 25],
#          [15, 21],
#          [17, 26],
#          [18, 21],
#          [ 9, 24]]),
#   array([[ 4, 23],
#          [20, 23],
#          [ 5, 11],
#          [ 5, 20],
#          [ 4, 23]]),
#   array([[ 4, 13],
#          [14, 17],
#          [ 8, 14],
#          [ 2,  5],
#          [13, 16]]),
#   array([[ 0, 23],
#          [10, 25],
#          [ 5, 21],
#          [18, 22],
#          [11, 15]]),
#   array([[ 0, 20],
#          [12, 22],
#          [24, 27],
#          [17, 21],
#          [14, 17]]),
#   array([[ 4, 23],
#          [12, 15],
#          [ 3, 21],
#          [ 6,  9],
#          [10, 20]]),
#   array([[ 8, 20],
#          [ 7, 18],
#          [ 0, 19],
#          [23, 26],
#          [11, 19]]),
#   array([[18, 26],
#          [23, 26],
#          [17, 21],
#          [12, 18],
#          [14, 23]]),
#   array([[ 3, 26],
#          [ 6,  9],
#          [24, 27],
#          [18, 25],
#          [19, 24]]),
#   array([[ 9, 15],
#          [16, 26],
#          [20, 23],
#          [ 7, 15],
#          [17, 22]]),
#   array([[24, 27],
#          [13, 16],
#          [22, 26],
#          [15, 18],
#          [10, 14]]),
#   array([[19, 22],
#          [17, 25],
#          [15, 21],
#          [ 9, 24],
#          [24, 27]]),
#   array([[15, 24],
#          [ 5, 12],
#          [10, 13],
#          [14, 17],
#          [10, 19]]),
#   array([[ 0, 20],
#          [23, 26],
#          [13, 23],
#          [ 2, 11],
#          [ 9, 12]]),
#   array([[10, 15],
#          [24, 27],
#          [ 1,  9],
#          [18, 25],
#          [ 7, 10]]),
#   array([[20, 23],
#          [15, 22],
#          [12, 20],
#          [23, 26],
#          [ 2, 12]]),
#   array([[24, 27],
#          [19, 22],
#          [21, 24],
#          [14, 26],
#          [17, 24]]),
#   array([[ 9, 12],
#          [15, 23],
#          [12, 15],
#          [ 9, 19],
#          [17, 20]]),
#   array([[17, 23],
#          [16, 21],
#          [ 2,  5],
#          [ 7, 22],
#          [23, 26]]),
#   array([[11, 16],
#          [ 6, 23],
#          [11, 19],
#          [10, 16],
#          [19, 22]]),
#   array([[24, 27],
#          [15, 18],
#          [24, 27],
#          [12, 17],
#          [20, 26]]),
#   array([[ 3,  9],
#          [ 7, 16],
#          [15, 25],
#          [ 6,  9],
#          [ 5, 25]]),
#   array([[22, 25],
#          [ 4, 17],
#          [22, 25],
#          [10, 21],
#          [19, 22]]),
#   array([[11, 25],
#          [16, 19],
#          [11, 24],
#          [13, 25],
#          [11, 14]]),
#   array([[ 8, 16],
#          [22, 25],
#          [ 5, 25],
#          [13, 26],
#          [ 1, 19]]),
#   array([[24, 27],
#          [19, 25],
#          [16, 25],
#          [12, 26],
#          [14, 17]]),
#   array([[ 9, 12],
#          [ 5, 25],
#          [ 2,  6],
#          [ 4, 12],
#          [13, 26]]),
#   array([[ 5, 16],
#          [16, 19],
#          [ 9, 15],
#          [22, 25],
#          [ 7, 13]]),
#   array([[12, 22],
#          [ 7, 20],
#          [21, 26],
#          [16, 22],
#          [20, 23]]),
#   array([[14, 25],
#          [10, 14],
#          [17, 20],
#          [18, 21],
#          [ 9, 12]]),
#   array([[ 9, 26],
#          [ 7, 17],
#          [17, 22],
#          [10, 15],
#          [19, 22]]),
#   array([[13, 16],
#          [21, 24],
#          [19, 22],
#          [22, 25],
#          [20, 23]]),
#   array([[12, 15],
#          [11, 20],
#          [ 4, 16],
#          [ 3,  6],
#          [16, 19]]),
#   array([[15, 18],
#          [ 9, 21],
#          [17, 22],
#          [10, 13],
#          [ 4, 26]]),
#   array([[20, 23],
#          [20, 24],
#          [ 4, 17],
#          [ 1, 19],
#          [13, 16]]),
#   array([[ 4,  7],
#          [23, 26],
#          [ 7, 15],
#          [21, 24],
#          [14, 23]]),
#   array([[13, 16],
#          [ 7, 10],
#          [18, 26],
#          [ 8, 11],
#          [16, 21]]),
#   array([[ 5, 12],
#          [ 2, 20],
#          [ 3, 18],
#          [24, 27],
#          [ 1, 16]]),
#   array([[ 3, 15],
#          [ 6,  9],
#          [ 5, 22],
#          [19, 23],
#          [10, 21]]),
#   array([[11, 15],
#          [19, 22],
#          [12, 15],
#          [20, 23],
#          [22, 25]]),
#   array([[12, 15],
#          [ 2,  8],
#          [10, 25],
#          [ 1, 13],
#          [ 3, 14]]),
#   array([[22, 25],
#          [22, 25],
#          [21, 24],
#          [20, 23],
#          [ 3, 15]]),
#   array([[ 0, 15],
#          [10, 13],
#          [ 3, 12],
#          [ 7, 21],
#          [ 4, 25]]),
#   array([[21, 24],
#          [ 6, 10],
#          [13, 17],
#          [23, 26],
#          [10, 13]]),
#   array([[ 7, 19],
#          [ 2, 10],
#          [13, 23],
#          [10, 20],
#          [17, 20]]),
#   array([[19, 22],
#          [20, 26],
#          [14, 24],
#          [13, 16],
#          [20, 23]]),
#   array([[ 0, 24],
#          [13, 22],
#          [ 7, 17],
#          [21, 25],
#          [11, 14]]),
#   array([[16, 22],
#          [24, 27],
#          [15, 20],
#          [ 7, 11],
#          [17, 20]]),
#   array([[14, 17],
#          [ 5, 20],
#          [12, 22],
#          [ 9, 17],
#          [ 2, 10]]),
#   array([[15, 18],
#          [10, 15],
#          [20, 25],
#          [16, 19],
#          [18, 26]]),
#   array([[16, 20],
#          [11, 22],
#          [ 2, 21],
#          [15, 23],
#          [ 5, 19]]),
#   array([[ 9, 25],
#          [ 0,  4],
#          [19, 24],
#          [16, 19],
#          [ 9, 23]]),
#   array([[23, 26],
#          [20, 23],
#          [ 5, 24],
#          [21, 25],
#          [21, 24]]),
#   array([[ 0, 22],
#          [12, 15],
#          [24, 27],
#          [24, 27],
#          [ 1, 20]]),
#   array([[16, 19],
#          [24, 27],
#          [19, 23],
#          [ 2, 26],
#          [23, 26]]),
#   array([[ 4, 24],
#          [ 9, 26],
#          [24, 27],
#          [11, 26],
#          [ 4,  8]]),
#   array([[19, 23],
#          [ 6,  9],
#          [11, 14],
#          [ 4, 11],
#          [10, 13]]),
#   array([[11, 18],
#          [23, 26],
#          [ 7, 26],
#          [ 6, 22],
#          [18, 25]]),
#   array([[15, 24],
#          [24, 27],
#          [22, 25],
#          [19, 22],
#          [10, 24]]),
#   array([[ 5, 11],
#          [20, 26],
#          [ 8, 11],
#          [ 3, 20],
#          [21, 24]]),
#   array([[ 5,  8],
#          [10, 16],
#          [20, 23],
#          [20, 24],
#          [20, 25]]),
#   array([[11, 14],
#          [15, 26],
#          [19, 25],
#          [14, 17],
#          [ 4, 10]]),
#   array([[10, 15],
#          [16, 19],
#          [14, 21],
#          [16, 26],
#          [14, 18]]),
#   array([[11, 18],
#          [19, 22],
#          [18, 21],
#          [ 8, 26],
#          [20, 26]]),
#   array([[20, 26],
#          [ 0,  3],
#          [22, 26],
#          [ 6, 26],
#          [22, 25]]),
#   array([[15, 20],
#          [19, 23],
#          [15, 26],
#          [ 8, 21],
#          [16, 26]]),
#   array([[ 1, 22],
#          [23, 26],
#          [20, 23],
#          [ 8, 12],
#          [21, 26]]),
#   array([[22, 25],
#          [18, 21],
#          [ 1, 11],
#          [ 2, 18],
#          [18, 22]]),
#   array([[13, 16],
#          [19, 24],
#          [ 7, 24],
#          [ 8, 23],
#          [ 6, 23]]),
#   array([[20, 23],
#          [12, 15],
#          [15, 18],
#          [21, 24],
#          [17, 25]]),
#   array([[ 0, 16],
#          [22, 25],
#          [15, 24],
#          [22, 25],
#          [20, 23]]),
#   array([[14, 18],
#          [14, 26],
#          [ 5, 22],
#          [11, 26],
#          [ 8, 16]]),
#   array([[19, 26],
#          [11, 14],
#          [15, 19],
#          [21, 25],
#          [ 3, 15]]),
#   array([[20, 25],
#          [19, 23],
#          [13, 23],
#          [15, 18],
#          [19, 22]]),
#   array([[ 8, 22],
#          [ 6, 21],
#          [ 4,  8],
#          [14, 18],
#          [ 8, 19]]),
#   array([[ 3,  6],
#          [15, 21],
#          [ 9, 18],
#          [17, 20],
#          [ 6,  9]]),
#   array([[21, 25],
#          [ 2, 22],
#          [20, 23],
#          [16, 19],
#          [ 1, 11]]),
#   array([[ 0, 10],
#          [18, 21],
#          [23, 26],
#          [13, 19],
#          [ 5, 11]]),
#   array([[ 8, 17],
#          [18, 22],
#          [24, 27],
#          [13, 16],
#          [ 5, 21]]),
#   array([[23, 26],
#          [23, 26],
#          [17, 25],
#          [15, 18],
#          [ 2, 13]]),
#   array([[ 7, 22],
#          [20, 23],
#          [19, 26],
#          [ 9, 24],
#          [ 8, 11]]),
#   array([[ 6, 18],
#          [ 5,  8],
#          [23, 26],
#          [ 2, 15],
#          [21, 24]]),
#   array([[13, 25],
#          [ 8, 11],
#          [10, 13],
#          [14, 22],
#          [10, 24]]),
#   array([[22, 25],
#          [10, 13],
#          [ 6,  9],
#          [ 2,  5],
#          [21, 24]]),
#   array([[14, 17],
#          [10, 15],
#          [ 3,  6],
#          [ 6, 21],
#          [ 2, 14]]),
#   array([[12, 26],
#          [23, 26],
#          [24, 27],
#          [14, 17],
#          [ 2, 14]]),
#   array([[17, 21],
#          [18, 24],
#          [12, 19],
#          [ 9, 19],
#          [16, 26]]),
#   array([[ 1, 26],
#          [ 1,  7],
#          [ 6,  9],
#          [ 8, 13],
#          [23, 26]]),
#   array([[ 2,  5],
#          [ 1, 22],
#          [24, 27],
#          [22, 26],
#          [ 2,  5]]),
#   array([[10, 19],
#          [22, 26],
#          [12, 22],
#          [ 6, 25],
#          [12, 24]]),
#   array([[ 1, 21],
#          [12, 20],
#          [ 2, 14],
#          [ 1, 17],
#          [22, 25]]),
#   array([[21, 24],
#          [23, 26],
#          [17, 22],
#          [ 2, 19],
#          [17, 20]]),
#   array([[18, 21],
#          [ 7, 18],
#          [11, 26],
#          [21, 24],
#          [16, 26]]),
#   array([[ 0, 16],
#          [22, 25],
#          [18, 21],
#          [ 8, 11],
#          [ 4, 23]]),
#   array([[ 1, 23],
#          [12, 15],
#          [13, 16],
#          [ 1, 26],
#          [ 3, 19]]),
#   array([[18, 21],
#          [ 6, 10],
#          [ 4, 12],
#          [ 7, 10],
#          [ 1,  4]]),
#   array([[12, 15],
#          [ 1, 26],
#          [ 1, 11],
#          [ 6, 25],
#          [15, 24]]),
#   array([[11, 14],
#          [ 9, 24],
#          [ 1, 18],
#          [ 3, 20],
#          [11, 25]]),
#   array([[ 5, 23],
#          [ 8, 20],
#          [21, 24],
#          [11, 26],
#          [ 3, 13]]),
#   array([[ 3, 23],
#          [ 1, 26],
#          [24, 27],
#          [21, 24],
#          [ 2, 26]]),
#   array([[24, 27],
#          [12, 20],
#          [14, 18],
#          [24, 27],
#          [17, 26]]),
#   array([[ 1, 13],
#          [16, 19],
#          [18, 24],
#          [20, 23],
#          [16, 21]]),
#   array([[10, 19],
#          [19, 26],
#          [22, 25],
#          [21, 24],
#          [11, 14]]),
#   array([[23, 26],
#          [ 1, 25],
#          [ 7, 23],
#          [13, 19],
#          [11, 18]]),
#   array([[14, 24],
#          [ 3, 10],
#          [20, 25],
#          [19, 22],
#          [ 6, 13]]),
#   array([[13, 24],
#          [10, 19],
#          [15, 26],
#          [21, 26],
#          [20, 23]]),
#   array([[ 0, 21],
#          [11, 20],
#          [ 5,  8],
#          [ 4, 20],
#          [ 1,  5]]),
#   array([[ 7, 24],
#          [ 8, 13],
#          [12, 15],
#          [ 4, 11],
#          [13, 24]]),
#   array([[ 5, 24],
#          [ 0, 25],
#          [15, 21],
#          [12, 21],
#          [ 5, 11]]),
#   array([[23, 26],
#          [12, 26],
#          [16, 23],
#          [ 6, 11],
#          [17, 20]]),
#   array([[ 8, 11],
#          [21, 24],
#          [ 5, 21],
#          [ 3, 14],
#          [ 5, 23]]),
#   array([[13, 25],
#          [22, 25],
#          [ 9, 22],
#          [16, 24],
#          [24, 27]]),
#   array([[ 9, 18],
#          [ 9, 18],
#          [15, 18],
#          [15, 18],
#          [ 6, 26]]),
#   array([[18, 24],
#          [16, 24],
#          [10, 15],
#          [ 4, 26],
#          [23, 26]]),
#   array([[13, 16],
#          [19, 22],
#          [ 1,  8],
#          [18, 26],
#          [14, 21]]),
#   array([[17, 24],
#          [17, 21],
#          [10, 13],
#          [14, 17],
#          [ 9, 18]]),
#   array([[22, 25],
#          [ 3, 21],
#          [14, 17],
#          [12, 15],
#          [ 5, 25]]),
#   array([[15, 18],
#          [ 5, 11],
#          [ 7, 11],
#          [15, 18],
#          [ 1,  4]]),
#   array([[16, 21],
#          [15, 25],
#          [22, 25],
#          [15, 20],
#          [16, 26]]),
#   array([[23, 26],
#          [15, 26],
#          [23, 26],
#          [ 3, 20],
#          [ 6, 19]]),
#   array([[10, 14],
#          [ 9, 25],
#          [ 1, 24],
#          [ 0, 26],
#          [11, 17]]),
#   array([[ 4, 25],
#          [21, 24],
#          [17, 26],
#          [ 1,  8],
#          [11, 16]]),
#   array([[10, 18],
#          [17, 21],
#          [22, 25],
#          [21, 24],
#          [16, 20]]),
#   array([[22, 25],
#          [21, 26],
#          [20, 23],
#          [11, 15],
#          [21, 24]]),
#   array([[15, 23],
#          [ 6, 16],
#          [18, 26],
#          [15, 20],
#          [10, 13]]),
#   array([[ 4, 11],
#          [ 6, 19],
#          [15, 26],
#          [ 8, 22],
#          [ 2,  6]]),
#   array([[10, 22],
#          [22, 25],
#          [24, 27],
#          [ 0,  4],
#          [23, 26]]),
#   array([[ 2, 18],
#          [12, 17],
#          [16, 19],
#          [16, 25],
#          [13, 25]]),
#   array([[17, 20],
#          [ 8, 20],
#          [ 3, 26],
#          [14, 26],
#          [ 0, 22]]),
#   array([[19, 23],
#          [ 1,  6],
#          [22, 25],
#          [ 2, 19],
#          [22, 25]]),
#   array([[ 6, 24],
#          [ 7, 11],
#          [11, 22],
#          [19, 22],
#          [ 4,  7]]),
#   array([[21, 24],
#          [12, 16],
#          [11, 19],
#          [ 9, 26],
#          [ 2,  5]]),
#   array([[21, 24],
#          [19, 22],
#          [24, 27],
#          [ 3, 26],
#          [12, 19]])],
#  'estimators': [DecisionTreeClassifier(criterion='entropy', random_state=1968010291),
#   DecisionTreeClassifier(criterion='entropy', random_state=975057917),
#   DecisionTreeClassifier(criterion='entropy', random_state=1958604663),
#   DecisionTreeClassifier(criterion='entropy', random_state=155154304),
#   DecisionTreeClassifier(criterion='entropy', random_state=2021479225),
#   DecisionTreeClassifier(criterion='entropy', random_state=1080618360),
#   DecisionTreeClassifier(criterion='entropy', random_state=175965834),
#   DecisionTreeClassifier(criterion='entropy', random_state=477702304),
#   DecisionTreeClassifier(criterion='entropy', random_state=447652891),
#   DecisionTreeClassifier(criterion='entropy', random_state=856512192),
#   DecisionTreeClassifier(criterion='entropy', random_state=924893766),
#   DecisionTreeClassifier(criterion='entropy', random_state=1078079810),
#   DecisionTreeClassifier(criterion='entropy', random_state=1625075790),
#   DecisionTreeClassifier(criterion='entropy', random_state=1490987250),
#   DecisionTreeClassifier(criterion='entropy', random_state=336281302),
#   DecisionTreeClassifier(criterion='entropy', random_state=643624811),
#   DecisionTreeClassifier(criterion='entropy', random_state=962969160),
#   DecisionTreeClassifier(criterion='entropy', random_state=1121152332),
#   DecisionTreeClassifier(criterion='entropy', random_state=314020505),
#   DecisionTreeClassifier(criterion='entropy', random_state=1800445613),
#   DecisionTreeClassifier(criterion='entropy', random_state=377516025),
#   DecisionTreeClassifier(criterion='entropy', random_state=580623907),
#   DecisionTreeClassifier(criterion='entropy', random_state=878672736),
#   DecisionTreeClassifier(criterion='entropy', random_state=952668914),
#   DecisionTreeClassifier(criterion='entropy', random_state=1126257423),
#   DecisionTreeClassifier(criterion='entropy', random_state=929445700),
#   DecisionTreeClassifier(criterion='entropy', random_state=309624538),
#   DecisionTreeClassifier(criterion='entropy', random_state=1867936433),
#   DecisionTreeClassifier(criterion='entropy', random_state=39891876),
#   DecisionTreeClassifier(criterion='entropy', random_state=226414580),
#   DecisionTreeClassifier(criterion='entropy', random_state=555391429),
#   DecisionTreeClassifier(criterion='entropy', random_state=1372378871),
#   DecisionTreeClassifier(criterion='entropy', random_state=170571640),
#   DecisionTreeClassifier(criterion='entropy', random_state=2109751696),
#   DecisionTreeClassifier(criterion='entropy', random_state=1735948208),
#   DecisionTreeClassifier(criterion='entropy', random_state=1242060094),
#   DecisionTreeClassifier(criterion='entropy', random_state=575716471),
#   DecisionTreeClassifier(criterion='entropy', random_state=1150950113),
#   DecisionTreeClassifier(criterion='entropy', random_state=856072118),
#   DecisionTreeClassifier(criterion='entropy', random_state=2067821301),
#   DecisionTreeClassifier(criterion='entropy', random_state=1613147213),
#   DecisionTreeClassifier(criterion='entropy', random_state=1542330561),
#   DecisionTreeClassifier(criterion='entropy', random_state=137808569),
#   DecisionTreeClassifier(criterion='entropy', random_state=263701348),
#   DecisionTreeClassifier(criterion='entropy', random_state=1612832943),
#   DecisionTreeClassifier(criterion='entropy', random_state=719226420),
#   DecisionTreeClassifier(criterion='entropy', random_state=1708420104),
#   DecisionTreeClassifier(criterion='entropy', random_state=1901141030),
#   DecisionTreeClassifier(criterion='entropy', random_state=1868139580),
#   DecisionTreeClassifier(criterion='entropy', random_state=193518411),
#   DecisionTreeClassifier(criterion='entropy', random_state=1753669060),
#   DecisionTreeClassifier(criterion='entropy', random_state=855102577),
#   DecisionTreeClassifier(criterion='entropy', random_state=2120575224),
#   DecisionTreeClassifier(criterion='entropy', random_state=1700639784),
#   DecisionTreeClassifier(criterion='entropy', random_state=1585549022),
#   DecisionTreeClassifier(criterion='entropy', random_state=699631476),
#   DecisionTreeClassifier(criterion='entropy', random_state=1950518801),
#   DecisionTreeClassifier(criterion='entropy', random_state=1543420612),
#   DecisionTreeClassifier(criterion='entropy', random_state=470763249),
#   DecisionTreeClassifier(criterion='entropy', random_state=457872217),
#   DecisionTreeClassifier(criterion='entropy', random_state=1071289242),
#   DecisionTreeClassifier(criterion='entropy', random_state=1430697676),
#   DecisionTreeClassifier(criterion='entropy', random_state=2107317692),
#   DecisionTreeClassifier(criterion='entropy', random_state=934538614),
#   DecisionTreeClassifier(criterion='entropy', random_state=728151314),
#   DecisionTreeClassifier(criterion='entropy', random_state=1591681927),
#   DecisionTreeClassifier(criterion='entropy', random_state=177371249),
#   DecisionTreeClassifier(criterion='entropy', random_state=299095944),
#   DecisionTreeClassifier(criterion='entropy', random_state=1837625725),
#   DecisionTreeClassifier(criterion='entropy', random_state=1175234328),
#   DecisionTreeClassifier(criterion='entropy', random_state=648029035),
#   DecisionTreeClassifier(criterion='entropy', random_state=796620954),
#   DecisionTreeClassifier(criterion='entropy', random_state=27480541),
#   DecisionTreeClassifier(criterion='entropy', random_state=298801290),
#   DecisionTreeClassifier(criterion='entropy', random_state=735739407),
#   DecisionTreeClassifier(criterion='entropy', random_state=935551674),
#   DecisionTreeClassifier(criterion='entropy', random_state=1037811683),
#   DecisionTreeClassifier(criterion='entropy', random_state=833705901),
#   DecisionTreeClassifier(criterion='entropy', random_state=1814217923),
#   DecisionTreeClassifier(criterion='entropy', random_state=340452947),
#   DecisionTreeClassifier(criterion='entropy', random_state=542836666),
#   DecisionTreeClassifier(criterion='entropy', random_state=563542081),
#   DecisionTreeClassifier(criterion='entropy', random_state=968601401),
#   DecisionTreeClassifier(criterion='entropy', random_state=1116334986),
#   DecisionTreeClassifier(criterion='entropy', random_state=273434202),
#   DecisionTreeClassifier(criterion='entropy', random_state=49298537),
#   DecisionTreeClassifier(criterion='entropy', random_state=1255941325),
#   DecisionTreeClassifier(criterion='entropy', random_state=1333968867),
#   DecisionTreeClassifier(criterion='entropy', random_state=648029771),
#   DecisionTreeClassifier(criterion='entropy', random_state=54433113),
#   DecisionTreeClassifier(criterion='entropy', random_state=606639911),
#   DecisionTreeClassifier(criterion='entropy', random_state=995238590),
#   DecisionTreeClassifier(criterion='entropy', random_state=526087454),
#   DecisionTreeClassifier(criterion='entropy', random_state=1345950669),
#   DecisionTreeClassifier(criterion='entropy', random_state=1970756818),
#   DecisionTreeClassifier(criterion='entropy', random_state=501180391),
#   DecisionTreeClassifier(criterion='entropy', random_state=137459904),
#   DecisionTreeClassifier(criterion='entropy', random_state=152852838),
#   DecisionTreeClassifier(criterion='entropy', random_state=68630640),
#   DecisionTreeClassifier(criterion='entropy', random_state=1371916593),
#   DecisionTreeClassifier(criterion='entropy', random_state=295204245),
#   DecisionTreeClassifier(criterion='entropy', random_state=1301777002),
#   DecisionTreeClassifier(criterion='entropy', random_state=1216700766),
#   DecisionTreeClassifier(criterion='entropy', random_state=842830157),
#   DecisionTreeClassifier(criterion='entropy', random_state=1690738510),
#   DecisionTreeClassifier(criterion='entropy', random_state=984151927),
#   DecisionTreeClassifier(criterion='entropy', random_state=113677213),
#   DecisionTreeClassifier(criterion='entropy', random_state=2097056747),
#   DecisionTreeClassifier(criterion='entropy', random_state=1570560973),
#   DecisionTreeClassifier(criterion='entropy', random_state=1905225225),
#   DecisionTreeClassifier(criterion='entropy', random_state=1585582787),
#   DecisionTreeClassifier(criterion='entropy', random_state=1950147726),
#   DecisionTreeClassifier(criterion='entropy', random_state=1488622977),
#   DecisionTreeClassifier(criterion='entropy', random_state=1944547844),
#   DecisionTreeClassifier(criterion='entropy', random_state=1882239401),
#   DecisionTreeClassifier(criterion='entropy', random_state=133880876),
#   DecisionTreeClassifier(criterion='entropy', random_state=170564804),
#   DecisionTreeClassifier(criterion='entropy', random_state=1152650344),
#   DecisionTreeClassifier(criterion='entropy', random_state=1175330855),
#   DecisionTreeClassifier(criterion='entropy', random_state=71612204),
#   DecisionTreeClassifier(criterion='entropy', random_state=1785187818),
#   DecisionTreeClassifier(criterion='entropy', random_state=1646165361),
#   DecisionTreeClassifier(criterion='entropy', random_state=1362440530),
#   DecisionTreeClassifier(criterion='entropy', random_state=1487592820),
#   DecisionTreeClassifier(criterion='entropy', random_state=249363051),
#   DecisionTreeClassifier(criterion='entropy', random_state=8972845),
#   DecisionTreeClassifier(criterion='entropy', random_state=1547161158),
#   DecisionTreeClassifier(criterion='entropy', random_state=504719067),
#   DecisionTreeClassifier(criterion='entropy', random_state=1939872686),
#   DecisionTreeClassifier(criterion='entropy', random_state=1894939835),
#   DecisionTreeClassifier(criterion='entropy', random_state=36811616),
#   DecisionTreeClassifier(criterion='entropy', random_state=369818490),
#   DecisionTreeClassifier(criterion='entropy', random_state=1488487921),
#   DecisionTreeClassifier(criterion='entropy', random_state=1263583876),
#   DecisionTreeClassifier(criterion='entropy', random_state=1506697823),
#   DecisionTreeClassifier(criterion='entropy', random_state=1846816473),
#   DecisionTreeClassifier(criterion='entropy', random_state=361516749),
#   DecisionTreeClassifier(criterion='entropy', random_state=1029519668),
#   DecisionTreeClassifier(criterion='entropy', random_state=1823484765),
#   DecisionTreeClassifier(criterion='entropy', random_state=1771991151),
#   DecisionTreeClassifier(criterion='entropy', random_state=1726746894),
#   DecisionTreeClassifier(criterion='entropy', random_state=401838967),
#   DecisionTreeClassifier(criterion='entropy', random_state=1417466078),
#   DecisionTreeClassifier(criterion='entropy', random_state=1250460230),
#   DecisionTreeClassifier(criterion='entropy', random_state=1955200325),
#   DecisionTreeClassifier(criterion='entropy', random_state=1874356343),
#   DecisionTreeClassifier(criterion='entropy', random_state=673082214),
#   DecisionTreeClassifier(criterion='entropy', random_state=429163954),
#   DecisionTreeClassifier(criterion='entropy', random_state=784557252),
#   DecisionTreeClassifier(criterion='entropy', random_state=915189862),
#   DecisionTreeClassifier(criterion='entropy', random_state=1503178172),
#   DecisionTreeClassifier(criterion='entropy', random_state=1021998796),
#   DecisionTreeClassifier(criterion='entropy', random_state=1737504705),
#   DecisionTreeClassifier(criterion='entropy', random_state=1014369865),
#   DecisionTreeClassifier(criterion='entropy', random_state=1105925753),
#   DecisionTreeClassifier(criterion='entropy', random_state=1073063933),
#   DecisionTreeClassifier(criterion='entropy', random_state=501960665),
#   DecisionTreeClassifier(criterion='entropy', random_state=559553903),
#   DecisionTreeClassifier(criterion='entropy', random_state=170687978),
#   DecisionTreeClassifier(criterion='entropy', random_state=1203799777),
#   DecisionTreeClassifier(criterion='entropy', random_state=1866757047),
#   DecisionTreeClassifier(criterion='entropy', random_state=1985657360),
#   DecisionTreeClassifier(criterion='entropy', random_state=1264434654),
#   DecisionTreeClassifier(criterion='entropy', random_state=1440435087),
#   DecisionTreeClassifier(criterion='entropy', random_state=37093234),
#   DecisionTreeClassifier(criterion='entropy', random_state=1719520327),
#   DecisionTreeClassifier(criterion='entropy', random_state=1085238255),
#   DecisionTreeClassifier(criterion='entropy', random_state=1688933889),
#   DecisionTreeClassifier(criterion='entropy', random_state=1961642047),
#   DecisionTreeClassifier(criterion='entropy', random_state=203661943),
#   DecisionTreeClassifier(criterion='entropy', random_state=1571375452),
#   DecisionTreeClassifier(criterion='entropy', random_state=1799600644),
#   DecisionTreeClassifier(criterion='entropy', random_state=247986443),
#   DecisionTreeClassifier(criterion='entropy', random_state=254989834),
#   DecisionTreeClassifier(criterion='entropy', random_state=862323051),
#   DecisionTreeClassifier(criterion='entropy', random_state=2091222579),
#   DecisionTreeClassifier(criterion='entropy', random_state=2094185781),
#   DecisionTreeClassifier(criterion='entropy', random_state=1275657942),
#   DecisionTreeClassifier(criterion='entropy', random_state=287703525),
#   DecisionTreeClassifier(criterion='entropy', random_state=510415317),
#   DecisionTreeClassifier(criterion='entropy', random_state=646095117),
#   DecisionTreeClassifier(criterion='entropy', random_state=1777072301),
#   DecisionTreeClassifier(criterion='entropy', random_state=1589647680),
#   DecisionTreeClassifier(criterion='entropy', random_state=283262237),
#   DecisionTreeClassifier(criterion='entropy', random_state=218606441),
#   DecisionTreeClassifier(criterion='entropy', random_state=469697398),
#   DecisionTreeClassifier(criterion='entropy', random_state=1181278285),
#   DecisionTreeClassifier(criterion='entropy', random_state=1373955077),
#   DecisionTreeClassifier(criterion='entropy', random_state=1391847882),
#   DecisionTreeClassifier(criterion='entropy', random_state=870557700),
#   DecisionTreeClassifier(criterion='entropy', random_state=856292793),
#   DecisionTreeClassifier(criterion='entropy', random_state=1335052790),
#   DecisionTreeClassifier(criterion='entropy', random_state=2061346706),
#   DecisionTreeClassifier(criterion='entropy', random_state=570548504),
#   DecisionTreeClassifier(criterion='entropy', random_state=1857169959),
#   DecisionTreeClassifier(criterion='entropy', random_state=493684562),
#   DecisionTreeClassifier(criterion='entropy', random_state=1485589563),
#   DecisionTreeClassifier(criterion='entropy', random_state=601816507),
#   DecisionTreeClassifier(criterion='entropy', random_state=1458818854),
#   DecisionTreeClassifier(criterion='entropy', random_state=127132049)],
#  'n_classes': 2,
#  'fit_time': 338782}

# %%
# Réalisation des prédictions

y_pred = clf_rf_ts.predict(X_test)

# %% [markdown]
# ## 5. Évaluation

# %%
# Élaboration de la matrice de confusion

pd.crosstab(y_test, y_pred, rownames = ["Classe réelle"], colnames = ["Classe prédite"])
# Out:
# Classe prédite     0    1
# Classe réelle
# 0               9799  244
# 1               2033  878

# %%
# Élaboration du rapport de classification

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90     10043
#            1       0.78      0.30      0.44      2911
#
#     accuracy                           0.82     12954
#    macro avg       0.81      0.64      0.67     12954
# weighted avg       0.82      0.82      0.79     12954
