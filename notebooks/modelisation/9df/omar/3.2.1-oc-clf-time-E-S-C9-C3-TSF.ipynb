# %% [markdown]
# # **Classification** des **séries temporelles** avec `sktime`

# %% [markdown]
# ## Métadonnées

# %% [markdown]
# - **Expérience nº :** 3.2.1
# - **Date :** 09/11/2023
# - **Heure :** 14:56
# - **Données :** `ready_Evaporation_Sunshine_Cloud9am_Cloud3pm.csv`
# - **Tri :** par défaut
# - **Découpage :** `TimeSeriesSplit`
# - **Mise à l'échelle :** non
# - **Rééquilibrage :** non
# - **Conversion :** `numpyfy`
# - **Algorithme :** TSF

# %% [markdown]
# ## Sommaire

# %% [markdown]
# 1. Initialisation
# 2. Découpage
# 3. Conversion
# 4. Modélisation
# 5. Évaluation

# %% [markdown]
# ## 1. Initialisation

# %%
# Importation des bibliothèques et modules nécessaires au fonctionnement de ce notebook

import pandas as pd
import numpy as np

from sklearn.metrics import classification_report

# %%
# Importation du jeu de données et enregistrement dans le DataFrame `df`

df = pd.read_csv("../../../../data/processed/omar/ready_Evaporation_Sunshine_Cloud9am_Cloud3pm.csv", index_col = 1)
df = df.drop(columns = "Unnamed: 0")

# %%
# Inspection de la structure de `df`

df.head()
# Out:
#             MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  \
# Date
# 2009-01-01     13.3     34.2       0.0           61.0          11.0
# 2009-01-02     14.7     26.1       0.0           46.0           7.0
# 2009-01-03     13.6     22.3       0.0           30.0           6.0
# 2009-01-04     17.7     31.2       0.0           39.0           9.0
# 2009-01-05     15.5     38.8       0.0           50.0           7.0
#
#             WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# Date
# 2009-01-01     14.013296         67.0    51.422456       1005.6  1015.640417
# 2009-01-02     24.000000         59.0    54.000000       1012.9  1013.500000
# 2009-01-03     15.000000         57.0    51.000000       1021.9  1019.200000
# 2009-01-04     15.000000         62.0    43.000000       1018.7  1013.600000
# 2009-01-05     17.000000         67.0    19.000000       1013.2  1007.600000
#
#             ...  year  month  day  LocationNum  WindGustDirNum  WindDir9amNum  \
# Date        ...
# 2009-01-01  ...  2009      1    1            1        3.141593       1.178097
# 2009-01-02  ...  2009      1    2            1        5.497787       5.497787
# 2009-01-03  ...  2009      1    3            1        1.178097       5.890486
# 2009-01-04  ...  2009      1    4            1        0.785398       1.178097
# 2009-01-05  ...  2009      1    5            1        3.926991       1.178097
#
#             WindDir3pmNum   Latitude   Longitude  CodeRegionNum
# Date
# 2009-01-01       2.917968 -33.881667  150.744163              0
# 2009-01-02       5.497787 -33.881667  150.744163              0
# 2009-01-03       0.785398 -33.881667  150.744163              0
# 2009-01-04       1.570796 -33.881667  150.744163              0
# 2009-01-05       3.141593 -33.881667  150.744163              0
#
# [5 rows x 24 columns]

# %%
# Inspection de la structure de `df`

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18907 entries, 2009-01-01 to 2017-06-25
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   MinTemp         18907 non-null  float64
#  1   MaxTemp         18907 non-null  float64
#  2   Rainfall        18907 non-null  float64
#  3   WindGustSpeed   18907 non-null  float64
#  4   WindSpeed9am    18907 non-null  float64
#  5   WindSpeed3pm    18907 non-null  float64
#  6   Humidity9am     18907 non-null  float64
#  7   Humidity3pm     18907 non-null  float64
#  8   Pressure9am     18907 non-null  float64
#  9   Pressure3pm     18907 non-null  float64
#  10  Temp9am         18907 non-null  float64
#  11  Temp3pm         18907 non-null  float64
#  12  RainToday       18907 non-null  int64
#  13  RainTomorrow    18907 non-null  int64
#  14  year            18907 non-null  int64
#  15  month           18907 non-null  int64
#  16  day             18907 non-null  int64
#  17  LocationNum     18907 non-null  int64
#  18  WindGustDirNum  18907 non-null  float64
#  19  WindDir9amNum   18907 non-null  float64
#  20  WindDir3pmNum   18907 non-null  float64
#  21  Latitude        18907 non-null  float64
#  22  Longitude       18907 non-null  float64
#  23  CodeRegionNum   18907 non-null  int64
# dtypes: float64(17), int64(7)
# memory usage: 3.6+ MB

# %% [markdown]
# ## 2. Découpage

# %%
# Découpage de `df` sur l'axe des colonnes : séparation des variables explicatives (`data`) et cible (`target`)

data = df.drop(columns = "RainTomorrow")
target = df["RainTomorrow"]

# %%
# Découpage de `data` et de `target` sur l'axe des lignes : séparation des jeux d'entraînement (`*_train`) et de test (`*_test`) avec le splitter `TimeSeriesSplit`

from sklearn.model_selection import TimeSeriesSplit

tss = TimeSeriesSplit(n_splits = 5) ## Nous fixons le paramètre `n_splits` à 5 afin d'avoir une répartition de 80 / 20 entre les jeux d'entraînement et de test, respectivement.

for train_index, test_index in tss.split(data):
    X_train, X_test = data.iloc[train_index, :], data.iloc[test_index,:]
    y_train, y_test = target.iloc[train_index], target.iloc[test_index]

# %% [markdown]
# ## 3. Conversion

# %%
# Importation de la fonction artisanale `numpyfy`

from numpyfy import numpyfy

# %%
# Application de la fonction `numpyfy` aux 4 jeux de données issus du découpage effectué par le splitter `TimeSeriesSplit` afin de les convertir en arrays et ainsi les rendre compatibles avec `sktime`

X_train, X_test, y_train, y_test = numpyfy(X_train, X_test, y_train, y_test)

# %% [markdown]
# ## 4. Modélisation

# %%
# Instanciation d'un modèle classificateur via un Pipeline

from sklearn.pipeline import Pipeline
from sktime.transformations.panel.compose import ColumnConcatenator
from sktime.classification.interval_based import TimeSeriesForestClassifier

steps = [
    ("concatenate", ColumnConcatenator()), ## Cette étape permet de transformer les jeux de données multivariées en univariées afin qu'ils puissent être traités par `TimeSeriesForestClassifier`.
    ("classify", TimeSeriesForestClassifier()),
]

clf_rf_ts = Pipeline(steps)

# %%
# Récupération des paramètres initiaux de la TSF

clf_rf_ts["classify"].get_params()
# Out:
# {'min_interval': 3, 'n_estimators': 200, 'n_jobs': 1, 'random_state': None}

# %%
# Entraînement du modèle

clf_rf_ts.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('concatenate', ColumnConcatenator()),
#                 ('classify', TimeSeriesForestClassifier())])

# %%
# Récupération des paramètres ajustés de la TSF

clf_rf_ts["classify"].get_fitted_params()
# Out:
# {'classes': array([0, 1]),
#  'intervals': [array([[15, 18],
#          [ 3, 16],
#          [ 4, 19],
#          [ 1,  4]]),
#   array([[ 4, 10],
#          [14, 17],
#          [ 5, 15],
#          [ 1,  6]]),
#   array([[16, 19],
#          [ 1, 14],
#          [11, 14],
#          [14, 21]]),
#   array([[ 7, 13],
#          [17, 20],
#          [ 2, 19],
#          [ 4,  9]]),
#   array([[ 0,  5],
#          [17, 20],
#          [14, 19],
#          [ 9, 18]]),
#   array([[17, 20],
#          [ 4, 19],
#          [ 0,  3],
#          [18, 21]]),
#   array([[10, 16],
#          [ 2, 11],
#          [ 7, 15],
#          [16, 21]]),
#   array([[15, 20],
#          [14, 17],
#          [11, 14],
#          [10, 13]]),
#   array([[ 2, 21],
#          [ 4, 13],
#          [ 2, 17],
#          [14, 19]]),
#   array([[ 5, 14],
#          [14, 17],
#          [11, 20],
#          [15, 18]]),
#   array([[12, 15],
#          [ 7, 10],
#          [18, 21],
#          [ 3, 12]]),
#   array([[14, 21],
#          [ 2, 17],
#          [19, 22],
#          [ 6, 19]]),
#   array([[16, 19],
#          [15, 19],
#          [ 7, 14],
#          [ 1, 17]]),
#   array([[ 2,  7],
#          [ 5, 20],
#          [ 5,  8],
#          [16, 19]]),
#   array([[11, 18],
#          [ 0,  3],
#          [11, 21],
#          [19, 22]]),
#   array([[13, 16],
#          [18, 21],
#          [14, 19],
#          [15, 18]]),
#   array([[12, 21],
#          [ 2, 13],
#          [ 5, 11],
#          [ 3,  9]]),
#   array([[19, 22],
#          [ 7, 12],
#          [ 2, 19],
#          [ 2, 18]]),
#   array([[10, 16],
#          [14, 17],
#          [17, 21],
#          [10, 14]]),
#   array([[ 7, 17],
#          [16, 19],
#          [16, 21],
#          [ 5,  8]]),
#   array([[19, 22],
#          [13, 16],
#          [19, 22],
#          [ 1, 13]]),
#   array([[17, 20],
#          [ 8, 19],
#          [ 8, 12],
#          [17, 20]]),
#   array([[ 1, 13],
#          [16, 19],
#          [ 6, 10],
#          [15, 18]]),
#   array([[ 0,  5],
#          [ 9, 16],
#          [ 6, 15],
#          [ 6, 18]]),
#   array([[18, 21],
#          [19, 22],
#          [12, 18],
#          [ 6, 21]]),
#   array([[18, 21],
#          [ 7, 13],
#          [ 1, 14],
#          [16, 19]]),
#   array([[ 2,  6],
#          [15, 19],
#          [ 4,  7],
#          [ 8, 19]]),
#   array([[ 8, 11],
#          [ 5,  8],
#          [17, 20],
#          [ 6, 20]]),
#   array([[10, 13],
#          [15, 21],
#          [ 9, 12],
#          [15, 18]]),
#   array([[19, 22],
#          [12, 15],
#          [ 1, 21],
#          [ 8, 13]]),
#   array([[15, 20],
#          [15, 21],
#          [15, 18],
#          [12, 15]]),
#   array([[ 4,  9],
#          [17, 21],
#          [ 7, 10],
#          [ 1, 21]]),
#   array([[19, 22],
#          [10, 13],
#          [10, 13],
#          [ 1,  6]]),
#   array([[ 4, 11],
#          [16, 19],
#          [ 5,  8],
#          [ 4, 18]]),
#   array([[14, 18],
#          [ 9, 19],
#          [10, 13],
#          [ 0, 15]]),
#   array([[ 9, 18],
#          [ 8, 19],
#          [14, 17],
#          [12, 19]]),
#   array([[ 7, 21],
#          [ 3,  6],
#          [18, 21],
#          [ 2, 21]]),
#   array([[ 3,  7],
#          [19, 22],
#          [ 8, 16],
#          [ 3, 15]]),
#   array([[ 0,  8],
#          [11, 14],
#          [13, 19],
#          [ 6, 12]]),
#   array([[ 3, 19],
#          [ 0, 11],
#          [14, 19],
#          [16, 20]]),
#   array([[11, 14],
#          [ 3, 21],
#          [12, 21],
#          [18, 21]]),
#   array([[ 8, 15],
#          [11, 18],
#          [ 7, 14],
#          [ 4, 12]]),
#   array([[10, 13],
#          [19, 22],
#          [13, 16],
#          [11, 20]]),
#   array([[ 3, 21],
#          [18, 21],
#          [ 2,  5],
#          [ 6,  9]]),
#   array([[16, 19],
#          [ 5,  8],
#          [19, 22],
#          [15, 21]]),
#   array([[ 5, 13],
#          [ 0, 21],
#          [14, 17],
#          [ 6, 13]]),
#   array([[15, 21],
#          [14, 17],
#          [ 2,  5],
#          [12, 18]]),
#   array([[12, 17],
#          [ 1,  6],
#          [ 7, 20],
#          [ 6, 19]]),
#   array([[ 4, 21],
#          [ 7, 15],
#          [19, 22],
#          [16, 20]]),
#   array([[18, 21],
#          [ 4,  7],
#          [19, 22],
#          [ 2, 17]]),
#   array([[18, 21],
#          [ 2,  7],
#          [ 8, 18],
#          [ 3, 21]]),
#   array([[ 8, 14],
#          [ 7, 10],
#          [ 0, 14],
#          [12, 17]]),
#   array([[19, 22],
#          [ 6, 13],
#          [15, 18],
#          [10, 20]]),
#   array([[ 5, 16],
#          [ 4, 17],
#          [ 0, 18],
#          [16, 19]]),
#   array([[15, 19],
#          [10, 19],
#          [17, 20],
#          [ 4, 21]]),
#   array([[18, 21],
#          [ 1, 15],
#          [15, 19],
#          [ 7, 17]]),
#   array([[ 4, 21],
#          [11, 17],
#          [ 7, 14],
#          [14, 17]]),
#   array([[ 4, 16],
#          [11, 14],
#          [18, 21],
#          [ 0, 18]]),
#   array([[ 5, 10],
#          [18, 21],
#          [19, 22],
#          [13, 16]]),
#   array([[16, 19],
#          [ 4, 15],
#          [15, 19],
#          [ 1,  6]]),
#   array([[14, 17],
#          [ 0, 20],
#          [10, 15],
#          [14, 20]]),
#   array([[10, 13],
#          [10, 13],
#          [13, 16],
#          [ 9, 18]]),
#   array([[ 1,  9],
#          [12, 19],
#          [ 6, 15],
#          [17, 20]]),
#   array([[15, 18],
#          [ 6, 12],
#          [ 6, 12],
#          [ 7, 16]]),
#   array([[14, 18],
#          [ 9, 16],
#          [ 0,  9],
#          [ 6, 19]]),
#   array([[16, 19],
#          [ 2, 20],
#          [19, 22],
#          [ 8, 11]]),
#   array([[ 0,  9],
#          [14, 17],
#          [ 5, 11],
#          [18, 21]]),
#   array([[19, 22],
#          [12, 17],
#          [10, 17],
#          [11, 18]]),
#   array([[ 2, 11],
#          [11, 20],
#          [ 7, 10],
#          [12, 15]]),
#   array([[13, 20],
#          [ 3, 12],
#          [18, 21],
#          [14, 19]]),
#   array([[ 5, 20],
#          [12, 15],
#          [13, 20],
#          [14, 21]]),
#   array([[14, 18],
#          [ 8, 12],
#          [18, 21],
#          [ 0, 17]]),
#   array([[ 0,  3],
#          [ 6, 10],
#          [ 7, 10],
#          [ 7, 15]]),
#   array([[11, 17],
#          [ 2, 19],
#          [14, 20],
#          [17, 20]]),
#   array([[18, 21],
#          [ 2,  5],
#          [ 8, 21],
#          [ 6, 11]]),
#   array([[14, 21],
#          [10, 20],
#          [ 1, 18],
#          [13, 20]]),
#   array([[ 4, 16],
#          [14, 17],
#          [ 4,  7],
#          [15, 18]]),
#   array([[ 8, 19],
#          [ 2, 17],
#          [13, 19],
#          [17, 20]]),
#   array([[ 1, 14],
#          [11, 14],
#          [13, 16],
#          [14, 17]]),
#   array([[ 9, 21],
#          [ 0,  4],
#          [18, 21],
#          [ 0,  3]]),
#   array([[13, 21],
#          [ 4, 17],
#          [ 9, 18],
#          [ 4, 20]]),
#   array([[15, 20],
#          [16, 20],
#          [ 7, 18],
#          [ 2, 17]]),
#   array([[ 2, 18],
#          [10, 20],
#          [ 9, 21],
#          [ 2, 15]]),
#   array([[15, 18],
#          [11, 20],
#          [ 4, 11],
#          [13, 18]]),
#   array([[ 4, 19],
#          [ 2,  8],
#          [16, 19],
#          [ 8, 11]]),
#   array([[ 3,  9],
#          [ 3, 21],
#          [ 2, 15],
#          [11, 14]]),
#   array([[ 2,  8],
#          [ 9, 15],
#          [16, 19],
#          [ 6,  9]]),
#   array([[16, 19],
#          [11, 19],
#          [ 2, 16],
#          [ 5, 13]]),
#   array([[16, 21],
#          [ 2, 20],
#          [10, 20],
#          [ 8, 16]]),
#   array([[ 9, 17],
#          [ 0, 16],
#          [11, 20],
#          [17, 21]]),
#   array([[18, 21],
#          [10, 14],
#          [14, 17],
#          [10, 13]]),
#   array([[19, 22],
#          [14, 17],
#          [ 5, 17],
#          [15, 18]]),
#   array([[14, 17],
#          [ 6, 15],
#          [19, 22],
#          [13, 19]]),
#   array([[14, 18],
#          [ 3, 16],
#          [ 7, 10],
#          [13, 17]]),
#   array([[ 6,  9],
#          [ 8, 14],
#          [19, 22],
#          [12, 16]]),
#   array([[ 5, 12],
#          [ 8, 17],
#          [18, 21],
#          [10, 20]]),
#   array([[15, 19],
#          [11, 16],
#          [12, 15],
#          [ 6, 12]]),
#   array([[ 4,  7],
#          [12, 19],
#          [ 0, 10],
#          [10, 17]]),
#   array([[ 7, 10],
#          [ 1,  5],
#          [15, 21],
#          [ 0,  3]]),
#   array([[ 1,  9],
#          [ 1,  8],
#          [ 9, 19],
#          [ 3,  9]]),
#   array([[15, 20],
#          [18, 21],
#          [ 4, 20],
#          [ 8, 20]]),
#   array([[15, 18],
#          [ 9, 15],
#          [19, 22],
#          [15, 21]]),
#   array([[ 5, 17],
#          [ 8, 15],
#          [ 6, 10],
#          [11, 17]]),
#   array([[17, 20],
#          [ 7, 10],
#          [10, 13],
#          [10, 13]]),
#   array([[13, 16],
#          [ 6, 10],
#          [ 5, 21],
#          [ 3, 16]]),
#   array([[16, 19],
#          [ 5,  8],
#          [ 2,  5],
#          [14, 17]]),
#   array([[10, 20],
#          [ 7, 10],
#          [ 5, 20],
#          [13, 19]]),
#   array([[11, 17],
#          [ 2, 15],
#          [ 7, 19],
#          [13, 18]]),
#   array([[ 5, 16],
#          [ 1,  7],
#          [ 1,  4],
#          [ 4, 12]]),
#   array([[ 3, 10],
#          [12, 15],
#          [12, 16],
#          [11, 19]]),
#   array([[ 2, 15],
#          [ 0,  3],
#          [18, 21],
#          [11, 21]]),
#   array([[16, 20],
#          [ 8, 19],
#          [14, 17],
#          [ 3,  6]]),
#   array([[17, 20],
#          [17, 20],
#          [ 2,  6],
#          [ 0, 18]]),
#   array([[ 5,  8],
#          [ 1,  4],
#          [19, 22],
#          [ 3, 16]]),
#   array([[10, 13],
#          [ 4, 19],
#          [16, 19],
#          [12, 15]]),
#   array([[ 6, 17],
#          [ 7, 10],
#          [13, 17],
#          [ 3,  7]]),
#   array([[ 2,  7],
#          [ 7, 11],
#          [19, 22],
#          [14, 20]]),
#   array([[16, 19],
#          [13, 18],
#          [18, 21],
#          [17, 20]]),
#   array([[12, 18],
#          [ 4, 20],
#          [ 3,  6],
#          [17, 20]]),
#   array([[ 6, 15],
#          [17, 21],
#          [ 0,  7],
#          [ 4, 17]]),
#   array([[ 4, 17],
#          [11, 19],
#          [ 0, 12],
#          [14, 18]]),
#   array([[ 2, 20],
#          [ 3,  6],
#          [13, 16],
#          [15, 18]]),
#   array([[12, 16],
#          [13, 16],
#          [18, 21],
#          [19, 22]]),
#   array([[13, 17],
#          [17, 20],
#          [19, 22],
#          [19, 22]]),
#   array([[ 9, 19],
#          [18, 21],
#          [ 6, 20],
#          [ 4, 12]]),
#   array([[10, 13],
#          [ 9, 19],
#          [ 1, 18],
#          [ 4, 19]]),
#   array([[ 1,  8],
#          [15, 18],
#          [19, 22],
#          [ 4,  7]]),
#   array([[10, 21],
#          [15, 20],
#          [10, 16],
#          [16, 19]]),
#   array([[ 4, 14],
#          [15, 20],
#          [18, 21],
#          [ 8, 21]]),
#   array([[ 3, 14],
#          [17, 21],
#          [ 5, 11],
#          [ 1,  4]]),
#   array([[ 1, 18],
#          [ 0, 14],
#          [17, 21],
#          [ 5, 14]]),
#   array([[18, 21],
#          [ 0, 19],
#          [ 9, 18],
#          [19, 22]]),
#   array([[ 8, 19],
#          [19, 22],
#          [ 4, 14],
#          [ 2, 19]]),
#   array([[ 5, 21],
#          [17, 21],
#          [ 7, 16],
#          [15, 19]]),
#   array([[ 5,  8],
#          [14, 17],
#          [19, 22],
#          [ 1, 20]]),
#   array([[11, 14],
#          [16, 19],
#          [ 5, 13],
#          [ 9, 20]]),
#   array([[10, 16],
#          [ 5, 17],
#          [16, 21],
#          [18, 21]]),
#   array([[11, 20],
#          [ 8, 12],
#          [ 8, 11],
#          [13, 17]]),
#   array([[14, 19],
#          [17, 20],
#          [15, 21],
#          [17, 21]]),
#   array([[13, 16],
#          [14, 18],
#          [10, 20],
#          [11, 18]]),
#   array([[17, 20],
#          [ 4, 17],
#          [10, 17],
#          [17, 20]]),
#   array([[ 0, 13],
#          [11, 20],
#          [ 7, 18],
#          [11, 17]]),
#   array([[ 1, 17],
#          [14, 19],
#          [ 7, 10],
#          [15, 19]]),
#   array([[15, 18],
#          [ 7, 21],
#          [15, 18],
#          [ 7, 12]]),
#   array([[12, 15],
#          [ 5,  8],
#          [ 9, 16],
#          [13, 17]]),
#   array([[13, 19],
#          [14, 17],
#          [17, 20],
#          [ 5, 20]]),
#   array([[ 2,  9],
#          [ 0, 10],
#          [17, 21],
#          [ 4, 13]]),
#   array([[ 5, 13],
#          [ 0, 18],
#          [ 5,  8],
#          [ 4, 14]]),
#   array([[17, 20],
#          [ 8, 21],
#          [17, 20],
#          [ 0,  6]]),
#   array([[17, 20],
#          [12, 19],
#          [ 7, 19],
#          [10, 19]]),
#   array([[13, 16],
#          [13, 18],
#          [12, 15],
#          [ 4,  7]]),
#   array([[17, 20],
#          [ 8, 21],
#          [ 5, 17],
#          [ 4,  8]]),
#   array([[15, 18],
#          [12, 20],
#          [16, 21],
#          [ 0, 13]]),
#   array([[ 6, 18],
#          [19, 22],
#          [15, 18],
#          [ 5, 18]]),
#   array([[ 1,  4],
#          [18, 21],
#          [10, 14],
#          [16, 19]]),
#   array([[12, 18],
#          [ 0,  3],
#          [19, 22],
#          [ 6, 14]]),
#   array([[13, 16],
#          [ 2, 16],
#          [17, 20],
#          [19, 22]]),
#   array([[18, 21],
#          [ 4,  7],
#          [18, 21],
#          [ 8, 13]]),
#   array([[ 0, 10],
#          [ 6,  9],
#          [ 6, 20],
#          [ 6, 20]]),
#   array([[16, 19],
#          [ 3, 10],
#          [11, 20],
#          [18, 21]]),
#   array([[ 2, 18],
#          [17, 21],
#          [14, 21],
#          [14, 17]]),
#   array([[ 1,  8],
#          [10, 19],
#          [ 6, 10],
#          [10, 13]]),
#   array([[18, 21],
#          [17, 21],
#          [12, 18],
#          [10, 13]]),
#   array([[ 0,  6],
#          [ 3, 11],
#          [ 2, 21],
#          [13, 16]]),
#   array([[ 8, 11],
#          [17, 20],
#          [17, 21],
#          [13, 16]]),
#   array([[ 2,  5],
#          [ 1, 13],
#          [ 6, 16],
#          [ 9, 21]]),
#   array([[ 2,  5],
#          [ 8, 13],
#          [ 5, 10],
#          [ 9, 19]]),
#   array([[11, 18],
#          [ 6, 15],
#          [11, 18],
#          [16, 20]]),
#   array([[14, 17],
#          [ 2, 16],
#          [16, 19],
#          [13, 21]]),
#   array([[10, 17],
#          [ 2, 16],
#          [16, 19],
#          [ 5, 16]]),
#   array([[12, 18],
#          [10, 14],
#          [ 6, 11],
#          [ 4, 11]]),
#   array([[12, 19],
#          [ 8, 14],
#          [ 4, 11],
#          [ 0,  7]]),
#   array([[13, 16],
#          [11, 18],
#          [19, 22],
#          [ 1, 13]]),
#   array([[ 0, 18],
#          [19, 22],
#          [17, 21],
#          [ 2, 19]]),
#   array([[ 6, 21],
#          [16, 19],
#          [ 6, 17],
#          [13, 20]]),
#   array([[11, 14],
#          [17, 20],
#          [17, 20],
#          [ 9, 17]]),
#   array([[ 4, 15],
#          [11, 14],
#          [10, 19],
#          [12, 20]]),
#   array([[ 1,  4],
#          [ 1,  5],
#          [16, 19],
#          [12, 15]]),
#   array([[12, 15],
#          [19, 22],
#          [ 4,  7],
#          [ 4, 12]]),
#   array([[ 0,  3],
#          [14, 19],
#          [ 4, 12],
#          [19, 22]]),
#   array([[19, 22],
#          [13, 16],
#          [ 3, 16],
#          [ 1,  9]]),
#   array([[17, 20],
#          [13, 17],
#          [13, 21],
#          [ 4, 12]]),
#   array([[10, 13],
#          [ 1, 19],
#          [ 9, 21],
#          [18, 21]]),
#   array([[ 6, 15],
#          [ 7, 10],
#          [ 5, 20],
#          [ 5,  8]]),
#   array([[13, 16],
#          [18, 21],
#          [ 3, 18],
#          [ 8, 19]]),
#   array([[ 5,  8],
#          [ 5, 12],
#          [ 0, 13],
#          [10, 18]]),
#   array([[ 0,  5],
#          [11, 14],
#          [12, 21],
#          [ 5, 11]]),
#   array([[ 6, 13],
#          [ 5, 21],
#          [ 0, 15],
#          [ 0, 20]]),
#   array([[17, 21],
#          [19, 22],
#          [ 0, 21],
#          [ 6, 15]]),
#   array([[13, 17],
#          [14, 19],
#          [ 6, 17],
#          [17, 20]]),
#   array([[ 3, 13],
#          [12, 15],
#          [ 8, 17],
#          [ 4, 11]]),
#   array([[ 8, 11],
#          [ 4, 19],
#          [ 9, 14],
#          [16, 19]]),
#   array([[ 3, 21],
#          [ 8, 11],
#          [19, 22],
#          [18, 21]]),
#   array([[15, 18],
#          [ 1, 10],
#          [11, 21],
#          [ 3, 12]]),
#   array([[13, 20],
#          [19, 22],
#          [ 7, 11],
#          [ 9, 17]]),
#   array([[ 5,  8],
#          [13, 16],
#          [18, 21],
#          [ 0,  3]]),
#   array([[17, 20],
#          [15, 20],
#          [10, 19],
#          [ 2,  5]]),
#   array([[12, 17],
#          [14, 17],
#          [ 7, 20],
#          [ 8, 21]]),
#   array([[4, 9],
#          [4, 7],
#          [0, 3],
#          [0, 6]]),
#   array([[ 8, 15],
#          [18, 21],
#          [ 7, 10],
#          [ 8, 16]])],
#  'estimators': [DecisionTreeClassifier(criterion='entropy', random_state=1576071106),
#   DecisionTreeClassifier(criterion='entropy', random_state=277715315),
#   DecisionTreeClassifier(criterion='entropy', random_state=106177623),
#   DecisionTreeClassifier(criterion='entropy', random_state=241670681),
#   DecisionTreeClassifier(criterion='entropy', random_state=1678928602),
#   DecisionTreeClassifier(criterion='entropy', random_state=335085978),
#   DecisionTreeClassifier(criterion='entropy', random_state=254102087),
#   DecisionTreeClassifier(criterion='entropy', random_state=1628589097),
#   DecisionTreeClassifier(criterion='entropy', random_state=1782622650),
#   DecisionTreeClassifier(criterion='entropy', random_state=1289411564),
#   DecisionTreeClassifier(criterion='entropy', random_state=1100640366),
#   DecisionTreeClassifier(criterion='entropy', random_state=1437915027),
#   DecisionTreeClassifier(criterion='entropy', random_state=79830027),
#   DecisionTreeClassifier(criterion='entropy', random_state=323224711),
#   DecisionTreeClassifier(criterion='entropy', random_state=31341993),
#   DecisionTreeClassifier(criterion='entropy', random_state=1411056203),
#   DecisionTreeClassifier(criterion='entropy', random_state=972414192),
#   DecisionTreeClassifier(criterion='entropy', random_state=2072353562),
#   DecisionTreeClassifier(criterion='entropy', random_state=871347910),
#   DecisionTreeClassifier(criterion='entropy', random_state=852349727),
#   DecisionTreeClassifier(criterion='entropy', random_state=445701083),
#   DecisionTreeClassifier(criterion='entropy', random_state=1099859903),
#   DecisionTreeClassifier(criterion='entropy', random_state=1393425302),
#   DecisionTreeClassifier(criterion='entropy', random_state=615467321),
#   DecisionTreeClassifier(criterion='entropy', random_state=145548406),
#   DecisionTreeClassifier(criterion='entropy', random_state=1306315262),
#   DecisionTreeClassifier(criterion='entropy', random_state=1614339075),
#   DecisionTreeClassifier(criterion='entropy', random_state=1650808216),
#   DecisionTreeClassifier(criterion='entropy', random_state=328744655),
#   DecisionTreeClassifier(criterion='entropy', random_state=1970541202),
#   DecisionTreeClassifier(criterion='entropy', random_state=2057832771),
#   DecisionTreeClassifier(criterion='entropy', random_state=1259434905),
#   DecisionTreeClassifier(criterion='entropy', random_state=1059921313),
#   DecisionTreeClassifier(criterion='entropy', random_state=853233702),
#   DecisionTreeClassifier(criterion='entropy', random_state=678874818),
#   DecisionTreeClassifier(criterion='entropy', random_state=106283039),
#   DecisionTreeClassifier(criterion='entropy', random_state=39748466),
#   DecisionTreeClassifier(criterion='entropy', random_state=455355980),
#   DecisionTreeClassifier(criterion='entropy', random_state=2113997402),
#   DecisionTreeClassifier(criterion='entropy', random_state=194571263),
#   DecisionTreeClassifier(criterion='entropy', random_state=1151503492),
#   DecisionTreeClassifier(criterion='entropy', random_state=1216281395),
#   DecisionTreeClassifier(criterion='entropy', random_state=355896288),
#   DecisionTreeClassifier(criterion='entropy', random_state=2070249506),
#   DecisionTreeClassifier(criterion='entropy', random_state=691232315),
#   DecisionTreeClassifier(criterion='entropy', random_state=2062244817),
#   DecisionTreeClassifier(criterion='entropy', random_state=1229476500),
#   DecisionTreeClassifier(criterion='entropy', random_state=1074451113),
#   DecisionTreeClassifier(criterion='entropy', random_state=645524097),
#   DecisionTreeClassifier(criterion='entropy', random_state=1995196404),
#   DecisionTreeClassifier(criterion='entropy', random_state=2051609258),
#   DecisionTreeClassifier(criterion='entropy', random_state=1235296591),
#   DecisionTreeClassifier(criterion='entropy', random_state=1959610012),
#   DecisionTreeClassifier(criterion='entropy', random_state=1184639845),
#   DecisionTreeClassifier(criterion='entropy', random_state=1401414143),
#   DecisionTreeClassifier(criterion='entropy', random_state=193231432),
#   DecisionTreeClassifier(criterion='entropy', random_state=1615672589),
#   DecisionTreeClassifier(criterion='entropy', random_state=423835086),
#   DecisionTreeClassifier(criterion='entropy', random_state=246426080),
#   DecisionTreeClassifier(criterion='entropy', random_state=1878413753),
#   DecisionTreeClassifier(criterion='entropy', random_state=789865823),
#   DecisionTreeClassifier(criterion='entropy', random_state=1866041815),
#   DecisionTreeClassifier(criterion='entropy', random_state=544803896),
#   DecisionTreeClassifier(criterion='entropy', random_state=1035706407),
#   DecisionTreeClassifier(criterion='entropy', random_state=1755815761),
#   DecisionTreeClassifier(criterion='entropy', random_state=1986720221),
#   DecisionTreeClassifier(criterion='entropy', random_state=1433783555),
#   DecisionTreeClassifier(criterion='entropy', random_state=1083991086),
#   DecisionTreeClassifier(criterion='entropy', random_state=2011607104),
#   DecisionTreeClassifier(criterion='entropy', random_state=1759515934),
#   DecisionTreeClassifier(criterion='entropy', random_state=647851666),
#   DecisionTreeClassifier(criterion='entropy', random_state=1652655354),
#   DecisionTreeClassifier(criterion='entropy', random_state=2003078580),
#   DecisionTreeClassifier(criterion='entropy', random_state=1010051640),
#   DecisionTreeClassifier(criterion='entropy', random_state=317987485),
#   DecisionTreeClassifier(criterion='entropy', random_state=1352339406),
#   DecisionTreeClassifier(criterion='entropy', random_state=1005756564),
#   DecisionTreeClassifier(criterion='entropy', random_state=198955382),
#   DecisionTreeClassifier(criterion='entropy', random_state=377944923),
#   DecisionTreeClassifier(criterion='entropy', random_state=2035769784),
#   DecisionTreeClassifier(criterion='entropy', random_state=668986398),
#   DecisionTreeClassifier(criterion='entropy', random_state=397448245),
#   DecisionTreeClassifier(criterion='entropy', random_state=197502341),
#   DecisionTreeClassifier(criterion='entropy', random_state=1161792454),
#   DecisionTreeClassifier(criterion='entropy', random_state=2023954336),
#   DecisionTreeClassifier(criterion='entropy', random_state=1396065147),
#   DecisionTreeClassifier(criterion='entropy', random_state=2008412854),
#   DecisionTreeClassifier(criterion='entropy', random_state=1275735434),
#   DecisionTreeClassifier(criterion='entropy', random_state=2070367667),
#   DecisionTreeClassifier(criterion='entropy', random_state=1593484364),
#   DecisionTreeClassifier(criterion='entropy', random_state=1400689363),
#   DecisionTreeClassifier(criterion='entropy', random_state=1170025924),
#   DecisionTreeClassifier(criterion='entropy', random_state=907315162),
#   DecisionTreeClassifier(criterion='entropy', random_state=234441701),
#   DecisionTreeClassifier(criterion='entropy', random_state=85552368),
#   DecisionTreeClassifier(criterion='entropy', random_state=991569230),
#   DecisionTreeClassifier(criterion='entropy', random_state=127633248),
#   DecisionTreeClassifier(criterion='entropy', random_state=1934939381),
#   DecisionTreeClassifier(criterion='entropy', random_state=1080158432),
#   DecisionTreeClassifier(criterion='entropy', random_state=2050503666),
#   DecisionTreeClassifier(criterion='entropy', random_state=1591388525),
#   DecisionTreeClassifier(criterion='entropy', random_state=2039093213),
#   DecisionTreeClassifier(criterion='entropy', random_state=721856803),
#   DecisionTreeClassifier(criterion='entropy', random_state=174655347),
#   DecisionTreeClassifier(criterion='entropy', random_state=684278452),
#   DecisionTreeClassifier(criterion='entropy', random_state=611073521),
#   DecisionTreeClassifier(criterion='entropy', random_state=652889079),
#   DecisionTreeClassifier(criterion='entropy', random_state=468977628),
#   DecisionTreeClassifier(criterion='entropy', random_state=164802207),
#   DecisionTreeClassifier(criterion='entropy', random_state=672965813),
#   DecisionTreeClassifier(criterion='entropy', random_state=773475456),
#   DecisionTreeClassifier(criterion='entropy', random_state=1850795907),
#   DecisionTreeClassifier(criterion='entropy', random_state=2137296202),
#   DecisionTreeClassifier(criterion='entropy', random_state=306981393),
#   DecisionTreeClassifier(criterion='entropy', random_state=1913528130),
#   DecisionTreeClassifier(criterion='entropy', random_state=98683270),
#   DecisionTreeClassifier(criterion='entropy', random_state=217648549),
#   DecisionTreeClassifier(criterion='entropy', random_state=1140280024),
#   DecisionTreeClassifier(criterion='entropy', random_state=727293647),
#   DecisionTreeClassifier(criterion='entropy', random_state=1513220145),
#   DecisionTreeClassifier(criterion='entropy', random_state=599288442),
#   DecisionTreeClassifier(criterion='entropy', random_state=420235193),
#   DecisionTreeClassifier(criterion='entropy', random_state=996115453),
#   DecisionTreeClassifier(criterion='entropy', random_state=1863855991),
#   DecisionTreeClassifier(criterion='entropy', random_state=1142245044),
#   DecisionTreeClassifier(criterion='entropy', random_state=1766476544),
#   DecisionTreeClassifier(criterion='entropy', random_state=868809683),
#   DecisionTreeClassifier(criterion='entropy', random_state=1470551778),
#   DecisionTreeClassifier(criterion='entropy', random_state=83563350),
#   DecisionTreeClassifier(criterion='entropy', random_state=244957558),
#   DecisionTreeClassifier(criterion='entropy', random_state=954250778),
#   DecisionTreeClassifier(criterion='entropy', random_state=1424235820),
#   DecisionTreeClassifier(criterion='entropy', random_state=1477371531),
#   DecisionTreeClassifier(criterion='entropy', random_state=207387297),
#   DecisionTreeClassifier(criterion='entropy', random_state=1138071096),
#   DecisionTreeClassifier(criterion='entropy', random_state=1462226196),
#   DecisionTreeClassifier(criterion='entropy', random_state=1682360145),
#   DecisionTreeClassifier(criterion='entropy', random_state=1786967210),
#   DecisionTreeClassifier(criterion='entropy', random_state=387052923),
#   DecisionTreeClassifier(criterion='entropy', random_state=1846993870),
#   DecisionTreeClassifier(criterion='entropy', random_state=1817416047),
#   DecisionTreeClassifier(criterion='entropy', random_state=2067716899),
#   DecisionTreeClassifier(criterion='entropy', random_state=673099944),
#   DecisionTreeClassifier(criterion='entropy', random_state=1648413704),
#   DecisionTreeClassifier(criterion='entropy', random_state=1513287337),
#   DecisionTreeClassifier(criterion='entropy', random_state=1839816635),
#   DecisionTreeClassifier(criterion='entropy', random_state=1739441893),
#   DecisionTreeClassifier(criterion='entropy', random_state=840216752),
#   DecisionTreeClassifier(criterion='entropy', random_state=283075776),
#   DecisionTreeClassifier(criterion='entropy', random_state=1387022285),
#   DecisionTreeClassifier(criterion='entropy', random_state=341673390),
#   DecisionTreeClassifier(criterion='entropy', random_state=1718741786),
#   DecisionTreeClassifier(criterion='entropy', random_state=686248122),
#   DecisionTreeClassifier(criterion='entropy', random_state=198324080),
#   DecisionTreeClassifier(criterion='entropy', random_state=750578832),
#   DecisionTreeClassifier(criterion='entropy', random_state=545572762),
#   DecisionTreeClassifier(criterion='entropy', random_state=1531384643),
#   DecisionTreeClassifier(criterion='entropy', random_state=317667805),
#   DecisionTreeClassifier(criterion='entropy', random_state=661517870),
#   DecisionTreeClassifier(criterion='entropy', random_state=894237688),
#   DecisionTreeClassifier(criterion='entropy', random_state=917512559),
#   DecisionTreeClassifier(criterion='entropy', random_state=1183602560),
#   DecisionTreeClassifier(criterion='entropy', random_state=1208441528),
#   DecisionTreeClassifier(criterion='entropy', random_state=1865751677),
#   DecisionTreeClassifier(criterion='entropy', random_state=1852493501),
#   DecisionTreeClassifier(criterion='entropy', random_state=1884650593),
#   DecisionTreeClassifier(criterion='entropy', random_state=2089850586),
#   DecisionTreeClassifier(criterion='entropy', random_state=112345134),
#   DecisionTreeClassifier(criterion='entropy', random_state=167726259),
#   DecisionTreeClassifier(criterion='entropy', random_state=1124292731),
#   DecisionTreeClassifier(criterion='entropy', random_state=125296299),
#   DecisionTreeClassifier(criterion='entropy', random_state=1299349489),
#   DecisionTreeClassifier(criterion='entropy', random_state=1750600328),
#   DecisionTreeClassifier(criterion='entropy', random_state=508085921),
#   DecisionTreeClassifier(criterion='entropy', random_state=1194654558),
#   DecisionTreeClassifier(criterion='entropy', random_state=2113009034),
#   DecisionTreeClassifier(criterion='entropy', random_state=701412598),
#   DecisionTreeClassifier(criterion='entropy', random_state=1374288243),
#   DecisionTreeClassifier(criterion='entropy', random_state=245600846),
#   DecisionTreeClassifier(criterion='entropy', random_state=780007758),
#   DecisionTreeClassifier(criterion='entropy', random_state=1486350913),
#   DecisionTreeClassifier(criterion='entropy', random_state=1154793996),
#   DecisionTreeClassifier(criterion='entropy', random_state=779531079),
#   DecisionTreeClassifier(criterion='entropy', random_state=1104605852),
#   DecisionTreeClassifier(criterion='entropy', random_state=540312331),
#   DecisionTreeClassifier(criterion='entropy', random_state=858621864),
#   DecisionTreeClassifier(criterion='entropy', random_state=547872371),
#   DecisionTreeClassifier(criterion='entropy', random_state=2076856617),
#   DecisionTreeClassifier(criterion='entropy', random_state=415073769),
#   DecisionTreeClassifier(criterion='entropy', random_state=106344781),
#   DecisionTreeClassifier(criterion='entropy', random_state=1580558448),
#   DecisionTreeClassifier(criterion='entropy', random_state=1986457014),
#   DecisionTreeClassifier(criterion='entropy', random_state=922741615),
#   DecisionTreeClassifier(criterion='entropy', random_state=1626560375),
#   DecisionTreeClassifier(criterion='entropy', random_state=475179590),
#   DecisionTreeClassifier(criterion='entropy', random_state=1606005339),
#   DecisionTreeClassifier(criterion='entropy', random_state=1877812130),
#   DecisionTreeClassifier(criterion='entropy', random_state=1219236093),
#   DecisionTreeClassifier(criterion='entropy', random_state=955750390),
#   DecisionTreeClassifier(criterion='entropy', random_state=1221760038)],
#  'n_classes': 2,
#  'fit_time': 57129}

# %%
# Réalisation des prédictions

y_pred = clf_rf_ts.predict(X_test)

# %% [markdown]
# ## 5. Évaluation

# %%
# Élaboration de la matrice de confusion

pd.crosstab(y_test, y_pred, rownames = ["Classe réelle"], colnames = ["Classe prédite"])
# Out:
# Classe prédite     0    1
# Classe réelle
# 0               1882  206
# 1                356  707

# %%
# Élaboration du rapport de classification

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87      2088
#            1       0.77      0.67      0.72      1063
#
#     accuracy                           0.82      3151
#    macro avg       0.81      0.78      0.79      3151
# weighted avg       0.82      0.82      0.82      3151
