# %% [markdown]
# # **Classification** des **séries temporelles** avec `sktime`

# %% [markdown]
# ## Métadonnées

# %% [markdown]
# - **Expérience nº :** 7.2.2
# - **Date :** 11/11/2023
# - **Heure :** 12:28
# - **Données :** `ready_Evaporation_Sunshine_Pressure9am_Pressure3pm_Cloud9am_Cloud3pm.csv`
# - **Tri :** index chronologique
# - **Découpage :** `TimeSeriesSplit`
# - **Mise à l'échelle :** non
# - **Rééquilibrage :** non
# - **Conversion :** `numpyfy`
# - **Algorithme :** TSF

# %% [markdown]
# ## Sommaire

# %% [markdown]
# 1. Initialisation
# 2. Découpage
# 3. Conversion
# 4. Modélisation
# 5. Évaluation

# %% [markdown]
# ## 1. Initialisation

# %%
# Importation des bibliothèques et modules nécessaires au fonctionnement de ce notebook

import pandas as pd
import numpy as np

from sklearn.metrics import classification_report

# %%
# Importation du jeu de données et enregistrement dans le DataFrame `df`

df = pd.read_csv("../../../../data/processed/omar/ready_Evaporation_Sunshine_Pressure9am_Pressure3pm_Cloud9am_Cloud3pm.csv", index_col = 1).sort_index()
df = df.drop(columns = "Unnamed: 0")

# %%
# Inspection de la structure de `df`

df.head()
# Out:
#             MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  \
# Date
# 2008-12-01     15.2     32.6       0.0      59.000000     13.000000
# 2008-12-01      5.2     13.0       0.4      46.172309     15.912884
# 2008-12-02     15.0     31.7       0.0      28.000000     13.000000
# 2008-12-02      3.0     15.0       0.4      46.172309     26.000000
# 2008-12-03     15.9     33.4       0.0      52.000000      9.000000
#
#             WindSpeed3pm  Humidity9am  Humidity3pm    Temp9am    Temp3pm  ...  \
# Date                                                                      ...
# 2008-12-01     22.000000    35.000000    23.000000  24.400000  31.300000  ...
# 2008-12-01     15.090231    77.114297    69.660632   6.905934  10.345942  ...
# 2008-12-02     15.000000    64.000000    38.000000  20.400000  30.100000  ...
# 2008-12-02     24.000000    66.000000    51.000000   7.100000  14.200000  ...
# 2008-12-03     30.000000    63.000000    16.000000  21.000000  31.400000  ...
#
#             year  month  day  LocationNum  WindGustDirNum  WindDir9amNum  \
# Date
# 2008-12-01  2008     12    1            8        2.748894       1.178097
# 2008-12-01  2008     12    1           17        3.005216       3.013693
# 2008-12-02  2008     12    2            8        0.392699       1.178097
# 2008-12-02  2008     12    2           17        3.005216       3.141593
# 2008-12-03  2008     12    3            8        2.356194       1.570796
#
#             WindDir3pmNum   Latitude   Longitude  CodeRegionNum
# Date
# 2008-12-01       3.141593 -33.751195  150.694171              0
# 2008-12-01       2.779950 -35.533333  148.783333              1
# 2008-12-02       1.570796 -33.751195  150.694171              0
# 2008-12-02       2.748894 -35.533333  148.783333              1
# 2008-12-03       2.356194 -33.751195  150.694171              0
#
# [5 rows x 22 columns]

# %%
# Inspection de la structure de `df`

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8668 entries, 2008-12-01 to 2017-06-25
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   MinTemp         8668 non-null   float64
#  1   MaxTemp         8668 non-null   float64
#  2   Rainfall        8668 non-null   float64
#  3   WindGustSpeed   8668 non-null   float64
#  4   WindSpeed9am    8668 non-null   float64
#  5   WindSpeed3pm    8668 non-null   float64
#  6   Humidity9am     8668 non-null   float64
#  7   Humidity3pm     8668 non-null   float64
#  8   Temp9am         8668 non-null   float64
#  9   Temp3pm         8668 non-null   float64
#  10  RainToday       8668 non-null   int64
#  11  RainTomorrow    8668 non-null   int64
#  12  year            8668 non-null   int64
#  13  month           8668 non-null   int64
#  14  day             8668 non-null   int64
#  15  LocationNum     8668 non-null   int64
#  16  WindGustDirNum  8668 non-null   float64
#  17  WindDir9amNum   8668 non-null   float64
#  18  WindDir3pmNum   8668 non-null   float64
#  19  Latitude        8668 non-null   float64
#  20  Longitude       8668 non-null   float64
#  21  CodeRegionNum   8668 non-null   int64
# dtypes: float64(15), int64(7)
# memory usage: 1.5+ MB

# %% [markdown]
# ## 2. Découpage

# %%
# Découpage de `df` sur l'axe des colonnes : séparation des variables explicatives (`data`) et cible (`target`)

data = df.drop(columns = "RainTomorrow")
target = df["RainTomorrow"]

# %%
# Découpage de `data` et de `target` sur l'axe des lignes : séparation des jeux d'entraînement (`*_train`) et de test (`*_test`) avec le splitter `TimeSeriesSplit`

from sklearn.model_selection import TimeSeriesSplit

tss = TimeSeriesSplit(n_splits = 5) ## Nous fixons le paramètre `n_splits` à 5 afin d'avoir une répartition de 80 / 20 entre les jeux d'entraînement et de test, respectivement.

for train_index, test_index in tss.split(data):
    X_train, X_test = data.iloc[train_index, :], data.iloc[test_index,:]
    y_train, y_test = target.iloc[train_index], target.iloc[test_index]

# %% [markdown]
# ## 3. Conversion

# %%
# Importation de la fonction artisanale `numpyfy`

from numpyfy import numpyfy

# %%
# Application de la fonction `numpyfy` aux 4 jeux de données issus du découpage effectué par le splitter `TimeSeriesSplit` afin de les convertir en arrays et ainsi les rendre compatibles avec `sktime`

X_train, X_test, y_train, y_test = numpyfy(X_train, X_test, y_train, y_test)

# %% [markdown]
# ## 4. Modélisation

# %%
# Instanciation d'un modèle classificateur via un Pipeline

from sklearn.pipeline import Pipeline
from sktime.transformations.panel.compose import ColumnConcatenator
from sktime.classification.interval_based import TimeSeriesForestClassifier

steps = [
    ("concatenate", ColumnConcatenator()), ## Cette étape permet de transformer les jeux de données multivariées en univariées afin qu'ils puissent être traités par `TimeSeriesForestClassifier`.
    ("classify", TimeSeriesForestClassifier()),
]

clf_rf_ts = Pipeline(steps)

# %%
# Récupération des paramètres initiaux de la TSF

clf_rf_ts["classify"].get_params()
# Out:
# {'min_interval': 3, 'n_estimators': 200, 'n_jobs': 1, 'random_state': None}

# %%
# Entraînement du modèle

clf_rf_ts.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('concatenate', ColumnConcatenator()),
#                 ('classify', TimeSeriesForestClassifier())])

# %%
# Récupération des paramètres ajustés de la TSF

clf_rf_ts["classify"].get_fitted_params()
# Out:
# {'classes': array([0, 1]),
#  'intervals': [array([[14, 17],
#          [12, 15],
#          [ 7, 13],
#          [13, 16]]),
#   array([[ 6, 18],
#          [17, 20],
#          [ 7, 11],
#          [ 9, 17]]),
#   array([[13, 17],
#          [ 2, 16],
#          [ 8, 15],
#          [14, 17]]),
#   array([[ 3, 11],
#          [ 5, 17],
#          [11, 19],
#          [12, 15]]),
#   array([[ 4, 19],
#          [ 0,  3],
#          [ 6, 15],
#          [15, 18]]),
#   array([[16, 19],
#          [ 4, 15],
#          [ 8, 18],
#          [ 5, 16]]),
#   array([[12, 18],
#          [10, 15],
#          [ 6, 14],
#          [11, 16]]),
#   array([[ 0,  3],
#          [ 3, 18],
#          [ 9, 16],
#          [ 5,  9]]),
#   array([[17, 20],
#          [ 8, 11],
#          [ 6, 16],
#          [ 5,  8]]),
#   array([[ 3, 16],
#          [12, 15],
#          [ 6,  9],
#          [12, 15]]),
#   array([[ 7, 12],
#          [ 8, 13],
#          [12, 16],
#          [ 9, 17]]),
#   array([[12, 19],
#          [ 9, 16],
#          [ 7, 17],
#          [12, 18]]),
#   array([[17, 20],
#          [ 7, 13],
#          [10, 18],
#          [10, 15]]),
#   array([[14, 17],
#          [ 0, 10],
#          [ 2, 18],
#          [13, 18]]),
#   array([[ 8, 11],
#          [16, 19],
#          [11, 16],
#          [ 0,  6]]),
#   array([[ 4, 16],
#          [12, 16],
#          [ 3,  8],
#          [15, 18]]),
#   array([[12, 15],
#          [ 2,  5],
#          [ 1, 15],
#          [17, 20]]),
#   array([[13, 17],
#          [ 9, 13],
#          [10, 19],
#          [ 8, 14]]),
#   array([[12, 15],
#          [ 4,  9],
#          [17, 20],
#          [ 9, 19]]),
#   array([[17, 20],
#          [12, 15],
#          [12, 16],
#          [14, 17]]),
#   array([[14, 18],
#          [ 0,  8],
#          [ 1, 18],
#          [ 7, 10]]),
#   array([[ 4, 12],
#          [13, 16],
#          [16, 19],
#          [ 7, 10]]),
#   array([[ 2, 18],
#          [ 6,  9],
#          [ 5,  9],
#          [ 8, 11]]),
#   array([[ 4, 17],
#          [ 6,  9],
#          [17, 20],
#          [ 0,  3]]),
#   array([[ 0, 17],
#          [ 1,  7],
#          [ 8, 13],
#          [ 3, 17]]),
#   array([[ 3, 17],
#          [ 1, 11],
#          [ 0, 14],
#          [ 3,  6]]),
#   array([[16, 19],
#          [ 1,  4],
#          [ 1,  4],
#          [ 0, 12]]),
#   array([[12, 15],
#          [15, 19],
#          [ 5, 15],
#          [ 2,  9]]),
#   array([[ 4,  7],
#          [ 0, 19],
#          [ 5,  8],
#          [ 6, 10]]),
#   array([[ 4, 17],
#          [ 1, 15],
#          [10, 16],
#          [15, 18]]),
#   array([[ 9, 18],
#          [17, 20],
#          [ 8, 17],
#          [ 8, 12]]),
#   array([[ 1, 16],
#          [ 7, 17],
#          [10, 13],
#          [11, 15]]),
#   array([[14, 17],
#          [14, 17],
#          [17, 20],
#          [17, 20]]),
#   array([[ 1, 13],
#          [ 6, 10],
#          [10, 13],
#          [ 3, 12]]),
#   array([[17, 20],
#          [11, 14],
#          [13, 16],
#          [ 7, 16]]),
#   array([[ 5,  8],
#          [15, 18],
#          [13, 16],
#          [ 6, 19]]),
#   array([[ 0,  9],
#          [15, 19],
#          [ 1,  8],
#          [15, 19]]),
#   array([[ 2,  6],
#          [ 8, 12],
#          [ 4, 19],
#          [ 8, 11]]),
#   array([[ 3,  9],
#          [ 9, 17],
#          [ 5, 10],
#          [14, 17]]),
#   array([[ 0, 19],
#          [ 2, 16],
#          [ 1, 17],
#          [10, 15]]),
#   array([[ 4, 15],
#          [ 7, 10],
#          [16, 19],
#          [15, 18]]),
#   array([[11, 14],
#          [ 7, 19],
#          [ 7, 13],
#          [11, 14]]),
#   array([[13, 16],
#          [17, 20],
#          [ 3, 11],
#          [14, 17]]),
#   array([[15, 19],
#          [ 9, 14],
#          [ 8, 11],
#          [ 3, 14]]),
#   array([[12, 15],
#          [12, 15],
#          [ 6, 15],
#          [12, 15]]),
#   array([[12, 15],
#          [13, 16],
#          [ 1,  9],
#          [ 0, 13]]),
#   array([[17, 20],
#          [ 0,  9],
#          [15, 18],
#          [ 6, 12]]),
#   array([[ 2, 11],
#          [15, 18],
#          [10, 13],
#          [ 1,  6]]),
#   array([[17, 20],
#          [ 3,  7],
#          [ 6,  9],
#          [ 5, 14]]),
#   array([[ 9, 17],
#          [ 8, 12],
#          [12, 15],
#          [ 1, 18]]),
#   array([[11, 14],
#          [10, 16],
#          [ 7, 10],
#          [15, 18]]),
#   array([[10, 13],
#          [ 7, 10],
#          [ 8, 19],
#          [ 8, 17]]),
#   array([[ 7, 15],
#          [ 1, 12],
#          [14, 19],
#          [13, 16]]),
#   array([[16, 19],
#          [ 5, 13],
#          [ 2,  5],
#          [ 7, 15]]),
#   array([[ 9, 17],
#          [15, 18],
#          [ 4, 10],
#          [16, 19]]),
#   array([[ 0, 10],
#          [11, 14],
#          [13, 17],
#          [ 5,  8]]),
#   array([[ 0,  3],
#          [ 2, 11],
#          [ 7, 14],
#          [ 1, 10]]),
#   array([[17, 20],
#          [13, 18],
#          [ 2, 10],
#          [16, 19]]),
#   array([[ 2, 15],
#          [11, 14],
#          [ 7, 17],
#          [ 6, 14]]),
#   array([[ 2, 18],
#          [ 1,  4],
#          [ 9, 13],
#          [10, 13]]),
#   array([[17, 20],
#          [ 1,  6],
#          [17, 20],
#          [15, 19]]),
#   array([[ 1, 11],
#          [ 6, 10],
#          [11, 19],
#          [ 9, 15]]),
#   array([[12, 15],
#          [16, 19],
#          [ 9, 12],
#          [ 1,  7]]),
#   array([[17, 20],
#          [ 5, 18],
#          [16, 19],
#          [16, 19]]),
#   array([[13, 16],
#          [ 8, 12],
#          [16, 19],
#          [ 9, 17]]),
#   array([[14, 18],
#          [ 0, 12],
#          [ 3, 12],
#          [17, 20]]),
#   array([[ 5, 14],
#          [17, 20],
#          [ 9, 16],
#          [ 8, 13]]),
#   array([[ 7, 15],
#          [ 1,  4],
#          [ 3,  6],
#          [15, 18]]),
#   array([[ 2,  5],
#          [ 3, 11],
#          [ 5,  8],
#          [14, 17]]),
#   array([[12, 17],
#          [ 8, 17],
#          [ 7, 17],
#          [14, 17]]),
#   array([[ 0,  3],
#          [12, 15],
#          [14, 17],
#          [ 9, 12]]),
#   array([[15, 18],
#          [15, 18],
#          [ 5, 13],
#          [17, 20]]),
#   array([[15, 18],
#          [ 7, 10],
#          [ 8, 11],
#          [ 7, 11]]),
#   array([[16, 19],
#          [15, 18],
#          [ 7, 10],
#          [17, 20]]),
#   array([[ 1, 14],
#          [15, 19],
#          [ 6, 15],
#          [ 0,  3]]),
#   array([[10, 13],
#          [11, 15],
#          [15, 18],
#          [12, 18]]),
#   array([[ 4,  7],
#          [ 4, 15],
#          [ 5, 13],
#          [ 1,  4]]),
#   array([[17, 20],
#          [ 1,  9],
#          [ 7, 19],
#          [ 6, 15]]),
#   array([[ 1,  4],
#          [14, 17],
#          [ 5, 16],
#          [14, 18]]),
#   array([[ 1, 17],
#          [16, 19],
#          [ 0,  4],
#          [16, 19]]),
#   array([[ 3, 11],
#          [ 0, 12],
#          [ 5,  8],
#          [10, 13]]),
#   array([[14, 17],
#          [17, 20],
#          [15, 18],
#          [16, 19]]),
#   array([[14, 17],
#          [17, 20],
#          [ 6, 16],
#          [14, 17]]),
#   array([[ 7, 12],
#          [ 5, 16],
#          [ 3, 13],
#          [16, 19]]),
#   array([[ 5, 13],
#          [13, 19],
#          [ 4, 12],
#          [ 7, 13]]),
#   array([[17, 20],
#          [ 5, 17],
#          [ 1,  5],
#          [13, 18]]),
#   array([[ 6, 14],
#          [16, 19],
#          [10, 13],
#          [ 6, 13]]),
#   array([[11, 15],
#          [ 3,  6],
#          [11, 19],
#          [10, 13]]),
#   array([[ 9, 17],
#          [14, 18],
#          [11, 18],
#          [17, 20]]),
#   array([[ 8, 11],
#          [ 0, 19],
#          [13, 17],
#          [11, 15]]),
#   array([[ 5, 16],
#          [ 6,  9],
#          [ 0, 16],
#          [ 2,  9]]),
#   array([[ 6, 12],
#          [ 0, 13],
#          [ 2,  8],
#          [12, 17]]),
#   array([[ 5, 19],
#          [11, 17],
#          [16, 19],
#          [15, 19]]),
#   array([[ 5,  9],
#          [ 3, 17],
#          [ 8, 18],
#          [ 1, 14]]),
#   array([[11, 19],
#          [13, 16],
#          [13, 16],
#          [ 2,  6]]),
#   array([[15, 18],
#          [15, 18],
#          [ 8, 18],
#          [ 4, 19]]),
#   array([[ 1,  6],
#          [14, 19],
#          [12, 15],
#          [ 1,  4]]),
#   array([[ 3,  9],
#          [ 4, 13],
#          [ 6, 12],
#          [16, 19]]),
#   array([[12, 18],
#          [ 3,  8],
#          [17, 20],
#          [ 4, 14]]),
#   array([[ 8, 12],
#          [ 1,  4],
#          [ 5, 11],
#          [17, 20]]),
#   array([[16, 19],
#          [ 5, 17],
#          [ 8, 14],
#          [ 9, 12]]),
#   array([[ 5,  9],
#          [16, 19],
#          [16, 19],
#          [ 3, 17]]),
#   array([[ 3,  8],
#          [15, 19],
#          [ 2,  7],
#          [12, 15]]),
#   array([[10, 13],
#          [13, 19],
#          [ 6,  9],
#          [10, 16]]),
#   array([[ 3, 11],
#          [ 4, 11],
#          [ 0,  9],
#          [17, 20]]),
#   array([[ 2,  5],
#          [15, 18],
#          [ 1,  4],
#          [ 5, 15]]),
#   array([[ 1, 12],
#          [11, 18],
#          [ 3, 16],
#          [14, 18]]),
#   array([[14, 17],
#          [12, 18],
#          [12, 16],
#          [ 9, 18]]),
#   array([[14, 17],
#          [ 7, 12],
#          [12, 16],
#          [11, 16]]),
#   array([[11, 14],
#          [17, 20],
#          [11, 14],
#          [ 6,  9]]),
#   array([[10, 19],
#          [13, 16],
#          [11, 19],
#          [ 9, 15]]),
#   array([[ 2,  8],
#          [ 4,  9],
#          [11, 14],
#          [14, 17]]),
#   array([[17, 20],
#          [13, 16],
#          [11, 17],
#          [ 6, 18]]),
#   array([[17, 20],
#          [ 1,  7],
#          [17, 20],
#          [ 3, 16]]),
#   array([[10, 15],
#          [ 5, 12],
#          [ 6,  9],
#          [ 8, 11]]),
#   array([[14, 17],
#          [ 4, 18],
#          [17, 20],
#          [ 1, 15]]),
#   array([[ 5,  9],
#          [16, 19],
#          [ 1, 18],
#          [ 3,  9]]),
#   array([[ 9, 12],
#          [ 8, 17],
#          [ 6, 12],
#          [ 0, 16]]),
#   array([[ 1,  6],
#          [ 7, 16],
#          [ 5, 17],
#          [ 6,  9]]),
#   array([[ 3, 16],
#          [ 3,  9],
#          [ 8, 12],
#          [ 1,  4]]),
#   array([[ 1, 18],
#          [17, 20],
#          [10, 14],
#          [12, 18]]),
#   array([[ 1,  5],
#          [ 6, 10],
#          [ 9, 14],
#          [16, 19]]),
#   array([[ 5,  8],
#          [ 7, 13],
#          [12, 16],
#          [ 1, 10]]),
#   array([[ 3, 19],
#          [ 6, 14],
#          [ 9, 12],
#          [16, 19]]),
#   array([[ 5,  8],
#          [ 0, 17],
#          [ 4, 15],
#          [12, 16]]),
#   array([[17, 20],
#          [ 6,  9],
#          [ 4, 13],
#          [17, 20]]),
#   array([[13, 16],
#          [12, 18],
#          [ 6, 19],
#          [15, 18]]),
#   array([[11, 18],
#          [16, 19],
#          [ 9, 12],
#          [15, 18]]),
#   array([[ 3, 12],
#          [ 1,  4],
#          [14, 17],
#          [ 2, 14]]),
#   array([[13, 17],
#          [12, 19],
#          [ 5, 15],
#          [16, 19]]),
#   array([[12, 16],
#          [11, 19],
#          [12, 15],
#          [12, 17]]),
#   array([[15, 18],
#          [11, 16],
#          [ 7, 15],
#          [ 3,  8]]),
#   array([[13, 18],
#          [ 7, 19],
#          [11, 18],
#          [14, 17]]),
#   array([[ 8, 15],
#          [ 5,  8],
#          [15, 19],
#          [11, 14]]),
#   array([[ 3,  8],
#          [11, 16],
#          [ 2, 15],
#          [17, 20]]),
#   array([[11, 18],
#          [ 1,  4],
#          [ 2, 17],
#          [ 6, 19]]),
#   array([[ 0, 14],
#          [13, 16],
#          [10, 13],
#          [ 1, 16]]),
#   array([[ 6,  9],
#          [ 6, 15],
#          [10, 17],
#          [ 2, 15]]),
#   array([[11, 18],
#          [ 0, 13],
#          [12, 17],
#          [ 2,  9]]),
#   array([[10, 13],
#          [ 1, 13],
#          [ 5, 16],
#          [ 2,  5]]),
#   array([[11, 14],
#          [11, 18],
#          [ 3, 10],
#          [ 8, 11]]),
#   array([[ 2,  9],
#          [ 8, 15],
#          [ 8, 17],
#          [17, 20]]),
#   array([[ 2, 12],
#          [ 5, 17],
#          [17, 20],
#          [11, 14]]),
#   array([[17, 20],
#          [ 1,  6],
#          [15, 19],
#          [ 6,  9]]),
#   array([[ 5, 12],
#          [17, 20],
#          [ 5, 10],
#          [ 4, 10]]),
#   array([[17, 20],
#          [ 8, 16],
#          [ 3,  6],
#          [ 7, 10]]),
#   array([[ 1, 12],
#          [13, 19],
#          [13, 16],
#          [10, 16]]),
#   array([[12, 17],
#          [ 6, 10],
#          [ 7, 10],
#          [ 1, 16]]),
#   array([[ 5,  8],
#          [ 3,  6],
#          [ 1, 12],
#          [13, 18]]),
#   array([[16, 19],
#          [13, 16],
#          [ 4,  7],
#          [ 8, 11]]),
#   array([[14, 17],
#          [15, 18],
#          [11, 15],
#          [11, 18]]),
#   array([[16, 19],
#          [ 5, 19],
#          [ 2, 19],
#          [ 8, 11]]),
#   array([[11, 14],
#          [ 0, 13],
#          [ 7, 16],
#          [12, 15]]),
#   array([[ 1,  4],
#          [10, 15],
#          [ 1, 15],
#          [ 5, 10]]),
#   array([[ 2, 11],
#          [ 6,  9],
#          [ 9, 17],
#          [ 8, 11]]),
#   array([[16, 19],
#          [12, 16],
#          [ 3, 10],
#          [17, 20]]),
#   array([[17, 20],
#          [17, 20],
#          [15, 18],
#          [ 9, 18]]),
#   array([[ 9, 12],
#          [ 8, 12],
#          [12, 18],
#          [ 0,  3]]),
#   array([[ 0,  9],
#          [ 7, 17],
#          [ 3, 14],
#          [ 6, 16]]),
#   array([[16, 19],
#          [ 5,  8],
#          [ 5, 12],
#          [13, 17]]),
#   array([[13, 16],
#          [ 6, 18],
#          [ 5,  8],
#          [ 2,  9]]),
#   array([[10, 18],
#          [17, 20],
#          [16, 19],
#          [ 3,  6]]),
#   array([[ 1, 18],
#          [13, 16],
#          [ 1,  4],
#          [14, 17]]),
#   array([[ 7, 11],
#          [12, 17],
#          [ 1,  7],
#          [ 0,  3]]),
#   array([[ 7, 14],
#          [ 7, 18],
#          [ 4, 18],
#          [15, 19]]),
#   array([[ 8, 19],
#          [14, 17],
#          [16, 19],
#          [16, 19]]),
#   array([[ 5, 10],
#          [ 5,  8],
#          [ 4, 17],
#          [14, 19]]),
#   array([[ 0,  7],
#          [ 7, 15],
#          [ 4, 17],
#          [ 1,  5]]),
#   array([[13, 18],
#          [13, 18],
#          [ 7, 16],
#          [ 6, 16]]),
#   array([[ 9, 16],
#          [ 2,  5],
#          [15, 18],
#          [ 2, 15]]),
#   array([[ 8, 15],
#          [ 2, 15],
#          [ 2,  8],
#          [13, 16]]),
#   array([[14, 18],
#          [ 5, 12],
#          [ 0, 10],
#          [ 3,  6]]),
#   array([[ 3, 14],
#          [12, 15],
#          [11, 14],
#          [16, 19]]),
#   array([[ 0,  3],
#          [10, 14],
#          [ 4, 16],
#          [11, 19]]),
#   array([[ 7, 19],
#          [ 8, 11],
#          [15, 18],
#          [15, 18]]),
#   array([[ 4,  7],
#          [ 7, 18],
#          [14, 18],
#          [ 8, 12]]),
#   array([[14, 19],
#          [12, 15],
#          [12, 19],
#          [17, 20]]),
#   array([[ 0, 13],
#          [13, 16],
#          [14, 17],
#          [ 2,  5]]),
#   array([[10, 17],
#          [ 8, 12],
#          [15, 18],
#          [11, 16]]),
#   array([[ 5, 15],
#          [17, 20],
#          [14, 19],
#          [10, 13]]),
#   array([[ 9, 14],
#          [17, 20],
#          [15, 18],
#          [14, 17]]),
#   array([[11, 14],
#          [13, 16],
#          [ 2,  5],
#          [ 0, 12]]),
#   array([[16, 19],
#          [ 8, 11],
#          [ 0, 16],
#          [10, 16]]),
#   array([[ 9, 12],
#          [17, 20],
#          [ 7, 19],
#          [ 8, 12]]),
#   array([[ 7, 19],
#          [ 5, 10],
#          [12, 15],
#          [ 4, 12]]),
#   array([[ 8, 11],
#          [ 6, 19],
#          [10, 16],
#          [13, 16]]),
#   array([[17, 20],
#          [ 4,  9],
#          [ 5, 11],
#          [10, 19]]),
#   array([[ 9, 14],
#          [ 5, 12],
#          [ 4, 14],
#          [15, 19]]),
#   array([[ 2, 13],
#          [ 9, 12],
#          [ 6,  9],
#          [ 0,  7]]),
#   array([[12, 18],
#          [ 7, 19],
#          [11, 14],
#          [ 3,  8]]),
#   array([[ 0, 11],
#          [14, 17],
#          [12, 19],
#          [15, 18]]),
#   array([[ 8, 17],
#          [16, 19],
#          [ 4, 11],
#          [ 2, 16]]),
#   array([[ 3,  8],
#          [11, 14],
#          [ 8, 19],
#          [ 9, 12]]),
#   array([[14, 17],
#          [ 5, 11],
#          [ 7, 10],
#          [13, 17]]),
#   array([[ 8, 14],
#          [ 9, 12],
#          [ 2, 14],
#          [ 3,  6]]),
#   array([[13, 16],
#          [ 0, 10],
#          [ 6,  9],
#          [17, 20]]),
#   array([[ 8, 18],
#          [ 7, 17],
#          [ 8, 11],
#          [11, 19]]),
#   array([[16, 19],
#          [ 1,  8],
#          [ 2, 12],
#          [17, 20]]),
#   array([[11, 15],
#          [10, 17],
#          [16, 19],
#          [15, 18]]),
#   array([[10, 15],
#          [ 6, 17],
#          [ 9, 15],
#          [ 9, 13]])],
#  'estimators': [DecisionTreeClassifier(criterion='entropy', random_state=2024204424),
#   DecisionTreeClassifier(criterion='entropy', random_state=1614528196),
#   DecisionTreeClassifier(criterion='entropy', random_state=1109292346),
#   DecisionTreeClassifier(criterion='entropy', random_state=2074696705),
#   DecisionTreeClassifier(criterion='entropy', random_state=695959995),
#   DecisionTreeClassifier(criterion='entropy', random_state=1748025434),
#   DecisionTreeClassifier(criterion='entropy', random_state=277188249),
#   DecisionTreeClassifier(criterion='entropy', random_state=1293834272),
#   DecisionTreeClassifier(criterion='entropy', random_state=1567393617),
#   DecisionTreeClassifier(criterion='entropy', random_state=1128224171),
#   DecisionTreeClassifier(criterion='entropy', random_state=570596404),
#   DecisionTreeClassifier(criterion='entropy', random_state=1195798954),
#   DecisionTreeClassifier(criterion='entropy', random_state=775982399),
#   DecisionTreeClassifier(criterion='entropy', random_state=1839995277),
#   DecisionTreeClassifier(criterion='entropy', random_state=1023861621),
#   DecisionTreeClassifier(criterion='entropy', random_state=277737183),
#   DecisionTreeClassifier(criterion='entropy', random_state=1677545827),
#   DecisionTreeClassifier(criterion='entropy', random_state=994434760),
#   DecisionTreeClassifier(criterion='entropy', random_state=443215588),
#   DecisionTreeClassifier(criterion='entropy', random_state=1687190697),
#   DecisionTreeClassifier(criterion='entropy', random_state=278625686),
#   DecisionTreeClassifier(criterion='entropy', random_state=1467765545),
#   DecisionTreeClassifier(criterion='entropy', random_state=446550431),
#   DecisionTreeClassifier(criterion='entropy', random_state=108701698),
#   DecisionTreeClassifier(criterion='entropy', random_state=763853965),
#   DecisionTreeClassifier(criterion='entropy', random_state=1879324659),
#   DecisionTreeClassifier(criterion='entropy', random_state=1922993737),
#   DecisionTreeClassifier(criterion='entropy', random_state=282977558),
#   DecisionTreeClassifier(criterion='entropy', random_state=478615921),
#   DecisionTreeClassifier(criterion='entropy', random_state=379627121),
#   DecisionTreeClassifier(criterion='entropy', random_state=246492815),
#   DecisionTreeClassifier(criterion='entropy', random_state=1067011144),
#   DecisionTreeClassifier(criterion='entropy', random_state=1631896033),
#   DecisionTreeClassifier(criterion='entropy', random_state=891659643),
#   DecisionTreeClassifier(criterion='entropy', random_state=261663967),
#   DecisionTreeClassifier(criterion='entropy', random_state=1461299148),
#   DecisionTreeClassifier(criterion='entropy', random_state=462912628),
#   DecisionTreeClassifier(criterion='entropy', random_state=808327046),
#   DecisionTreeClassifier(criterion='entropy', random_state=410327138),
#   DecisionTreeClassifier(criterion='entropy', random_state=2116494488),
#   DecisionTreeClassifier(criterion='entropy', random_state=684198395),
#   DecisionTreeClassifier(criterion='entropy', random_state=672421801),
#   DecisionTreeClassifier(criterion='entropy', random_state=1021597701),
#   DecisionTreeClassifier(criterion='entropy', random_state=836969917),
#   DecisionTreeClassifier(criterion='entropy', random_state=828762803),
#   DecisionTreeClassifier(criterion='entropy', random_state=1918017324),
#   DecisionTreeClassifier(criterion='entropy', random_state=655930387),
#   DecisionTreeClassifier(criterion='entropy', random_state=201726023),
#   DecisionTreeClassifier(criterion='entropy', random_state=2062328508),
#   DecisionTreeClassifier(criterion='entropy', random_state=961778452),
#   DecisionTreeClassifier(criterion='entropy', random_state=845842039),
#   DecisionTreeClassifier(criterion='entropy', random_state=245459409),
#   DecisionTreeClassifier(criterion='entropy', random_state=131629101),
#   DecisionTreeClassifier(criterion='entropy', random_state=1495207165),
#   DecisionTreeClassifier(criterion='entropy', random_state=1056545481),
#   DecisionTreeClassifier(criterion='entropy', random_state=994632459),
#   DecisionTreeClassifier(criterion='entropy', random_state=572621770),
#   DecisionTreeClassifier(criterion='entropy', random_state=599922419),
#   DecisionTreeClassifier(criterion='entropy', random_state=4981815),
#   DecisionTreeClassifier(criterion='entropy', random_state=912705023),
#   DecisionTreeClassifier(criterion='entropy', random_state=1307752308),
#   DecisionTreeClassifier(criterion='entropy', random_state=564880017),
#   DecisionTreeClassifier(criterion='entropy', random_state=6601912),
#   DecisionTreeClassifier(criterion='entropy', random_state=545138603),
#   DecisionTreeClassifier(criterion='entropy', random_state=416888393),
#   DecisionTreeClassifier(criterion='entropy', random_state=1453864918),
#   DecisionTreeClassifier(criterion='entropy', random_state=518591840),
#   DecisionTreeClassifier(criterion='entropy', random_state=809859314),
#   DecisionTreeClassifier(criterion='entropy', random_state=422582401),
#   DecisionTreeClassifier(criterion='entropy', random_state=1136037472),
#   DecisionTreeClassifier(criterion='entropy', random_state=1532386712),
#   DecisionTreeClassifier(criterion='entropy', random_state=2008794330),
#   DecisionTreeClassifier(criterion='entropy', random_state=1679844436),
#   DecisionTreeClassifier(criterion='entropy', random_state=471270249),
#   DecisionTreeClassifier(criterion='entropy', random_state=154400582),
#   DecisionTreeClassifier(criterion='entropy', random_state=345970288),
#   DecisionTreeClassifier(criterion='entropy', random_state=1709038746),
#   DecisionTreeClassifier(criterion='entropy', random_state=1132708569),
#   DecisionTreeClassifier(criterion='entropy', random_state=336110975),
#   DecisionTreeClassifier(criterion='entropy', random_state=1504791494),
#   DecisionTreeClassifier(criterion='entropy', random_state=1967687417),
#   DecisionTreeClassifier(criterion='entropy', random_state=1084691948),
#   DecisionTreeClassifier(criterion='entropy', random_state=781046872),
#   DecisionTreeClassifier(criterion='entropy', random_state=1931502159),
#   DecisionTreeClassifier(criterion='entropy', random_state=1901063087),
#   DecisionTreeClassifier(criterion='entropy', random_state=251768567),
#   DecisionTreeClassifier(criterion='entropy', random_state=331684003),
#   DecisionTreeClassifier(criterion='entropy', random_state=1842471651),
#   DecisionTreeClassifier(criterion='entropy', random_state=968132981),
#   DecisionTreeClassifier(criterion='entropy', random_state=1642514337),
#   DecisionTreeClassifier(criterion='entropy', random_state=2105441624),
#   DecisionTreeClassifier(criterion='entropy', random_state=1839804366),
#   DecisionTreeClassifier(criterion='entropy', random_state=1841731087),
#   DecisionTreeClassifier(criterion='entropy', random_state=1668764783),
#   DecisionTreeClassifier(criterion='entropy', random_state=428043526),
#   DecisionTreeClassifier(criterion='entropy', random_state=636278503),
#   DecisionTreeClassifier(criterion='entropy', random_state=41180505),
#   DecisionTreeClassifier(criterion='entropy', random_state=1147331678),
#   DecisionTreeClassifier(criterion='entropy', random_state=500912337),
#   DecisionTreeClassifier(criterion='entropy', random_state=1548320992),
#   DecisionTreeClassifier(criterion='entropy', random_state=1813042198),
#   DecisionTreeClassifier(criterion='entropy', random_state=880964520),
#   DecisionTreeClassifier(criterion='entropy', random_state=631766516),
#   DecisionTreeClassifier(criterion='entropy', random_state=1481890727),
#   DecisionTreeClassifier(criterion='entropy', random_state=347160290),
#   DecisionTreeClassifier(criterion='entropy', random_state=155577432),
#   DecisionTreeClassifier(criterion='entropy', random_state=1968560200),
#   DecisionTreeClassifier(criterion='entropy', random_state=74541135),
#   DecisionTreeClassifier(criterion='entropy', random_state=73067132),
#   DecisionTreeClassifier(criterion='entropy', random_state=2074144325),
#   DecisionTreeClassifier(criterion='entropy', random_state=1618082050),
#   DecisionTreeClassifier(criterion='entropy', random_state=1081151458),
#   DecisionTreeClassifier(criterion='entropy', random_state=614560720),
#   DecisionTreeClassifier(criterion='entropy', random_state=1264740866),
#   DecisionTreeClassifier(criterion='entropy', random_state=316916960),
#   DecisionTreeClassifier(criterion='entropy', random_state=1650004897),
#   DecisionTreeClassifier(criterion='entropy', random_state=1501037932),
#   DecisionTreeClassifier(criterion='entropy', random_state=1247726375),
#   DecisionTreeClassifier(criterion='entropy', random_state=308221896),
#   DecisionTreeClassifier(criterion='entropy', random_state=1842380523),
#   DecisionTreeClassifier(criterion='entropy', random_state=488293150),
#   DecisionTreeClassifier(criterion='entropy', random_state=883698529),
#   DecisionTreeClassifier(criterion='entropy', random_state=1597842092),
#   DecisionTreeClassifier(criterion='entropy', random_state=1577722985),
#   DecisionTreeClassifier(criterion='entropy', random_state=2099614415),
#   DecisionTreeClassifier(criterion='entropy', random_state=361454306),
#   DecisionTreeClassifier(criterion='entropy', random_state=1304256851),
#   DecisionTreeClassifier(criterion='entropy', random_state=1908134298),
#   DecisionTreeClassifier(criterion='entropy', random_state=579849508),
#   DecisionTreeClassifier(criterion='entropy', random_state=606779824),
#   DecisionTreeClassifier(criterion='entropy', random_state=1250480135),
#   DecisionTreeClassifier(criterion='entropy', random_state=488448872),
#   DecisionTreeClassifier(criterion='entropy', random_state=1005691939),
#   DecisionTreeClassifier(criterion='entropy', random_state=129773056),
#   DecisionTreeClassifier(criterion='entropy', random_state=339282317),
#   DecisionTreeClassifier(criterion='entropy', random_state=2017121024),
#   DecisionTreeClassifier(criterion='entropy', random_state=1829724328),
#   DecisionTreeClassifier(criterion='entropy', random_state=1712973165),
#   DecisionTreeClassifier(criterion='entropy', random_state=2039157522),
#   DecisionTreeClassifier(criterion='entropy', random_state=877391953),
#   DecisionTreeClassifier(criterion='entropy', random_state=1177692959),
#   DecisionTreeClassifier(criterion='entropy', random_state=674962936),
#   DecisionTreeClassifier(criterion='entropy', random_state=265182505),
#   DecisionTreeClassifier(criterion='entropy', random_state=811476899),
#   DecisionTreeClassifier(criterion='entropy', random_state=454124545),
#   DecisionTreeClassifier(criterion='entropy', random_state=2141447395),
#   DecisionTreeClassifier(criterion='entropy', random_state=58798623),
#   DecisionTreeClassifier(criterion='entropy', random_state=856442305),
#   DecisionTreeClassifier(criterion='entropy', random_state=142800278),
#   DecisionTreeClassifier(criterion='entropy', random_state=1942055929),
#   DecisionTreeClassifier(criterion='entropy', random_state=1330199001),
#   DecisionTreeClassifier(criterion='entropy', random_state=578839475),
#   DecisionTreeClassifier(criterion='entropy', random_state=1218227796),
#   DecisionTreeClassifier(criterion='entropy', random_state=244580233),
#   DecisionTreeClassifier(criterion='entropy', random_state=382704142),
#   DecisionTreeClassifier(criterion='entropy', random_state=1504994824),
#   DecisionTreeClassifier(criterion='entropy', random_state=1437315448),
#   DecisionTreeClassifier(criterion='entropy', random_state=715852202),
#   DecisionTreeClassifier(criterion='entropy', random_state=1051399951),
#   DecisionTreeClassifier(criterion='entropy', random_state=695153853),
#   DecisionTreeClassifier(criterion='entropy', random_state=1766477891),
#   DecisionTreeClassifier(criterion='entropy', random_state=1582542452),
#   DecisionTreeClassifier(criterion='entropy', random_state=1134491379),
#   DecisionTreeClassifier(criterion='entropy', random_state=527983843),
#   DecisionTreeClassifier(criterion='entropy', random_state=2131763513),
#   DecisionTreeClassifier(criterion='entropy', random_state=741300655),
#   DecisionTreeClassifier(criterion='entropy', random_state=409494459),
#   DecisionTreeClassifier(criterion='entropy', random_state=721190226),
#   DecisionTreeClassifier(criterion='entropy', random_state=1693540607),
#   DecisionTreeClassifier(criterion='entropy', random_state=311708298),
#   DecisionTreeClassifier(criterion='entropy', random_state=527405274),
#   DecisionTreeClassifier(criterion='entropy', random_state=1024701306),
#   DecisionTreeClassifier(criterion='entropy', random_state=529190382),
#   DecisionTreeClassifier(criterion='entropy', random_state=206444067),
#   DecisionTreeClassifier(criterion='entropy', random_state=829382463),
#   DecisionTreeClassifier(criterion='entropy', random_state=1489339140),
#   DecisionTreeClassifier(criterion='entropy', random_state=446320284),
#   DecisionTreeClassifier(criterion='entropy', random_state=1864192808),
#   DecisionTreeClassifier(criterion='entropy', random_state=1549456165),
#   DecisionTreeClassifier(criterion='entropy', random_state=1632046041),
#   DecisionTreeClassifier(criterion='entropy', random_state=290466180),
#   DecisionTreeClassifier(criterion='entropy', random_state=1242998195),
#   DecisionTreeClassifier(criterion='entropy', random_state=2098141473),
#   DecisionTreeClassifier(criterion='entropy', random_state=360649634),
#   DecisionTreeClassifier(criterion='entropy', random_state=1478144130),
#   DecisionTreeClassifier(criterion='entropy', random_state=1416044956),
#   DecisionTreeClassifier(criterion='entropy', random_state=938678489),
#   DecisionTreeClassifier(criterion='entropy', random_state=286996721),
#   DecisionTreeClassifier(criterion='entropy', random_state=1397915271),
#   DecisionTreeClassifier(criterion='entropy', random_state=1146382092),
#   DecisionTreeClassifier(criterion='entropy', random_state=383909463),
#   DecisionTreeClassifier(criterion='entropy', random_state=871313981),
#   DecisionTreeClassifier(criterion='entropy', random_state=2114669510),
#   DecisionTreeClassifier(criterion='entropy', random_state=1055428762),
#   DecisionTreeClassifier(criterion='entropy', random_state=1269360540),
#   DecisionTreeClassifier(criterion='entropy', random_state=559948790),
#   DecisionTreeClassifier(criterion='entropy', random_state=1436629973),
#   DecisionTreeClassifier(criterion='entropy', random_state=1313871492),
#   DecisionTreeClassifier(criterion='entropy', random_state=420461771),
#   DecisionTreeClassifier(criterion='entropy', random_state=676463148)],
#  'n_classes': 2,
#  'fit_time': 45441}

# %%
# Réalisation des prédictions

y_pred = clf_rf_ts.predict(X_test)

# %% [markdown]
# ## 5. Évaluation

# %%
# Élaboration de la matrice de confusion

pd.crosstab(y_test, y_pred, rownames = ["Classe réelle"], colnames = ["Classe prédite"])
# Out:
# Classe prédite     0    1
# Classe réelle
# 0               1115   33
# 1                180  116

# %%
# Élaboration du rapport de classification

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91      1148
#            1       0.78      0.39      0.52       296
#
#     accuracy                           0.85      1444
#    macro avg       0.82      0.68      0.72      1444
# weighted avg       0.84      0.85      0.83      1444
