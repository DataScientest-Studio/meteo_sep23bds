# %% [markdown]
# # **Classification** des **séries temporelles** avec `sktime`

# %% [markdown]
# ## Métadonnées

# %% [markdown]
# - **Expérience nº :** 2.2.1
# - **Date :** 09/11/2023
# - **Heure :** 14:38
# - **Données :** `ready_Evaporation_Sunshine.csv`
# - **Tri :** par défaut
# - **Découpage :** `TimeSeriesSplit`
# - **Mise à l'échelle :** non
# - **Rééquilibrage :** non
# - **Conversion :** `numpyfy`
# - **Algorithme :** TSF

# %% [markdown]
# ## Sommaire

# %% [markdown]
# 1. Initialisation
# 2. Découpage
# 3. Conversion
# 4. Modélisation
# 5. Évaluation

# %% [markdown]
# ## 1. Initialisation

# %%
# Importation des bibliothèques et modules nécessaires au fonctionnement de ce notebook

import pandas as pd
import numpy as np

from sklearn.metrics import classification_report

# %%
# Importation du jeu de données et enregistrement dans le DataFrame `df`

df = pd.read_csv("../../../../data/processed/omar/ready_Evaporation_Sunshine.csv", index_col = 1)
df = df.drop(columns = "Unnamed: 0")

# %%
# Inspection de la structure de `df`

df.head()
# Out:
#             MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  \
# Date
# 2008-12-01     13.4     22.9       0.6           44.0          20.0
# 2008-12-02      7.4     25.1       0.0           44.0           4.0
# 2008-12-03     12.9     25.7       0.0           46.0          19.0
# 2008-12-04      9.2     28.0       0.0           24.0          11.0
# 2008-12-05     17.5     32.3       1.0           41.0           7.0
#
#             WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  \
# Date
# 2008-12-01          24.0         71.0         22.0       1007.7       1007.1
# 2008-12-02          22.0         44.0         25.0       1010.6       1007.8
# 2008-12-03          26.0         38.0         30.0       1007.6       1008.7
# 2008-12-04           9.0         45.0         16.0       1017.6       1012.8
# 2008-12-05          20.0         82.0         33.0       1010.8       1006.0
#
#             ...  year  month  day  LocationNum  WindGustDirNum  WindDir9amNum  \
# Date        ...
# 2008-12-01  ...  2008     12    1            0        3.141593       3.141593
# 2008-12-02  ...  2008     12    2            0        2.748894       1.963495
# 2008-12-03  ...  2008     12    3            0        3.534292       3.141593
# 2008-12-04  ...  2008     12    4            0        0.785398       5.497787
# 2008-12-05  ...  2008     12    5            0        3.141593       0.392699
#
#             WindDir3pmNum   Latitude  Longitude  CodeRegionNum
# Date
# 2008-12-01       2.748894 -36.080477  146.91628              0
# 2008-12-02       3.534292 -36.080477  146.91628              0
# 2008-12-03       3.534292 -36.080477  146.91628              0
# 2008-12-04       0.000000 -36.080477  146.91628              0
# 2008-12-05       2.356194 -36.080477  146.91628              0
#
# [5 rows x 26 columns]

# %%
# Inspection de la structure de `df`

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10453 entries, 2008-12-01 to 2017-06-24
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   MinTemp         10453 non-null  float64
#  1   MaxTemp         10453 non-null  float64
#  2   Rainfall        10453 non-null  float64
#  3   WindGustSpeed   10453 non-null  float64
#  4   WindSpeed9am    10453 non-null  float64
#  5   WindSpeed3pm    10453 non-null  float64
#  6   Humidity9am     10453 non-null  float64
#  7   Humidity3pm     10453 non-null  float64
#  8   Pressure9am     10453 non-null  float64
#  9   Pressure3pm     10453 non-null  float64
#  10  Cloud9am        10453 non-null  float64
#  11  Cloud3pm        10453 non-null  float64
#  12  Temp9am         10453 non-null  float64
#  13  Temp3pm         10453 non-null  float64
#  14  RainToday       10453 non-null  int64
#  15  RainTomorrow    10453 non-null  int64
#  16  year            10453 non-null  int64
#  17  month           10453 non-null  int64
#  18  day             10453 non-null  int64
#  19  LocationNum     10453 non-null  int64
#  20  WindGustDirNum  10453 non-null  float64
#  21  WindDir9amNum   10453 non-null  float64
#  22  WindDir3pmNum   10453 non-null  float64
#  23  Latitude        10453 non-null  float64
#  24  Longitude       10453 non-null  float64
#  25  CodeRegionNum   10453 non-null  int64
# dtypes: float64(19), int64(7)
# memory usage: 2.2+ MB

# %% [markdown]
# ## 2. Découpage

# %%
# Découpage de `df` sur l'axe des colonnes : séparation des variables explicatives (`data`) et cible (`target`)

data = df.drop(columns = "RainTomorrow")
target = df["RainTomorrow"]

# %%
# Découpage de `data` et de `target` sur l'axe des lignes : séparation des jeux d'entraînement (`*_train`) et de test (`*_test`) avec le splitter `TimeSeriesSplit`

from sklearn.model_selection import TimeSeriesSplit

tss = TimeSeriesSplit(n_splits = 5) ## Nous fixons le paramètre `n_splits` à 5 afin d'avoir une répartition de 80 / 20 entre les jeux d'entraînement et de test, respectivement.

for train_index, test_index in tss.split(data):
    X_train, X_test = data.iloc[train_index, :], data.iloc[test_index,:]
    y_train, y_test = target.iloc[train_index], target.iloc[test_index]

# %% [markdown]
# ## 3. Conversion

# %%
# Importation de la fonction artisanale `numpyfy`

from numpyfy import numpyfy

# %%
# Application de la fonction `numpyfy` aux 4 jeux de données issus du découpage effectué par le splitter `TimeSeriesSplit` afin de les convertir en arrays et ainsi les rendre compatibles avec `sktime`

X_train, X_test, y_train, y_test = numpyfy(X_train, X_test, y_train, y_test)

# %% [markdown]
# ## 4. Modélisation

# %%
# Instanciation d'un modèle classificateur via un Pipeline

from sklearn.pipeline import Pipeline
from sktime.transformations.panel.compose import ColumnConcatenator
from sktime.classification.interval_based import TimeSeriesForestClassifier

steps = [
    ("concatenate", ColumnConcatenator()), ## Cette étape permet de transformer les jeux de données multivariées en univariées afin qu'ils puissent être traités par `TimeSeriesForestClassifier`.
    ("classify", TimeSeriesForestClassifier()),
]

clf_rf_ts = Pipeline(steps)

# %%
# Récupération des paramètres initiaux de la TSF

clf_rf_ts["classify"].get_params()
# Out:
# {'min_interval': 3, 'n_estimators': 200, 'n_jobs': 1, 'random_state': None}

# %%
# Entraînement du modèle

clf_rf_ts.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('concatenate', ColumnConcatenator()),
#                 ('classify', TimeSeriesForestClassifier())])

# %%
# Récupération des paramètres ajustés de la TSF

clf_rf_ts["classify"].get_fitted_params()
# Out:
# {'classes': array([0, 1]),
#  'intervals': [array([[12, 23],
#          [10, 18],
#          [ 1, 13],
#          [ 7, 20],
#          [ 5,  8]]),
#   array([[10, 19],
#          [ 1, 17],
#          [18, 23],
#          [17, 23],
#          [ 1,  4]]),
#   array([[11, 14],
#          [ 1,  6],
#          [11, 18],
#          [ 4, 18],
#          [14, 17]]),
#   array([[ 4, 18],
#          [12, 15],
#          [ 6, 23],
#          [ 1, 13],
#          [19, 23]]),
#   array([[ 2, 19],
#          [ 9, 12],
#          [ 6, 19],
#          [12, 22],
#          [16, 19]]),
#   array([[ 5,  8],
#          [ 8, 22],
#          [ 3,  9],
#          [18, 23],
#          [ 3, 11]]),
#   array([[ 7, 20],
#          [21, 24],
#          [15, 23],
#          [ 3, 19],
#          [12, 20]]),
#   array([[20, 23],
#          [ 3, 19],
#          [ 3,  6],
#          [12, 15],
#          [ 5, 23]]),
#   array([[ 9, 22],
#          [17, 22],
#          [ 2, 18],
#          [17, 20],
#          [ 6, 13]]),
#   array([[ 4, 19],
#          [11, 17],
#          [ 1, 18],
#          [11, 18],
#          [12, 22]]),
#   array([[11, 15],
#          [20, 23],
#          [19, 22],
#          [11, 18],
#          [21, 24]]),
#   array([[ 7, 22],
#          [ 8, 19],
#          [ 4,  7],
#          [14, 18],
#          [19, 22]]),
#   array([[15, 18],
#          [ 0,  4],
#          [11, 15],
#          [10, 19],
#          [ 5, 17]]),
#   array([[10, 22],
#          [17, 21],
#          [11, 14],
#          [ 6, 14],
#          [ 1, 18]]),
#   array([[ 0, 12],
#          [ 7, 12],
#          [ 0, 17],
#          [ 9, 14],
#          [ 4, 19]]),
#   array([[ 6, 12],
#          [16, 19],
#          [18, 21],
#          [10, 23],
#          [11, 16]]),
#   array([[ 8, 16],
#          [ 5, 18],
#          [ 7, 10],
#          [10, 13],
#          [12, 15]]),
#   array([[20, 23],
#          [13, 22],
#          [19, 22],
#          [18, 21],
#          [11, 18]]),
#   array([[20, 23],
#          [20, 23],
#          [10, 21],
#          [ 2, 16],
#          [14, 18]]),
#   array([[11, 18],
#          [15, 20],
#          [ 3,  6],
#          [ 6,  9],
#          [ 6, 17]]),
#   array([[ 2, 11],
#          [ 9, 23],
#          [17, 20],
#          [14, 17],
#          [ 3,  6]]),
#   array([[15, 22],
#          [15, 18],
#          [10, 13],
#          [ 0,  6],
#          [ 2, 12]]),
#   array([[19, 22],
#          [15, 23],
#          [ 5, 16],
#          [ 8, 17],
#          [19, 22]]),
#   array([[ 2, 18],
#          [13, 21],
#          [ 6, 16],
#          [ 5, 23],
#          [15, 21]]),
#   array([[ 1, 16],
#          [ 1, 18],
#          [14, 17],
#          [15, 18],
#          [15, 23]]),
#   array([[ 5, 19],
#          [18, 22],
#          [14, 17],
#          [15, 23],
#          [ 5, 11]]),
#   array([[ 7, 10],
#          [13, 16],
#          [ 5, 12],
#          [ 6, 20],
#          [17, 20]]),
#   array([[21, 24],
#          [10, 13],
#          [ 5, 12],
#          [11, 22],
#          [ 9, 18]]),
#   array([[21, 24],
#          [ 9, 20],
#          [21, 24],
#          [ 9, 23],
#          [ 3,  6]]),
#   array([[ 6, 23],
#          [ 6, 21],
#          [ 3, 21],
#          [ 3,  6],
#          [17, 20]]),
#   array([[ 7, 15],
#          [20, 23],
#          [15, 18],
#          [17, 20],
#          [10, 22]]),
#   array([[ 3, 10],
#          [ 4,  7],
#          [ 3, 20],
#          [ 6, 20],
#          [ 2,  7]]),
#   array([[17, 21],
#          [15, 20],
#          [ 0, 21],
#          [ 7, 10],
#          [16, 19]]),
#   array([[ 7, 10],
#          [19, 22],
#          [15, 18],
#          [ 1,  6],
#          [ 0,  3]]),
#   array([[17, 22],
#          [11, 17],
#          [ 1, 13],
#          [11, 14],
#          [ 3, 11]]),
#   array([[ 9, 12],
#          [ 7, 23],
#          [16, 22],
#          [11, 14],
#          [ 3,  6]]),
#   array([[ 2,  5],
#          [16, 20],
#          [11, 23],
#          [11, 23],
#          [ 2, 16]]),
#   array([[ 1, 12],
#          [17, 20],
#          [ 5,  9],
#          [ 1, 23],
#          [ 1,  4]]),
#   array([[ 1, 17],
#          [19, 22],
#          [16, 21],
#          [20, 23],
#          [ 4,  9]]),
#   array([[20, 23],
#          [11, 14],
#          [21, 24],
#          [ 5, 10],
#          [15, 18]]),
#   array([[10, 21],
#          [17, 23],
#          [14, 17],
#          [11, 14],
#          [ 0, 17]]),
#   array([[ 5, 18],
#          [15, 22],
#          [19, 22],
#          [10, 23],
#          [18, 21]]),
#   array([[16, 19],
#          [ 0, 19],
#          [ 0,  5],
#          [ 4, 22],
#          [16, 19]]),
#   array([[11, 18],
#          [ 3, 12],
#          [ 4,  7],
#          [21, 24],
#          [ 7, 22]]),
#   array([[ 3, 17],
#          [ 7, 10],
#          [ 4, 20],
#          [ 1, 17],
#          [13, 23]]),
#   array([[ 0,  7],
#          [ 0, 18],
#          [13, 18],
#          [ 3,  6],
#          [ 5, 21]]),
#   array([[ 8, 14],
#          [ 3, 13],
#          [16, 19],
#          [19, 23],
#          [15, 20]]),
#   array([[ 2, 22],
#          [17, 20],
#          [17, 20],
#          [21, 24],
#          [20, 23]]),
#   array([[13, 16],
#          [ 4, 20],
#          [ 7, 12],
#          [13, 16],
#          [ 5,  8]]),
#   array([[ 7, 20],
#          [17, 20],
#          [18, 21],
#          [16, 20],
#          [ 4,  7]]),
#   array([[21, 24],
#          [16, 19],
#          [ 2, 13],
#          [ 1,  4],
#          [19, 22]]),
#   array([[ 3, 19],
#          [20, 23],
#          [ 4,  7],
#          [ 6, 13],
#          [ 2, 10]]),
#   array([[18, 21],
#          [ 5, 19],
#          [ 0,  3],
#          [13, 22],
#          [17, 20]]),
#   array([[12, 15],
#          [18, 21],
#          [10, 16],
#          [ 2, 15],
#          [15, 18]]),
#   array([[ 4, 10],
#          [16, 19],
#          [18, 21],
#          [ 4,  7],
#          [11, 15]]),
#   array([[19, 22],
#          [ 1,  6],
#          [ 2,  7],
#          [21, 24],
#          [19, 23]]),
#   array([[13, 16],
#          [11, 20],
#          [ 0,  5],
#          [11, 22],
#          [13, 19]]),
#   array([[11, 18],
#          [ 1, 20],
#          [12, 15],
#          [ 4, 23],
#          [15, 18]]),
#   array([[ 6, 14],
#          [20, 23],
#          [10, 18],
#          [13, 16],
#          [ 3, 12]]),
#   array([[ 5, 16],
#          [14, 23],
#          [17, 22],
#          [ 9, 17],
#          [10, 16]]),
#   array([[17, 20],
#          [ 1, 18],
#          [ 1, 12],
#          [ 8, 11],
#          [19, 22]]),
#   array([[ 6, 16],
#          [ 8, 16],
#          [11, 18],
#          [ 7, 10],
#          [17, 20]]),
#   array([[ 8, 18],
#          [ 1, 19],
#          [19, 23],
#          [ 9, 18],
#          [ 6,  9]]),
#   array([[18, 21],
#          [ 8, 11],
#          [ 7, 10],
#          [ 9, 12],
#          [14, 17]]),
#   array([[ 9, 12],
#          [10, 20],
#          [ 8, 15],
#          [15, 18],
#          [19, 22]]),
#   array([[ 3, 10],
#          [ 8, 19],
#          [13, 17],
#          [18, 21],
#          [17, 20]]),
#   array([[16, 19],
#          [11, 14],
#          [11, 20],
#          [ 9, 22],
#          [18, 21]]),
#   array([[19, 22],
#          [ 6, 12],
#          [ 4,  8],
#          [ 8, 16],
#          [10, 22]]),
#   array([[13, 22],
#          [15, 20],
#          [11, 14],
#          [20, 23],
#          [17, 22]]),
#   array([[ 2, 13],
#          [ 9, 20],
#          [ 0,  8],
#          [14, 19],
#          [ 3, 16]]),
#   array([[14, 22],
#          [ 6, 12],
#          [12, 17],
#          [ 9, 21],
#          [17, 20]]),
#   array([[12, 15],
#          [ 8, 14],
#          [10, 23],
#          [12, 16],
#          [18, 21]]),
#   array([[ 6, 11],
#          [ 9, 13],
#          [ 1, 11],
#          [21, 24],
#          [11, 19]]),
#   array([[11, 20],
#          [14, 17],
#          [11, 14],
#          [ 3, 22],
#          [21, 24]]),
#   array([[ 0, 11],
#          [ 9, 17],
#          [17, 20],
#          [ 8, 16],
#          [20, 23]]),
#   array([[11, 17],
#          [10, 17],
#          [12, 15],
#          [14, 22],
#          [12, 15]]),
#   array([[20, 23],
#          [ 2, 22],
#          [ 6, 13],
#          [13, 22],
#          [16, 21]]),
#   array([[11, 15],
#          [ 7, 10],
#          [ 7, 18],
#          [16, 19],
#          [13, 18]]),
#   array([[ 2, 15],
#          [ 6, 11],
#          [19, 22],
#          [18, 22],
#          [17, 20]]),
#   array([[14, 20],
#          [ 8, 14],
#          [ 7, 18],
#          [ 1, 15],
#          [ 2, 15]]),
#   array([[13, 22],
#          [14, 17],
#          [11, 15],
#          [10, 13],
#          [11, 14]]),
#   array([[11, 14],
#          [ 4,  7],
#          [ 5, 13],
#          [13, 16],
#          [20, 23]]),
#   array([[19, 23],
#          [ 1,  8],
#          [ 0, 21],
#          [ 4, 17],
#          [19, 22]]),
#   array([[ 4, 14],
#          [12, 22],
#          [17, 21],
#          [12, 15],
#          [ 8, 16]]),
#   array([[ 0,  3],
#          [ 1, 10],
#          [ 6, 15],
#          [12, 15],
#          [14, 17]]),
#   array([[12, 16],
#          [ 5,  8],
#          [21, 24],
#          [ 4, 23],
#          [10, 21]]),
#   array([[16, 23],
#          [20, 23],
#          [19, 23],
#          [10, 22],
#          [21, 24]]),
#   array([[16, 22],
#          [ 3, 17],
#          [ 9, 16],
#          [ 4, 17],
#          [10, 22]]),
#   array([[ 1, 15],
#          [ 3,  6],
#          [ 3, 23],
#          [12, 15],
#          [16, 20]]),
#   array([[ 6, 15],
#          [14, 18],
#          [ 1,  4],
#          [17, 23],
#          [ 4, 15]]),
#   array([[16, 21],
#          [15, 18],
#          [19, 23],
#          [17, 20],
#          [14, 23]]),
#   array([[10, 13],
#          [ 4,  9],
#          [ 0,  3],
#          [16, 21],
#          [ 4, 23]]),
#   array([[ 2, 19],
#          [ 0, 15],
#          [ 4,  7],
#          [12, 19],
#          [ 2, 10]]),
#   array([[ 6,  9],
#          [ 1,  8],
#          [ 0, 20],
#          [18, 21],
#          [16, 21]]),
#   array([[11, 21],
#          [ 3, 16],
#          [ 4, 13],
#          [18, 21],
#          [ 6, 12]]),
#   array([[ 6, 21],
#          [ 1, 11],
#          [ 0, 17],
#          [10, 18],
#          [14, 17]]),
#   array([[ 3, 14],
#          [ 5, 13],
#          [ 8, 17],
#          [17, 20],
#          [ 5,  8]]),
#   array([[13, 23],
#          [ 5, 15],
#          [16, 22],
#          [ 4, 21],
#          [18, 21]]),
#   array([[19, 23],
#          [ 6, 18],
#          [12, 19],
#          [17, 22],
#          [14, 21]]),
#   array([[18, 22],
#          [10, 20],
#          [ 3,  7],
#          [ 2, 18],
#          [ 7, 14]]),
#   array([[ 7, 10],
#          [12, 15],
#          [10, 16],
#          [17, 20],
#          [21, 24]]),
#   array([[ 7, 10],
#          [11, 20],
#          [20, 23],
#          [ 9, 12],
#          [12, 20]]),
#   array([[ 8, 21],
#          [ 6,  9],
#          [21, 24],
#          [13, 19],
#          [ 3,  6]]),
#   array([[16, 20],
#          [ 0,  3],
#          [ 3, 11],
#          [21, 24],
#          [13, 19]]),
#   array([[13, 20],
#          [17, 20],
#          [13, 21],
#          [10, 13],
#          [ 3, 23]]),
#   array([[21, 24],
#          [20, 23],
#          [16, 22],
#          [ 8, 14],
#          [ 6, 19]]),
#   array([[16, 19],
#          [10, 23],
#          [11, 14],
#          [14, 17],
#          [ 2, 20]]),
#   array([[10, 16],
#          [17, 20],
#          [12, 15],
#          [12, 15],
#          [12, 15]]),
#   array([[19, 22],
#          [ 6, 17],
#          [ 1, 23],
#          [ 3, 12],
#          [15, 21]]),
#   array([[20, 23],
#          [ 9, 19],
#          [17, 20],
#          [20, 23],
#          [17, 20]]),
#   array([[19, 22],
#          [14, 21],
#          [16, 19],
#          [21, 24],
#          [20, 23]]),
#   array([[16, 19],
#          [16, 21],
#          [ 1, 13],
#          [20, 23],
#          [21, 24]]),
#   array([[19, 22],
#          [12, 19],
#          [ 1,  4],
#          [10, 20],
#          [11, 14]]),
#   array([[ 2,  7],
#          [ 8, 22],
#          [ 4,  8],
#          [ 6, 12],
#          [19, 23]]),
#   array([[15, 20],
#          [ 8, 14],
#          [ 3, 22],
#          [13, 18],
#          [16, 22]]),
#   array([[16, 19],
#          [ 5,  8],
#          [10, 21],
#          [ 8, 17],
#          [ 6, 11]]),
#   array([[ 6, 19],
#          [14, 17],
#          [19, 23],
#          [ 3,  6],
#          [11, 16]]),
#   array([[15, 23],
#          [ 5, 15],
#          [ 8, 11],
#          [ 4, 20],
#          [14, 17]]),
#   array([[20, 23],
#          [11, 23],
#          [20, 23],
#          [18, 21],
#          [17, 20]]),
#   array([[ 5,  9],
#          [ 6, 17],
#          [ 6, 20],
#          [16, 19],
#          [ 0, 18]]),
#   array([[ 1, 19],
#          [ 0, 17],
#          [ 6, 12],
#          [11, 21],
#          [ 2, 18]]),
#   array([[ 4, 15],
#          [ 8, 23],
#          [16, 20],
#          [ 5,  9],
#          [18, 21]]),
#   array([[ 1, 21],
#          [17, 20],
#          [ 7, 19],
#          [ 8, 20],
#          [11, 18]]),
#   array([[ 1,  5],
#          [19, 22],
#          [12, 19],
#          [ 1, 14],
#          [20, 23]]),
#   array([[ 5,  8],
#          [ 4, 21],
#          [ 6, 15],
#          [ 3,  7],
#          [ 5,  8]]),
#   array([[19, 22],
#          [ 5, 10],
#          [ 6, 11],
#          [16, 19],
#          [14, 20]]),
#   array([[ 4, 12],
#          [ 2, 21],
#          [ 4, 23],
#          [18, 21],
#          [11, 23]]),
#   array([[ 3,  6],
#          [16, 22],
#          [ 9, 21],
#          [ 5, 22],
#          [16, 20]]),
#   array([[13, 20],
#          [ 8, 18],
#          [15, 22],
#          [ 4, 22],
#          [ 2,  5]]),
#   array([[12, 15],
#          [14, 19],
#          [ 6, 21],
#          [ 5, 12],
#          [ 9, 12]]),
#   array([[14, 17],
#          [16, 23],
#          [19, 22],
#          [ 5, 21],
#          [18, 21]]),
#   array([[ 5, 11],
#          [13, 18],
#          [ 4, 12],
#          [20, 23],
#          [ 5, 17]]),
#   array([[16, 19],
#          [16, 19],
#          [12, 15],
#          [ 0,  3],
#          [15, 20]]),
#   array([[ 2, 16],
#          [11, 22],
#          [ 1, 16],
#          [ 1, 14],
#          [19, 22]]),
#   array([[ 0,  3],
#          [12, 19],
#          [16, 19],
#          [ 9, 12],
#          [20, 23]]),
#   array([[10, 19],
#          [ 0, 18],
#          [ 2, 12],
#          [18, 22],
#          [19, 23]]),
#   array([[11, 14],
#          [21, 24],
#          [ 5, 16],
#          [13, 16],
#          [ 0,  9]]),
#   array([[ 7, 19],
#          [ 6,  9],
#          [20, 23],
#          [20, 23],
#          [20, 23]]),
#   array([[18, 21],
#          [ 9, 21],
#          [13, 16],
#          [11, 20],
#          [21, 24]]),
#   array([[10, 17],
#          [10, 14],
#          [15, 18],
#          [ 0, 16],
#          [ 4,  7]]),
#   array([[19, 22],
#          [17, 21],
#          [ 0, 23],
#          [15, 18],
#          [15, 22]]),
#   array([[18, 21],
#          [ 9, 16],
#          [17, 20],
#          [ 1, 16],
#          [17, 22]]),
#   array([[17, 20],
#          [ 8, 13],
#          [ 4, 17],
#          [14, 21],
#          [ 5, 16]]),
#   array([[14, 23],
#          [ 2, 23],
#          [ 4, 23],
#          [20, 23],
#          [ 7, 18]]),
#   array([[ 7, 21],
#          [20, 23],
#          [20, 23],
#          [ 7, 12],
#          [ 0,  3]]),
#   array([[ 3,  8],
#          [ 0,  6],
#          [17, 20],
#          [ 7, 23],
#          [ 5,  8]]),
#   array([[ 9, 12],
#          [19, 22],
#          [16, 21],
#          [17, 20],
#          [18, 21]]),
#   array([[21, 24],
#          [ 2,  5],
#          [ 2,  8],
#          [ 8, 12],
#          [ 2, 22]]),
#   array([[ 5,  9],
#          [ 6, 15],
#          [ 7, 23],
#          [16, 19],
#          [17, 23]]),
#   array([[14, 17],
#          [16, 20],
#          [14, 22],
#          [ 6,  9],
#          [ 8, 23]]),
#   array([[12, 15],
#          [17, 20],
#          [ 0, 21],
#          [ 0,  6],
#          [20, 23]]),
#   array([[ 4, 23],
#          [17, 21],
#          [ 3, 22],
#          [11, 14],
#          [ 1,  4]]),
#   array([[16, 19],
#          [ 6, 16],
#          [15, 20],
#          [ 1, 23],
#          [12, 20]]),
#   array([[ 2, 15],
#          [ 0, 23],
#          [ 8, 21],
#          [11, 17],
#          [12, 15]]),
#   array([[16, 19],
#          [ 2,  5],
#          [11, 22],
#          [19, 22],
#          [ 7, 15]]),
#   array([[ 5, 11],
#          [10, 18],
#          [ 1,  4],
#          [17, 20],
#          [ 7, 18]]),
#   array([[15, 18],
#          [ 1,  8],
#          [12, 15],
#          [13, 16],
#          [ 8, 22]]),
#   array([[ 9, 12],
#          [ 0,  3],
#          [ 2,  8],
#          [19, 22],
#          [15, 22]]),
#   array([[19, 22],
#          [21, 24],
#          [ 8, 11],
#          [14, 17],
#          [ 9, 14]]),
#   array([[ 0,  6],
#          [ 2, 23],
#          [21, 24],
#          [19, 22],
#          [20, 23]]),
#   array([[14, 21],
#          [15, 21],
#          [14, 17],
#          [11, 18],
#          [ 8, 16]]),
#   array([[15, 18],
#          [ 5, 13],
#          [20, 23],
#          [ 3,  7],
#          [ 5, 15]]),
#   array([[ 3, 10],
#          [ 2,  7],
#          [18, 21],
#          [17, 20],
#          [ 5, 10]]),
#   array([[18, 21],
#          [ 6, 14],
#          [18, 21],
#          [17, 21],
#          [ 5,  8]]),
#   array([[ 8, 11],
#          [ 8, 16],
#          [ 7, 21],
#          [12, 18],
#          [21, 24]]),
#   array([[11, 21],
#          [ 1,  4],
#          [15, 18],
#          [ 6, 19],
#          [12, 21]]),
#   array([[ 8, 13],
#          [ 7, 14],
#          [ 4, 20],
#          [19, 22],
#          [ 3, 18]]),
#   array([[ 7, 23],
#          [ 6, 19],
#          [ 3, 14],
#          [18, 21],
#          [14, 20]]),
#   array([[12, 15],
#          [16, 20],
#          [ 9, 13],
#          [ 8, 19],
#          [17, 20]]),
#   array([[ 8, 11],
#          [ 0, 10],
#          [ 9, 12],
#          [ 4, 23],
#          [ 6, 20]]),
#   array([[13, 16],
#          [14, 17],
#          [21, 24],
#          [ 1, 20],
#          [17, 22]]),
#   array([[18, 21],
#          [ 3, 19],
#          [ 3,  6],
#          [14, 22],
#          [ 6,  9]]),
#   array([[18, 22],
#          [ 6, 20],
#          [19, 22],
#          [18, 23],
#          [10, 15]]),
#   array([[15, 18],
#          [ 1,  6],
#          [ 5, 14],
#          [13, 16],
#          [12, 15]]),
#   array([[20, 23],
#          [ 5, 16],
#          [11, 23],
#          [14, 17],
#          [12, 17]]),
#   array([[ 2, 23],
#          [19, 22],
#          [ 1,  4],
#          [ 0,  3],
#          [ 5, 14]]),
#   array([[17, 22],
#          [21, 24],
#          [15, 18],
#          [ 2, 23],
#          [12, 15]]),
#   array([[13, 22],
#          [ 2, 17],
#          [ 0, 18],
#          [21, 24],
#          [ 1,  9]]),
#   array([[17, 20],
#          [ 3, 10],
#          [15, 18],
#          [ 3,  8],
#          [ 3, 21]]),
#   array([[16, 23],
#          [17, 22],
#          [ 9, 12],
#          [ 4,  7],
#          [16, 19]]),
#   array([[18, 23],
#          [18, 22],
#          [13, 16],
#          [18, 21],
#          [ 5,  9]]),
#   array([[13, 18],
#          [ 0, 20],
#          [ 5, 22],
#          [ 4, 21],
#          [ 1, 21]]),
#   array([[ 9, 17],
#          [17, 23],
#          [13, 16],
#          [ 7, 17],
#          [16, 19]]),
#   array([[14, 17],
#          [20, 23],
#          [ 3, 11],
#          [ 3, 13],
#          [ 6, 13]]),
#   array([[12, 16],
#          [ 5, 12],
#          [ 6, 13],
#          [ 7, 11],
#          [ 7, 10]]),
#   array([[10, 22],
#          [16, 23],
#          [17, 20],
#          [ 8, 22],
#          [11, 15]]),
#   array([[16, 19],
#          [14, 17],
#          [ 1, 14],
#          [18, 21],
#          [20, 23]]),
#   array([[12, 16],
#          [ 3, 20],
#          [15, 18],
#          [ 7, 10],
#          [13, 19]]),
#   array([[ 6, 18],
#          [ 2, 12],
#          [ 3,  6],
#          [12, 17],
#          [ 2,  7]]),
#   array([[14, 17],
#          [10, 13],
#          [15, 20],
#          [ 0,  8],
#          [19, 22]]),
#   array([[21, 24],
#          [ 8, 17],
#          [16, 23],
#          [ 3, 20],
#          [ 6, 10]]),
#   array([[16, 19],
#          [18, 21],
#          [ 7, 15],
#          [13, 16],
#          [16, 19]]),
#   array([[ 7, 17],
#          [ 4,  7],
#          [19, 23],
#          [10, 17],
#          [ 7, 10]]),
#   array([[ 2, 21],
#          [ 4, 19],
#          [14, 18],
#          [11, 14],
#          [17, 23]]),
#   array([[ 4, 10],
#          [14, 20],
#          [ 3, 15],
#          [10, 13],
#          [21, 24]]),
#   array([[13, 16],
#          [ 4, 15],
#          [ 7, 14],
#          [ 2, 18],
#          [ 9, 22]]),
#   array([[10, 20],
#          [13, 20],
#          [ 1, 10],
#          [21, 24],
#          [10, 14]]),
#   array([[12, 21],
#          [15, 19],
#          [ 4, 17],
#          [ 1, 15],
#          [11, 23]]),
#   array([[11, 14],
#          [10, 13],
#          [ 9, 16],
#          [ 1,  4],
#          [13, 16]]),
#   array([[15, 18],
#          [ 3, 16],
#          [ 7, 10],
#          [15, 18],
#          [14, 17]])],
#  'estimators': [DecisionTreeClassifier(criterion='entropy', random_state=102461370),
#   DecisionTreeClassifier(criterion='entropy', random_state=135714466),
#   DecisionTreeClassifier(criterion='entropy', random_state=248631649),
#   DecisionTreeClassifier(criterion='entropy', random_state=1073071895),
#   DecisionTreeClassifier(criterion='entropy', random_state=428690893),
#   DecisionTreeClassifier(criterion='entropy', random_state=1907097793),
#   DecisionTreeClassifier(criterion='entropy', random_state=2107885952),
#   DecisionTreeClassifier(criterion='entropy', random_state=799432214),
#   DecisionTreeClassifier(criterion='entropy', random_state=1498817342),
#   DecisionTreeClassifier(criterion='entropy', random_state=2035872914),
#   DecisionTreeClassifier(criterion='entropy', random_state=485753066),
#   DecisionTreeClassifier(criterion='entropy', random_state=1451706449),
#   DecisionTreeClassifier(criterion='entropy', random_state=161928246),
#   DecisionTreeClassifier(criterion='entropy', random_state=1286026138),
#   DecisionTreeClassifier(criterion='entropy', random_state=1615695382),
#   DecisionTreeClassifier(criterion='entropy', random_state=1505964487),
#   DecisionTreeClassifier(criterion='entropy', random_state=1212262802),
#   DecisionTreeClassifier(criterion='entropy', random_state=1512581120),
#   DecisionTreeClassifier(criterion='entropy', random_state=1046439242),
#   DecisionTreeClassifier(criterion='entropy', random_state=1445068205),
#   DecisionTreeClassifier(criterion='entropy', random_state=870523608),
#   DecisionTreeClassifier(criterion='entropy', random_state=1616564231),
#   DecisionTreeClassifier(criterion='entropy', random_state=1986428271),
#   DecisionTreeClassifier(criterion='entropy', random_state=1455505735),
#   DecisionTreeClassifier(criterion='entropy', random_state=1034652318),
#   DecisionTreeClassifier(criterion='entropy', random_state=1670750317),
#   DecisionTreeClassifier(criterion='entropy', random_state=342692137),
#   DecisionTreeClassifier(criterion='entropy', random_state=1045112889),
#   DecisionTreeClassifier(criterion='entropy', random_state=1090056153),
#   DecisionTreeClassifier(criterion='entropy', random_state=1220768067),
#   DecisionTreeClassifier(criterion='entropy', random_state=507234727),
#   DecisionTreeClassifier(criterion='entropy', random_state=1610536288),
#   DecisionTreeClassifier(criterion='entropy', random_state=1667794638),
#   DecisionTreeClassifier(criterion='entropy', random_state=476345920),
#   DecisionTreeClassifier(criterion='entropy', random_state=541717277),
#   DecisionTreeClassifier(criterion='entropy', random_state=2145246712),
#   DecisionTreeClassifier(criterion='entropy', random_state=1105196688),
#   DecisionTreeClassifier(criterion='entropy', random_state=899059951),
#   DecisionTreeClassifier(criterion='entropy', random_state=1474718059),
#   DecisionTreeClassifier(criterion='entropy', random_state=911163773),
#   DecisionTreeClassifier(criterion='entropy', random_state=750538303),
#   DecisionTreeClassifier(criterion='entropy', random_state=1615827398),
#   DecisionTreeClassifier(criterion='entropy', random_state=1839681729),
#   DecisionTreeClassifier(criterion='entropy', random_state=1644799709),
#   DecisionTreeClassifier(criterion='entropy', random_state=786761410),
#   DecisionTreeClassifier(criterion='entropy', random_state=1485012243),
#   DecisionTreeClassifier(criterion='entropy', random_state=1500956684),
#   DecisionTreeClassifier(criterion='entropy', random_state=1232927594),
#   DecisionTreeClassifier(criterion='entropy', random_state=2116025914),
#   DecisionTreeClassifier(criterion='entropy', random_state=2067179335),
#   DecisionTreeClassifier(criterion='entropy', random_state=1026997481),
#   DecisionTreeClassifier(criterion='entropy', random_state=946140637),
#   DecisionTreeClassifier(criterion='entropy', random_state=209121918),
#   DecisionTreeClassifier(criterion='entropy', random_state=1903495440),
#   DecisionTreeClassifier(criterion='entropy', random_state=913740160),
#   DecisionTreeClassifier(criterion='entropy', random_state=678444918),
#   DecisionTreeClassifier(criterion='entropy', random_state=1803869568),
#   DecisionTreeClassifier(criterion='entropy', random_state=748953249),
#   DecisionTreeClassifier(criterion='entropy', random_state=1978705487),
#   DecisionTreeClassifier(criterion='entropy', random_state=286346222),
#   DecisionTreeClassifier(criterion='entropy', random_state=551799703),
#   DecisionTreeClassifier(criterion='entropy', random_state=1348841754),
#   DecisionTreeClassifier(criterion='entropy', random_state=2081967396),
#   DecisionTreeClassifier(criterion='entropy', random_state=263819058),
#   DecisionTreeClassifier(criterion='entropy', random_state=936103293),
#   DecisionTreeClassifier(criterion='entropy', random_state=762171313),
#   DecisionTreeClassifier(criterion='entropy', random_state=291089070),
#   DecisionTreeClassifier(criterion='entropy', random_state=1848443270),
#   DecisionTreeClassifier(criterion='entropy', random_state=1305600842),
#   DecisionTreeClassifier(criterion='entropy', random_state=1736304711),
#   DecisionTreeClassifier(criterion='entropy', random_state=472071774),
#   DecisionTreeClassifier(criterion='entropy', random_state=635832769),
#   DecisionTreeClassifier(criterion='entropy', random_state=83969337),
#   DecisionTreeClassifier(criterion='entropy', random_state=1197800443),
#   DecisionTreeClassifier(criterion='entropy', random_state=362169270),
#   DecisionTreeClassifier(criterion='entropy', random_state=1857288071),
#   DecisionTreeClassifier(criterion='entropy', random_state=1894668381),
#   DecisionTreeClassifier(criterion='entropy', random_state=185271873),
#   DecisionTreeClassifier(criterion='entropy', random_state=1200940764),
#   DecisionTreeClassifier(criterion='entropy', random_state=4953338),
#   DecisionTreeClassifier(criterion='entropy', random_state=246515479),
#   DecisionTreeClassifier(criterion='entropy', random_state=828097550),
#   DecisionTreeClassifier(criterion='entropy', random_state=269332493),
#   DecisionTreeClassifier(criterion='entropy', random_state=52888285),
#   DecisionTreeClassifier(criterion='entropy', random_state=105098237),
#   DecisionTreeClassifier(criterion='entropy', random_state=716411580),
#   DecisionTreeClassifier(criterion='entropy', random_state=294593719),
#   DecisionTreeClassifier(criterion='entropy', random_state=143215104),
#   DecisionTreeClassifier(criterion='entropy', random_state=915108157),
#   DecisionTreeClassifier(criterion='entropy', random_state=677998211),
#   DecisionTreeClassifier(criterion='entropy', random_state=1808977015),
#   DecisionTreeClassifier(criterion='entropy', random_state=517284358),
#   DecisionTreeClassifier(criterion='entropy', random_state=816844568),
#   DecisionTreeClassifier(criterion='entropy', random_state=995849820),
#   DecisionTreeClassifier(criterion='entropy', random_state=1735595232),
#   DecisionTreeClassifier(criterion='entropy', random_state=2137806952),
#   DecisionTreeClassifier(criterion='entropy', random_state=1461615975),
#   DecisionTreeClassifier(criterion='entropy', random_state=1800213922),
#   DecisionTreeClassifier(criterion='entropy', random_state=1484598782),
#   DecisionTreeClassifier(criterion='entropy', random_state=2106071116),
#   DecisionTreeClassifier(criterion='entropy', random_state=1731470191),
#   DecisionTreeClassifier(criterion='entropy', random_state=1699990560),
#   DecisionTreeClassifier(criterion='entropy', random_state=1294673207),
#   DecisionTreeClassifier(criterion='entropy', random_state=1155317089),
#   DecisionTreeClassifier(criterion='entropy', random_state=1914064139),
#   DecisionTreeClassifier(criterion='entropy', random_state=878829128),
#   DecisionTreeClassifier(criterion='entropy', random_state=1083415664),
#   DecisionTreeClassifier(criterion='entropy', random_state=1507771677),
#   DecisionTreeClassifier(criterion='entropy', random_state=1999650754),
#   DecisionTreeClassifier(criterion='entropy', random_state=1309891071),
#   DecisionTreeClassifier(criterion='entropy', random_state=274598418),
#   DecisionTreeClassifier(criterion='entropy', random_state=2023765839),
#   DecisionTreeClassifier(criterion='entropy', random_state=269862940),
#   DecisionTreeClassifier(criterion='entropy', random_state=398323331),
#   DecisionTreeClassifier(criterion='entropy', random_state=1682236033),
#   DecisionTreeClassifier(criterion='entropy', random_state=124053190),
#   DecisionTreeClassifier(criterion='entropy', random_state=861478316),
#   DecisionTreeClassifier(criterion='entropy', random_state=161652832),
#   DecisionTreeClassifier(criterion='entropy', random_state=1929897223),
#   DecisionTreeClassifier(criterion='entropy', random_state=1611897060),
#   DecisionTreeClassifier(criterion='entropy', random_state=889267393),
#   DecisionTreeClassifier(criterion='entropy', random_state=1347844217),
#   DecisionTreeClassifier(criterion='entropy', random_state=113863705),
#   DecisionTreeClassifier(criterion='entropy', random_state=1653931788),
#   DecisionTreeClassifier(criterion='entropy', random_state=184573833),
#   DecisionTreeClassifier(criterion='entropy', random_state=1128590140),
#   DecisionTreeClassifier(criterion='entropy', random_state=261065700),
#   DecisionTreeClassifier(criterion='entropy', random_state=766691910),
#   DecisionTreeClassifier(criterion='entropy', random_state=614825958),
#   DecisionTreeClassifier(criterion='entropy', random_state=568165261),
#   DecisionTreeClassifier(criterion='entropy', random_state=1901259143),
#   DecisionTreeClassifier(criterion='entropy', random_state=1586947965),
#   DecisionTreeClassifier(criterion='entropy', random_state=603594997),
#   DecisionTreeClassifier(criterion='entropy', random_state=1523753082),
#   DecisionTreeClassifier(criterion='entropy', random_state=543816155),
#   DecisionTreeClassifier(criterion='entropy', random_state=1754960229),
#   DecisionTreeClassifier(criterion='entropy', random_state=1346680942),
#   DecisionTreeClassifier(criterion='entropy', random_state=1861788021),
#   DecisionTreeClassifier(criterion='entropy', random_state=1955559647),
#   DecisionTreeClassifier(criterion='entropy', random_state=815806990),
#   DecisionTreeClassifier(criterion='entropy', random_state=2015653913),
#   DecisionTreeClassifier(criterion='entropy', random_state=1949862863),
#   DecisionTreeClassifier(criterion='entropy', random_state=1902750716),
#   DecisionTreeClassifier(criterion='entropy', random_state=1443492531),
#   DecisionTreeClassifier(criterion='entropy', random_state=2101475154),
#   DecisionTreeClassifier(criterion='entropy', random_state=879304817),
#   DecisionTreeClassifier(criterion='entropy', random_state=70880949),
#   DecisionTreeClassifier(criterion='entropy', random_state=219129258),
#   DecisionTreeClassifier(criterion='entropy', random_state=2023766825),
#   DecisionTreeClassifier(criterion='entropy', random_state=655265310),
#   DecisionTreeClassifier(criterion='entropy', random_state=208308281),
#   DecisionTreeClassifier(criterion='entropy', random_state=392442656),
#   DecisionTreeClassifier(criterion='entropy', random_state=1114993800),
#   DecisionTreeClassifier(criterion='entropy', random_state=109501679),
#   DecisionTreeClassifier(criterion='entropy', random_state=1981200724),
#   DecisionTreeClassifier(criterion='entropy', random_state=1270622612),
#   DecisionTreeClassifier(criterion='entropy', random_state=90746312),
#   DecisionTreeClassifier(criterion='entropy', random_state=38216466),
#   DecisionTreeClassifier(criterion='entropy', random_state=913719797),
#   DecisionTreeClassifier(criterion='entropy', random_state=1066614569),
#   DecisionTreeClassifier(criterion='entropy', random_state=470080200),
#   DecisionTreeClassifier(criterion='entropy', random_state=1840780901),
#   DecisionTreeClassifier(criterion='entropy', random_state=858316516),
#   DecisionTreeClassifier(criterion='entropy', random_state=535438428),
#   DecisionTreeClassifier(criterion='entropy', random_state=1267162264),
#   DecisionTreeClassifier(criterion='entropy', random_state=345147585),
#   DecisionTreeClassifier(criterion='entropy', random_state=827334096),
#   DecisionTreeClassifier(criterion='entropy', random_state=576201196),
#   DecisionTreeClassifier(criterion='entropy', random_state=740858181),
#   DecisionTreeClassifier(criterion='entropy', random_state=1494351290),
#   DecisionTreeClassifier(criterion='entropy', random_state=1687306725),
#   DecisionTreeClassifier(criterion='entropy', random_state=50878814),
#   DecisionTreeClassifier(criterion='entropy', random_state=334766184),
#   DecisionTreeClassifier(criterion='entropy', random_state=1301460393),
#   DecisionTreeClassifier(criterion='entropy', random_state=1863182847),
#   DecisionTreeClassifier(criterion='entropy', random_state=531006791),
#   DecisionTreeClassifier(criterion='entropy', random_state=413813919),
#   DecisionTreeClassifier(criterion='entropy', random_state=317305436),
#   DecisionTreeClassifier(criterion='entropy', random_state=923795052),
#   DecisionTreeClassifier(criterion='entropy', random_state=968197732),
#   DecisionTreeClassifier(criterion='entropy', random_state=434930061),
#   DecisionTreeClassifier(criterion='entropy', random_state=1918406614),
#   DecisionTreeClassifier(criterion='entropy', random_state=371992174),
#   DecisionTreeClassifier(criterion='entropy', random_state=674741512),
#   DecisionTreeClassifier(criterion='entropy', random_state=1355519503),
#   DecisionTreeClassifier(criterion='entropy', random_state=707426692),
#   DecisionTreeClassifier(criterion='entropy', random_state=220694864),
#   DecisionTreeClassifier(criterion='entropy', random_state=548161987),
#   DecisionTreeClassifier(criterion='entropy', random_state=809246231),
#   DecisionTreeClassifier(criterion='entropy', random_state=1434100789),
#   DecisionTreeClassifier(criterion='entropy', random_state=1794897565),
#   DecisionTreeClassifier(criterion='entropy', random_state=426334402),
#   DecisionTreeClassifier(criterion='entropy', random_state=269064936),
#   DecisionTreeClassifier(criterion='entropy', random_state=1484845299),
#   DecisionTreeClassifier(criterion='entropy', random_state=2145134152),
#   DecisionTreeClassifier(criterion='entropy', random_state=527545238),
#   DecisionTreeClassifier(criterion='entropy', random_state=94982),
#   DecisionTreeClassifier(criterion='entropy', random_state=454589080),
#   DecisionTreeClassifier(criterion='entropy', random_state=1902262031),
#   DecisionTreeClassifier(criterion='entropy', random_state=74017514)],
#  'n_classes': 2,
#  'fit_time': 34545}

# %%
# Réalisation des prédictions

y_pred = clf_rf_ts.predict(X_test)

# %% [markdown]
# ## 5. Évaluation

# %%
# Élaboration de la matrice de confusion

pd.crosstab(y_test, y_pred, rownames = ["Classe réelle"], colnames = ["Classe prédite"])
# Out:
# Classe prédite     0   1
# Classe réelle
# 0               1574   9
# 1                138  21

# %%
# Élaboration du rapport de classification

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96      1583
#            1       0.70      0.13      0.22       159
#
#     accuracy                           0.92      1742
#    macro avg       0.81      0.56      0.59      1742
# weighted avg       0.90      0.92      0.89      1742
