# %% [markdown]
# # **Classification** des **séries temporelles** avec `sktime`

# %% [markdown]
# ## Métadonnées

# %% [markdown]
# - **Expérience nº :** 6.2.2
# - **Date :** 11/11/2023
# - **Heure :** 12:24
# - **Données :** `ready_Evaporation_Sunshine_WindGustDir_WindGustSpeed_Pressure9am_Pressure3pm_WindGustDirNum.csv`
# - **Tri :** index chronologique
# - **Découpage :** `TimeSeriesSplit`
# - **Mise à l'échelle :** non
# - **Rééquilibrage :** non
# - **Conversion :** `numpyfy`
# - **Algorithme :** TSF

# %% [markdown]
# ## Sommaire

# %% [markdown]
# 1. Initialisation
# 2. Découpage
# 3. Conversion
# 4. Modélisation
# 5. Évaluation

# %% [markdown]
# ## 1. Initialisation

# %%
# Importation des bibliothèques et modules nécessaires au fonctionnement de ce notebook

import pandas as pd
import numpy as np

from sklearn.metrics import classification_report

# %%
# Importation du jeu de données et enregistrement dans le DataFrame `df`

df = pd.read_csv("../../../data/9df/Alex/ready_Evaporation_Sunshine_WindGustDir_WindGustSpeed_Pressure9am_Pressure3pm_WindGustDirNum.csv", index_col = 1).sort_index()
df = df.drop(columns = "Unnamed: 0")

# %%
# Inspection de la structure de `df`

df.head()
# Out:
#               MinTemp    MaxTemp  Rainfall  WindSpeed9am  WindSpeed3pm  \
# Date
# 2008-12-01  13.200000  24.083742       0.0      6.000000     19.000000
# 2008-12-02  13.738447  32.200000       0.0      5.986227     19.000000
# 2008-12-03  16.200000  32.200000       0.0      2.000000      2.000000
# 2008-12-04  19.200000  24.000000       0.0     22.000000     22.000000
# 2008-12-05  18.800000  30.200000       0.0      4.000000     10.614458
#
#             Humidity9am  Humidity3pm  Cloud9am  Cloud3pm    Temp9am  ...  \
# Date                                                                 ...
# 2008-12-01    50.000000    24.000000       3.0       4.0  21.800000  ...
# 2008-12-02    74.014791    59.000000       4.0       0.0  18.101224  ...
# 2008-12-03    74.000000    26.000000       4.0       4.0  22.200000  ...
# 2008-12-04    66.000000    61.000000       7.0       5.0  20.400000  ...
# 2008-12-05    85.000000    57.328215       8.0       4.0  20.000000  ...
#
#             year  month  day  LocationNum  WindDir9amNum  WindDir3pmNum  \
# Date
# 2008-12-01  2008     12    1            5       2.356194       2.356194
# 2008-12-02  2008     12    2            5       3.068698       0.785398
# 2008-12-03  2008     12    3            5       1.570796       5.497787
# 2008-12-04  2008     12    4            5       5.497787       5.497787
# 2008-12-05  2008     12    5            5       0.785398       4.021947
#
#              Latitude   Longitude  CodeRegionNum  NonMesNum
# Date
# 2008-12-01 -32.919295  151.779535              0          3
# 2008-12-02 -32.919295  151.779535              0          3
# 2008-12-03 -32.919295  151.779535              0          3
# 2008-12-04 -32.919295  151.779535              0          3
# 2008-12-05 -32.919295  151.779535              0          3
#
# [5 rows x 23 columns]

# %%
# Inspection de la structure de `df`

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2929 entries, 2008-12-01 to 2017-06-24
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        2929 non-null   float64
#  1   MaxTemp        2929 non-null   float64
#  2   Rainfall       2929 non-null   float64
#  3   WindSpeed9am   2929 non-null   float64
#  4   WindSpeed3pm   2929 non-null   float64
#  5   Humidity9am    2929 non-null   float64
#  6   Humidity3pm    2929 non-null   float64
#  7   Cloud9am       2929 non-null   float64
#  8   Cloud3pm       2929 non-null   float64
#  9   Temp9am        2929 non-null   float64
#  10  Temp3pm        2929 non-null   float64
#  11  RainToday      2929 non-null   int64
#  12  RainTomorrow   2929 non-null   int64
#  13  year           2929 non-null   int64
#  14  month          2929 non-null   int64
#  15  day            2929 non-null   int64
#  16  LocationNum    2929 non-null   int64
#  17  WindDir9amNum  2929 non-null   float64
#  18  WindDir3pmNum  2929 non-null   float64
#  19  Latitude       2929 non-null   float64
#  20  Longitude      2929 non-null   float64
#  21  CodeRegionNum  2929 non-null   int64
#  22  NonMesNum      2929 non-null   int64
# dtypes: float64(15), int64(8)
# memory usage: 549.2+ KB

# %% [markdown]
# ## 2. Découpage

# %%
# Découpage de `df` sur l'axe des colonnes : séparation des variables explicatives (`data`) et cible (`target`)

data = df.drop(columns = "RainTomorrow")
target = df["RainTomorrow"]

# %%
# Découpage de `data` et de `target` sur l'axe des lignes : séparation des jeux d'entraînement (`*_train`) et de test (`*_test`) avec le splitter `TimeSeriesSplit`

from sklearn.model_selection import TimeSeriesSplit

tss = TimeSeriesSplit(n_splits = 5) ## Nous fixons le paramètre `n_splits` à 5 afin d'avoir une répartition de 80 / 20 entre les jeux d'entraînement et de test, respectivement.

for train_index, test_index in tss.split(data):
    X_train, X_test = data.iloc[train_index, :], data.iloc[test_index,:]
    y_train, y_test = target.iloc[train_index], target.iloc[test_index]

# %% [markdown]
# ## 3. Conversion

# %%
# Importation de la fonction artisanale `numpyfy`

from numpyfy import numpyfy

# %%
# Application de la fonction `numpyfy` aux 4 jeux de données issus du découpage effectué par le splitter `TimeSeriesSplit` afin de les convertir en arrays et ainsi les rendre compatibles avec `sktime`

X_train, X_test, y_train, y_test = numpyfy(X_train, X_test, y_train, y_test)

# %% [markdown]
# ## 4. Modélisation

# %%
# Instanciation d'un modèle classificateur via un Pipeline

from sklearn.pipeline import Pipeline
from sktime.transformations.panel.compose import ColumnConcatenator
from sktime.classification.interval_based import TimeSeriesForestClassifier

steps = [
    ("concatenate", ColumnConcatenator()), ## Cette étape permet de transformer les jeux de données multivariées en univariées afin qu'ils puissent être traités par `TimeSeriesForestClassifier`.
    ("classify", TimeSeriesForestClassifier()),
]

clf_rf_ts = Pipeline(steps)

# %%
# Récupération des paramètres initiaux de la TSF

clf_rf_ts["classify"].get_params()
# Out:
# {'min_interval': 3, 'n_estimators': 200, 'n_jobs': 1, 'random_state': None}

# %%
# Entraînement du modèle

clf_rf_ts.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('concatenate', ColumnConcatenator()),
#                 ('classify', TimeSeriesForestClassifier())])

# %%
# Récupération des paramètres ajustés de la TSF

clf_rf_ts["classify"].get_fitted_params()
# Out:
# {'classes': array([0, 1]),
#  'intervals': [array([[ 3,  7],
#          [14, 17],
#          [ 2, 13],
#          [12, 19]]),
#   array([[ 3, 19],
#          [ 0,  7],
#          [16, 19],
#          [17, 20]]),
#   array([[ 3,  8],
#          [10, 19],
#          [ 0, 10],
#          [12, 18]]),
#   array([[ 5,  8],
#          [ 7, 15],
#          [12, 20],
#          [11, 16]]),
#   array([[ 7, 20],
#          [14, 17],
#          [ 5,  8],
#          [ 1,  9]]),
#   array([[17, 20],
#          [14, 19],
#          [ 5, 13],
#          [ 4,  7]]),
#   array([[ 3, 20],
#          [ 2, 17],
#          [14, 17],
#          [14, 17]]),
#   array([[ 5, 18],
#          [ 6, 17],
#          [16, 20],
#          [10, 13]]),
#   array([[15, 18],
#          [ 4, 19],
#          [ 1,  4],
#          [ 4, 13]]),
#   array([[ 4, 10],
#          [ 9, 16],
#          [16, 19],
#          [17, 20]]),
#   array([[14, 19],
#          [10, 20],
#          [17, 20],
#          [13, 19]]),
#   array([[ 7, 13],
#          [15, 19],
#          [ 6, 14],
#          [ 0, 12]]),
#   array([[17, 20],
#          [17, 20],
#          [ 7, 12],
#          [17, 20]]),
#   array([[16, 19],
#          [ 4, 19],
#          [ 3, 14],
#          [ 7, 10]]),
#   array([[ 3, 12],
#          [10, 13],
#          [14, 19],
#          [13, 17]]),
#   array([[17, 20],
#          [16, 19],
#          [ 2,  5],
#          [ 6, 20]]),
#   array([[ 7, 10],
#          [18, 21],
#          [12, 19],
#          [17, 20]]),
#   array([[ 1, 13],
#          [ 0,  3],
#          [18, 21],
#          [ 1, 10]]),
#   array([[16, 19],
#          [18, 21],
#          [10, 16],
#          [10, 13]]),
#   array([[ 5, 18],
#          [ 3,  8],
#          [ 1,  4],
#          [ 8, 12]]),
#   array([[15, 18],
#          [ 8, 14],
#          [ 6, 10],
#          [14, 20]]),
#   array([[ 6, 17],
#          [ 1,  4],
#          [14, 19],
#          [16, 19]]),
#   array([[17, 20],
#          [ 7, 13],
#          [ 9, 16],
#          [ 2,  8]]),
#   array([[17, 20],
#          [17, 20],
#          [ 4, 17],
#          [ 8, 11]]),
#   array([[13, 16],
#          [ 2, 14],
#          [ 4, 10],
#          [11, 16]]),
#   array([[ 9, 16],
#          [ 6, 18],
#          [14, 20],
#          [ 4,  7]]),
#   array([[ 4, 18],
#          [ 2, 16],
#          [11, 14],
#          [12, 20]]),
#   array([[ 3, 16],
#          [16, 20],
#          [ 5, 12],
#          [12, 19]]),
#   array([[16, 19],
#          [ 5, 10],
#          [ 4,  7],
#          [ 1,  8]]),
#   array([[10, 13],
#          [14, 17],
#          [16, 20],
#          [10, 14]]),
#   array([[ 0,  7],
#          [12, 20],
#          [12, 18],
#          [11, 16]]),
#   array([[ 9, 14],
#          [ 9, 13],
#          [ 1,  4],
#          [10, 13]]),
#   array([[13, 16],
#          [18, 21],
#          [ 6, 11],
#          [10, 19]]),
#   array([[11, 20],
#          [ 1, 12],
#          [18, 21],
#          [ 2,  7]]),
#   array([[10, 16],
#          [10, 13],
#          [ 4, 18],
#          [ 7, 13]]),
#   array([[ 3, 16],
#          [10, 13],
#          [11, 19],
#          [18, 21]]),
#   array([[ 9, 12],
#          [ 2, 17],
#          [ 8, 17],
#          [12, 15]]),
#   array([[10, 13],
#          [ 1, 15],
#          [ 8, 18],
#          [17, 20]]),
#   array([[10, 13],
#          [18, 21],
#          [ 4, 20],
#          [ 2, 20]]),
#   array([[12, 20],
#          [10, 13],
#          [11, 15],
#          [14, 17]]),
#   array([[12, 16],
#          [10, 19],
#          [ 6,  9],
#          [ 9, 18]]),
#   array([[ 1,  7],
#          [ 8, 13],
#          [15, 18],
#          [ 2,  5]]),
#   array([[ 8, 19],
#          [12, 17],
#          [ 4, 14],
#          [ 2,  5]]),
#   array([[ 1,  4],
#          [ 5, 18],
#          [16, 19],
#          [ 3, 19]]),
#   array([[12, 15],
#          [ 9, 14],
#          [17, 20],
#          [15, 20]]),
#   array([[10, 13],
#          [ 8, 15],
#          [12, 16],
#          [12, 15]]),
#   array([[ 7, 15],
#          [ 4,  8],
#          [11, 17],
#          [ 0, 11]]),
#   array([[ 1, 17],
#          [10, 17],
#          [ 3,  6],
#          [ 7, 14]]),
#   array([[12, 16],
#          [ 6,  9],
#          [ 3, 11],
#          [13, 16]]),
#   array([[12, 15],
#          [ 3,  6],
#          [15, 20],
#          [12, 15]]),
#   array([[11, 14],
#          [ 7, 20],
#          [ 4,  7],
#          [ 8, 17]]),
#   array([[10, 14],
#          [ 8, 17],
#          [ 4, 11],
#          [14, 17]]),
#   array([[10, 13],
#          [10, 20],
#          [ 4,  9],
#          [ 2, 14]]),
#   array([[18, 21],
#          [ 6, 18],
#          [ 1, 12],
#          [ 8, 17]]),
#   array([[11, 15],
#          [ 2,  5],
#          [14, 17],
#          [ 6,  9]]),
#   array([[ 9, 17],
#          [ 5, 13],
#          [16, 19],
#          [ 2, 11]]),
#   array([[ 3, 12],
#          [ 8, 11],
#          [ 0,  3],
#          [12, 20]]),
#   array([[15, 18],
#          [18, 21],
#          [ 3,  8],
#          [ 5, 10]]),
#   array([[ 8, 20],
#          [18, 21],
#          [ 8, 16],
#          [11, 14]]),
#   array([[ 4, 11],
#          [ 9, 20],
#          [ 3,  6],
#          [14, 17]]),
#   array([[ 5, 17],
#          [12, 16],
#          [13, 17],
#          [ 7, 11]]),
#   array([[10, 13],
#          [ 4,  9],
#          [ 5,  8],
#          [ 9, 20]]),
#   array([[ 1, 13],
#          [11, 14],
#          [14, 17],
#          [16, 19]]),
#   array([[ 7, 16],
#          [17, 20],
#          [14, 17],
#          [ 5, 11]]),
#   array([[15, 18],
#          [ 3,  6],
#          [ 6, 11],
#          [12, 17]]),
#   array([[ 5, 15],
#          [18, 21],
#          [13, 16],
#          [14, 17]]),
#   array([[ 0, 11],
#          [16, 19],
#          [ 7, 15],
#          [ 9, 12]]),
#   array([[ 0,  3],
#          [ 1, 18],
#          [ 5, 17],
#          [15, 19]]),
#   array([[ 5, 10],
#          [ 0, 20],
#          [ 5, 16],
#          [13, 17]]),
#   array([[16, 19],
#          [ 9, 12],
#          [ 7, 10],
#          [17, 20]]),
#   array([[ 3,  6],
#          [ 8, 11],
#          [13, 18],
#          [ 2,  5]]),
#   array([[12, 16],
#          [ 3, 12],
#          [ 4, 14],
#          [12, 15]]),
#   array([[ 4, 20],
#          [ 0,  8],
#          [ 3,  8],
#          [ 2, 13]]),
#   array([[ 6, 17],
#          [ 7, 11],
#          [12, 18],
#          [ 2,  5]]),
#   array([[18, 21],
#          [12, 19],
#          [16, 20],
#          [14, 17]]),
#   array([[ 0, 11],
#          [ 7, 10],
#          [14, 20],
#          [17, 20]]),
#   array([[ 8, 11],
#          [ 4, 19],
#          [ 9, 12],
#          [10, 13]]),
#   array([[ 1,  9],
#          [ 9, 12],
#          [ 3, 10],
#          [ 3,  6]]),
#   array([[ 3,  6],
#          [18, 21],
#          [16, 19],
#          [ 8, 17]]),
#   array([[ 5, 20],
#          [14, 20],
#          [16, 19],
#          [17, 20]]),
#   array([[11, 18],
#          [ 9, 16],
#          [ 5, 12],
#          [17, 20]]),
#   array([[12, 15],
#          [13, 16],
#          [ 3, 19],
#          [16, 19]]),
#   array([[16, 19],
#          [17, 20],
#          [15, 18],
#          [ 6, 10]]),
#   array([[12, 17],
#          [12, 17],
#          [ 2,  5],
#          [ 8, 11]]),
#   array([[12, 19],
#          [17, 20],
#          [ 8, 19],
#          [10, 14]]),
#   array([[ 2, 16],
#          [ 6, 11],
#          [10, 19],
#          [12, 18]]),
#   array([[10, 13],
#          [ 8, 11],
#          [10, 13],
#          [16, 20]]),
#   array([[ 4, 14],
#          [ 5, 17],
#          [ 8, 11],
#          [11, 15]]),
#   array([[ 1, 13],
#          [ 9, 20],
#          [ 5,  8],
#          [10, 18]]),
#   array([[14, 17],
#          [ 0,  3],
#          [ 7, 10],
#          [11, 14]]),
#   array([[ 1, 18],
#          [17, 20],
#          [12, 19],
#          [ 2, 13]]),
#   array([[ 0,  7],
#          [ 5,  8],
#          [ 9, 13],
#          [13, 16]]),
#   array([[ 1,  7],
#          [ 7, 13],
#          [11, 19],
#          [16, 19]]),
#   array([[ 4, 11],
#          [14, 17],
#          [17, 20],
#          [13, 16]]),
#   array([[12, 17],
#          [ 4, 14],
#          [18, 21],
#          [ 5, 11]]),
#   array([[ 7, 20],
#          [16, 20],
#          [16, 19],
#          [ 9, 12]]),
#   array([[ 3,  6],
#          [ 6, 11],
#          [ 4,  9],
#          [14, 18]]),
#   array([[16, 19],
#          [ 0,  3],
#          [ 7, 14],
#          [13, 16]]),
#   array([[ 6, 15],
#          [13, 16],
#          [ 7, 12],
#          [15, 18]]),
#   array([[ 4,  7],
#          [13, 16],
#          [ 0, 12],
#          [ 8, 11]]),
#   array([[17, 20],
#          [ 0, 15],
#          [ 7, 18],
#          [13, 16]]),
#   array([[ 4,  7],
#          [15, 20],
#          [ 5, 16],
#          [ 4,  7]]),
#   array([[ 1, 12],
#          [ 4, 20],
#          [10, 13],
#          [ 1,  6]]),
#   array([[ 2,  5],
#          [17, 20],
#          [ 6, 15],
#          [14, 17]]),
#   array([[ 4, 15],
#          [14, 17],
#          [ 1,  4],
#          [18, 21]]),
#   array([[ 0, 13],
#          [12, 16],
#          [14, 19],
#          [ 9, 14]]),
#   array([[17, 20],
#          [16, 19],
#          [ 0, 16],
#          [ 0,  3]]),
#   array([[ 1,  4],
#          [ 8, 11],
#          [12, 15],
#          [ 1, 18]]),
#   array([[ 6, 15],
#          [ 7, 11],
#          [17, 20],
#          [15, 18]]),
#   array([[ 0, 16],
#          [ 8, 12],
#          [16, 20],
#          [12, 18]]),
#   array([[18, 21],
#          [ 2,  5],
#          [ 9, 17],
#          [11, 20]]),
#   array([[ 2,  6],
#          [15, 20],
#          [12, 17],
#          [16, 19]]),
#   array([[10, 17],
#          [18, 21],
#          [ 5, 14],
#          [10, 20]]),
#   array([[10, 13],
#          [10, 13],
#          [17, 20],
#          [16, 20]]),
#   array([[10, 13],
#          [ 0, 12],
#          [ 0, 20],
#          [ 6, 16]]),
#   array([[18, 21],
#          [ 2, 12],
#          [18, 21],
#          [ 3,  8]]),
#   array([[18, 21],
#          [ 4, 11],
#          [15, 20],
#          [18, 21]]),
#   array([[ 8, 12],
#          [14, 20],
#          [ 9, 12],
#          [10, 13]]),
#   array([[ 2,  5],
#          [16, 19],
#          [10, 13],
#          [ 5, 14]]),
#   array([[17, 20],
#          [ 4, 16],
#          [13, 19],
#          [ 9, 12]]),
#   array([[15, 18],
#          [15, 18],
#          [16, 19],
#          [ 7, 13]]),
#   array([[ 3,  7],
#          [ 3,  7],
#          [11, 14],
#          [ 0, 16]]),
#   array([[11, 14],
#          [10, 15],
#          [14, 19],
#          [ 1,  7]]),
#   array([[ 9, 15],
#          [13, 20],
#          [11, 14],
#          [ 5, 14]]),
#   array([[15, 18],
#          [ 8, 11],
#          [ 4, 15],
#          [ 4, 15]]),
#   array([[ 6,  9],
#          [ 9, 20],
#          [10, 18],
#          [ 5,  8]]),
#   array([[ 8, 20],
#          [18, 21],
#          [ 2, 13],
#          [ 6, 16]]),
#   array([[ 8, 14],
#          [ 0,  3],
#          [ 2,  6],
#          [18, 21]]),
#   array([[ 5, 20],
#          [ 4, 17],
#          [17, 20],
#          [11, 16]]),
#   array([[ 1, 15],
#          [ 0,  6],
#          [ 4, 11],
#          [ 1,  4]]),
#   array([[ 9, 12],
#          [ 1, 10],
#          [ 7, 15],
#          [ 6, 15]]),
#   array([[ 2, 10],
#          [ 2, 11],
#          [ 7, 14],
#          [11, 14]]),
#   array([[ 3, 18],
#          [17, 20],
#          [ 2, 18],
#          [ 3, 20]]),
#   array([[18, 21],
#          [ 7, 17],
#          [14, 20],
#          [ 3,  7]]),
#   array([[10, 14],
#          [10, 14],
#          [ 2,  9],
#          [ 5, 15]]),
#   array([[ 0, 13],
#          [ 9, 12],
#          [12, 17],
#          [12, 20]]),
#   array([[ 4, 11],
#          [10, 20],
#          [12, 15],
#          [10, 13]]),
#   array([[ 4, 10],
#          [ 6, 15],
#          [ 3,  6],
#          [ 3,  6]]),
#   array([[ 9, 12],
#          [ 7, 16],
#          [13, 16],
#          [14, 19]]),
#   array([[ 5, 17],
#          [11, 18],
#          [15, 20],
#          [ 3, 14]]),
#   array([[ 1, 12],
#          [15, 18],
#          [ 2,  8],
#          [ 4, 15]]),
#   array([[ 1, 15],
#          [12, 20],
#          [ 0, 10],
#          [ 4, 16]]),
#   array([[ 7, 10],
#          [ 6,  9],
#          [ 3,  6],
#          [17, 20]]),
#   array([[18, 21],
#          [18, 21],
#          [ 6, 10],
#          [10, 16]]),
#   array([[ 7, 10],
#          [16, 20],
#          [11, 20],
#          [ 5,  8]]),
#   array([[10, 13],
#          [ 1, 15],
#          [ 0,  7],
#          [ 4, 14]]),
#   array([[ 4, 11],
#          [11, 20],
#          [ 2,  5],
#          [15, 18]]),
#   array([[ 9, 17],
#          [ 5, 10],
#          [ 6, 15],
#          [ 0, 17]]),
#   array([[ 1,  7],
#          [ 5,  8],
#          [15, 18],
#          [ 6, 16]]),
#   array([[17, 20],
#          [ 0, 11],
#          [ 2,  5],
#          [15, 19]]),
#   array([[ 0,  3],
#          [11, 14],
#          [10, 13],
#          [14, 17]]),
#   array([[10, 17],
#          [16, 20],
#          [ 8, 11],
#          [ 9, 16]]),
#   array([[15, 20],
#          [ 6,  9],
#          [ 1, 19],
#          [ 3, 19]]),
#   array([[ 9, 20],
#          [14, 19],
#          [ 3, 16],
#          [18, 21]]),
#   array([[ 8, 12],
#          [ 6, 10],
#          [16, 19],
#          [ 6, 18]]),
#   array([[ 0, 14],
#          [12, 16],
#          [13, 20],
#          [ 7, 12]]),
#   array([[ 0,  8],
#          [16, 19],
#          [17, 20],
#          [18, 21]]),
#   array([[15, 18],
#          [ 9, 18],
#          [12, 15],
#          [13, 16]]),
#   array([[15, 19],
#          [15, 19],
#          [ 3, 19],
#          [ 3, 12]]),
#   array([[ 8, 19],
#          [14, 18],
#          [17, 20],
#          [ 3,  6]]),
#   array([[ 2, 15],
#          [ 6, 11],
#          [ 6, 16],
#          [ 9, 19]]),
#   array([[15, 20],
#          [ 4, 15],
#          [ 9, 19],
#          [17, 20]]),
#   array([[ 2, 15],
#          [ 9, 18],
#          [ 9, 20],
#          [14, 19]]),
#   array([[ 2,  5],
#          [ 1,  7],
#          [ 4, 16],
#          [11, 15]]),
#   array([[11, 14],
#          [15, 20],
#          [11, 20],
#          [ 8, 11]]),
#   array([[15, 20],
#          [ 1,  9],
#          [14, 17],
#          [16, 20]]),
#   array([[14, 17],
#          [ 5,  8],
#          [ 7, 10],
#          [ 9, 16]]),
#   array([[ 1,  6],
#          [ 0, 11],
#          [ 2,  8],
#          [15, 18]]),
#   array([[13, 16],
#          [ 8, 13],
#          [14, 17],
#          [18, 21]]),
#   array([[17, 20],
#          [13, 16],
#          [ 0,  3],
#          [ 9, 13]]),
#   array([[ 8, 11],
#          [11, 20],
#          [ 7, 11],
#          [ 0,  8]]),
#   array([[ 7, 19],
#          [ 6,  9],
#          [11, 16],
#          [ 8, 12]]),
#   array([[14, 17],
#          [17, 20],
#          [14, 17],
#          [ 3, 15]]),
#   array([[ 9, 12],
#          [ 6, 20],
#          [ 2, 16],
#          [14, 17]]),
#   array([[17, 20],
#          [18, 21],
#          [ 7, 11],
#          [15, 18]]),
#   array([[18, 21],
#          [12, 15],
#          [11, 14],
#          [ 4, 14]]),
#   array([[17, 20],
#          [16, 19],
#          [ 6, 17],
#          [15, 19]]),
#   array([[ 7, 12],
#          [13, 16],
#          [ 9, 15],
#          [ 0,  7]]),
#   array([[13, 16],
#          [ 4,  7],
#          [ 4,  9],
#          [14, 19]]),
#   array([[10, 13],
#          [ 1, 19],
#          [14, 18],
#          [18, 21]]),
#   array([[ 7, 19],
#          [ 6, 20],
#          [ 1, 20],
#          [18, 21]]),
#   array([[ 1, 11],
#          [14, 17],
#          [ 7, 16],
#          [ 9, 16]]),
#   array([[ 9, 12],
#          [10, 13],
#          [10, 15],
#          [ 8, 18]]),
#   array([[18, 21],
#          [14, 18],
#          [ 2,  5],
#          [ 1,  4]]),
#   array([[ 3, 17],
#          [11, 17],
#          [10, 19],
#          [ 7, 19]]),
#   array([[ 5, 17],
#          [14, 17],
#          [11, 17],
#          [17, 20]]),
#   array([[ 6, 15],
#          [ 4, 20],
#          [ 2, 11],
#          [12, 15]]),
#   array([[ 9, 12],
#          [ 6, 10],
#          [11, 20],
#          [ 0, 14]]),
#   array([[16, 19],
#          [ 2,  5],
#          [ 5, 20],
#          [ 6,  9]]),
#   array([[ 6, 19],
#          [ 5,  9],
#          [ 5, 10],
#          [14, 17]]),
#   array([[ 5,  8],
#          [12, 20],
#          [10, 19],
#          [ 9, 16]]),
#   array([[ 4,  8],
#          [ 7, 10],
#          [ 0,  8],
#          [ 4,  9]]),
#   array([[16, 19],
#          [ 4, 13],
#          [10, 18],
#          [16, 20]]),
#   array([[16, 19],
#          [16, 19],
#          [ 6, 10],
#          [10, 13]]),
#   array([[ 7, 13],
#          [ 5,  8],
#          [ 3, 16],
#          [13, 16]]),
#   array([[ 8, 11],
#          [ 9, 19],
#          [13, 16],
#          [13, 16]]),
#   array([[ 8, 11],
#          [ 6, 10],
#          [ 2, 19],
#          [ 5,  9]]),
#   array([[10, 20],
#          [18, 21],
#          [ 8, 11],
#          [ 0,  9]]),
#   array([[12, 18],
#          [ 8, 19],
#          [ 5, 20],
#          [ 4, 14]]),
#   array([[ 3,  8],
#          [ 5, 11],
#          [ 2,  7],
#          [10, 17]])],
#  'estimators': [DecisionTreeClassifier(criterion='entropy', random_state=1723212012),
#   DecisionTreeClassifier(criterion='entropy', random_state=504440862),
#   DecisionTreeClassifier(criterion='entropy', random_state=1690219740),
#   DecisionTreeClassifier(criterion='entropy', random_state=687653935),
#   DecisionTreeClassifier(criterion='entropy', random_state=730493955),
#   DecisionTreeClassifier(criterion='entropy', random_state=1355919516),
#   DecisionTreeClassifier(criterion='entropy', random_state=582193291),
#   DecisionTreeClassifier(criterion='entropy', random_state=709772881),
#   DecisionTreeClassifier(criterion='entropy', random_state=418513390),
#   DecisionTreeClassifier(criterion='entropy', random_state=876646088),
#   DecisionTreeClassifier(criterion='entropy', random_state=1220015122),
#   DecisionTreeClassifier(criterion='entropy', random_state=437042045),
#   DecisionTreeClassifier(criterion='entropy', random_state=267845871),
#   DecisionTreeClassifier(criterion='entropy', random_state=120413353),
#   DecisionTreeClassifier(criterion='entropy', random_state=1376058231),
#   DecisionTreeClassifier(criterion='entropy', random_state=2000587311),
#   DecisionTreeClassifier(criterion='entropy', random_state=909502208),
#   DecisionTreeClassifier(criterion='entropy', random_state=1334579511),
#   DecisionTreeClassifier(criterion='entropy', random_state=1083310651),
#   DecisionTreeClassifier(criterion='entropy', random_state=2101001540),
#   DecisionTreeClassifier(criterion='entropy', random_state=310223031),
#   DecisionTreeClassifier(criterion='entropy', random_state=470562068),
#   DecisionTreeClassifier(criterion='entropy', random_state=257648203),
#   DecisionTreeClassifier(criterion='entropy', random_state=877107344),
#   DecisionTreeClassifier(criterion='entropy', random_state=997589912),
#   DecisionTreeClassifier(criterion='entropy', random_state=686139518),
#   DecisionTreeClassifier(criterion='entropy', random_state=801357121),
#   DecisionTreeClassifier(criterion='entropy', random_state=931429959),
#   DecisionTreeClassifier(criterion='entropy', random_state=844177958),
#   DecisionTreeClassifier(criterion='entropy', random_state=804901890),
#   DecisionTreeClassifier(criterion='entropy', random_state=936913546),
#   DecisionTreeClassifier(criterion='entropy', random_state=487055919),
#   DecisionTreeClassifier(criterion='entropy', random_state=645937158),
#   DecisionTreeClassifier(criterion='entropy', random_state=1836821231),
#   DecisionTreeClassifier(criterion='entropy', random_state=970112064),
#   DecisionTreeClassifier(criterion='entropy', random_state=1706905073),
#   DecisionTreeClassifier(criterion='entropy', random_state=1322346748),
#   DecisionTreeClassifier(criterion='entropy', random_state=198929140),
#   DecisionTreeClassifier(criterion='entropy', random_state=1141604240),
#   DecisionTreeClassifier(criterion='entropy', random_state=1946155099),
#   DecisionTreeClassifier(criterion='entropy', random_state=1357944060),
#   DecisionTreeClassifier(criterion='entropy', random_state=1976025826),
#   DecisionTreeClassifier(criterion='entropy', random_state=1885741857),
#   DecisionTreeClassifier(criterion='entropy', random_state=335486802),
#   DecisionTreeClassifier(criterion='entropy', random_state=355407416),
#   DecisionTreeClassifier(criterion='entropy', random_state=1482578132),
#   DecisionTreeClassifier(criterion='entropy', random_state=792411589),
#   DecisionTreeClassifier(criterion='entropy', random_state=398402656),
#   DecisionTreeClassifier(criterion='entropy', random_state=1251299144),
#   DecisionTreeClassifier(criterion='entropy', random_state=646570600),
#   DecisionTreeClassifier(criterion='entropy', random_state=274518724),
#   DecisionTreeClassifier(criterion='entropy', random_state=1735698265),
#   DecisionTreeClassifier(criterion='entropy', random_state=1004426440),
#   DecisionTreeClassifier(criterion='entropy', random_state=470026896),
#   DecisionTreeClassifier(criterion='entropy', random_state=255777867),
#   DecisionTreeClassifier(criterion='entropy', random_state=1273281606),
#   DecisionTreeClassifier(criterion='entropy', random_state=1307216778),
#   DecisionTreeClassifier(criterion='entropy', random_state=143325741),
#   DecisionTreeClassifier(criterion='entropy', random_state=45725727),
#   DecisionTreeClassifier(criterion='entropy', random_state=1053386292),
#   DecisionTreeClassifier(criterion='entropy', random_state=1039107642),
#   DecisionTreeClassifier(criterion='entropy', random_state=496213114),
#   DecisionTreeClassifier(criterion='entropy', random_state=992001966),
#   DecisionTreeClassifier(criterion='entropy', random_state=1322552133),
#   DecisionTreeClassifier(criterion='entropy', random_state=1815371948),
#   DecisionTreeClassifier(criterion='entropy', random_state=284043390),
#   DecisionTreeClassifier(criterion='entropy', random_state=156981246),
#   DecisionTreeClassifier(criterion='entropy', random_state=262806205),
#   DecisionTreeClassifier(criterion='entropy', random_state=1008041555),
#   DecisionTreeClassifier(criterion='entropy', random_state=1165248083),
#   DecisionTreeClassifier(criterion='entropy', random_state=1800130904),
#   DecisionTreeClassifier(criterion='entropy', random_state=170331578),
#   DecisionTreeClassifier(criterion='entropy', random_state=1375478704),
#   DecisionTreeClassifier(criterion='entropy', random_state=301489462),
#   DecisionTreeClassifier(criterion='entropy', random_state=956110760),
#   DecisionTreeClassifier(criterion='entropy', random_state=1127872774),
#   DecisionTreeClassifier(criterion='entropy', random_state=643151475),
#   DecisionTreeClassifier(criterion='entropy', random_state=2017855586),
#   DecisionTreeClassifier(criterion='entropy', random_state=1300627422),
#   DecisionTreeClassifier(criterion='entropy', random_state=936214304),
#   DecisionTreeClassifier(criterion='entropy', random_state=591183560),
#   DecisionTreeClassifier(criterion='entropy', random_state=519736371),
#   DecisionTreeClassifier(criterion='entropy', random_state=520980059),
#   DecisionTreeClassifier(criterion='entropy', random_state=637523825),
#   DecisionTreeClassifier(criterion='entropy', random_state=729542811),
#   DecisionTreeClassifier(criterion='entropy', random_state=1311151680),
#   DecisionTreeClassifier(criterion='entropy', random_state=327234864),
#   DecisionTreeClassifier(criterion='entropy', random_state=1331433522),
#   DecisionTreeClassifier(criterion='entropy', random_state=1139999476),
#   DecisionTreeClassifier(criterion='entropy', random_state=1859295499),
#   DecisionTreeClassifier(criterion='entropy', random_state=338026200),
#   DecisionTreeClassifier(criterion='entropy', random_state=793389686),
#   DecisionTreeClassifier(criterion='entropy', random_state=1942040292),
#   DecisionTreeClassifier(criterion='entropy', random_state=1604429672),
#   DecisionTreeClassifier(criterion='entropy', random_state=1185542458),
#   DecisionTreeClassifier(criterion='entropy', random_state=60033007),
#   DecisionTreeClassifier(criterion='entropy', random_state=2016842893),
#   DecisionTreeClassifier(criterion='entropy', random_state=1888105085),
#   DecisionTreeClassifier(criterion='entropy', random_state=1555845155),
#   DecisionTreeClassifier(criterion='entropy', random_state=1769116785),
#   DecisionTreeClassifier(criterion='entropy', random_state=845896369),
#   DecisionTreeClassifier(criterion='entropy', random_state=1055012350),
#   DecisionTreeClassifier(criterion='entropy', random_state=1508722168),
#   DecisionTreeClassifier(criterion='entropy', random_state=888221732),
#   DecisionTreeClassifier(criterion='entropy', random_state=196221366),
#   DecisionTreeClassifier(criterion='entropy', random_state=257820049),
#   DecisionTreeClassifier(criterion='entropy', random_state=846830535),
#   DecisionTreeClassifier(criterion='entropy', random_state=1195327286),
#   DecisionTreeClassifier(criterion='entropy', random_state=1636144947),
#   DecisionTreeClassifier(criterion='entropy', random_state=720967389),
#   DecisionTreeClassifier(criterion='entropy', random_state=681084032),
#   DecisionTreeClassifier(criterion='entropy', random_state=1301358717),
#   DecisionTreeClassifier(criterion='entropy', random_state=248026350),
#   DecisionTreeClassifier(criterion='entropy', random_state=405183791),
#   DecisionTreeClassifier(criterion='entropy', random_state=993637841),
#   DecisionTreeClassifier(criterion='entropy', random_state=870737192),
#   DecisionTreeClassifier(criterion='entropy', random_state=1849127836),
#   DecisionTreeClassifier(criterion='entropy', random_state=288411128),
#   DecisionTreeClassifier(criterion='entropy', random_state=1412277884),
#   DecisionTreeClassifier(criterion='entropy', random_state=1916642527),
#   DecisionTreeClassifier(criterion='entropy', random_state=488082544),
#   DecisionTreeClassifier(criterion='entropy', random_state=1460601257),
#   DecisionTreeClassifier(criterion='entropy', random_state=1063908817),
#   DecisionTreeClassifier(criterion='entropy', random_state=1471226448),
#   DecisionTreeClassifier(criterion='entropy', random_state=1120308308),
#   DecisionTreeClassifier(criterion='entropy', random_state=1406976185),
#   DecisionTreeClassifier(criterion='entropy', random_state=838609186),
#   DecisionTreeClassifier(criterion='entropy', random_state=1457208142),
#   DecisionTreeClassifier(criterion='entropy', random_state=2046831042),
#   DecisionTreeClassifier(criterion='entropy', random_state=697669182),
#   DecisionTreeClassifier(criterion='entropy', random_state=993859282),
#   DecisionTreeClassifier(criterion='entropy', random_state=1578178494),
#   DecisionTreeClassifier(criterion='entropy', random_state=680660736),
#   DecisionTreeClassifier(criterion='entropy', random_state=1082184628),
#   DecisionTreeClassifier(criterion='entropy', random_state=766143619),
#   DecisionTreeClassifier(criterion='entropy', random_state=199446303),
#   DecisionTreeClassifier(criterion='entropy', random_state=469636411),
#   DecisionTreeClassifier(criterion='entropy', random_state=1228256094),
#   DecisionTreeClassifier(criterion='entropy', random_state=2124843021),
#   DecisionTreeClassifier(criterion='entropy', random_state=240693181),
#   DecisionTreeClassifier(criterion='entropy', random_state=1078061111),
#   DecisionTreeClassifier(criterion='entropy', random_state=151171551),
#   DecisionTreeClassifier(criterion='entropy', random_state=1582991130),
#   DecisionTreeClassifier(criterion='entropy', random_state=370254729),
#   DecisionTreeClassifier(criterion='entropy', random_state=416270207),
#   DecisionTreeClassifier(criterion='entropy', random_state=1249106553),
#   DecisionTreeClassifier(criterion='entropy', random_state=832632410),
#   DecisionTreeClassifier(criterion='entropy', random_state=1966796680),
#   DecisionTreeClassifier(criterion='entropy', random_state=2118878701),
#   DecisionTreeClassifier(criterion='entropy', random_state=477340475),
#   DecisionTreeClassifier(criterion='entropy', random_state=929568966),
#   DecisionTreeClassifier(criterion='entropy', random_state=1718969160),
#   DecisionTreeClassifier(criterion='entropy', random_state=1805333939),
#   DecisionTreeClassifier(criterion='entropy', random_state=229022801),
#   DecisionTreeClassifier(criterion='entropy', random_state=1434386383),
#   DecisionTreeClassifier(criterion='entropy', random_state=2111839938),
#   DecisionTreeClassifier(criterion='entropy', random_state=1438327252),
#   DecisionTreeClassifier(criterion='entropy', random_state=1480693303),
#   DecisionTreeClassifier(criterion='entropy', random_state=435019014),
#   DecisionTreeClassifier(criterion='entropy', random_state=1552529247),
#   DecisionTreeClassifier(criterion='entropy', random_state=1258010375),
#   DecisionTreeClassifier(criterion='entropy', random_state=865650589),
#   DecisionTreeClassifier(criterion='entropy', random_state=961047235),
#   DecisionTreeClassifier(criterion='entropy', random_state=27282018),
#   DecisionTreeClassifier(criterion='entropy', random_state=1082891148),
#   DecisionTreeClassifier(criterion='entropy', random_state=996693457),
#   DecisionTreeClassifier(criterion='entropy', random_state=119032747),
#   DecisionTreeClassifier(criterion='entropy', random_state=392767242),
#   DecisionTreeClassifier(criterion='entropy', random_state=1426830787),
#   DecisionTreeClassifier(criterion='entropy', random_state=1674530797),
#   DecisionTreeClassifier(criterion='entropy', random_state=1772973457),
#   DecisionTreeClassifier(criterion='entropy', random_state=25713066),
#   DecisionTreeClassifier(criterion='entropy', random_state=579672684),
#   DecisionTreeClassifier(criterion='entropy', random_state=1145013),
#   DecisionTreeClassifier(criterion='entropy', random_state=192976541),
#   DecisionTreeClassifier(criterion='entropy', random_state=1556133682),
#   DecisionTreeClassifier(criterion='entropy', random_state=441348664),
#   DecisionTreeClassifier(criterion='entropy', random_state=2035899862),
#   DecisionTreeClassifier(criterion='entropy', random_state=1713531854),
#   DecisionTreeClassifier(criterion='entropy', random_state=786151708),
#   DecisionTreeClassifier(criterion='entropy', random_state=418122441),
#   DecisionTreeClassifier(criterion='entropy', random_state=954394144),
#   DecisionTreeClassifier(criterion='entropy', random_state=1972497791),
#   DecisionTreeClassifier(criterion='entropy', random_state=1390694100),
#   DecisionTreeClassifier(criterion='entropy', random_state=999983724),
#   DecisionTreeClassifier(criterion='entropy', random_state=123754618),
#   DecisionTreeClassifier(criterion='entropy', random_state=810213786),
#   DecisionTreeClassifier(criterion='entropy', random_state=151477304),
#   DecisionTreeClassifier(criterion='entropy', random_state=1042172280),
#   DecisionTreeClassifier(criterion='entropy', random_state=1468952618),
#   DecisionTreeClassifier(criterion='entropy', random_state=1080526446),
#   DecisionTreeClassifier(criterion='entropy', random_state=1297009736),
#   DecisionTreeClassifier(criterion='entropy', random_state=1247674037),
#   DecisionTreeClassifier(criterion='entropy', random_state=1250649191),
#   DecisionTreeClassifier(criterion='entropy', random_state=214498347),
#   DecisionTreeClassifier(criterion='entropy', random_state=1404032955),
#   DecisionTreeClassifier(criterion='entropy', random_state=948627969),
#   DecisionTreeClassifier(criterion='entropy', random_state=86565547),
#   DecisionTreeClassifier(criterion='entropy', random_state=1333760199),
#   DecisionTreeClassifier(criterion='entropy', random_state=1394754485)],
#  'n_classes': 2,
#  'fit_time': 12648}

# %%
# Réalisation des prédictions

y_pred = clf_rf_ts.predict(X_test)

# %% [markdown]
# ## 5. Évaluation

# %%
# Élaboration de la matrice de confusion

pd.crosstab(y_test, y_pred, rownames = ["Classe réelle"], colnames = ["Classe prédite"])
# Out:
# Classe prédite    0   1
# Classe réelle
# 0               348  28
# 1                81  31

# %%
# Élaboration du rapport de classification

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.86       376
#            1       0.53      0.28      0.36       112
#
#     accuracy                           0.78       488
#    macro avg       0.67      0.60      0.61       488
# weighted avg       0.75      0.78      0.75       488
