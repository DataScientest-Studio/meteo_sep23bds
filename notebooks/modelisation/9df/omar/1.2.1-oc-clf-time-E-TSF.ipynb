# %% [markdown]
# # **Classification** des **séries temporelles** avec `sktime`

# %% [markdown]
# ## Métadonnées

# %% [markdown]
# - **Expérience nº :** 1.2.1
# - **Date :** 05/11/2023
# - **Heure :** 13:31
# - **Données :** `ready_Evaporation.csv`
# - **Tri :** par défaut
# - **Découpage :** `TimeSeriesSplit`
# - **Mise à l'échelle :** non
# - **Rééquilibrage :** non
# - **Conversion :** `numpyfy`
# - **Algorithme :** TSF

# %% [markdown]
# ## Sommaire

# %% [markdown]
# 1. Initialisation
# 2. Découpage
# 3. Conversion
# 4. Modélisation
# 5. Évaluation

# %% [markdown]
# ## 1. Initialisation

# %%
# Importation des bibliothèques et modules nécessaires au fonctionnement de ce notebook

import pandas as pd
import numpy as np

from sklearn.metrics import classification_report

# %%
# Importation du jeu de données et enregistrement dans le DataFrame `df`

df = pd.read_csv("../../../data/9df/Omar/ready_Evaporation.csv", index_col = 1)
df = df.drop(columns = "Unnamed: 0")

# %%
# Inspection de la structure de `df`

df.head()
# Out:
#               MinTemp  MaxTemp  Rainfall  Sunshine  WindGustSpeed  \
# Date
# 2009-01-01  18.800000     38.4       0.0      13.1      50.000000
# 2009-01-02  22.000000     39.1       0.0      13.2      52.000000
# 2009-01-03  15.900000     35.6       0.0      12.7      43.473477
# 2009-01-04  12.456393     37.0       0.0      13.3      43.000000
# 2009-01-05  21.800000     38.6       0.0      13.2      59.000000
#
#             WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# Date
# 2009-01-01          22.0          13.0         46.0         20.0       1010.4
# 2009-01-02           4.0          31.0         38.0         23.0       1008.3
# 2009-01-03          13.0          28.0         58.0         29.0       1012.1
# 2009-01-04          24.0          20.0         45.0         19.0       1016.6
# 2009-01-05          15.0          15.0         35.0         15.0       1014.1
#
#             ...  year  month  day  LocationNum  WindGustDirNum  WindDir9amNum  \
# Date        ...
# 2009-01-01  ...  2009      1    1           38        0.000000       5.890486
# 2009-01-02  ...  2009      1    2           38        0.000000       2.356194
# 2009-01-03  ...  2009      1    3           38        2.896869       9.424778
# 2009-01-04  ...  2009      1    4           38        5.497787       5.497787
# 2009-01-05  ...  2009      1    5           38        0.000000       5.890486
#
#             WindDir3pmNum   Latitude  Longitude  CodeRegionNum
# Date
# 2009-01-01       5.497787 -31.667778    116.015              5
# 2009-01-02       3.926991 -31.667778    116.015              5
# 2009-01-03       4.319690 -31.667778    116.015              5
# 2009-01-04       5.890486 -31.667778    116.015              5
# 2009-01-05       5.105088 -31.667778    116.015              5
#
# [5 rows x 27 columns]

# %%
# Inspection de la structure de `df`

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2646 entries, 2009-01-01 to 2017-06-25
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   MinTemp         2646 non-null   float64
#  1   MaxTemp         2646 non-null   float64
#  2   Rainfall        2646 non-null   float64
#  3   Sunshine        2646 non-null   float64
#  4   WindGustSpeed   2646 non-null   float64
#  5   WindSpeed9am    2646 non-null   float64
#  6   WindSpeed3pm    2646 non-null   float64
#  7   Humidity9am     2646 non-null   float64
#  8   Humidity3pm     2646 non-null   float64
#  9   Pressure9am     2646 non-null   float64
#  10  Pressure3pm     2646 non-null   float64
#  11  Cloud9am        2646 non-null   float64
#  12  Cloud3pm        2646 non-null   float64
#  13  Temp9am         2646 non-null   float64
#  14  Temp3pm         2646 non-null   float64
#  15  RainToday       2646 non-null   int64
#  16  RainTomorrow    2646 non-null   int64
#  17  year            2646 non-null   int64
#  18  month           2646 non-null   int64
#  19  day             2646 non-null   int64
#  20  LocationNum     2646 non-null   int64
#  21  WindGustDirNum  2646 non-null   float64
#  22  WindDir9amNum   2646 non-null   float64
#  23  WindDir3pmNum   2646 non-null   float64
#  24  Latitude        2646 non-null   float64
#  25  Longitude       2646 non-null   float64
#  26  CodeRegionNum   2646 non-null   int64
# dtypes: float64(20), int64(7)
# memory usage: 578.8+ KB

# %% [markdown]
# ## 2. Découpage

# %%
# Découpage de `df` sur l'axe des colonnes : séparation des variables explicatives (`data`) et cible (`target`)

data = df.drop(columns = "RainTomorrow")
target = df["RainTomorrow"]

# %%
# Découpage de `data` et de `target` sur l'axe des lignes : séparation des jeux d'entraînement (`*_train`) et de test (`*_test`) avec le splitter `TimeSeriesSplit`

from sklearn.model_selection import TimeSeriesSplit

tss = TimeSeriesSplit(n_splits = 5) ## Nous fixons le paramètre `n_splits` à 5 afin d'avoir une répartition de 80 / 20 entre les jeux d'entraînement et de test, respectivement.

for train_index, test_index in tss.split(data):
    X_train, X_test = data.iloc[train_index, :], data.iloc[test_index,:]
    y_train, y_test = target.iloc[train_index], target.iloc[test_index]

# %% [markdown]
# ## 3. Conversion

# %%
# Importation de la fonction artisanale `numpyfy`

from numpyfy import numpyfy

# %%
# Application de la fonction `numpyfy` aux 4 jeux de données issus du découpage effectué par le splitter `TimeSeriesSplit` afin de les convertir en arrays et ainsi les rendre compatibles avec `sktime`

X_train, X_test, y_train, y_test = numpyfy(X_train, X_test, y_train, y_test)

# %% [markdown]
# ## 4. Modélisation

# %% [markdown]
# La méthode TSF (_time series forest_) appartient à la famille des approches de classification des séries temporelles basées sur les **intervalles** (_interval-based approaches_).
#
# Il s'agit d'une adaptation aux séries temporelles de l'algorithme _random forest classifier_ (RCF).
#
# La TSF utilise un arbre de décision pour chaque intervalle, les arbres de décision agrégés constituant la forêt. Chaque arbre de décision est un modèle d'apprentissage automatique qui attribue ensuite une classe à son intervalle de données. Étant donné que les arbres de décision s'entraînent sur un intervalle différent de la série temporelle globale, ils peuvent ne pas produire la même classification, d'où la nécessité du vote d'ensemble à la fin du processus.
#
# Des études expérimentales ont démontré que la TSF est capable de produire de meilleurs résultats que la KNN + DTW.
#
# Références :
# 1. https://developer.ibm.com/learningpaths/get-started-time-series-classification-api/what-is-time-series-classification
# 2. https://towardsdatascience.com/a-brief-introduction-to-time-series-classification-algorithms-7b4284d31b97
# 3. https://arxiv.org/abs/1602.01711

# %%
# Instanciation d'un modèle classificateur via un Pipeline

from sklearn.pipeline import Pipeline
from sktime.transformations.panel.compose import ColumnConcatenator
from sktime.classification.interval_based import TimeSeriesForestClassifier

steps = [
    ("concatenate", ColumnConcatenator()), ## Cette étape permet de transformer les jeux de données multivariées en univariées afin qu'ils puissent être traités par `TimeSeriesForestClassifier`.
    ("classify", TimeSeriesForestClassifier()),
]

clf_rf_ts = Pipeline(steps)

# %%
# Récupération des paramètres initiaux de la TSF

clf_rf_ts["classify"].get_params()
# Out:
# {'min_interval': 3, 'n_estimators': 200, 'n_jobs': 1, 'random_state': None}

# %%
# Entraînement du modèle

clf_rf_ts.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('concatenate', ColumnConcatenator()),
#                 ('classify', TimeSeriesForestClassifier())])

# %%
# Récupération des paramètres ajustés de la TSF

clf_rf_ts["classify"].get_fitted_params()
# Out:
# {'classes': array([0, 1]),
#  'intervals': [array([[16, 19],
#          [ 0,  9],
#          [22, 25],
#          [14, 24],
#          [11, 14]]),
#   array([[ 7, 11],
#          [14, 19],
#          [10, 20],
#          [13, 17],
#          [22, 25]]),
#   array([[18, 24],
#          [15, 19],
#          [20, 23],
#          [14, 19],
#          [14, 21]]),
#   array([[ 5, 20],
#          [19, 23],
#          [12, 15],
#          [15, 23],
#          [ 0,  8]]),
#   array([[ 4, 19],
#          [16, 24],
#          [ 8, 13],
#          [ 6,  9],
#          [17, 20]]),
#   array([[11, 24],
#          [20, 24],
#          [13, 19],
#          [ 3, 11],
#          [11, 14]]),
#   array([[ 5,  8],
#          [ 0, 18],
#          [ 2, 24],
#          [13, 16],
#          [18, 21]]),
#   array([[ 2, 10],
#          [15, 23],
#          [ 8, 12],
#          [13, 17],
#          [20, 23]]),
#   array([[11, 20],
#          [16, 23],
#          [ 2,  6],
#          [ 2,  5],
#          [ 8, 18]]),
#   array([[ 4, 19],
#          [11, 14],
#          [22, 25],
#          [12, 20],
#          [15, 20]]),
#   array([[13, 16],
#          [22, 25],
#          [16, 22],
#          [10, 24],
#          [ 3,  6]]),
#   array([[10, 16],
#          [ 3,  6],
#          [17, 20],
#          [ 6, 19],
#          [16, 19]]),
#   array([[ 6, 18],
#          [13, 16],
#          [19, 22],
#          [18, 22],
#          [ 9, 17]]),
#   array([[14, 17],
#          [22, 25],
#          [10, 17],
#          [ 4, 13],
#          [11, 14]]),
#   array([[ 5, 24],
#          [17, 20],
#          [11, 18],
#          [21, 24],
#          [ 7, 21]]),
#   array([[ 9, 16],
#          [13, 16],
#          [ 4, 19],
#          [ 5, 16],
#          [ 9, 14]]),
#   array([[ 1,  8],
#          [17, 24],
#          [15, 22],
#          [11, 14],
#          [ 2, 12]]),
#   array([[ 4, 19],
#          [11, 14],
#          [22, 25],
#          [ 9, 17],
#          [18, 21]]),
#   array([[ 0,  8],
#          [12, 17],
#          [ 2, 22],
#          [ 7, 12],
#          [14, 24]]),
#   array([[12, 21],
#          [19, 22],
#          [ 3, 17],
#          [ 8, 11],
#          [14, 20]]),
#   array([[17, 20],
#          [ 5, 24],
#          [20, 23],
#          [ 8, 23],
#          [15, 20]]),
#   array([[ 6, 19],
#          [ 7, 17],
#          [10, 16],
#          [14, 18],
#          [13, 24]]),
#   array([[17, 23],
#          [13, 19],
#          [19, 22],
#          [ 8, 11],
#          [15, 19]]),
#   array([[ 6, 10],
#          [ 4, 21],
#          [12, 23],
#          [ 3,  6],
#          [22, 25]]),
#   array([[12, 19],
#          [ 1,  4],
#          [20, 23],
#          [21, 24],
#          [ 4,  9]]),
#   array([[13, 17],
#          [ 7, 11],
#          [19, 22],
#          [12, 21],
#          [20, 23]]),
#   array([[16, 23],
#          [16, 24],
#          [21, 24],
#          [21, 24],
#          [ 1, 10]]),
#   array([[ 1, 19],
#          [ 3,  6],
#          [ 5, 13],
#          [ 6, 15],
#          [13, 16]]),
#   array([[ 5, 15],
#          [22, 25],
#          [21, 24],
#          [ 8, 11],
#          [16, 19]]),
#   array([[ 9, 13],
#          [14, 23],
#          [ 6, 18],
#          [17, 21],
#          [ 0, 10]]),
#   array([[ 3, 13],
#          [18, 22],
#          [ 7, 20],
#          [18, 21],
#          [ 5, 10]]),
#   array([[11, 17],
#          [12, 15],
#          [ 1, 15],
#          [11, 14],
#          [ 0, 17]]),
#   array([[ 5, 16],
#          [13, 19],
#          [16, 19],
#          [14, 17],
#          [ 7, 12]]),
#   array([[22, 25],
#          [ 8, 24],
#          [22, 25],
#          [21, 24],
#          [ 9, 22]]),
#   array([[ 0, 17],
#          [ 4,  9],
#          [22, 25],
#          [ 0, 18],
#          [13, 16]]),
#   array([[ 4, 19],
#          [18, 22],
#          [ 8, 13],
#          [15, 18],
#          [19, 23]]),
#   array([[20, 23],
#          [ 7, 10],
#          [ 6, 24],
#          [22, 25],
#          [12, 15]]),
#   array([[ 7, 10],
#          [ 5, 12],
#          [12, 15],
#          [22, 25],
#          [ 7, 24]]),
#   array([[14, 17],
#          [12, 21],
#          [ 3,  8],
#          [12, 23],
#          [15, 18]]),
#   array([[11, 15],
#          [ 9, 19],
#          [ 3, 21],
#          [22, 25],
#          [13, 23]]),
#   array([[ 9, 17],
#          [16, 24],
#          [12, 20],
#          [ 1, 15],
#          [ 6,  9]]),
#   array([[ 8, 19],
#          [15, 21],
#          [11, 24],
#          [17, 20],
#          [22, 25]]),
#   array([[ 3,  6],
#          [ 7, 12],
#          [10, 20],
#          [19, 22],
#          [11, 14]]),
#   array([[ 7, 20],
#          [ 2,  5],
#          [18, 22],
#          [17, 20],
#          [ 4, 18]]),
#   array([[ 8, 17],
#          [ 7, 11],
#          [ 4,  7],
#          [ 9, 18],
#          [18, 24]]),
#   array([[17, 20],
#          [17, 21],
#          [16, 19],
#          [20, 23],
#          [13, 22]]),
#   array([[10, 21],
#          [ 5, 11],
#          [10, 20],
#          [13, 16],
#          [18, 23]]),
#   array([[17, 22],
#          [12, 24],
#          [ 3, 23],
#          [ 1, 22],
#          [12, 23]]),
#   array([[ 0, 19],
#          [21, 24],
#          [ 1, 15],
#          [ 9, 12],
#          [ 4, 10]]),
#   array([[20, 24],
#          [ 3, 11],
#          [14, 21],
#          [ 0, 13],
#          [ 0,  4]]),
#   array([[15, 18],
#          [13, 16],
#          [13, 23],
#          [ 8, 11],
#          [18, 22]]),
#   array([[11, 14],
#          [ 3, 20],
#          [13, 22],
#          [15, 18],
#          [21, 24]]),
#   array([[ 2, 16],
#          [20, 23],
#          [ 8, 18],
#          [10, 21],
#          [ 3, 23]]),
#   array([[ 9, 21],
#          [10, 23],
#          [21, 24],
#          [13, 20],
#          [15, 18]]),
#   array([[10, 19],
#          [16, 19],
#          [15, 18],
#          [ 3, 12],
#          [10, 13]]),
#   array([[ 0,  3],
#          [18, 24],
#          [ 5,  9],
#          [13, 21],
#          [14, 18]]),
#   array([[ 4, 20],
#          [ 9, 13],
#          [14, 21],
#          [13, 19],
#          [ 8, 24]]),
#   array([[ 7, 14],
#          [12, 22],
#          [ 8, 22],
#          [ 0, 16],
#          [ 4, 16]]),
#   array([[13, 19],
#          [ 8, 11],
#          [ 3,  6],
#          [ 8, 13],
#          [19, 22]]),
#   array([[17, 21],
#          [12, 18],
#          [22, 25],
#          [ 7, 15],
#          [11, 19]]),
#   array([[17, 20],
#          [ 4, 10],
#          [22, 25],
#          [ 3,  8],
#          [19, 22]]),
#   array([[ 8, 18],
#          [18, 23],
#          [11, 18],
#          [17, 21],
#          [19, 22]]),
#   array([[ 5, 12],
#          [11, 14],
#          [ 9, 12],
#          [ 8, 12],
#          [ 5, 13]]),
#   array([[18, 24],
#          [ 1,  9],
#          [14, 17],
#          [ 1, 17],
#          [ 5, 12]]),
#   array([[10, 13],
#          [16, 21],
#          [10, 13],
#          [ 7, 21],
#          [ 5, 24]]),
#   array([[ 7, 19],
#          [21, 24],
#          [10, 19],
#          [12, 22],
#          [17, 23]]),
#   array([[18, 21],
#          [ 8, 17],
#          [10, 19],
#          [22, 25],
#          [ 8, 11]]),
#   array([[13, 18],
#          [ 4, 24],
#          [ 1,  7],
#          [16, 19],
#          [12, 18]]),
#   array([[ 2, 22],
#          [ 4,  7],
#          [17, 24],
#          [ 8, 17],
#          [ 4,  8]]),
#   array([[ 5,  8],
#          [ 6, 20],
#          [20, 23],
#          [ 6, 23],
#          [ 9, 15]]),
#   array([[ 5, 13],
#          [17, 23],
#          [ 7, 14],
#          [15, 18],
#          [16, 20]]),
#   array([[ 9, 19],
#          [ 3, 18],
#          [ 5, 19],
#          [ 9, 18],
#          [10, 23]]),
#   array([[21, 24],
#          [ 6, 24],
#          [ 8, 13],
#          [21, 24],
#          [13, 16]]),
#   array([[ 7, 21],
#          [21, 24],
#          [16, 21],
#          [ 0, 18],
#          [ 3, 23]]),
#   array([[ 5,  8],
#          [ 7, 17],
#          [ 8, 23],
#          [19, 24],
#          [12, 15]]),
#   array([[ 8, 23],
#          [20, 23],
#          [ 7, 17],
#          [ 3, 12],
#          [14, 17]]),
#   array([[ 0, 19],
#          [ 8, 15],
#          [18, 21],
#          [19, 24],
#          [19, 22]]),
#   array([[ 6,  9],
#          [13, 20],
#          [ 8, 16],
#          [17, 23],
#          [10, 14]]),
#   array([[ 8, 23],
#          [ 6, 11],
#          [22, 25],
#          [15, 24],
#          [ 5, 23]]),
#   array([[18, 23],
#          [20, 23],
#          [ 0, 13],
#          [17, 22],
#          [22, 25]]),
#   array([[ 3, 15],
#          [16, 23],
#          [11, 14],
#          [ 2,  5],
#          [11, 20]]),
#   array([[18, 21],
#          [16, 24],
#          [ 8, 22],
#          [14, 24],
#          [18, 21]]),
#   array([[13, 17],
#          [19, 22],
#          [22, 25],
#          [11, 16],
#          [ 2,  7]]),
#   array([[ 2, 24],
#          [13, 16],
#          [21, 24],
#          [ 3, 19],
#          [22, 25]]),
#   array([[ 1, 11],
#          [22, 25],
#          [22, 25],
#          [16, 19],
#          [ 7, 20]]),
#   array([[11, 18],
#          [11, 16],
#          [16, 23],
#          [ 1,  9],
#          [21, 24]]),
#   array([[19, 22],
#          [12, 15],
#          [14, 17],
#          [18, 23],
#          [14, 17]]),
#   array([[ 9, 12],
#          [10, 19],
#          [20, 23],
#          [19, 23],
#          [ 6, 15]]),
#   array([[ 2,  5],
#          [ 6, 10],
#          [ 4,  9],
#          [11, 20],
#          [ 6, 21]]),
#   array([[ 8, 22],
#          [ 0, 15],
#          [22, 25],
#          [ 8, 22],
#          [ 6, 18]]),
#   array([[ 8, 14],
#          [ 2, 21],
#          [18, 24],
#          [ 5, 24],
#          [17, 20]]),
#   array([[ 0, 14],
#          [ 0,  3],
#          [ 3,  7],
#          [ 3, 20],
#          [13, 16]]),
#   array([[14, 22],
#          [ 8, 18],
#          [21, 24],
#          [10, 18],
#          [22, 25]]),
#   array([[18, 22],
#          [ 3, 20],
#          [17, 21],
#          [14, 17],
#          [22, 25]]),
#   array([[ 6,  9],
#          [18, 21],
#          [16, 21],
#          [11, 15],
#          [ 4, 19]]),
#   array([[14, 21],
#          [21, 24],
#          [11, 20],
#          [ 8, 11],
#          [13, 18]]),
#   array([[ 7, 18],
#          [ 8, 11],
#          [18, 21],
#          [11, 23],
#          [ 9, 22]]),
#   array([[ 4, 20],
#          [ 9, 19],
#          [ 1, 12],
#          [21, 24],
#          [ 6, 14]]),
#   array([[20, 23],
#          [16, 22],
#          [14, 19],
#          [ 5, 10],
#          [ 7, 20]]),
#   array([[ 0,  4],
#          [ 1, 15],
#          [ 7, 17],
#          [21, 24],
#          [19, 22]]),
#   array([[14, 20],
#          [11, 19],
#          [13, 19],
#          [ 5,  8],
#          [10, 13]]),
#   array([[ 4, 10],
#          [19, 22],
#          [15, 24],
#          [19, 22],
#          [11, 15]]),
#   array([[ 7, 20],
#          [ 3, 24],
#          [ 0,  3],
#          [17, 22],
#          [20, 23]]),
#   array([[ 5, 23],
#          [22, 25],
#          [22, 25],
#          [16, 19],
#          [15, 18]]),
#   array([[ 9, 20],
#          [18, 22],
#          [ 7, 10],
#          [ 7, 20],
#          [21, 24]]),
#   array([[22, 25],
#          [17, 20],
#          [22, 25],
#          [ 6,  9],
#          [ 1, 10]]),
#   array([[17, 24],
#          [ 6, 15],
#          [13, 16],
#          [ 1, 18],
#          [17, 23]]),
#   array([[ 7, 22],
#          [22, 25],
#          [19, 23],
#          [16, 19],
#          [11, 19]]),
#   array([[14, 23],
#          [16, 19],
#          [16, 19],
#          [11, 14],
#          [ 9, 15]]),
#   array([[ 7, 22],
#          [ 7, 12],
#          [17, 23],
#          [20, 24],
#          [19, 24]]),
#   array([[14, 22],
#          [21, 24],
#          [ 6, 21],
#          [15, 18],
#          [ 0,  6]]),
#   array([[ 7, 20],
#          [ 7, 24],
#          [21, 24],
#          [18, 21],
#          [13, 16]]),
#   array([[11, 17],
#          [ 3,  8],
#          [10, 13],
#          [11, 18],
#          [ 4, 24]]),
#   array([[ 1, 12],
#          [11, 24],
#          [ 9, 12],
#          [19, 23],
#          [ 7, 10]]),
#   array([[21, 24],
#          [ 0,  4],
#          [ 6, 24],
#          [ 3, 17],
#          [11, 15]]),
#   array([[16, 24],
#          [ 7, 15],
#          [18, 21],
#          [ 5, 15],
#          [22, 25]]),
#   array([[ 9, 13],
#          [16, 19],
#          [16, 19],
#          [15, 18],
#          [ 4,  7]]),
#   array([[18, 21],
#          [15, 23],
#          [14, 20],
#          [22, 25],
#          [13, 16]]),
#   array([[22, 25],
#          [14, 20],
#          [15, 18],
#          [18, 21],
#          [18, 23]]),
#   array([[19, 22],
#          [ 0, 10],
#          [15, 23],
#          [ 5, 14],
#          [ 7, 13]]),
#   array([[13, 24],
#          [ 7, 10],
#          [ 6, 19],
#          [13, 17],
#          [22, 25]]),
#   array([[ 0,  8],
#          [ 5, 23],
#          [ 8, 20],
#          [12, 23],
#          [20, 23]]),
#   array([[12, 15],
#          [ 2,  5],
#          [19, 23],
#          [22, 25],
#          [17, 23]]),
#   array([[22, 25],
#          [10, 16],
#          [20, 23],
#          [18, 21],
#          [ 9, 21]]),
#   array([[16, 24],
#          [10, 13],
#          [ 5, 15],
#          [ 2,  7],
#          [ 0,  6]]),
#   array([[ 0, 14],
#          [22, 25],
#          [17, 24],
#          [22, 25],
#          [16, 23]]),
#   array([[11, 14],
#          [10, 13],
#          [18, 21],
#          [20, 23],
#          [22, 25]]),
#   array([[ 9, 19],
#          [15, 18],
#          [22, 25],
#          [12, 15],
#          [ 7, 12]]),
#   array([[ 3, 20],
#          [ 5, 24],
#          [ 2, 14],
#          [ 5, 16],
#          [ 7, 20]]),
#   array([[ 5, 17],
#          [13, 17],
#          [ 7, 15],
#          [ 2, 16],
#          [12, 24]]),
#   array([[16, 19],
#          [14, 23],
#          [ 0, 17],
#          [17, 21],
#          [10, 22]]),
#   array([[21, 24],
#          [18, 23],
#          [ 8, 22],
#          [10, 21],
#          [ 4,  7]]),
#   array([[13, 16],
#          [ 7, 24],
#          [ 6, 12],
#          [15, 23],
#          [13, 22]]),
#   array([[19, 24],
#          [ 3, 12],
#          [ 3,  6],
#          [ 2, 17],
#          [ 8, 19]]),
#   array([[ 6, 11],
#          [ 0,  3],
#          [ 4, 24],
#          [15, 20],
#          [21, 24]]),
#   array([[ 1, 12],
#          [17, 21],
#          [ 2, 22],
#          [ 9, 12],
#          [15, 18]]),
#   array([[ 9, 12],
#          [ 8, 19],
#          [18, 24],
#          [ 6, 11],
#          [21, 24]]),
#   array([[20, 23],
#          [21, 24],
#          [ 1, 13],
#          [14, 19],
#          [ 6, 16]]),
#   array([[17, 21],
#          [ 4, 24],
#          [ 9, 19],
#          [ 9, 12],
#          [ 6, 24]]),
#   array([[ 2, 11],
#          [ 6,  9],
#          [ 9, 12],
#          [17, 20],
#          [12, 22]]),
#   array([[16, 19],
#          [ 8, 16],
#          [20, 23],
#          [22, 25],
#          [18, 24]]),
#   array([[ 7, 10],
#          [ 3, 22],
#          [ 3, 22],
#          [ 9, 15],
#          [10, 24]]),
#   array([[ 3, 14],
#          [ 1, 17],
#          [11, 20],
#          [ 7, 22],
#          [18, 21]]),
#   array([[ 8, 12],
#          [ 1, 20],
#          [ 3, 14],
#          [ 2, 18],
#          [18, 21]]),
#   array([[ 7, 24],
#          [22, 25],
#          [20, 23],
#          [20, 24],
#          [15, 18]]),
#   array([[ 4, 10],
#          [10, 15],
#          [ 4, 23],
#          [15, 19],
#          [ 3, 20]]),
#   array([[ 9, 17],
#          [15, 18],
#          [ 5, 21],
#          [17, 20],
#          [ 8, 16]]),
#   array([[21, 24],
#          [21, 24],
#          [ 0, 15],
#          [12, 21],
#          [12, 24]]),
#   array([[ 8, 19],
#          [ 9, 22],
#          [ 6, 21],
#          [ 9, 13],
#          [ 3, 13]]),
#   array([[10, 18],
#          [14, 17],
#          [ 8, 14],
#          [21, 24],
#          [16, 19]]),
#   array([[14, 17],
#          [18, 21],
#          [18, 21],
#          [ 9, 20],
#          [21, 24]]),
#   array([[16, 23],
#          [ 2, 22],
#          [ 0, 15],
#          [18, 24],
#          [13, 20]]),
#   array([[21, 24],
#          [21, 24],
#          [18, 22],
#          [14, 22],
#          [ 5, 13]]),
#   array([[15, 24],
#          [18, 21],
#          [13, 19],
#          [ 9, 13],
#          [19, 22]]),
#   array([[14, 22],
#          [ 8, 20],
#          [19, 22],
#          [21, 24],
#          [12, 17]]),
#   array([[ 8, 21],
#          [22, 25],
#          [14, 17],
#          [ 4, 20],
#          [ 9, 19]]),
#   array([[ 2, 24],
#          [ 7, 14],
#          [ 5, 10],
#          [15, 22],
#          [ 5,  8]]),
#   array([[ 2, 14],
#          [ 4, 16],
#          [18, 21],
#          [18, 24],
#          [11, 14]]),
#   array([[ 9, 13],
#          [16, 19],
#          [22, 25],
#          [ 6, 19],
#          [ 2, 23]]),
#   array([[21, 24],
#          [17, 20],
#          [18, 22],
#          [ 7, 24],
#          [ 6,  9]]),
#   array([[22, 25],
#          [ 3, 24],
#          [11, 16],
#          [18, 21],
#          [14, 22]]),
#   array([[14, 18],
#          [ 2, 16],
#          [11, 21],
#          [21, 24],
#          [12, 18]]),
#   array([[ 3, 16],
#          [ 9, 12],
#          [ 8, 11],
#          [ 9, 12],
#          [ 8, 11]]),
#   array([[ 0, 13],
#          [ 2, 16],
#          [ 6, 24],
#          [14, 23],
#          [15, 21]]),
#   array([[15, 19],
#          [17, 20],
#          [ 1, 20],
#          [19, 23],
#          [ 5,  8]]),
#   array([[12, 15],
#          [18, 21],
#          [12, 15],
#          [18, 21],
#          [21, 24]]),
#   array([[ 7, 17],
#          [17, 20],
#          [20, 23],
#          [ 6,  9],
#          [ 8, 11]]),
#   array([[ 0,  3],
#          [16, 19],
#          [21, 24],
#          [ 4, 11],
#          [20, 23]]),
#   array([[20, 23],
#          [17, 20],
#          [17, 20],
#          [ 9, 19],
#          [ 1,  8]]),
#   array([[20, 24],
#          [ 1, 20],
#          [22, 25],
#          [ 2, 12],
#          [11, 14]]),
#   array([[18, 21],
#          [14, 20],
#          [ 7, 22],
#          [ 9, 14],
#          [ 6, 14]]),
#   array([[13, 24],
#          [22, 25],
#          [ 7, 21],
#          [ 6, 15],
#          [22, 25]]),
#   array([[20, 24],
#          [ 9, 19],
#          [ 2, 22],
#          [22, 25],
#          [ 6,  9]]),
#   array([[ 0, 14],
#          [14, 19],
#          [19, 23],
#          [12, 19],
#          [ 4, 15]]),
#   array([[10, 14],
#          [17, 22],
#          [18, 21],
#          [20, 23],
#          [18, 21]]),
#   array([[17, 20],
#          [ 7, 15],
#          [ 6, 17],
#          [ 0, 24],
#          [13, 22]]),
#   array([[ 8, 15],
#          [20, 23],
#          [ 3, 16],
#          [15, 18],
#          [ 6, 11]]),
#   array([[16, 19],
#          [ 3, 21],
#          [14, 17],
#          [ 2,  9],
#          [14, 20]]),
#   array([[10, 16],
#          [10, 21],
#          [10, 23],
#          [20, 23],
#          [ 4, 19]]),
#   array([[15, 18],
#          [21, 24],
#          [20, 23],
#          [12, 23],
#          [ 1, 13]]),
#   array([[ 7, 19],
#          [20, 23],
#          [ 2,  9],
#          [ 2,  9],
#          [15, 18]]),
#   array([[ 1, 11],
#          [ 6, 12],
#          [10, 17],
#          [19, 22],
#          [ 5, 17]]),
#   array([[ 7, 16],
#          [21, 24],
#          [13, 16],
#          [10, 13],
#          [ 2, 11]]),
#   array([[21, 24],
#          [10, 22],
#          [21, 24],
#          [11, 24],
#          [20, 24]]),
#   array([[16, 22],
#          [12, 15],
#          [ 2, 13],
#          [15, 18],
#          [13, 16]]),
#   array([[ 3, 22],
#          [ 2, 17],
#          [19, 24],
#          [ 0,  3],
#          [22, 25]]),
#   array([[12, 22],
#          [12, 15],
#          [ 9, 21],
#          [14, 17],
#          [16, 19]]),
#   array([[ 2, 24],
#          [ 6, 22],
#          [10, 23],
#          [ 6,  9],
#          [21, 24]]),
#   array([[ 0,  3],
#          [ 7, 14],
#          [ 3, 20],
#          [ 6, 14],
#          [ 6, 17]]),
#   array([[17, 20],
#          [13, 19],
#          [ 4,  7],
#          [20, 23],
#          [ 3,  9]]),
#   array([[ 1,  9],
#          [ 4,  8],
#          [14, 22],
#          [15, 18],
#          [ 1,  7]]),
#   array([[19, 22],
#          [16, 24],
#          [14, 17],
#          [12, 21],
#          [ 8, 11]]),
#   array([[ 0, 10],
#          [13, 16],
#          [18, 21],
#          [ 2, 10],
#          [22, 25]]),
#   array([[14, 24],
#          [12, 23],
#          [20, 23],
#          [ 7, 24],
#          [ 6, 14]]),
#   array([[15, 18],
#          [21, 24],
#          [ 0, 24],
#          [13, 19],
#          [12, 23]]),
#   array([[20, 23],
#          [12, 18],
#          [ 6,  9],
#          [ 9, 12],
#          [14, 22]]),
#   array([[10, 15],
#          [17, 20],
#          [ 5, 20],
#          [14, 23],
#          [17, 21]]),
#   array([[ 2, 24],
#          [ 6, 20],
#          [16, 22],
#          [ 8, 16],
#          [ 1, 23]]),
#   array([[ 0,  6],
#          [ 1, 22],
#          [15, 18],
#          [ 9, 12],
#          [ 4, 16]]),
#   array([[18, 23],
#          [17, 20],
#          [19, 22],
#          [ 4,  7],
#          [ 3,  9]])],
#  'estimators': [DecisionTreeClassifier(criterion='entropy', random_state=1328320820),
#   DecisionTreeClassifier(criterion='entropy', random_state=1185937607),
#   DecisionTreeClassifier(criterion='entropy', random_state=257824390),
#   DecisionTreeClassifier(criterion='entropy', random_state=1288770701),
#   DecisionTreeClassifier(criterion='entropy', random_state=1205195637),
#   DecisionTreeClassifier(criterion='entropy', random_state=1329175947),
#   DecisionTreeClassifier(criterion='entropy', random_state=355407225),
#   DecisionTreeClassifier(criterion='entropy', random_state=88090831),
#   DecisionTreeClassifier(criterion='entropy', random_state=1259195046),
#   DecisionTreeClassifier(criterion='entropy', random_state=1037153972),
#   DecisionTreeClassifier(criterion='entropy', random_state=1431016106),
#   DecisionTreeClassifier(criterion='entropy', random_state=1603860440),
#   DecisionTreeClassifier(criterion='entropy', random_state=994288285),
#   DecisionTreeClassifier(criterion='entropy', random_state=2027186744),
#   DecisionTreeClassifier(criterion='entropy', random_state=138616173),
#   DecisionTreeClassifier(criterion='entropy', random_state=2072380673),
#   DecisionTreeClassifier(criterion='entropy', random_state=670653909),
#   DecisionTreeClassifier(criterion='entropy', random_state=402877571),
#   DecisionTreeClassifier(criterion='entropy', random_state=905641947),
#   DecisionTreeClassifier(criterion='entropy', random_state=2046896636),
#   DecisionTreeClassifier(criterion='entropy', random_state=1088608462),
#   DecisionTreeClassifier(criterion='entropy', random_state=1611202185),
#   DecisionTreeClassifier(criterion='entropy', random_state=1441600351),
#   DecisionTreeClassifier(criterion='entropy', random_state=2043356823),
#   DecisionTreeClassifier(criterion='entropy', random_state=1418388762),
#   DecisionTreeClassifier(criterion='entropy', random_state=1466644613),
#   DecisionTreeClassifier(criterion='entropy', random_state=1205962337),
#   DecisionTreeClassifier(criterion='entropy', random_state=1842531029),
#   DecisionTreeClassifier(criterion='entropy', random_state=333961649),
#   DecisionTreeClassifier(criterion='entropy', random_state=2026184690),
#   DecisionTreeClassifier(criterion='entropy', random_state=819318409),
#   DecisionTreeClassifier(criterion='entropy', random_state=640438598),
#   DecisionTreeClassifier(criterion='entropy', random_state=896489246),
#   DecisionTreeClassifier(criterion='entropy', random_state=855783577),
#   DecisionTreeClassifier(criterion='entropy', random_state=1536897322),
#   DecisionTreeClassifier(criterion='entropy', random_state=1583010874),
#   DecisionTreeClassifier(criterion='entropy', random_state=1261719601),
#   DecisionTreeClassifier(criterion='entropy', random_state=1492792034),
#   DecisionTreeClassifier(criterion='entropy', random_state=1724774690),
#   DecisionTreeClassifier(criterion='entropy', random_state=1315755978),
#   DecisionTreeClassifier(criterion='entropy', random_state=1144966731),
#   DecisionTreeClassifier(criterion='entropy', random_state=1251993252),
#   DecisionTreeClassifier(criterion='entropy', random_state=1404565239),
#   DecisionTreeClassifier(criterion='entropy', random_state=2108076172),
#   DecisionTreeClassifier(criterion='entropy', random_state=1707073671),
#   DecisionTreeClassifier(criterion='entropy', random_state=1361754456),
#   DecisionTreeClassifier(criterion='entropy', random_state=1591329224),
#   DecisionTreeClassifier(criterion='entropy', random_state=1719159217),
#   DecisionTreeClassifier(criterion='entropy', random_state=531917927),
#   DecisionTreeClassifier(criterion='entropy', random_state=1237139052),
#   DecisionTreeClassifier(criterion='entropy', random_state=1424724806),
#   DecisionTreeClassifier(criterion='entropy', random_state=1257017747),
#   DecisionTreeClassifier(criterion='entropy', random_state=1788796025),
#   DecisionTreeClassifier(criterion='entropy', random_state=2118322274),
#   DecisionTreeClassifier(criterion='entropy', random_state=1175289566),
#   DecisionTreeClassifier(criterion='entropy', random_state=1230516983),
#   DecisionTreeClassifier(criterion='entropy', random_state=1294023193),
#   DecisionTreeClassifier(criterion='entropy', random_state=574326647),
#   DecisionTreeClassifier(criterion='entropy', random_state=813650694),
#   DecisionTreeClassifier(criterion='entropy', random_state=1516434107),
#   DecisionTreeClassifier(criterion='entropy', random_state=61306879),
#   DecisionTreeClassifier(criterion='entropy', random_state=1688690789),
#   DecisionTreeClassifier(criterion='entropy', random_state=739985120),
#   DecisionTreeClassifier(criterion='entropy', random_state=439390492),
#   DecisionTreeClassifier(criterion='entropy', random_state=909810241),
#   DecisionTreeClassifier(criterion='entropy', random_state=1442723953),
#   DecisionTreeClassifier(criterion='entropy', random_state=265782128),
#   DecisionTreeClassifier(criterion='entropy', random_state=1694069321),
#   DecisionTreeClassifier(criterion='entropy', random_state=825627253),
#   DecisionTreeClassifier(criterion='entropy', random_state=1877803116),
#   DecisionTreeClassifier(criterion='entropy', random_state=1128325801),
#   DecisionTreeClassifier(criterion='entropy', random_state=598969901),
#   DecisionTreeClassifier(criterion='entropy', random_state=1218761875),
#   DecisionTreeClassifier(criterion='entropy', random_state=1303381157),
#   DecisionTreeClassifier(criterion='entropy', random_state=571595470),
#   DecisionTreeClassifier(criterion='entropy', random_state=228278389),
#   DecisionTreeClassifier(criterion='entropy', random_state=1079553731),
#   DecisionTreeClassifier(criterion='entropy', random_state=314975228),
#   DecisionTreeClassifier(criterion='entropy', random_state=1658246751),
#   DecisionTreeClassifier(criterion='entropy', random_state=502288921),
#   DecisionTreeClassifier(criterion='entropy', random_state=2070338642),
#   DecisionTreeClassifier(criterion='entropy', random_state=11268133),
#   DecisionTreeClassifier(criterion='entropy', random_state=2081483412),
#   DecisionTreeClassifier(criterion='entropy', random_state=1222922836),
#   DecisionTreeClassifier(criterion='entropy', random_state=1478875150),
#   DecisionTreeClassifier(criterion='entropy', random_state=1760218252),
#   DecisionTreeClassifier(criterion='entropy', random_state=1554545176),
#   DecisionTreeClassifier(criterion='entropy', random_state=711284502),
#   DecisionTreeClassifier(criterion='entropy', random_state=1050301313),
#   DecisionTreeClassifier(criterion='entropy', random_state=1341221652),
#   DecisionTreeClassifier(criterion='entropy', random_state=1742915626),
#   DecisionTreeClassifier(criterion='entropy', random_state=1015354712),
#   DecisionTreeClassifier(criterion='entropy', random_state=812695766),
#   DecisionTreeClassifier(criterion='entropy', random_state=563321578),
#   DecisionTreeClassifier(criterion='entropy', random_state=1462641298),
#   DecisionTreeClassifier(criterion='entropy', random_state=1524822544),
#   DecisionTreeClassifier(criterion='entropy', random_state=1284062126),
#   DecisionTreeClassifier(criterion='entropy', random_state=1100568057),
#   DecisionTreeClassifier(criterion='entropy', random_state=1899500558),
#   DecisionTreeClassifier(criterion='entropy', random_state=1608109625),
#   DecisionTreeClassifier(criterion='entropy', random_state=693517647),
#   DecisionTreeClassifier(criterion='entropy', random_state=518129324),
#   DecisionTreeClassifier(criterion='entropy', random_state=1607692567),
#   DecisionTreeClassifier(criterion='entropy', random_state=1165184402),
#   DecisionTreeClassifier(criterion='entropy', random_state=1550427313),
#   DecisionTreeClassifier(criterion='entropy', random_state=291897461),
#   DecisionTreeClassifier(criterion='entropy', random_state=1842277465),
#   DecisionTreeClassifier(criterion='entropy', random_state=891683177),
#   DecisionTreeClassifier(criterion='entropy', random_state=241134875),
#   DecisionTreeClassifier(criterion='entropy', random_state=609334763),
#   DecisionTreeClassifier(criterion='entropy', random_state=895572264),
#   DecisionTreeClassifier(criterion='entropy', random_state=1118152614),
#   DecisionTreeClassifier(criterion='entropy', random_state=979389584),
#   DecisionTreeClassifier(criterion='entropy', random_state=78994557),
#   DecisionTreeClassifier(criterion='entropy', random_state=1731685833),
#   DecisionTreeClassifier(criterion='entropy', random_state=856827219),
#   DecisionTreeClassifier(criterion='entropy', random_state=897770857),
#   DecisionTreeClassifier(criterion='entropy', random_state=398383459),
#   DecisionTreeClassifier(criterion='entropy', random_state=1401807120),
#   DecisionTreeClassifier(criterion='entropy', random_state=928829512),
#   DecisionTreeClassifier(criterion='entropy', random_state=1822412754),
#   DecisionTreeClassifier(criterion='entropy', random_state=290941349),
#   DecisionTreeClassifier(criterion='entropy', random_state=1463634033),
#   DecisionTreeClassifier(criterion='entropy', random_state=353875393),
#   DecisionTreeClassifier(criterion='entropy', random_state=1467554240),
#   DecisionTreeClassifier(criterion='entropy', random_state=1651210398),
#   DecisionTreeClassifier(criterion='entropy', random_state=1582879811),
#   DecisionTreeClassifier(criterion='entropy', random_state=1349652760),
#   DecisionTreeClassifier(criterion='entropy', random_state=1896237303),
#   DecisionTreeClassifier(criterion='entropy', random_state=927414602),
#   DecisionTreeClassifier(criterion='entropy', random_state=275045066),
#   DecisionTreeClassifier(criterion='entropy', random_state=1983065991),
#   DecisionTreeClassifier(criterion='entropy', random_state=807257123),
#   DecisionTreeClassifier(criterion='entropy', random_state=8911828),
#   DecisionTreeClassifier(criterion='entropy', random_state=323898730),
#   DecisionTreeClassifier(criterion='entropy', random_state=2083439827),
#   DecisionTreeClassifier(criterion='entropy', random_state=1192315236),
#   DecisionTreeClassifier(criterion='entropy', random_state=1780834856),
#   DecisionTreeClassifier(criterion='entropy', random_state=1097954973),
#   DecisionTreeClassifier(criterion='entropy', random_state=2082260694),
#   DecisionTreeClassifier(criterion='entropy', random_state=720143372),
#   DecisionTreeClassifier(criterion='entropy', random_state=162841196),
#   DecisionTreeClassifier(criterion='entropy', random_state=523071940),
#   DecisionTreeClassifier(criterion='entropy', random_state=302747800),
#   DecisionTreeClassifier(criterion='entropy', random_state=834395471),
#   DecisionTreeClassifier(criterion='entropy', random_state=579291038),
#   DecisionTreeClassifier(criterion='entropy', random_state=1764384214),
#   DecisionTreeClassifier(criterion='entropy', random_state=1439649742),
#   DecisionTreeClassifier(criterion='entropy', random_state=1300611578),
#   DecisionTreeClassifier(criterion='entropy', random_state=133197570),
#   DecisionTreeClassifier(criterion='entropy', random_state=378037228),
#   DecisionTreeClassifier(criterion='entropy', random_state=2065191237),
#   DecisionTreeClassifier(criterion='entropy', random_state=869183480),
#   DecisionTreeClassifier(criterion='entropy', random_state=1468235138),
#   DecisionTreeClassifier(criterion='entropy', random_state=2063214821),
#   DecisionTreeClassifier(criterion='entropy', random_state=1959859255),
#   DecisionTreeClassifier(criterion='entropy', random_state=700856641),
#   DecisionTreeClassifier(criterion='entropy', random_state=683586143),
#   DecisionTreeClassifier(criterion='entropy', random_state=759898975),
#   DecisionTreeClassifier(criterion='entropy', random_state=226443075),
#   DecisionTreeClassifier(criterion='entropy', random_state=259107038),
#   DecisionTreeClassifier(criterion='entropy', random_state=275928690),
#   DecisionTreeClassifier(criterion='entropy', random_state=1628542068),
#   DecisionTreeClassifier(criterion='entropy', random_state=521788784),
#   DecisionTreeClassifier(criterion='entropy', random_state=298524585),
#   DecisionTreeClassifier(criterion='entropy', random_state=1647039038),
#   DecisionTreeClassifier(criterion='entropy', random_state=1220072074),
#   DecisionTreeClassifier(criterion='entropy', random_state=503182742),
#   DecisionTreeClassifier(criterion='entropy', random_state=1095769759),
#   DecisionTreeClassifier(criterion='entropy', random_state=192962878),
#   DecisionTreeClassifier(criterion='entropy', random_state=1406994343),
#   DecisionTreeClassifier(criterion='entropy', random_state=925360784),
#   DecisionTreeClassifier(criterion='entropy', random_state=1891505341),
#   DecisionTreeClassifier(criterion='entropy', random_state=2073556830),
#   DecisionTreeClassifier(criterion='entropy', random_state=1565796307),
#   DecisionTreeClassifier(criterion='entropy', random_state=1562100613),
#   DecisionTreeClassifier(criterion='entropy', random_state=424958896),
#   DecisionTreeClassifier(criterion='entropy', random_state=1796778150),
#   DecisionTreeClassifier(criterion='entropy', random_state=259035580),
#   DecisionTreeClassifier(criterion='entropy', random_state=694985256),
#   DecisionTreeClassifier(criterion='entropy', random_state=71428163),
#   DecisionTreeClassifier(criterion='entropy', random_state=1732399416),
#   DecisionTreeClassifier(criterion='entropy', random_state=508575181),
#   DecisionTreeClassifier(criterion='entropy', random_state=182005304),
#   DecisionTreeClassifier(criterion='entropy', random_state=130554052),
#   DecisionTreeClassifier(criterion='entropy', random_state=240144927),
#   DecisionTreeClassifier(criterion='entropy', random_state=360145902),
#   DecisionTreeClassifier(criterion='entropy', random_state=104588757),
#   DecisionTreeClassifier(criterion='entropy', random_state=1557143790),
#   DecisionTreeClassifier(criterion='entropy', random_state=1746739210),
#   DecisionTreeClassifier(criterion='entropy', random_state=807193019),
#   DecisionTreeClassifier(criterion='entropy', random_state=1902201588),
#   DecisionTreeClassifier(criterion='entropy', random_state=1793462170),
#   DecisionTreeClassifier(criterion='entropy', random_state=1924674175),
#   DecisionTreeClassifier(criterion='entropy', random_state=991764957),
#   DecisionTreeClassifier(criterion='entropy', random_state=1351799726),
#   DecisionTreeClassifier(criterion='entropy', random_state=1274369068),
#   DecisionTreeClassifier(criterion='entropy', random_state=1157573920),
#   DecisionTreeClassifier(criterion='entropy', random_state=1887630988),
#   DecisionTreeClassifier(criterion='entropy', random_state=1531217139)],
#  'n_classes': 2,
#  'fit_time': 5426}

# %%
# Réalisation des prédictions

y_pred = clf_rf_ts.predict(X_test)

# %% [markdown]
# ## 5. Évaluation

# %%
# Élaboration de la matrice de confusion

pd.crosstab(y_test, y_pred, rownames = ["Classe réelle"], colnames = ["Classe prédite"])
# Out:
# Classe prédite    0   1
# Classe réelle
# 0               333  13
# 1                32  63

# %%
# Élaboration du rapport de classification

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94       346
#            1       0.83      0.66      0.74        95
#
#     accuracy                           0.90       441
#    macro avg       0.87      0.81      0.84       441
# weighted avg       0.89      0.90      0.89       441
